# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap, glove_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 6.91 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 14.1 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
model1s = [load_pickle('../data/glove_%.2d'% (number)) for number in range(1,8+1,1)]

def inner_CV_for_model1(corp, model1, method):
    print('inner_CV_for_model1')
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    '''
    p2_lr = {'class_weight':'balanced','solver': 'liblinear', 'penalty':'l2'}
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning model1
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8)
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    print('inner_CV_for_model2')
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning p2: the params for model2
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 11:16:22.734623
# inner_CV_for_model1
# {'model1': <models.features.glove_wrap object at 0x7f6854b85e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:16:23.014577
# [0.7, 0.7195121951219512, 0.7151515151515152, 0.7745664739884394, 0.7417218543046357]
# 0.7301904077133082
# -0.7301904077133082 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:16:40.487982
# [0.6909090909090909, 0.7317073170731708, 0.710843373493976, 0.7441860465116279, 0.7549668874172185]
# 0.7265225430810168
# -0.7265225430810168 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:16:58.127476
# [0.6838709677419356, 0.6867469879518073, 0.6987951807228916, 0.7294117647058823, 0.7532467532467533]
# 0.710414330873854
# -0.710414330873854 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a29ef60>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:17:17.042350
# [0.7261146496815287, 0.6951219512195121, 0.703030303030303, 0.7441860465116279, 0.7123287671232875]
# 0.7161563435132519
# -0.7161563435132519 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a1e7cf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:17:34.797535
# [0.6499999999999999, 0.6993865030674846, 0.75, 0.7542857142857142, 0.7581699346405228]
# 0.7223684303987443
# -0.7223684303987443 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a12fa90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:17:54.122630
# [0.6883116883116883, 0.7393939393939394, 0.7142857142857143, 0.7386363636363638, 0.75]
# 0.7261255411255412
# -0.7261255411255412 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f686a075828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:18:13.740537
# [0.7116564417177914, 0.7044025157232704, 0.7151515151515152, 0.7344632768361582, 0.7631578947368423]
# 0.7257663288331155
# -0.7257663288331155 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f6869fbd5c0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f695a0c0358>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:18:31.731860
# [0.674698795180723, 0.7195121951219512, 0.703030303030303, 0.7558139534883721, 0.7225806451612902]
# 0.715127178396528
# -0.715127178396528 -0.7301904077133082 1
# {'model1': <models.features.glove_wrap object at 0x7f68697c5198>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697c5470>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:18:50.720019
# [0.7185628742514969, 0.7305389221556886, 0.7305389221556886, 0.7816091954022988, 0.75]
# 0.7422499827930346
# -0.7422499827930346 -0.7422499827930346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:19:09.244861
# [0.7, 0.7195121951219512, 0.7151515151515152, 0.7745664739884394, 0.7417218543046357]
# 0.7301904077133082
# -0.7301904077133082 -0.7422499827930346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:19:28.152059
# [0.6962025316455697, 0.6832298136645963, 0.691358024691358, 0.7613636363636362, 0.6986301369863013]
# 0.7061568286702924
# -0.7061568286702924 -0.7422499827930346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:19:47.704913
# [0.6451612903225807, 0.6289308176100629, 0.6936416184971098, 0.7386363636363638, 0.6266666666666667]
# 0.6666073513465568
# -0.6666073513465568 -0.7422499827930346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:20:08.637592
# [0.6580645161290323, 0.6538461538461539, 0.7142857142857143, 0.7486033519553073, 0.6797385620915032]
# 0.6909076596615422
# -0.6909076596615422 -0.7422499827930346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:20:28.830551
# [0.7272727272727273, 0.738095238095238, 0.7484662576687118, 0.783625730994152, 0.794701986754967]
# 0.7584323881571592
# -0.7584323881571592 -0.7584323881571592
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:20:47.726078
# [0.6580645161290323, 0.6250000000000001, 0.6936416184971098, 0.7386363636363638, 0.6357615894039734]
# 0.670220817533296
# -0.670220817533296 -0.7584323881571592
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:21:09.268551
# [0.6580645161290323, 0.6242038216560509, 0.710059171597633, 0.7386363636363638, 0.6442953020134228]
# 0.6750518350065006
# -0.6750518350065006 -0.7584323881571592
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:21:29.786832
# [0.7590361445783134, 0.7272727272727273, 0.7607361963190185, 0.7882352941176471, 0.7999999999999999]
# 0.7670560724575411
# -0.7670560724575411 -0.7670560724575411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:21:48.640330
# [0.7295597484276728, 0.7116564417177914, 0.7594936708860759, 0.7738095238095237, 0.794701986754967]
# 0.7538442743192062
# -0.7538442743192062 -0.7670560724575411
# {'model1': <models.features.glove_wrap object at 0x7f68697b7630>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f68697bee48>}
# 0.7889908256880734
# outer fold
# 2019-08-21 11:22:11.967372
# inner_CV_for_model1
# {'model1': <models.features.glove_wrap object at 0x7f6854b85e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:22:12.352514
# [0.7088607594936708, 0.7926829268292682, 0.6878980891719745, 0.8098159509202455, 0.7272727272727273]
# 0.7453060907375774
# -0.7453060907375774 -0.7453060907375774 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:22:31.576675
# [0.7283950617283951, 0.7664670658682634, 0.7051282051282051, 0.8098159509202455, 0.7439024390243902]
# 0.7507417445338997
# -0.7507417445338997 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f686a30c160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:22:50.360191
# [0.7349397590361447, 0.7560975609756098, 0.6802721088435375, 0.8313253012048193, 0.7407407407407407]
# 0.7486750941601704
# -0.7486750941601704 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f686a29ef60>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:23:07.156772
# [0.7250000000000001, 0.7515151515151515, 0.6753246753246753, 0.8214285714285715, 0.7295597484276728]
# 0.7405656293392142
# -0.7405656293392142 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f686a1e7cf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:23:25.318298
# [0.7407407407407407, 0.7654320987654321, 0.6754966887417219, 0.8023952095808382, 0.7607361963190185]
# 0.7489601868295502
# -0.7489601868295502 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f686a12fa90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:23:43.498992
# [0.710843373493976, 0.7738095238095237, 0.7088607594936708, 0.8143712574850299, 0.7349397590361447]
# 0.7485649346636689
# -0.7485649346636689 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f686a075828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:24:01.162118
# [0.7250000000000001, 0.7636363636363638, 0.7225806451612903, 0.8095238095238094, 0.7185628742514969]
# 0.7478607385145921
# -0.7478607385145921 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f6869fbd5c0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68697ac550>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:24:19.176353
# [0.7283950617283951, 0.782608695652174, 0.6928104575163399, 0.8023952095808382, 0.7439024390243902]
# 0.7500223727004274
# -0.7500223727004274 -0.7507417445338997 2
# {'model1': <models.features.glove_wrap object at 0x7f6869444198>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f686943af60>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:24:37.563626
# [0.738095238095238, 0.7607361963190185, 0.6923076923076923, 0.8165680473372782, 0.7515151515151515]
# 0.7518444651148758
# -0.7518444651148758 -0.7518444651148758
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:24:56.043911
# [0.7283950617283951, 0.7664670658682634, 0.7051282051282051, 0.8098159509202455, 0.7439024390243902]
# 0.7507417445338997
# -0.7507417445338997 -0.7518444651148758
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:25:13.976111
# [0.7160493827160493, 0.7607361963190185, 0.6878980891719745, 0.7710843373493975, 0.7439024390243902]
# 0.735934088916166
# -0.735934088916166 -0.7518444651148758
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:25:32.546744
# [0.6875000000000001, 0.7831325301204819, 0.6878980891719745, 0.7160493827160493, 0.7337278106508877]
# 0.7216615625318787
# -0.7216615625318787 -0.7518444651148758
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:25:51.873950
# [0.6993865030674846, 0.7904191616766467, 0.6962025316455697, 0.7544910179640719, 0.7272727272727273]
# 0.7335543883253001
# -0.7335543883253001 -0.7518444651148758
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:26:11.369539
# [0.7560975609756098, 0.7672955974842767, 0.7114093959731543, 0.8452380952380952, 0.7654320987654321]
# 0.7690945496873136
# -0.7690945496873136 -0.7690945496873136
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:26:30.468797
# [0.6875000000000001, 0.7831325301204819, 0.6835443037974684, 0.7160493827160493, 0.7337278106508877]
# 0.7207908054569775
# -0.7207908054569775 -0.7690945496873136
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:26:50.774146
# [0.691358024691358, 0.7976190476190476, 0.6835443037974684, 0.7160493827160493, 0.7349397590361447]
# 0.7247021035720136
# -0.7247021035720136 -0.7690945496873136
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:27:09.941310
# [0.7368421052631579, 0.7721518987341771, 0.7417218543046357, 0.8433734939759034, 0.7721518987341771]
# 0.7732482502024102
# -0.7732482502024102 -0.7732482502024102
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:27:27.444819
# [0.7619047619047619, 0.7733333333333333, 0.7638888888888891, 0.8192771084337349, 0.7368421052631579]
# 0.7710492395647754
# -0.7710492395647754 -0.7732482502024102
# {'model1': <models.features.glove_wrap object at 0x7f68697beda0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f68694445c0>}
# 0.819047619047619
# outer fold
# 2019-08-21 11:27:48.711013
# inner_CV_for_model1
# {'model1': <models.features.glove_wrap object at 0x7f6854b85e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:27:49.040572
# [0.6547619047619048, 0.7402597402597403, 0.7096774193548386, 0.7745664739884394, 0.7469879518072289]
# 0.7252506980344304
# -0.7252506980344304 -0.7252506980344304 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:28:07.492191
# [0.7142857142857143, 0.7239263803680983, 0.7388535031847134, 0.7909604519774011, 0.7453416149068324]
# 0.7426735329445519
# -0.7426735329445519 -0.7426735329445519 2
# {'model1': <models.features.glove_wrap object at 0x7f686a30c160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:28:26.495531
# [0.6909090909090909, 0.7643312101910827, 0.7295597484276728, 0.7674418604651162, 0.7411764705882353]
# 0.7386836761162396
# -0.7386836761162396 -0.7426735329445519 2
# {'model1': <models.features.glove_wrap object at 0x7f686a29ef60>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:28:45.835980
# [0.710059171597633, 0.7374999999999999, 0.7421383647798742, 0.7977528089887641, 0.7469879518072289]
# 0.7468876594347
# -0.7468876594347 -0.7468876594347 4
# {'model1': <models.features.glove_wrap object at 0x7f686a1e7cf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:05.759151
# [0.7093023255813952, 0.7361963190184049, 0.7453416149068324, 0.7647058823529411, 0.7560975609756098]
# 0.7423287405670367
# -0.7423287405670367 -0.7468876594347 4
# {'model1': <models.features.glove_wrap object at 0x7f686a12fa90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:23.893244
# [0.6707317073170732, 0.7530864197530863, 0.7295597484276728, 0.7771428571428571, 0.761904761904762]
# 0.7384850989090903
# -0.7384850989090903 -0.7468876594347 4
# {'model1': <models.features.glove_wrap object at 0x7f686a075828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:42.148020
# [0.6744186046511628, 0.7612903225806451, 0.735483870967742, 0.7909604519774011, 0.7710843373493975]
# 0.7466475175052696
# -0.7466475175052696 -0.7468876594347 4
# {'model1': <models.features.glove_wrap object at 0x7f6869fbd5c0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869444400>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:59.740968
# [0.670807453416149, 0.7468354430379747, 0.7051282051282051, 0.7796610169491525, 0.7701149425287357]
# 0.7345094122120432
# -0.7345094122120432 -0.7468876594347 4
# {'model1': <models.features.glove_wrap object at 0x7f6869448c50>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68694489b0>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:30:17.943254
# [0.7209302325581395, 0.7530864197530863, 0.7320261437908497, 0.7976878612716762, 0.7305389221556886]
# 0.7468539159058881
# -0.7468539159058881 -0.7468539159058881
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:30:37.284847
# [0.710059171597633, 0.7374999999999999, 0.7421383647798742, 0.7977528089887641, 0.7469879518072289]
# 0.7468876594347
# -0.7468876594347 -0.7468876594347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:30:57.002251
# [0.7093023255813952, 0.7564102564102564, 0.7058823529411765, 0.7845303867403315, 0.7544910179640719]
# 0.7421232679274463
# -0.7421232679274463 -0.7468876594347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:31:17.130401
# [0.710059171597633, 0.7012987012987013, 0.7239263803680983, 0.7471264367816093, 0.7011494252873562]
# 0.7167120230666797
# -0.7167120230666797 -0.7468876594347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:31:40.232502
# [0.6976744186046511, 0.7307692307692308, 0.7757575757575756, 0.7888888888888889, 0.7368421052631577]
# 0.7459864438567008
# -0.7459864438567008 -0.7468876594347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:32:00.395183
# [0.7349397590361447, 0.7341772151898733, 0.7368421052631579, 0.8135593220338982, 0.738095238095238]
# 0.7515227279236625
# -0.7515227279236625 -0.7515227279236625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:32:18.565595
# [0.710059171597633, 0.7012987012987013, 0.7239263803680983, 0.7514450867052024, 0.7085714285714286]
# 0.7190601537082127
# -0.7190601537082127 -0.7515227279236625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:32:40.369483
# [0.7134502923976608, 0.6928104575163399, 0.7116564417177914, 0.7701149425287357, 0.7283236994219653]
# 0.7232711667164986
# -0.7232711667164986 -0.7515227279236625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:33:01.847382
# [0.7185628742514969, 0.7484662576687118, 0.7549668874172185, 0.7784431137724551, 0.761904761904762]
# 0.7524687790029289
# -0.7524687790029289 -0.7524687790029289
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:33:19.237328
# [0.7195121951219512, 0.7594936708860759, 0.7682119205298013, 0.7625, 0.7515923566878981]
# 0.7522620286451452
# -0.7522620286451452 -0.7524687790029289
# {'model1': <models.features.glove_wrap object at 0x7f6869b04748>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f68697beeb8>}
# 0.7807486631016043
# outer fold
# 2019-08-21 11:33:41.934064
# inner_CV_for_model1
# {'model1': <models.features.glove_wrap object at 0x7f6854b85e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:33:42.171652
# [0.7305389221556886, 0.7544910179640719, 0.7215189873417721, 0.7407407407407407, 0.7701149425287357]
# 0.7434809221462018
# -0.7434809221462018 -0.7434809221462018 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:34:00.776760
# [0.7607361963190185, 0.757396449704142, 0.7453416149068324, 0.7393939393939394, 0.7692307692307692]
# 0.7544197939109403
# -0.7544197939109403 -0.7544197939109403 2
# {'model1': <models.features.glove_wrap object at 0x7f686a30c160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:34:19.251852
# [0.7672955974842767, 0.7514450867052024, 0.7532467532467533, 0.75, 0.7882352941176471]
# 0.7620445463107759
# -0.7620445463107759 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f686a29ef60>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:34:38.501505
# [0.7798742138364779, 0.7560975609756098, 0.7307692307692308, 0.7125, 0.7469879518072289]
# 0.7452457914777095
# -0.7452457914777095 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f686a1e7cf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:34:56.643094
# [0.7625, 0.7544910179640719, 0.7515923566878981, 0.7421383647798742, 0.757396449704142]
# 0.7536236378271972
# -0.7536236378271972 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f686a12fa90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:35:15.728463
# [0.7612903225806451, 0.7398843930635839, 0.75, 0.7407407407407407, 0.7816091954022988]
# 0.7547049303574537
# -0.7547049303574537 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f686a075828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:35:35.514413
# [0.7784431137724551, 0.7607361963190185, 0.7125, 0.7439024390243902, 0.783625730994152]
# 0.7558414960220032
# -0.7558414960220032 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f6869fbd5c0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869b07080>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:35:53.972545
# [0.7530864197530863, 0.7602339181286549, 0.7204968944099378, 0.7439024390243902, 0.757396449704142]
# 0.7470232242040422
# -0.7470232242040422 -0.7620445463107759 3
# {'model1': <models.features.glove_wrap object at 0x7f6869b058d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68694264a8>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:36:12.353107
# [0.782608695652174, 0.7840909090909091, 0.758169934640523, 0.7453416149068324, 0.7682926829268293]
# 0.7677007674434535
# -0.7677007674434535 -0.7677007674434535
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:36:30.635552
# [0.7672955974842767, 0.7514450867052024, 0.7532467532467533, 0.75, 0.7882352941176471]
# 0.7620445463107759
# -0.7620445463107759 -0.7677007674434535
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:36:50.642093
# [0.7672955974842767, 0.7325581395348836, 0.7368421052631579, 0.7195121951219512, 0.7804878048780488]
# 0.7473391684564635
# -0.7473391684564635 -0.7677007674434535
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:37:09.493585
# [0.7189542483660132, 0.7218934911242604, 0.7, 0.7160493827160493, 0.7701863354037267]
# 0.7254166915220099
# -0.7254166915220099 -0.7677007674434535
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:37:29.794172
# [0.7435897435897435, 0.7305389221556886, 0.7341772151898733, 0.7272727272727273, 0.7804878048780488]
# 0.7432132826172163
# -0.7432132826172163 -0.7677007674434535
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:37:49.588920
# [0.8121212121212122, 0.7906976744186047, 0.758169934640523, 0.7530864197530863, 0.8187134502923977]
# 0.7865577382451648
# -0.7865577382451648 -0.7865577382451648
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:38:08.799414
# [0.7189542483660132, 0.7294117647058823, 0.7, 0.7160493827160493, 0.7701863354037267]
# 0.7269203462383345
# -0.7269203462383345 -0.7865577382451648
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:38:29.832876
# [0.7515923566878981, 0.7176470588235295, 0.7169811320754716, 0.7116564417177914, 0.7852760736196319]
# 0.7366306125848645
# -0.7366306125848645 -0.7865577382451648
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:38:49.791890
# [0.8292682926829269, 0.783625730994152, 0.7564102564102564, 0.7547169811320754, 0.8192771084337349]
# 0.7886596739306291
# -0.7886596739306291 -0.7886596739306291
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:39:08.383934
# [0.8363636363636364, 0.7701863354037267, 0.7692307692307692, 0.7450980392156864, 0.8148148148148148]
# 0.7871387190057267
# -0.7871387190057267 -0.7886596739306291
# {'model1': <models.features.glove_wrap object at 0x7f686979acf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6869423fd0>}
# 0.7669902912621359
# outer fold
# 2019-08-21 11:39:29.385537
# inner_CV_for_model1
# {'model1': <models.features.glove_wrap object at 0x7f6854b85e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:39:29.836767
# [0.7738095238095237, 0.7065868263473054, 0.7044025157232704, 0.738095238095238, 0.8170731707317075]
# 0.747993454941409
# -0.747993454941409 -0.747993454941409 1
# {'model1': <models.features.glove_wrap object at 0x7f686a30c1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:39:47.804284
# [0.7664670658682634, 0.7325581395348836, 0.710843373493976, 0.7349397590361447, 0.8374999999999999]
# 0.7564616675866536
# -0.7564616675866536 -0.7564616675866536 2
# {'model1': <models.features.glove_wrap object at 0x7f686a30c160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:40:06.089838
# [0.7664670658682634, 0.7228915662650603, 0.7283950617283951, 0.7151515151515152, 0.8588957055214724]
# 0.7583601829069413
# -0.7583601829069413 -0.7583601829069413 3
# {'model1': <models.features.glove_wrap object at 0x7f686a29ef60>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:40:25.843259
# [0.7682926829268293, 0.7337278106508877, 0.7133757961783439, 0.735632183908046, 0.8311688311688312]
# 0.7564394609665875
# -0.7564394609665875 -0.7583601829069413 3
# {'model1': <models.features.glove_wrap object at 0x7f686a1e7cf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:40:43.831479
# [0.7142857142857143, 0.7425149700598802, 0.75, 0.7469879518072289, 0.8536585365853657]
# 0.7614894345476378
# -0.7614894345476378 -0.7614894345476378 5
# {'model1': <models.features.glove_wrap object at 0x7f686a12fa90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:41:04.549214
# [0.7272727272727273, 0.7590361445783134, 0.7080745341614907, 0.7218934911242604, 0.8518518518518519]
# 0.7536257497977287
# -0.7536257497977287 -0.7614894345476378 5
# {'model1': <models.features.glove_wrap object at 0x7f686a075828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:41:22.646711
# [0.7664670658682634, 0.7455621301775148, 0.7204968944099378, 0.7544910179640719, 0.7950310559006211]
# 0.7564096328640819
# -0.7564096328640819 -0.7614894345476378 5
# {'model1': <models.features.glove_wrap object at 0x7f6869fbd5c0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f68698b1cf8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:41:41.689255
# [0.757396449704142, 0.7185628742514969, 0.7204968944099378, 0.738095238095238, 0.8220858895705522]
# 0.7513274692062735
# -0.7513274692062735 -0.7614894345476378 5
# {'model1': <models.features.glove_wrap object at 0x7f6869441160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f6869441eb8>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:42:00.526163
# [0.738095238095238, 0.7425149700598802, 0.7547169811320754, 0.7560975609756098, 0.8518518518518519]
# 0.768655320422931
# -0.768655320422931 -0.768655320422931
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:42:19.724931
# [0.7142857142857143, 0.7425149700598802, 0.75, 0.7469879518072289, 0.8536585365853657]
# 0.7614894345476378
# -0.7614894345476378 -0.768655320422931
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:42:38.153406
# [0.7195121951219512, 0.7160493827160493, 0.7239263803680983, 0.703030303030303, 0.8641975308641975]
# 0.7453431584201199
# -0.7453431584201199 -0.768655320422931
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:42:56.788498
# [0.6666666666666667, 0.7361963190184049, 0.7368421052631577, 0.6826347305389222, 0.7654320987654321]
# 0.7175543840505167
# -0.7175543840505167 -0.768655320422931
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:43:18.402657
# [0.6993865030674846, 0.7317073170731708, 0.7228915662650603, 0.6909090909090909, 0.830188679245283]
# 0.7350166313120179
# -0.7350166313120179 -0.768655320422931
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:43:36.262944
# [0.7790697674418605, 0.7453416149068324, 0.7435897435897435, 0.7901234567901234, 0.8679245283018868]
# 0.7852098222060894
# -0.7852098222060894 -0.7852098222060894
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:43:55.297250
# [0.6666666666666667, 0.7317073170731708, 0.7411764705882353, 0.6826347305389222, 0.7777777777777778]
# 0.7199925925289545
# -0.7199925925289545 -0.7852098222060894
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:44:15.988968
# [0.6867469879518073, 0.7239263803680983, 0.7411764705882353, 0.6785714285714286, 0.7975460122699387]
# 0.7255934559499015
# -0.7255934559499015 -0.7852098222060894
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:44:35.676634
# [0.7831325301204819, 0.7435897435897435, 0.7654320987654321, 0.7848101265822786, 0.8749999999999999]
# 0.7903928998115872
# -0.7903928998115872 -0.7903928998115872
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:44:53.025494
# [0.773006134969325, 0.7329192546583853, 0.7417218543046357, 0.7870967741935484, 0.8333333333333334]
# 0.7736154702918456
# -0.7736154702918456 -0.7903928998115872
# {'model1': <models.features.glove_wrap object at 0x7f6869442c50>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6869431f28>}
# 0.7614213197969543
# save to ../pickle/2019-08-21 11:45:15.769895.pickle
# save to ../csv/2019-08-21 11:45:17.392367.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.783   0.783          0.788       0.778         0.868    0.864
#
#   train_recall train_accuracy  \
# 0  0.873        0.865
#
#                                                   model1  \
# 0  <models.features.glove_wrap object at 0x7f68697c5198>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 11:45:15.769895.pickle
# save to ../csv/2019-08-21 11:45:17.446046.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.783   0.783          0.788       0.778         0.868    0.864
#
#   train_recall train_accuracy  \
# 0  0.873        0.865
#
#                                                   model1  \
# 0  <models.features.glove_wrap object at 0x7f68697c5198>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 11:45:15.769895.pickle
# time: 29min 8s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
model1s = [load_pickle('../data/glove_%.2d'% (number)) for number in range(1,8+1,1)]

def inner_CV_for_model1(corp, model1, method):
    p2_lgbm = {'class_weight':'balanced', 'boosting':'gbrt'}
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp} 
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8, field = 'model1')
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    from models.fmin2 import p2_lgbm
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 11:45:31.838179
# {'model1': <models.features.glove_wrap object at 0x7f6869473630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:45:32.123676
# [0.7374999999999999, 0.7305389221556886, 0.7692307692307692, 0.782608695652174, 0.7875]
# 0.7614756774077264
# -0.7614756774077264 -0.7614756774077264 1
# {'model1': <models.features.glove_wrap object at 0x7f6869473898>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:47:25.669271
# [0.6928104575163399, 0.7757575757575756, 0.7672955974842767, 0.7901234567901234, 0.818181818181818]
# 0.7688337811460266
# -0.7688337811460266 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f68694738d0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:49:09.030752
# [0.717948717948718, 0.735483870967742, 0.7974683544303799, 0.7421383647798742, 0.8301886792452831]
# 0.7646455974743993
# -0.7646455974743993 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f68699ff6d8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:50:38.268046
# [0.7361963190184049, 0.761904761904762, 0.7749999999999999, 0.7530864197530863, 0.8026315789473685]
# 0.7657638159247243
# -0.7657638159247243 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f686934b4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:52:19.242810
# [0.7151515151515152, 0.7239263803680983, 0.7453416149068324, 0.7393939393939394, 0.7894736842105262]
# 0.7426574268061823
# -0.7426574268061823 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f6869816240>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:53:56.937665
# [0.7250000000000001, 0.7530864197530863, 0.7402597402597403, 0.7710843373493975, 0.7973856209150326]
# 0.7573632236554513
# -0.7573632236554513 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f686972bf98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:55:33.406092
# [0.7125, 0.7329192546583853, 0.7468354430379747, 0.7692307692307692, 0.7848101265822786]
# 0.7492591187018816
# -0.7492591187018816 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f6869197d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d940>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:57:08.016290
# [0.7088607594936708, 0.7453416149068324, 0.7798742138364779, 0.7544910179640719, 0.7837837837837837]
# 0.7544702779969673
# -0.7544702779969673 -0.7688337811460266 2
# {'model1': <models.features.glove_wrap object at 0x7f686979d5f8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979d400>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:58:50.985341
# [0.7421383647798742, 0.7682926829268293, 0.8076923076923077, 0.782608695652174, 0.7870967741935484]
# 0.7775657650489467
# -0.7775657650489467 -0.7775657650489467
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 12:10:27.091152
# [0.7435897435897435, 0.7757575757575756, 0.810126582278481, 0.7999999999999999, 0.7870967741935484]
# 0.7833141351638696
# -0.7833141351638696 -0.7833141351638696
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:19:12.078062
# [0.7133757961783439, 0.7710843373493975, 0.7848101265822786, 0.7798742138364779, 0.7973856209150326]
# 0.769306018972306
# -0.769306018972306 -0.7833141351638696
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 12:31:34.837465
# [0.7515923566878981, 0.787878787878788, 0.7741935483870969, 0.7875, 0.8157894736842106]
# 0.7833908333275987
# -0.7833908333275987 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 12:40:12.357820
# [0.7261146496815287, 0.761904761904762, 0.7712418300653595, 0.8050314465408805, 0.8051948051948051]
# 0.7738974986774672
# -0.7738974986774672 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:51:35.655802
# [0.7133757961783439, 0.7283950617283951, 0.7792207792207793, 0.8050314465408805, 0.7837837837837837]
# 0.7619613734904365
# -0.7619613734904365 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 13:04:24.835932
# [0.7133757961783439, 0.7250000000000001, 0.7870967741935484, 0.7975460122699387, 0.8000000000000002]
# 0.7646037165283663
# -0.7646037165283663 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 13:19:48.101960
# [0.7261146496815287, 0.7636363636363638, 0.7870967741935484, 0.7777777777777778, 0.794701986754967]
# 0.7698655104088371
# -0.7698655104088371 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 13:37:51.902504
# [0.7261146496815287, 0.7530864197530863, 0.8051948051948052, 0.787878787878788, 0.7741935483870969]
# 0.769293642179061
# -0.769293642179061 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 13:51:03.356651
# [0.7088607594936708, 0.7439024390243902, 0.7924528301886792, 0.8074534161490683, 0.8079470198675496]
# 0.7721232929446715
# -0.7721232929446715 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 14:04:04.798417
# [0.7361963190184049, 0.7636363636363638, 0.8050314465408805, 0.7904191616766467, 0.8026315789473685]
# 0.7795829739639328
# -0.7795829739639328 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:12:42.264612
# [0.7329192546583853, 0.7469879518072289, 0.8, 0.8024691358024691, 0.7870967741935484]
# 0.7738946232923263
# -0.7738946232923263 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:24:34.037626
# [0.7225806451612903, 0.7636363636363638, 0.7924528301886792, 0.7904191616766467, 0.8000000000000002]
# 0.773817800132596
# -0.773817800132596 -0.7833908333275987
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:40:33.071621
# [0.7607361963190185, 0.7682926829268293, 0.8098159509202455, 0.7852760736196319, 0.8025477707006369]
# 0.7853337348972723
# -0.7853337348972723 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 14:51:04.766031
# [0.7374999999999999, 0.7484662576687118, 0.8, 0.8024691358024691, 0.8026315789473685]
# 0.7782133944837099
# -0.7782133944837099 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 15:07:24.834157
# [0.7295597484276728, 0.7710843373493975, 0.8076923076923077, 0.7974683544303799, 0.8133333333333334]
# 0.7838276162466182
# -0.7838276162466182 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 15:21:57.171519
# [0.7152317880794701, 0.7484662576687118, 0.7631578947368421, 0.7975460122699387, 0.794701986754967]
# 0.763820787901986
# -0.763820787901986 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 15:39:04.148172
# [0.7421383647798742, 0.7560975609756098, 0.8176100628930817, 0.787878787878788, 0.7770700636942675]
# 0.7761589680443242
# -0.7761589680443242 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:49:14.470112
# [0.7250000000000001, 0.75, 0.7870967741935484, 0.8170731707317075, 0.8211920529801324]
# 0.7800723995810778
# -0.7800723995810778 -0.7853337348972723
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 16:00:48.694013
# [0.7654320987654321, 0.7577639751552795, 0.7814569536423841, 0.7560975609756098, 0.8026315789473685]
# 0.7726764334972148
# -0.7726764334972148 -0.7853337348972723
# {'model1': <models.features.glove_wrap object at 0x7f686979d438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f686979d4a8>}
# 0.7904761904761904
# outer fold
# 2019-08-21 16:13:33.452066
# {'model1': <models.features.glove_wrap object at 0x7f6869473630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:13:33.962214
# [0.7450980392156864, 0.7757575757575756, 0.7516778523489933, 0.8170731707317075, 0.773006134969325]
# 0.7725225546046577
# -0.7725225546046577 -0.7725225546046577 1
# {'model1': <models.features.glove_wrap object at 0x7f6869473898>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:15:25.510523
# [0.7721518987341771, 0.773006134969325, 0.7435897435897435, 0.8313253012048193, 0.75]
# 0.774014615699613
# -0.774014615699613 -0.774014615699613 2
# {'model1': <models.features.glove_wrap object at 0x7f68694738d0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:17:22.929646
# [0.7516778523489933, 0.7594936708860759, 0.7692307692307692, 0.8047337278106509, 0.7471264367816093]
# 0.7664524914116198
# -0.7664524914116198 -0.774014615699613 2
# {'model1': <models.features.glove_wrap object at 0x7f68699ff6d8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:19:10.591074
# [0.7749999999999999, 0.7374999999999999, 0.7777777777777778, 0.8125000000000001, 0.773006134969325]
# 0.7751567825494206
# -0.7751567825494206 -0.7751567825494206 4
# {'model1': <models.features.glove_wrap object at 0x7f686934b4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:21:07.631795
# [0.7682119205298013, 0.7777777777777778, 0.7432432432432432, 0.8192771084337349, 0.7469879518072289]
# 0.7710996003583572
# -0.7710996003583572 -0.7751567825494206 4
# {'model1': <models.features.glove_wrap object at 0x7f6869816240>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:22:59.545217
# [0.7702702702702703, 0.7721518987341771, 0.7549668874172185, 0.8098159509202455, 0.7421383647798742]
# 0.7698686744243571
# -0.7698686744243571 -0.7751567825494206 4
# {'model1': <models.features.glove_wrap object at 0x7f686972bf98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:24:49.808299
# [0.7702702702702703, 0.7515923566878981, 0.7152317880794701, 0.8187134502923977, 0.703030303030303]
# 0.751767633672068
# -0.751767633672068 -0.7751567825494206 4
# {'model1': <models.features.glove_wrap object at 0x7f6869197d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437358>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:27:20.109172
# [0.7468354430379747, 0.7898089171974522, 0.75, 0.7804878048780488, 0.7283236994219653]
# 0.7590911729070882
# -0.7590911729070882 -0.7751567825494206 4
# {'model1': <models.features.glove_wrap object at 0x7f6869437588>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f6869437208>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:29:30.659960
# [0.8152866242038217, 0.7973856209150327, 0.7612903225806451, 0.8220858895705522, 0.7515923566878981]
# 0.78952816279159
# -0.78952816279159 -0.78952816279159
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:46:01.540165
# [0.7516778523489933, 0.8152866242038217, 0.7662337662337663, 0.8095238095238094, 0.7607361963190185]
# 0.7806916497258818
# -0.7806916497258818 -0.78952816279159
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:58:25.136777
# [0.8051948051948052, 0.7898089171974522, 0.7843137254901961, 0.8198757763975155, 0.7710843373493975]
# 0.7940555123258732
# -0.7940555123258732 -0.7940555123258732
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 17:16:27.513727
# [0.7515923566878981, 0.802547770700637, 0.8076923076923077, 0.8433734939759034, 0.7547169811320754]
# 0.7919845820377643
# -0.7919845820377643 -0.7940555123258732
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:31:33.558824
# [0.7950310559006211, 0.7741935483870969, 0.7792207792207793, 0.8292682926829269, 0.7777777777777778]
# 0.7910982907938402
# -0.7910982907938402 -0.7940555123258732
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:46:12.132680
# [0.802547770700637, 0.782608695652174, 0.7662337662337663, 0.8374999999999999, 0.7757575757575756]
# 0.7929295616688306
# -0.7929295616688306 -0.7940555123258732
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:04:58.837544
# [0.7435897435897435, 0.794701986754967, 0.7875, 0.8170731707317075, 0.7483870967741936]
# 0.7782503995701224
# -0.7782503995701224 -0.7940555123258732
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 18:26:17.646453
# [0.8125000000000001, 0.7843137254901961, 0.7843137254901961, 0.830188679245283, 0.7777777777777778]
# 0.7978187816006905
# -0.7978187816006905 -0.7978187816006905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 18:41:35.338099
# [0.782051282051282, 0.802547770700637, 0.7712418300653595, 0.8313253012048193, 0.7924528301886792]
# 0.7959238028421554
# -0.7959238028421554 -0.7978187816006905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:56:17.346678
# [0.7974683544303799, 0.773006134969325, 0.7741935483870969, 0.8343558282208587, 0.7625]
# 0.788304773201532
# -0.788304773201532 -0.7978187816006905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:13:52.802090
# [0.7999999999999999, 0.7922077922077922, 0.7662337662337663, 0.8220858895705522, 0.7875]
# 0.7936054896024222
# -0.7936054896024222 -0.7978187816006905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:23:39.078424
# [0.7870967741935484, 0.7770700636942676, 0.7564102564102564, 0.8313253012048193, 0.7976190476190476]
# 0.7899042886243879
# -0.7899042886243879 -0.7978187816006905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:35:02.888498
# [0.810126582278481, 0.802547770700637, 0.7712418300653595, 0.8518518518518519, 0.7643312101910827]
# 0.8000198490174825
# -0.8000198490174825 -0.8000198490174825
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:48:30.473739
# [0.8026315789473684, 0.7948717948717949, 0.7417218543046357, 0.8271604938271605, 0.7777777777777778]
# 0.7888326999457475
# -0.7888326999457475 -0.8000198490174825
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 19:57:22.699587
# [0.8, 0.782051282051282, 0.7924528301886792, 0.8518518518518519, 0.7975460122699387]
# 0.8047803952723503
# -0.8047803952723503 -0.8047803952723503
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 20:07:49.792321
# [0.8205128205128205, 0.7974683544303799, 0.7870967741935484, 0.8322981366459627, 0.773006134969325]
# 0.8020764441504072
# -0.8020764441504072 -0.8047803952723503
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:21:27.897423
# [0.782051282051282, 0.7948717948717949, 0.7843137254901961, 0.8322981366459627, 0.7672955974842767]
# 0.7921661073087025
# -0.7921661073087025 -0.8047803952723503
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 20:36:25.387557
# [0.7631578947368421, 0.7672955974842767, 0.75, 0.8343558282208587, 0.7654320987654321]
# 0.7760482838414818
# -0.7760482838414818 -0.8047803952723503
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 20:44:57.679306
# [0.8, 0.7898089171974522, 0.7848101265822786, 0.8313253012048193, 0.7749999999999999]
# 0.7961888689969101
# -0.7961888689969101 -0.8047803952723503
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 20:55:40.879198
# [0.7770700636942676, 0.7924528301886792, 0.7894736842105262, 0.8072289156626505, 0.782608695652174]
# 0.7897668378816595
# -0.7897668378816595 -0.8047803952723503
# {'model1': <models.features.glove_wrap object at 0x7f6869437048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f6869431ac8>}
# 0.8019323671497585
# outer fold
# 2019-08-21 21:10:15.825836
# {'model1': <models.features.glove_wrap object at 0x7f6869473630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:10:16.220668
# [0.7530864197530863, 0.728476821192053, 0.7225806451612903, 0.7757575757575756, 0.8]
# 0.7559802923728011
# -0.7559802923728011 -0.7559802923728011 1
# {'model1': <models.features.glove_wrap object at 0x7f6869473898>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:12:18.653133
# [0.7612903225806451, 0.7770700636942676, 0.7741935483870969, 0.7577639751552795, 0.7654320987654321]
# 0.7671500017165441
# -0.7671500017165441 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f68694738d0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:14:27.003744
# [0.7439024390243902, 0.7692307692307692, 0.7636363636363638, 0.7425149700598802, 0.7636363636363638]
# 0.7565841811175534
# -0.7565841811175534 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f68699ff6d8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:16:50.193309
# [0.7225806451612903, 0.7225806451612903, 0.7798742138364779, 0.7439024390243902, 0.7852760736196319]
# 0.7508428033606162
# -0.7508428033606162 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f686934b4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:19:07.626839
# [0.7250000000000001, 0.7532467532467533, 0.7764705882352941, 0.7749999999999999, 0.7607361963190185]
# 0.7580907075602131
# -0.7580907075602131 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f6869816240>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:21:31.940676
# [0.7261146496815287, 0.7662337662337663, 0.7402597402597403, 0.75, 0.7898089171974522]
# 0.7544834146744974
# -0.7544834146744974 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f686972bf98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:23:39.794915
# [0.7544910179640719, 0.7549668874172185, 0.7625, 0.7664670658682634, 0.7672955974842767]
# 0.761144113746766
# -0.761144113746766 -0.7671500017165441 2
# {'model1': <models.features.glove_wrap object at 0x7f6869197d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697beac8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:26:04.883141
# [0.7515923566878981, 0.7701863354037267, 0.7924528301886792, 0.8072289156626505, 0.75]
# 0.7742920875885908
# -0.7742920875885908 -0.7742920875885908 8
# {'model1': <models.features.glove_wrap object at 0x7f68697be160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697be6a0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:28:19.697329
# [0.7710843373493975, 0.7532467532467533, 0.7468354430379747, 0.7999999999999999, 0.7607361963190185]
# 0.7663805459906288
# -0.7663805459906288 -0.7663805459906288
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:46:02.671465
# [0.7721518987341771, 0.7484662576687118, 0.7625, 0.757396449704142, 0.7882352941176471]
# 0.7657499800449357
# -0.7657499800449357 -0.7663805459906288
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:00:07.275712
# [0.7749999999999999, 0.7547169811320754, 0.7612903225806451, 0.7749999999999999, 0.7710843373493975]
# 0.7674183282124235
# -0.7674183282124235 -0.7674183282124235
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 22:20:40.995164
# [0.7701863354037267, 0.7532467532467533, 0.7662337662337663, 0.7757575757575756, 0.773006134969325]
# 0.7676861131222295
# -0.7676861131222295 -0.7676861131222295
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:36:35.574838
# [0.7798742138364779, 0.7721518987341771, 0.7612903225806451, 0.7875, 0.7790697674418605]
# 0.7759772405186321
# -0.7759772405186321 -0.7759772405186321
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:52:02.175704
# [0.7898089171974522, 0.75, 0.758169934640523, 0.7901234567901234, 0.7904191616766467]
# 0.775704294060949
# -0.775704294060949 -0.7759772405186321
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:11:39.099774
# [0.7692307692307692, 0.7798742138364779, 0.7564102564102564, 0.7951807228915663, 0.7928994082840236]
# 0.7787190741306187
# -0.7787190741306187 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 23:29:57.945909
# [0.7777777777777778, 0.7547169811320754, 0.7547169811320754, 0.7831325301204819, 0.8]
# 0.7740688540324822
# -0.7740688540324822 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 23:47:55.054535
# [0.7974683544303799, 0.7654320987654321, 0.7662337662337663, 0.7777777777777778, 0.7607361963190185]
# 0.7735296387052749
# -0.7735296387052749 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:57:21.067091
# [0.8024691358024691, 0.7468354430379747, 0.7549668874172185, 0.7701863354037267, 0.7647058823529411]
# 0.767832736802866
# -0.767832736802866 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 00:07:17.474297
# [0.7594936708860759, 0.7852760736196319, 0.7875, 0.773006134969325, 0.7857142857142857]
# 0.7781980330378637
# -0.7781980330378637 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:15:33.959978
# [0.7848101265822786, 0.7388535031847134, 0.7643312101910827, 0.7831325301204819, 0.7852760736196319]
# 0.7712806887396376
# -0.7712806887396376 -0.7787190741306187
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:25:03.130109
# [0.7901234567901234, 0.7770700636942676, 0.7712418300653595, 0.7999999999999999, 0.7636363636363638]
# 0.7804143428372228
# -0.7804143428372228 -0.7804143428372228
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:38:43.371531
# [0.7625, 0.7547169811320754, 0.7577639751552795, 0.7654320987654321, 0.7636363636363638]
# 0.7608098837378301
# -0.7608098837378301 -0.7804143428372228
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 00:47:42.823407
# [0.773006134969325, 0.7388535031847134, 0.7749999999999999, 0.7852760736196319, 0.7349397590361447]
# 0.761415094161963
# -0.761415094161963 -0.7804143428372228
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 00:57:17.601609
# [0.787878787878788, 0.7643312101910827, 0.7749999999999999, 0.7757575757575756, 0.7976190476190476]
# 0.7801173242892988
# -0.7801173242892988 -0.7804143428372228
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:09:38.827169
# [0.7875, 0.7749999999999999, 0.7792207792207793, 0.8024691358024691, 0.7831325301204819]
# 0.785464489028746
# -0.785464489028746 -0.785464489028746
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 01:23:18.320143
# [0.7625, 0.7682926829268293, 0.7662337662337663, 0.7647058823529411, 0.8143712574850299]
# 0.7752207177997134
# -0.7752207177997134 -0.785464489028746
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 01:32:24.753674
# [0.7654320987654321, 0.7468354430379747, 0.7643312101910827, 0.7804878048780488, 0.7901234567901234]
# 0.7694420027325324
# -0.7694420027325324 -0.785464489028746
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:43:37.034155
# [0.7749999999999999, 0.7374999999999999, 0.7594936708860759, 0.7544910179640719, 0.7928994082840236]
# 0.7638768194268343
# -0.7638768194268343 -0.785464489028746
# {'model1': <models.features.glove_wrap object at 0x7f68697be710>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f68697be320>}
# 0.8041237113402062
# outer fold
# 2019-08-22 01:55:14.136309
# {'model1': <models.features.glove_wrap object at 0x7f6869473630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:55:14.669523
# [0.7636363636363638, 0.7721518987341771, 0.75, 0.7088607594936708, 0.7948717948717949]
# 0.7579041633472012
# -0.7579041633472012 -0.7579041633472012 1
# {'model1': <models.features.glove_wrap object at 0x7f6869473898>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:56:31.144361
# [0.787878787878788, 0.7560975609756098, 0.7792207792207793, 0.7636363636363638, 0.7749999999999999]
# 0.7723666983423081
# -0.7723666983423081 -0.7723666983423081 2
# {'model1': <models.features.glove_wrap object at 0x7f68694738d0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:57:48.532241
# [0.8333333333333334, 0.7654320987654321, 0.7672955974842767, 0.7435897435897435, 0.7951807228915663]
# 0.7809662992128704
# -0.7809662992128704 -0.7809662992128704 3
# {'model1': <models.features.glove_wrap object at 0x7f68699ff6d8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:59:44.478907
# [0.7672955974842767, 0.773006134969325, 0.8072289156626505, 0.7142857142857143, 0.8518518518518519]
# 0.7827336428507637
# -0.7827336428507637 -0.7827336428507637 4
# {'model1': <models.features.glove_wrap object at 0x7f686934b4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:01:31.180151
# [0.7904191616766467, 0.782608695652174, 0.7515923566878981, 0.7215189873417721, 0.8292682926829269]
# 0.7750814988082835
# -0.7750814988082835 -0.7827336428507637 4
# {'model1': <models.features.glove_wrap object at 0x7f6869816240>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:02:53.323112
# [0.7951807228915663, 0.7515923566878981, 0.7721518987341771, 0.7169811320754716, 0.7999999999999999]
# 0.7671812220778226
# -0.7671812220778226 -0.7827336428507637 4
# {'model1': <models.features.glove_wrap object at 0x7f686972bf98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:04:13.253935
# [0.810126582278481, 0.7901234567901234, 0.7547169811320754, 0.7, 0.7926829268292682]
# 0.7695299894059896
# -0.7695299894059896 -0.7827336428507637 4
# {'model1': <models.features.glove_wrap object at 0x7f6869197d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:05:34.649569
# [0.75, 0.7664670658682634, 0.7721518987341771, 0.7374999999999999, 0.7974683544303799]
# 0.764717463806564
# -0.764717463806564 -0.7827336428507637 4
# {'model1': <models.features.glove_wrap object at 0x7f68697b7128>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f68697b7860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:07:00.030092
# [0.7950310559006211, 0.773006134969325, 0.7682119205298013, 0.7483870967741936, 0.8292682926829269]
# 0.7827809001713735
# -0.7827809001713735 -0.7827809001713735
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:16:11.740444
# [0.802547770700637, 0.7852760736196319, 0.8181818181818182, 0.7741935483870969, 0.8242424242424242]
# 0.8008883270263217
# -0.8008883270263217 -0.8008883270263217
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:23:41.879436
# [0.7852760736196319, 0.7926829268292682, 0.7973856209150327, 0.7402597402597403, 0.8354430379746836]
# 0.7902094799196713
# -0.7902094799196713 -0.8008883270263217
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 02:35:17.958202
# [0.7852760736196319, 0.7976190476190476, 0.794701986754967, 0.7435897435897435, 0.8095238095238094]
# 0.7861421322214399
# -0.7861421322214399 -0.8008883270263217
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 02:45:14.895817
# [0.8048780487804877, 0.7672955974842767, 0.7866666666666667, 0.7417218543046357, 0.8292682926829269]
# 0.7859660919837987
# -0.7859660919837987 -0.8008883270263217
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:55:49.673622
# [0.8023952095808382, 0.7532467532467533, 0.7894736842105262, 0.7248322147651006, 0.8427672955974842]
# 0.7825430314801405
# -0.7825430314801405 -0.8008883270263217
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:09:51.858023
# [0.8048780487804877, 0.7804878048780488, 0.8157894736842104, 0.7785234899328859, 0.8343558282208587]
# 0.8028069290992983
# -0.8028069290992983 -0.8028069290992983
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 03:21:42.715977
# [0.8165680473372782, 0.7701863354037267, 0.7662337662337663, 0.7417218543046357, 0.830188679245283]
# 0.7849797365049379
# ...
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:39:58.041952
# [0.7218934911242604, 0.7784431137724551, 0.758169934640523, 0.7374999999999999, 0.8050314465408805]
# 0.7602075972156237
# -0.7602075972156237 -0.7602075972156237 2
# {'model1': <models.features.glove_wrap object at 0x7f68694738d0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:41:20.583447
# [0.7484662576687118, 0.7125, 0.7215189873417721, 0.7529411764705881, 0.8333333333333334]
# 0.7537519509628811
# -0.7537519509628811 -0.7602075972156237 2
# {'model1': <models.features.glove_wrap object at 0x7f68699ff6d8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:42:49.604574
# [0.7804878048780488, 0.7852760736196319, 0.7133757961783439, 0.7749999999999999, 0.8170731707317075]
# 0.7742425690815464
# -0.7742425690815464 -0.7742425690815464 4
# {'model1': <models.features.glove_wrap object at 0x7f686934b4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:44:18.075965
# [0.7239263803680983, 0.7831325301204819, 0.7295597484276728, 0.761904761904762, 0.7594936708860759]
# 0.7516034183414182
# -0.7516034183414182 -0.7742425690815464 4
# {'model1': <models.features.glove_wrap object at 0x7f6869816240>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:45:48.570174
# [0.7975460122699387, 0.6993865030674846, 0.7307692307692308, 0.7484662576687118, 0.7770700636942676]
# 0.7506476134939268
# -0.7506476134939268 -0.7742425690815464 4
# {'model1': <models.features.glove_wrap object at 0x7f686972bf98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:47:16.540506
# [0.773006134969325, 0.7757575757575756, 0.7875, 0.7664670658682634, 0.8026315789473684]
# 0.7810724711085065
# -0.7810724711085065 -0.7810724711085065 7
# {'model1': <models.features.glove_wrap object at 0x7f6869197d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a0b8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 05:48:46.662709
# [0.7636363636363638, 0.7337278106508877, 0.7798742138364779, 0.7875, 0.8125000000000001]
# 0.7754476776247459
# -0.7754476776247459 -0.7810724711085065 7
# {'model1': <models.features.glove_wrap object at 0x7f686979af60>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f686979a4e0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 05:50:15.674698
# [0.773006134969325, 0.7852760736196319, 0.7564102564102564, 0.8, 0.7974683544303799]
# 0.7824321638859186
# -0.7824321638859186 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 05:59:49.529398
# [0.7530864197530863, 0.7590361445783134, 0.7515923566878981, 0.75, 0.7924528301886792]
# 0.7612335502415953
# -0.7612335502415953 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 06:07:36.832445
# [0.7411764705882353, 0.7317073170731708, 0.7643312101910827, 0.7950310559006211, 0.7814569536423841]
# 0.7627406014790988
# -0.7627406014790988 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 06:19:05.769671
# [0.7607361963190185, 0.7530864197530863, 0.7320261437908497, 0.782051282051282, 0.7733333333333333]
# 0.7602466750495139
# -0.7602466750495139 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 06:27:35.011482
# [0.75, 0.7455621301775148, 0.7468354430379747, 0.8, 0.7631578947368421]
# 0.7611110935904664
# -0.7611110935904664 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 06:36:29.477321
# [0.7455621301775148, 0.7577639751552795, 0.7368421052631579, 0.7975460122699387, 0.7712418300653595]
# 0.7617912105862501
# -0.7617912105862501 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 06:47:24.377737
# [0.7515151515151515, 0.7515151515151515, 0.735483870967742, 0.7974683544303799, 0.7612903225806451]
# 0.759454570201814
# -0.759454570201814 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 06:56:41.715781
# [0.7544910179640719, 0.757396449704142, 0.7547169811320754, 0.7848101265822786, 0.7712418300653595]
# 0.7645312810895855
# -0.7645312810895855 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 07:07:49.408443
# [0.7530864197530863, 0.7515151515151515, 0.7515923566878981, 0.75, 0.7948717948717949]
# 0.7602131445655861
# -0.7602131445655861 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:15:21.677133
# [0.7544910179640719, 0.7407407407407407, 0.7643312101910827, 0.7784431137724551, 0.7870967741935484]
# 0.7650205713723798
# -0.7650205713723798 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:24:00.919595
# [0.7515151515151515, 0.7425149700598802, 0.7564102564102564, 0.7701863354037267, 0.7973856209150327]
# 0.7636024668608096
# -0.7636024668608096 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:30:54.365687
# [0.7577639751552795, 0.7484662576687118, 0.7435897435897435, 0.8205128205128205, 0.7712418300653595]
# 0.768314925398383
# -0.768314925398383 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:38:59.118363
# [0.7654320987654321, 0.7590361445783134, 0.7721518987341771, 0.8024691358024691, 0.7898089171974522]
# 0.7777796390155688
# -0.7777796390155688 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:52:38.348985
# [0.75, 0.773006134969325, 0.7483870967741936, 0.7757575757575756, 0.8082191780821918]
# 0.7710739971166574
# -0.7710739971166574 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 08:00:51.117452
# [0.7664670658682634, 0.7515151515151515, 0.7515923566878981, 0.787878787878788, 0.7741935483870969]
# 0.7663293820674395
# -0.7663293820674395 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 08:08:51.910407
# [0.773006134969325, 0.7484662576687118, 0.7594936708860759, 0.7804878048780488, 0.7922077922077922]
# 0.7707323321219908
# -0.7707323321219908 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:18:11.672340
# [0.7692307692307692, 0.7590361445783134, 0.7435897435897435, 0.7926829268292682, 0.7814569536423841]
# 0.7691993075740957
# -0.7691993075740957 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 08:29:24.272839
# [0.7654320987654321, 0.7239263803680983, 0.7625, 0.7798742138364779, 0.7922077922077922]
# 0.76478809703556
# -0.76478809703556 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 08:36:27.372214
# [0.7530864197530863, 0.7530864197530863, 0.7564102564102564, 0.7950310559006211, 0.7741935483870969]
# 0.7663615400408293
# -0.7663615400408293 -0.7824321638859186
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 08:44:46.531830
# [0.7560975609756098, 0.7341772151898733, 0.7564102564102564, 0.782608695652174, 0.8129032258064517]
# 0.7684393908068731
# -0.7684393908068731 -0.7824321638859186
# {'model1': <models.features.glove_wrap object at 0x7f686979a0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f686979ad68>}
# 0.7539267015706805
# save to ../pickle/2019-08-22 08:52:51.433391.pickle
# save to ../csv/2019-08-22 08:52:54.775005.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.783   0.793          0.775       0.781         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                   model1  \
# 0  <models.features.glove_wrap object at 0x7f686979d5f8>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   model2  \
# 0  LGBMClassifier(bagging_fraction=0.5, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 08:52:51.433391.pickle
# save to ../csv/2019-08-22 08:52:54.812613.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.783   0.793          0.775       0.781         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                   model1  \
# 0  <models.features.glove_wrap object at 0x7f686979d5f8>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   model2  \
# 0  LGBMClassifier(bagging_fraction=0.5, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 08:52:51.433391.pickle
# time: 21h 7min 37s

# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.15 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 14.6 s

# %% [markdown]
# ### 1. BoW-NB and LR

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','nb','12']]: # do not scale seems better
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 15:41:47.609935
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 15:41:47.875377
# [0.7547169811320754, 0.8024691358024691, 0.830188679245283, 0.7901234567901234, 0.7712418300653595]
# 0.7897480166070621
# -0.7897480166070621 -0.7897480166070621
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 15:42:00.812333
# [0.7515923566878981, 0.7901234567901234, 0.8220858895705522, 0.7757575757575756, 0.7564102564102564]
# 0.7791939070432811
# -0.7791939070432811 -0.7897480166070621
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 15:42:13.061992
# [0.7468354430379747, 0.75, 0.8242424242424242, 0.7682926829268293, 0.7564102564102564]
# 0.7691561613234968
# -0.7691561613234968 -0.7897480166070621
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 15:42:26.104703
# [0.7341772151898733, 0.7560975609756098, 0.8170731707317075, 0.7719298245614035, 0.7450980392156863]
# 0.7648751621348561
# -0.7648751621348561 -0.7897480166070621
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 15:42:38.374279
# [0.7515923566878981, 0.7625, 0.8170731707317075, 0.7710843373493975, 0.75]
# 0.7704499729538006
# -0.7704499729538006 -0.7897480166070621
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 15:42:50.519035
# [0.773006134969325, 0.8, 0.8292682926829269, 0.8023952095808382, 0.7837837837837837]
# 0.7976906842033747
# -0.7976906842033747 -0.7976906842033747
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 15:43:03.876390
# [0.7421383647798742, 0.7560975609756098, 0.8098159509202455, 0.7719298245614035, 0.7435897435897436]
# 0.7647142889653754
# -0.7647142889653754 -0.7976906842033747
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 15:43:15.813940
# [0.7295597484276728, 0.7607361963190185, 0.8242424242424242, 0.761904761904762, 0.75]
# 0.7652886261787755
# -0.7652886261787755 -0.7976906842033747
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 15:43:28.284069
# [0.7798742138364779, 0.7950310559006211, 0.8363636363636364, 0.8227848101265822, 0.7894736842105262]
# 0.8047054800875688
# -0.8047054800875688 -0.8047054800875688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 15:43:40.455131
# [0.7901234567901234, 0.7682926829268293, 0.8198757763975155, 0.7558139534883721, 0.7702702702702703]
# 0.780875227974622
# -0.780875227974622 -0.8047054800875688
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', '12'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6daeab8198>}
# 0.8446601941747574
# outer fold
# 2019-08-20 15:43:56.034464
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 15:43:56.354022
# [0.8129032258064517, 0.8157894736842104, 0.7870967741935484, 0.8571428571428572, 0.7662337662337663]
# 0.8078332194121668
# -0.8078332194121668 -0.8078332194121668
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 15:44:08.639028
# [0.7974683544303799, 0.8205128205128205, 0.7870967741935484, 0.8466257668711655, 0.782608695652174]
# 0.8068624823320176
# -0.8068624823320176 -0.8078332194121668
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 15:44:20.557467
# [0.782051282051282, 0.8079470198675497, 0.7898089171974522, 0.8271604938271605, 0.7643312101910827]
# 0.7942597846269054
# -0.7942597846269054 -0.8078332194121668
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 15:44:32.789066
# [0.7721518987341771, 0.782051282051282, 0.7532467532467533, 0.8170731707317075, 0.7341772151898733]
# 0.7717400639907587
# -0.7717400639907587 -0.8078332194121668
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 15:44:44.894255
# [0.7770700636942676, 0.7898089171974522, 0.7898089171974522, 0.8220858895705522, 0.7483870967741936]
# 0.7854321768867836
# -0.7854321768867836 -0.8078332194121668
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 15:44:57.276465
# [0.8266666666666668, 0.8157894736842104, 0.8076923076923077, 0.8679245283018868, 0.7974683544303799]
# 0.8231082661550904
# -0.8231082661550904 -0.8231082661550904
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 15:45:09.925409
# [0.7770700636942676, 0.7898089171974522, 0.7532467532467533, 0.8242424242424242, 0.7515923566878981]
# 0.7791921030137591
# -0.7791921030137591 -0.8231082661550904
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 15:45:22.665281
# [0.7770700636942676, 0.782051282051282, 0.7692307692307692, 0.8292682926829269, 0.7435897435897435]
# 0.7802420302497979
# -0.7802420302497979 -0.8231082661550904
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 15:45:34.793737
# [0.8187919463087249, 0.8157894736842104, 0.8026315789473684, 0.8831168831168831, 0.782051282051282]
# 0.8204762328216937
# -0.8204762328216937 -0.8231082661550904
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 15:45:47.244221
# [0.8157894736842104, 0.7999999999999999, 0.7619047619047619, 0.8701298701298701, 0.7792207792207793]
# 0.8054089769879242
# -0.8054089769879242 -0.8231082661550904
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', '12'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6daf4d8f28>}
# 0.7899999999999999
# outer fold
# 2019-08-20 15:46:02.739417
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 15:46:03.051054
# [0.7612903225806451, 0.8157894736842104, 0.8121212121212122, 0.7607361963190185, 0.7875]
# 0.7874874409410173
# -0.7874874409410173 -0.7874874409410173
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 15:46:16.037423
# [0.8024691358024691, 0.8152866242038217, 0.8072289156626505, 0.7590361445783134, 0.7777777777777778]
# 0.7923597196050065
# -0.7923597196050065 -0.7923597196050065
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 15:46:29.228887
# [0.7875, 0.7974683544303799, 0.7926829268292682, 0.7692307692307692, 0.7577639751552795]
# 0.7809292051291393
# -0.7809292051291393 -0.7923597196050065
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 15:46:41.475241
# [0.7721518987341771, 0.7870967741935484, 0.7701863354037267, 0.7558139534883721, 0.7577639751552795]
# 0.7686025873950207
# -0.7686025873950207 -0.7923597196050065
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 15:46:54.078262
# [0.7721518987341771, 0.7870967741935484, 0.7852760736196319, 0.7647058823529411, 0.7607361963190185]
# 0.7739933650438634
# -0.7739933650438634 -0.7923597196050065
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 15:47:07.013850
# [0.7950310559006211, 0.8157894736842104, 0.8024691358024691, 0.782608695652174, 0.7894736842105262]
# 0.7970744090500002
# -0.7970744090500002 -0.7970744090500002
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 15:47:19.005380
# [0.7770700636942676, 0.802547770700637, 0.7852760736196319, 0.7602339181286549, 0.75]
# 0.7750255652286382
# -0.7750255652286382 -0.7970744090500002
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 15:47:32.453487
# [0.7770700636942676, 0.7948717948717949, 0.7926829268292682, 0.7558139534883721, 0.7577639751552795]
# 0.7756405428077964
# -0.7756405428077964 -0.7970744090500002
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 15:47:45.004704
# [0.7926829268292682, 0.8129032258064517, 0.8074534161490683, 0.75, 0.7924528301886792]
# 0.7910984797946934
# -0.7910984797946934 -0.7970744090500002
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 15:47:57.308767
# [0.7602339181286549, 0.8104575163398693, 0.782051282051282, 0.7516778523489933, 0.8074534161490683]
# 0.7823747970035735
# -0.7823747970035735 -0.7970744090500002
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', '12'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6daea98908>}
# 0.8432432432432432
# outer fold
# 2019-08-20 15:48:12.449951
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 15:48:12.766802
# [0.7808219178082192, 0.7721518987341771, 0.810126582278481, 0.7382550335570469, 0.8104575163398693]
# 0.7823625897435587
# -0.7823625897435587 -0.7823625897435587
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 15:48:25.338713
# [0.7712418300653595, 0.75, 0.7950310559006211, 0.7105263157894737, 0.8427672955974842]
# 0.7739132994705875
# -0.7739132994705875 -0.7823625897435587
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 15:48:37.478481
# [0.7672955974842767, 0.7662337662337663, 0.7852760736196319, 0.7236842105263157, 0.830188679245283]
# 0.7745356654218547
# -0.7745356654218547 -0.7823625897435587
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 15:48:50.004957
# [0.7341772151898733, 0.7450980392156864, 0.773006134969325, 0.6710526315789473, 0.7848101265822786]
# 0.7416288295072222
# -0.7416288295072222 -0.7823625897435587
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 15:49:02.066605
# [0.7594936708860759, 0.7643312101910827, 0.7804878048780488, 0.7105263157894737, 0.8152866242038217]
# 0.7660251251897006
# -0.7660251251897006 -0.7823625897435587
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 15:49:14.272025
# [0.8148148148148148, 0.7948717948717949, 0.8205128205128205, 0.7843137254901961, 0.8354430379746836]
# 0.8099912387328618
# -0.8099912387328618 -0.8099912387328618
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 15:49:26.501977
# [0.7435897435897435, 0.7483870967741936, 0.7777777777777778, 0.6797385620915033, 0.7922077922077922]
# 0.748340194488202
# -0.748340194488202 -0.8099912387328618
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 15:49:38.402061
# [0.7435897435897435, 0.7320261437908497, 0.773006134969325, 0.6928104575163399, 0.8051948051948052]
# 0.7493254570122128
# -0.7493254570122128 -0.8099912387328618
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 15:49:50.759175
# [0.8198757763975155, 0.7870967741935484, 0.8311688311688312, 0.7692307692307693, 0.8407643312101911]
# 0.8096272964401712
# -0.8096272964401712 -0.8099912387328618
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 15:50:02.560998
# [0.8227848101265822, 0.7784431137724551, 0.8148148148148148, 0.7625, 0.8395061728395061]
# 0.8036097823106717
# -0.8036097823106717 -0.8099912387328618
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', '12'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6daec73828>}
# 0.7980295566502462
# outer fold
# 2019-08-20 15:50:17.765660
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 15:50:18.092618
# [0.7749999999999999, 0.8125000000000001, 0.7636363636363638, 0.7749999999999999, 0.8]
# 0.7852272727272727
# -0.7852272727272727 -0.7852272727272727
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 15:50:30.596638
# [0.7926829268292682, 0.8074534161490683, 0.7710843373493975, 0.7973856209150327, 0.7870967741935484]
# 0.791140615087263
# -0.791140615087263 -0.791140615087263
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 15:50:42.430580
# [0.7852760736196319, 0.8074534161490683, 0.7664670658682634, 0.7712418300653595, 0.782051282051282]
# 0.782497933550721
# -0.782497933550721 -0.791140615087263
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 15:50:55.844599
# [0.7453416149068324, 0.7926829268292682, 0.7530864197530863, 0.7307692307692308, 0.7843137254901961]
# 0.7612387835497227
# -0.7612387835497227 -0.791140615087263
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 15:51:08.465914
# [0.7701863354037267, 0.8, 0.7607361963190185, 0.7564102564102564, 0.7792207792207793]
# 0.7733107134707561
# -0.7733107134707561 -0.791140615087263
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 15:51:21.616309
# [0.7950310559006211, 0.8074534161490683, 0.7757575757575756, 0.8220858895705522, 0.8227848101265822]
# 0.8046225495008799
# -0.8046225495008799 -0.8046225495008799
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 15:51:33.380235
# [0.7682926829268293, 0.7901234567901234, 0.7484662576687118, 0.75, 0.7763157894736843]
# 0.7666396373718698
# -0.7666396373718698 -0.8046225495008799
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 15:51:45.710971
# [0.7682926829268293, 0.7950310559006211, 0.7607361963190185, 0.7468354430379747, 0.7712418300653595]
# 0.7684274416499606
# -0.7684274416499606 -0.8046225495008799
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 15:51:58.432638
# [0.8148148148148148, 0.8104575163398693, 0.773006134969325, 0.8313253012048193, 0.8280254777070064]
# 0.811525849007167
# -0.811525849007167 -0.811525849007167
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 15:52:11.129171
# [0.825, 0.7848101265822786, 0.7852760736196319, 0.8374999999999999, 0.7749999999999999]
# 0.801517240040382
# -0.801517240040382 -0.811525849007167
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', '12'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6daf264160>}
# 0.8105263157894738
# make dir
# save to ../pickle/2019-08-20 15:52:26.137797.pickle
# make dir
# save to ../csv/2019-08-20 15:52:26.162899.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.817   0.844          0.794       0.818         0.938    0.948
#
#   train_recall train_accuracy model1  \
# 0  0.929        0.938          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#          method  tag                                  pickle_path
# 0  [wc, nb, 12]  AMT  ../pickle/2019-08-20 15:52:26.137797.pickle
# save to ../csv/2019-08-20 15:52:26.255971.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.817   0.844          0.794       0.818         0.938    0.948
#
#   train_recall train_accuracy model1  \
# 0  0.929        0.938          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#          method  tag                                  pickle_path
# 0  [wc, nb, 12]  AMT  ../pickle/2019-08-20 15:52:26.137797.pickle
# time: 10min 50s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lgbm
    
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','nb']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 15:52:38.573724
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 15:52:38.880770
# [0.6962025316455697, 0.7374999999999999, 0.7261146496815287, 0.7719298245614035, 0.7058823529411764]
# 0.7275258717659356
# -0.7275258717659356 -0.7275258717659356
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 16:01:23.560798
# [0.675, 0.7307692307692308, 0.7169811320754716, 0.7485380116959064, 0.7250000000000001]
# 0.7192576749081219
# -0.7192576749081219 -0.7275258717659356
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 16:07:09.226754
# [0.7239263803680983, 0.7125, 0.7421383647798742, 0.7810650887573963, 0.75]
# 0.7419259667810738
# -0.7419259667810738 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 16:18:32.521957
# [0.7088607594936708, 0.7169811320754716, 0.7142857142857143, 0.7692307692307692, 0.7096774193548386]
# 0.7238071588880929
# -0.7238071588880929 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 16:26:28.959094
# [0.6878980891719745, 0.7105263157894737, 0.7453416149068324, 0.7586206896551724, 0.7295597484276729]
# 0.7263892915902253
# -0.7263892915902253 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 16:32:24.239551
# [0.6967741935483871, 0.7239263803680983, 0.7012987012987013, 0.7745664739884394, 0.7450980392156863]
# 0.7283327576838625
# -0.7283327576838625 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 16:43:02.934454
# [0.7037037037037037, 0.7189542483660132, 0.7133757961783439, 0.7752808988764046, 0.7307692307692308]
# 0.7284167755787392
# -0.7284167755787392 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 16:51:03.858131
# [0.6923076923076923, 0.7295597484276728, 0.7307692307692308, 0.7500000000000001, 0.7320261437908496]
# 0.7269325630590892
# -0.7269325630590892 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-20 18:02:03.269645
# [0.6962025316455697, 0.7341772151898733, 0.7169811320754716, 0.7719298245614035, 0.717948717948718]
# 0.7274478842842071
# -0.7274478842842071 -0.7419259667810738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 19:23:37.000976
# [0.7204968944099378, 0.7564102564102564, 0.7388535031847134, 0.761904761904762, 0.7515923566878983]
# 0.7458515545195136
# -0.7458515545195136 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 20:43:36.612905
# [0.6296296296296297, 0.7006369426751592, 0.7012987012987013, 0.7586206896551724, 0.7133757961783439]
# 0.7007123518874012
# -0.7007123518874012 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 21:45:48.840879
# [0.6962025316455697, 0.7044025157232704, 0.7225806451612903, 0.7701149425287357, 0.7215189873417722]
# 0.7229639244801277
# -0.7229639244801277 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 21:53:36.439361
# [0.7250000000000001, 0.7483870967741936, 0.7272727272727273, 0.7784431137724551, 0.7368421052631577]
# 0.7431890086165069
# -0.7431890086165069 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 22:07:36.512765
# [0.6748466257668712, 0.6754966887417219, 0.7116564417177914, 0.7167630057803468, 0.717948717948718]
# 0.6993422959910898
# -0.6993422959910898 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-20 22:16:19.790635
# [0.6883116883116883, 0.7329192546583853, 0.7272727272727273, 0.761904761904762, 0.7142857142857143]
# 0.7249388292866554
# -0.7249388292866554 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 22:23:49.783328
# [0.7250000000000001, 0.7435897435897435, 0.7388535031847134, 0.7692307692307692, 0.7236842105263157]
# 0.7400716453063085
# -0.7400716453063085 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 22:36:06.832680
# [0.7044025157232704, 0.7283950617283951, 0.7295597484276728, 0.7529411764705881, 0.72]
# 0.7270597004699854
# -0.7270597004699854 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-20 22:47:32.104579
# [0.6835443037974684, 0.7142857142857143, 0.6754966887417219, 0.7727272727272727, 0.7125]
# 0.7117107959104355
# -0.7117107959104355 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 22:55:35.005111
# [0.7, 0.7169811320754716, 0.7329192546583853, 0.7816091954022988, 0.7225806451612902]
# 0.7308180454594891
# -0.7308180454594891 -0.7458515545195136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 23:03:01.750086
# [0.6499999999999999, 0.7073170731707318, 0.7133757961783439, 0.7167630057803468, 0.7215189873417722]
# 0.7017949724942388
# -0.7017949724942388 -0.7458515545195136
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'nb'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f6daf4f36d8>}
# 0.7981220657276996
# outer fold
# 2019-08-20 23:11:38.916276
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 23:11:39.363850
# [0.6790123456790124, 0.7485380116959064, 0.6351351351351352, 0.7701863354037267, 0.7185628742514969]
# 0.7102869404330555
# -0.7102869404330555 -0.7102869404330555
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 23:22:35.497479
# [0.654320987654321, 0.738095238095238, 0.6493506493506493, 0.7544910179640719, 0.6951219512195121]
# 0.6982759688567585
# -0.6982759688567585 -0.7102869404330555
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 23:35:03.833264
# [0.6792452830188679, 0.7544910179640719, 0.6802721088435375, 0.7564102564102564, 0.7329192546583853]
# 0.7206675841790238
# -0.7206675841790238 -0.7206675841790238
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 01:19:27.916297
# [0.6708860759493671, 0.7317073170731708, 0.6399999999999999, 0.7625, 0.7160493827160493]
# 0.7042285551477175
# -0.7042285551477175 -0.7206675841790238
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 03:22:04.515611
# [0.6928104575163399, 0.75, 0.6540880503144653, 0.7483870967741936, 0.7195121951219512]
# 0.71295955994539
# -0.71295955994539 -0.7206675841790238
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 04:43:48.372869
# [0.6875000000000001, 0.7558139534883721, 0.6624203821656051, 0.7564102564102564, 0.7317073170731708]
# 0.7187703818274809
# -0.7187703818274809 -0.7206675841790238
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 06:47:28.479807
# [0.6835443037974684, 0.7393939393939394, 0.6578947368421051, 0.7607361963190185, 0.7283950617283951]
# 0.7139928476161853
# -0.7139928476161853 -0.7206675841790238
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 08:41:39.709518
# [0.7037037037037037, 0.7515151515151515, 0.6666666666666666, 0.7594936708860759, 0.7250000000000001]
# 0.7212758385543195
# -0.7212758385543195 -0.7212758385543195
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 09:52:43.863683
# [0.6832298136645963, 0.7228915662650603, 0.6447368421052632, 0.7547169811320754, 0.7239263803680983]
# 0.7059003167070188
# -0.7059003167070188 -0.7212758385543195
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 09:56:40.764296
# [0.6540880503144653, 0.7317073170731708, 0.6577181208053691, 0.7721518987341771, 0.7151515151515152]
# 0.7061633804157395
# -0.7061633804157395 -0.7212758385543195
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 10:01:01.975566
# [0.7, 0.7630057803468208, 0.6399999999999999, 0.7682926829268293, 0.6496815286624203]
# 0.704195998387214
# -0.704195998387214 -0.7212758385543195
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 10:05:42.103310
# [0.6878980891719745, 0.7393939393939394, 0.6666666666666667, 0.7654320987654321, 0.7116564417177914]
# 0.7142094471431608
# -0.7142094471431608 -0.7212758385543195
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 10:09:39.387262
# [0.6875000000000001, 0.7710843373493975, 0.6802721088435375, 0.7749999999999999, 0.7439024390243902]
# 0.7315517770434651
# -0.7315517770434651 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 10:17:24.227677
# [0.6535947712418301, 0.7411764705882353, 0.631578947368421, 0.7607361963190185, 0.675]
# 0.6924172771035009
# -0.6924172771035009 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 10:21:58.371894
# [0.675, 0.7317073170731708, 0.68, 0.7749999999999999, 0.7393939393939394]
# 0.720220251293422
# -0.720220251293422 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 10:26:09.275142
# [0.6708860759493671, 0.7544910179640719, 0.6530612244897959, 0.7435897435897435, 0.7272727272727273]
# 0.7098601578531412
# -0.7098601578531412 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 10:32:37.274003
# [0.6878980891719745, 0.7439024390243902, 0.6712328767123288, 0.7388535031847134, 0.7341772151898733]
# 0.7152128246566561
# -0.7152128246566561 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 10:41:19.550719
# [0.6625766871165645, 0.7374999999999999, 0.6486486486486487, 0.7682926829268293, 0.6967741935483871]
# 0.7027584424480859
# -0.7027584424480859 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 10:46:38.910217
# [0.6871165644171778, 0.7368421052631577, 0.6666666666666666, 0.735483870967742, 0.7261904761904762]
# 0.710459936701044
# -0.710459936701044 -0.7315517770434651
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 10:51:06.116772
# [0.6709677419354838, 0.7228915662650603, 0.6399999999999999, 0.7749999999999999, 0.6451612903225807]
# 0.6908041197046249
# -0.6908041197046249 -0.7315517770434651
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'nb'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f6daebbe588>}
# 0.7860696517412936
# outer fold
# 2019-08-21 11:11:00.718246
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:11:01.171370
# [0.6583850931677019, 0.7096774193548386, 0.6923076923076923, 0.7, 0.7250000000000001]
# 0.6970740409660465
# -0.6970740409660465 -0.6970740409660465
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:22:42.215459
# [0.638036809815951, 0.7215189873417721, 0.6666666666666666, 0.7065868263473054, 0.7421383647798742]
# 0.6949895309903138
# -0.6949895309903138 -0.6970740409660465
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 11:32:04.661830
# [0.6887417218543046, 0.7152317880794701, 0.6878980891719745, 0.7361963190184049, 0.7215189873417721]
# 0.7099173810931853
# -0.7099173810931853 -0.7099173810931853
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 11:48:14.984085
# [0.6835443037974684, 0.7169811320754716, 0.6792452830188679, 0.7204968944099378, 0.7295597484276728]
# 0.7059654723458837
# -0.7059654723458837 -0.7099173810931853
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 12:00:51.289737
# [0.6832298136645963, 0.7329192546583853, 0.7169811320754716, 0.7195121951219512, 0.7239263803680983]
# 0.7153137551777006
# -0.7153137551777006 -0.7153137551777006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:09:30.634055
# [0.6792452830188679, 0.7261146496815287, 0.6923076923076923, 0.7393939393939394, 0.7204968944099378]
# 0.7115116917623933
# -0.7115116917623933 -0.7153137551777006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:23:17.637520
# [0.6790123456790124, 0.7105263157894737, 0.6751592356687897, 0.7329192546583853, 0.7329192546583853]
# 0.7061072812908094
# -0.7061072812908094 -0.7153137551777006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 12:35:55.304578
# [0.6538461538461539, 0.6967741935483871, 0.6923076923076923, 0.7250000000000001, 0.7283950617283951]
# 0.6992646202861257
# -0.6992646202861257 -0.7153137551777006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 12:49:59.975499
# [0.6625, 0.717948717948718, 0.6918238993710691, 0.710843373493976, 0.7453416149068324]
# 0.705691521144119
# -0.705691521144119 -0.7153137551777006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:58:55.289754
# [0.7215189873417721, 0.7421383647798742, 0.7037037037037037, 0.7388535031847134, 0.7261146496815287]
# 0.7264658417383185
# -0.7264658417383185 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 13:08:46.418571
# [0.6265060240963856, 0.7142857142857143, 0.6754966887417219, 0.6982248520710058, 0.7425149700598802]
# 0.6914056498509416
# -0.6914056498509416 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 13:20:22.054083
# [0.654320987654321, 0.7341772151898733, 0.6923076923076923, 0.7239263803680983, 0.7453416149068324]
# 0.7100147780853635
# -0.7100147780853635 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 13:30:12.919480
# [0.6753246753246753, 0.7261146496815287, 0.7189542483660132, 0.7250000000000001, 0.7374999999999999]
# 0.7165787146744435
# -0.7165787146744435 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 13:52:17.511626
# [0.6375, 0.7096774193548386, 0.641025641025641, 0.6867469879518073, 0.7317073170731708]
# 0.6813314730810915
# -0.6813314730810915 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 14:04:51.910043
# [0.6666666666666667, 0.75, 0.7044025157232704, 0.7407407407407407, 0.7341772151898733]
# 0.7191974276641102
# -0.7191974276641102 -0.7264658417383185
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 14:12:35.825719
# [0.6842105263157894, 0.75, 0.7225806451612903, 0.7469879518072289, 0.7295597484276728]
# 0.7266677743423963
# -0.7266677743423963 -0.7266677743423963
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 14:29:21.902020
# [0.6624203821656051, 0.7105263157894737, 0.6751592356687897, 0.7393939393939394, 0.7088607594936708]
# 0.6992721265022956
# -0.6992721265022956 -0.7266677743423963
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 14:45:22.134791
# [0.6190476190476192, 0.7051282051282051, 0.6951219512195121, 0.7160493827160493, 0.7425149700598802]
# 0.6955724256342533
# -0.6955724256342533 -0.7266677743423963
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 14:55:40.545765
# [0.6582278481012659, 0.735483870967742, 0.6878980891719745, 0.703030303030303, 0.7374999999999999]
# 0.704428022254257
# -0.704428022254257 -0.7266677743423963
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 15:04:09.456239
# [0.6296296296296297, 0.6973684210526315, 0.6415094339622641, 0.7261904761904762, 0.7239263803680983]
# 0.68372486824062
# -0.68372486824062 -0.7266677743423963
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'nb'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f6daefa5940>}
# 0.76
# outer fold
# 2019-08-21 15:18:40.700373
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:18:41.214855
# [0.7544910179640719, 0.7411764705882353, 0.7924528301886792, 0.641025641025641, 0.787878787878788]
# 0.7434049495290831
# -0.7434049495290831 -0.7434049495290831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:35:18.364839
# [0.7215189873417721, 0.7052023121387283, 0.7577639751552795, 0.6013071895424836, 0.75]
# 0.7071584928356527
# -0.7071584928356527 -0.7434049495290831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 15:47:20.774081
# [0.7547169811320754, 0.7664670658682634, 0.8, 0.6710526315789473, 0.7975460122699387]
# 0.757956538169845
# -0.757956538169845 -0.757956538169845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 16:05:13.096504
# [0.7530864197530863, 0.7425149700598802, 0.7692307692307692, 0.6751592356687897, 0.7701863354037267]
# 0.7420355460232504
# -0.7420355460232504 -0.757956538169845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 16:21:23.528114
# [0.7407407407407407, 0.757396449704142, 0.7875, 0.6883116883116883, 0.7926829268292682]
# 0.7533263611171679
# -0.7533263611171679 -0.757956538169845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:33:53.063866
# [0.7515151515151515, 0.7904191616766467, 0.8074534161490683, 0.6887417218543046, 0.8095238095238094]
# 0.7695306521437961
# -0.7695306521437961 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:51:41.903453
# [0.7439024390243902, 0.7294117647058823, 0.7612903225806451, 0.641025641025641, 0.7560975609756098]
# 0.7263455456624337
# -0.7263455456624337 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 17:07:30.388709
# [0.7654320987654321, 0.7738095238095237, 0.8125000000000001, 0.6710526315789473, 0.8072289156626505]
# 0.7660046339633106
# -0.7660046339633106 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 17:24:56.874158
# [0.7625, 0.7151515151515152, 0.7450980392156864, 0.6666666666666667, 0.7577639751552795]
# 0.7294360392378295
# -0.7294360392378295 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:36:14.081096
# [0.7407407407407407, 0.7529411764705881, 0.7901234567901234, 0.717948717948718, 0.782608695652174]
# 0.7568725575204688
# -0.7568725575204688 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 17:48:14.604558
# [0.7590361445783134, 0.6585365853658536, 0.7530864197530863, 0.632258064516129, 0.7485380116959064]
# 0.7102910451818578
# -0.7102910451818578 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:59:11.273418
# [0.7468354430379747, 0.7469879518072289, 0.758169934640523, 0.6496815286624203, 0.7682926829268293]
# 0.7339935082149951
# -0.7339935082149951 -0.7695306521437961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 18:09:22.679184
# [0.7607361963190185, 0.8045977011494253, 0.782051282051282, 0.7019867549668874, 0.8]
# 0.7698743868973226
# -0.7698743868973226 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 18:34:44.339022
# [0.7239263803680983, 0.710059171597633, 0.7999999999999999, 0.627450980392157, 0.75]
# 0.7222873064715776
# -0.7222873064715776 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 18:49:55.868765
# [0.7453416149068324, 0.7790697674418605, 0.7950310559006211, 0.7012987012987013, 0.7560975609756098]
# 0.755367740104725
# -0.755367740104725 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 18:58:58.661310
# [0.7682926829268293, 0.7647058823529411, 0.7975460122699387, 0.6933333333333332, 0.787878787878788]
# 0.7623513397523661
# -0.7623513397523661 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 19:11:41.856382
# [0.7594936708860759, 0.783625730994152, 0.8024691358024691, 0.6753246753246753, 0.8072289156626505]
# 0.7656284257340045
# -0.7656284257340045 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 19:26:46.930621
# [0.7393939393939394, 0.7398843930635839, 0.7532467532467533, 0.641025641025641, 0.761904761904762]
# 0.7270910977269358
# -0.7270910977269358 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:37:17.806207
# [0.7643312101910827, 0.7337278106508877, 0.7643312101910827, 0.6538461538461539, 0.782608695652174]
# 0.7397690161062761
# -0.7397690161062761 -0.7698743868973226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 19:45:20.754754
# [0.7349397590361447, 0.6335403726708074, 0.7564102564102564, 0.6405228758169934, 0.7664670658682634]
# 0.706376065960493
# -0.706376065960493 -0.7698743868973226
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'nb'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f6daefa5550>}
# 0.7960199004975126
# outer fold
# 2019-08-21 19:58:48.478835
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:58:49.051589
# [0.7044025157232704, 0.6967741935483871, 0.6883116883116883, 0.7295597484276728, 0.7777777777777778]
# 0.7193651847577592
# -0.7193651847577592 -0.7193651847577592
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 20:11:43.446643
# [0.6496815286624203, 0.7204968944099378, 0.6887417218543046, 0.6835443037974684, 0.7560975609756098]
# 0.6997124019399482
# -0.6997124019399482 -0.7193651847577592
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:21:38.640899
# [0.7250000000000001, 0.7133757961783439, 0.7204968944099378, 0.7283950617283951, 0.7777777777777778]
# 0.7330091060188909
# -0.7330091060188909 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 20:37:38.280403
# [0.6993865030674846, 0.7088607594936708, 0.7435897435897435, 0.7215189873417721, 0.773006134969325]
# 0.7292724256923993
# -0.7292724256923993 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 20:51:54.389927
# [0.6875000000000001, 0.7, 0.7393939393939394, 0.7329192546583853, 0.7857142857142857]
# 0.7291054959533221
# -0.7291054959533221 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:00:50.787268
# [0.7037037037037037, 0.7080745341614907, 0.7204968944099378, 0.7239263803680983, 0.7664670658682634]
# 0.7245337157022987
# -0.7245337157022987 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:14:01.626363
# [0.6871165644171778, 0.7006369426751592, 0.7133757961783439, 0.7044025157232704, 0.7672955974842767]
# 0.7145654832956455
# -0.7145654832956455 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 21:25:10.671194
# [0.7116564417177914, 0.6928104575163399, 0.7239263803680983, 0.7341772151898733, 0.7710843373493975]
# 0.7267309664283002
# -0.7267309664283002 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 21:38:23.963034
# [0.6951219512195121, 0.6835443037974684, 0.7160493827160493, 0.710843373493976, 0.7590361445783134]
# 0.7129190311610638
# -0.7129190311610638 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:46:44.053262
# [0.6982248520710058, 0.6797385620915033, 0.7317073170731708, 0.7272727272727273, 0.7636363636363638]
# 0.7201159644289541
# -0.7201159644289541 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:55:15.627814
# [0.6624203821656051, 0.717948717948718, 0.7133757961783439, 0.7160493827160493, 0.7455621301775148]
# 0.7110712818372462
# -0.7110712818372462 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:04:36.383321
# [0.6829268292682926, 0.7320261437908497, 0.7169811320754716, 0.7051282051282051, 0.7329192546583853]
# 0.7139963129842409
# -0.7139963129842409 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:12:52.008826
# [0.7361963190184049, 0.7105263157894737, 0.7058823529411765, 0.7407407407407407, 0.7682926829268293]
# 0.732327682283325
# -0.732327682283325 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:26:38.405759
# [0.691358024691358, 0.7250000000000001, 0.6797385620915033, 0.6787878787878788, 0.7439024390243902]
# 0.7037573809190262
# -0.7037573809190262 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 22:35:59.440499
# [0.7160493827160493, 0.6933333333333332, 0.7283950617283951, 0.7361963190184049, 0.7625]
# 0.7272948193592365
# -0.7272948193592365 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 22:43:55.456327
# [0.7239263803680983, 0.6887417218543046, 0.7096774193548386, 0.7329192546583853, 0.7329192546583853]
# 0.7176368061788024
# -0.7176368061788024 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:58:31.148122
# [0.6918238993710691, 0.7006369426751592, 0.7037037037037037, 0.7272727272727273, 0.7875]
# 0.7221874546045319
# -0.7221874546045319 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 23:12:11.647922
# [0.670807453416149, 0.7204968944099378, 0.7133757961783439, 0.674698795180723, 0.7329192546583853]
# 0.7024596387687078
# -0.7024596387687078 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 23:21:46.823217
# [0.6832298136645963, 0.6967741935483871, 0.7341772151898733, 0.7080745341614907, 0.7547169811320754]
# 0.7153945475392846
# -0.7153945475392846 -0.7330091060188909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 23:29:46.713979
# [0.6956521739130435, 0.7073170731707318, 0.7088607594936708, 0.703030303030303, 0.7831325301204819]
# 0.7195985679456463
# -0.7195985679456463 -0.7330091060188909
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'nb'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f6daec73f28>}
# 0.7083333333333334
# save to ../pickle/2019-08-21 23:42:08.928957.pickle
# save to ../csv/2019-08-21 23:42:10.412478.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.77    0.774          0.767       0.767         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=1, learning_rate=0.1,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=64,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#      method  tag                                  pickle_path
# 0  [wc, nb]  AMT  ../pickle/2019-08-21 23:42:08.928957.pickle
# save to ../csv/2019-08-21 23:42:10.497253.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.77    0.774          0.767       0.767         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=1, learning_rate=0.1,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=64,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#      method  tag                                  pickle_path
# 0  [wc, nb]  AMT  ../pickle/2019-08-21 23:42:08.928957.pickle
# time: 1d 7h 49min 44s

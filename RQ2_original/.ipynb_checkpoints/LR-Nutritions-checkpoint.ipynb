# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.54 µs
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# time: 41 ms

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 20.8 s

# %% [markdown]
# ### Nutritions only

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['nu','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-22 14:26:40.951796
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 14:26:41.168117
# [0.7857142857142857, 0.8098159509202455, 0.8152866242038217, 0.8481012658227849, 0.8627450980392157]
# 0.8243326449400709
# -0.8243326449400709 -0.8243326449400709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 14:26:45.993830
# [0.7857142857142857, 0.8024691358024691, 0.8152866242038217, 0.8481012658227849, 0.8684210526315789]
# 0.823998472834988
# -0.823998472834988 -0.8243326449400709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 14:26:50.303324
# [0.7810650887573963, 0.8024691358024691, 0.8152866242038217, 0.8481012658227849, 0.8684210526315789]
# 0.8230686334436103
# -0.8230686334436103 -0.8243326449400709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 14:26:55.800620
# [0.7810650887573963, 0.8074534161490683, 0.8152866242038217, 0.8407643312101911, 0.8645161290322579]
# 0.821817117870547
# -0.821817117870547 -0.8243326449400709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 14:27:00.656818
# [0.7810650887573963, 0.8024691358024691, 0.8152866242038217, 0.8407643312101911, 0.8645161290322579]
# 0.8208202618012272
# -0.8208202618012272 -0.8243326449400709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 14:27:05.513046
# [0.7928994082840236, 0.8292682926829269, 0.8176100628930817, 0.8518518518518519, 0.8609271523178808]
# 0.830511353605953
# -0.830511353605953 -0.830511353605953
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 14:27:11.157883
# [0.7810650887573963, 0.8074534161490683, 0.8152866242038217, 0.8407643312101911, 0.8645161290322579]
# 0.821817117870547
# -0.821817117870547 -0.830511353605953
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 14:27:16.064166
# [0.7810650887573963, 0.8074534161490683, 0.8152866242038217, 0.8407643312101911, 0.8645161290322579]
# 0.821817117870547
# -0.821817117870547 -0.830511353605953
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 14:27:21.269267
# [0.7757575757575756, 0.8313253012048193, 0.8024691358024691, 0.84472049689441, 0.8609271523178808]
# 0.8230399323954309
# -0.8230399323954309 -0.830511353605953
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 14:27:26.511066
# [0.7784431137724551, 0.8313253012048193, 0.7999999999999999, 0.8383233532934131, 0.8533333333333333]
# 0.8202850203208042
# -0.8202850203208042 -0.830511353605953
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f61946b7940>}
# 0.8651162790697673
# outer fold
# 2019-08-22 14:27:32.619999
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 14:27:32.888647
# [0.8311688311688312, 0.8536585365853657, 0.8152866242038217, 0.8374999999999999, 0.8023255813953489]
# 0.8279879146706735
# -0.8279879146706735 -0.8279879146706735
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 14:27:37.920063
# [0.8333333333333334, 0.8484848484848484, 0.8152866242038217, 0.8395061728395061, 0.8023255813953489]
# 0.8277873120513718
# -0.8277873120513718 -0.8279879146706735
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 14:27:42.925851
# [0.8366013071895425, 0.8484848484848484, 0.8152866242038217, 0.8322981366459627, 0.8092485549132948]
# 0.828383894287494
# -0.828383894287494 -0.828383894287494
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 14:27:48.110876
# [0.8366013071895425, 0.8484848484848484, 0.8051948051948052, 0.8395061728395061, 0.8092485549132948]
# 0.8278071377243995
# -0.8278071377243995 -0.828383894287494
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 14:27:52.708189
# [0.8366013071895425, 0.8484848484848484, 0.8051948051948052, 0.8395061728395061, 0.8092485549132948]
# 0.8278071377243995
# -0.8278071377243995 -0.828383894287494
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 14:27:57.614791
# [0.8441558441558442, 0.8518518518518519, 0.8211920529801325, 0.8322981366459627, 0.8047337278106509]
# 0.8308463226888885
# -0.8308463226888885 -0.8308463226888885
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 14:28:02.765210
# [0.8366013071895425, 0.8484848484848484, 0.8051948051948052, 0.8395061728395061, 0.8092485549132948]
# 0.8278071377243995
# -0.8278071377243995 -0.8308463226888885
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 14:28:07.784087
# [0.8366013071895425, 0.8484848484848484, 0.8051948051948052, 0.8395061728395061, 0.8092485549132948]
# 0.8278071377243995
# -0.8278071377243995 -0.8308463226888885
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 14:28:12.538214
# [0.8516129032258065, 0.84472049689441, 0.7724137931034484, 0.8271604938271605, 0.7852760736196319]
# 0.8162367521340915
# -0.8162367521340915 -0.8308463226888885
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 14:28:18.154405
# [0.84472049689441, 0.8284023668639053, 0.8, 0.8343558282208587, 0.8095238095238094]
# 0.8234005003005966
# -0.8234005003005966 -0.8308463226888885
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f61943eae48>}
# 0.7999999999999999
# outer fold
# 2019-08-22 14:28:24.559289
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 14:28:24.868626
# [0.8263473053892216, 0.8344370860927153, 0.7870967741935484, 0.8383233532934131, 0.7625]
# 0.8097409037937797
# -0.8097409037937797 -0.8097409037937797
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 14:28:30.554326
# [0.8343558282208587, 0.8344370860927153, 0.7870967741935484, 0.8452380952380952, 0.7792207792207793]
# 0.8160697125931995
# -0.8160697125931995 -0.8160697125931995
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 14:28:35.702331
# [0.8263473053892216, 0.8496732026143791, 0.7870967741935484, 0.8452380952380952, 0.7792207792207793]
# 0.8175152313312047
# -0.8175152313312047 -0.8175152313312047
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 14:28:40.955725
# [0.8263473053892216, 0.8496732026143791, 0.7870967741935484, 0.8452380952380952, 0.7843137254901961]
# 0.8185338205850881
# -0.8185338205850881 -0.8185338205850881
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 14:28:46.128474
# [0.8263473053892216, 0.8496732026143791, 0.7870967741935484, 0.8452380952380952, 0.7843137254901961]
# 0.8185338205850881
# -0.8185338205850881 -0.8185338205850881
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 14:28:51.060134
# [0.8292682926829269, 0.8749999999999999, 0.7974683544303799, 0.8295454545454545, 0.7763157894736843]
# 0.821519578226489
# -0.821519578226489 -0.821519578226489
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 14:28:55.907753
# [0.8263473053892216, 0.8496732026143791, 0.7870967741935484, 0.8452380952380952, 0.7843137254901961]
# 0.8185338205850881
# -0.8185338205850881 -0.821519578226489
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 14:29:00.976674
# [0.8263473053892216, 0.8496732026143791, 0.7870967741935484, 0.8452380952380952, 0.7843137254901961]
# 0.8185338205850881
# -0.8185338205850881 -0.821519578226489
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 14:29:05.924245
# [0.8242424242424242, 0.8157894736842104, 0.8125000000000001, 0.8323699421965318, 0.7651006711409395]
# 0.8100005022528212
# -0.8100005022528212 -0.821519578226489
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 14:29:10.872382
# [0.8070175438596491, 0.84472049689441, 0.7926829268292682, 0.8156424581005587, 0.7792207792207793]
# 0.807856840980933
# -0.807856840980933 -0.821519578226489
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f61943eaf60>}
# 0.8481675392670157
# outer fold
# 2019-08-22 14:29:17.303624
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 14:29:17.640367
# [0.8048780487804877, 0.8466257668711655, 0.8414634146341464, 0.8051948051948052, 0.8520710059171598]
# 0.8300466082795529
# -0.8300466082795529 -0.8300466082795529
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 14:29:22.886991
# [0.8048780487804877, 0.8518518518518519, 0.8433734939759034, 0.8051948051948052, 0.8520710059171598]
# 0.8314738411440417
# -0.8314738411440417 -0.8314738411440417
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 14:29:28.448829
# [0.8048780487804877, 0.8518518518518519, 0.8433734939759034, 0.8051948051948052, 0.8520710059171598]
# 0.8314738411440417
# -0.8314738411440417 -0.8314738411440417
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 14:29:33.104451
# [0.8048780487804877, 0.8518518518518519, 0.8484848484848484, 0.8051948051948052, 0.8520710059171598]
# 0.8324961120458306
# -0.8324961120458306 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 14:29:38.144755
# [0.8048780487804877, 0.8518518518518519, 0.8433734939759034, 0.8051948051948052, 0.8520710059171598]
# 0.8314738411440417
# -0.8314738411440417 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 14:29:42.458103
# [0.7975460122699387, 0.8588957055214724, 0.7843137254901961, 0.8051948051948052, 0.8554216867469879]
# 0.82027438704468
# -0.82027438704468 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 14:29:47.395009
# [0.8048780487804877, 0.8518518518518519, 0.8484848484848484, 0.8051948051948052, 0.8520710059171598]
# 0.8324961120458306
# -0.8324961120458306 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 14:29:51.996068
# [0.8048780487804877, 0.8518518518518519, 0.8484848484848484, 0.8051948051948052, 0.8520710059171598]
# 0.8324961120458306
# -0.8324961120458306 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 14:29:56.963512
# [0.7804878048780488, 0.8588957055214724, 0.782051282051282, 0.8051948051948052, 0.8502994011976048]
# 0.8153857997686427
# -0.8153857997686427 -0.8324961120458306
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 14:30:01.599746
# [0.757396449704142, 0.8322981366459627, 0.8143712574850299, 0.7894736842105262, 0.8402366863905325]
# 0.8067552428872385
# -0.8067552428872385 -0.8324961120458306
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}, 'corp': <models.features.fixed_makedata object at 0x7f61943ea748>}
# 0.8200000000000001
# outer fold
# 2019-08-22 14:30:07.952368
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 14:30:08.261079
# [0.7926829268292682, 0.8074534161490683, 0.8374999999999999, 0.8292682926829269, 0.8987341772151898]
# 0.8331277625752908
# -0.8331277625752908 -0.8331277625752908
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 14:30:13.189052
# [0.787878787878788, 0.8148148148148148, 0.823529411764706, 0.8322981366459627, 0.8987341772151898]
# 0.8314510656638923
# -0.8314510656638923 -0.8331277625752908
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 14:30:18.063657
# [0.7975460122699387, 0.8220858895705522, 0.823529411764706, 0.8322981366459627, 0.8944099378881988]
# 0.8339738776278717
# -0.8339738776278717 -0.8339738776278717
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 14:30:22.777506
# [0.7975460122699387, 0.8220858895705522, 0.823529411764706, 0.8292682926829269, 0.8944099378881988]
# 0.8333679088352645
# -0.8333679088352645 -0.8339738776278717
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 14:30:27.923448
# [0.7975460122699387, 0.8220858895705522, 0.823529411764706, 0.8292682926829269, 0.8944099378881988]
# 0.8333679088352645
# -0.8333679088352645 -0.8339738776278717
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 14:30:33.134257
# [0.8170731707317075, 0.8323699421965318, 0.8500000000000001, 0.8292682926829269, 0.89171974522293]
# 0.8440862301668192
# -0.8440862301668192 -0.8440862301668192
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 14:30:38.364787
# [0.7975460122699387, 0.8220858895705522, 0.823529411764706, 0.8292682926829269, 0.8944099378881988]
# 0.8333679088352645
# -0.8333679088352645 -0.8440862301668192
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 14:30:43.632073
# [0.7975460122699387, 0.8220858895705522, 0.823529411764706, 0.8292682926829269, 0.8944099378881988]
# 0.8333679088352645
# -0.8333679088352645 -0.8440862301668192
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 14:30:48.312317
# [0.8121212121212122, 0.8275862068965517, 0.8280254777070064, 0.8363636363636364, 0.9125]
# 0.8433193066176814
# -0.8433193066176814 -0.8440862301668192
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 14:30:52.404266
# [0.7975460122699387, 0.7926829268292682, 0.8198757763975155, 0.8271604938271605, 0.8999999999999999]
# 0.8274530418647768
# -0.8274530418647768 -0.8440862301668192
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f61943ea550>}
# 0.7920792079207921
# save to ../pickle/2019-08-22 14:30:58.313921.pickle
# save to ../csv/2019-08-22 14:30:58.327198.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.825   0.83           0.822       0.822         0.839    0.841
#
#   train_recall train_accuracy model1  \
# 0  0.837        0.836          None
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [nu, scale]  AMT  ../pickle/2019-08-22 14:30:58.313921.pickle
# save to ../csv/2019-08-22 14:30:58.433842.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.825   0.83           0.822       0.822         0.839    0.841
#
#   train_recall train_accuracy model1  \
# 0  0.837        0.836          None
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [nu, scale]  AMT  ../pickle/2019-08-22 14:30:58.313921.pickle
# time: 4min 29s

# %% [markdown]
# ### Combination1: word2vec + nutritions

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['wc', 'nb', 'nu','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-22 10:48:56.881425
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 10:48:57.155400
# [0.7901234567901234, 0.8242424242424242, 0.8461538461538461, 0.8048780487804877, 0.8079470198675496]
# 0.8146689591668862
# -0.8146689591668862 -0.8146689591668862
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 10:49:11.974025
# [0.7852760736196319, 0.8148148148148148, 0.830188679245283, 0.7975460122699387, 0.8133333333333334]
# 0.8082317826566003
# -0.8082317826566003 -0.8146689591668862
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 10:49:25.918803
# [0.7804878048780488, 0.8098159509202455, 0.830188679245283, 0.7926829268292682, 0.8211920529801324]
# 0.8068734829705955
# -0.8068734829705955 -0.8146689591668862
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 10:49:40.881301
# [0.7484662576687118, 0.8023952095808382, 0.8074534161490683, 0.7901234567901234, 0.7999999999999999]
# 0.7896876680377483
# -0.7896876680377483 -0.8146689591668862
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 10:49:55.352583
# [0.7710843373493975, 0.8048780487804877, 0.8198757763975155, 0.7901234567901234, 0.8157894736842106]
# 0.8003502186003469
# -0.8003502186003469 -0.8146689591668862
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 10:50:09.375982
# [0.7950310559006211, 0.8414634146341464, 0.864516129032258, 0.8407643312101911, 0.8552631578947368]
# 0.8394076177343907
# -0.8394076177343907 -0.8394076177343907
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 10:50:24.182736
# [0.7560975609756098, 0.8023952095808382, 0.8271604938271605, 0.7901234567901234, 0.8053691275167786]
# 0.7962291697381021
# -0.7962291697381021 -0.8394076177343907
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 10:50:38.597953
# [0.7636363636363638, 0.8072289156626505, 0.8271604938271605, 0.7901234567901234, 0.8157894736842106]
# 0.8007877407201018
# -0.8007877407201018 -0.8394076177343907
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 10:50:52.870464
# [0.8072289156626505, 0.8227848101265822, 0.860759493670886, 0.8481012658227849, 0.8645161290322579]
# 0.8406781228630322
# -0.8406781228630322 -0.8406781228630322
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 10:51:07.799279
# [0.7904191616766467, 0.7922077922077922, 0.8456375838926173, 0.8500000000000001, 0.8662420382165604]
# 0.8289013151987235
# -0.8289013151987235 -0.8406781228630322
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa64f463fd0>}
# 0.8599033816425121
# outer fold
# 2019-08-22 10:51:26.433816
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 10:51:26.753017
# [0.8789808917197451, 0.8641975308641975, 0.8053691275167785, 0.858974358974359, 0.8072289156626505]
# 0.8429501649475462
# -0.8429501649475462 -0.8429501649475462
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 10:51:41.223298
# [0.8717948717948718, 0.8518518518518519, 0.7972972972972973, 0.858974358974359, 0.7951807228915663]
# 0.8350198205619892
# -0.8350198205619892 -0.8429501649475462
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 10:51:55.116163
# [0.8774193548387097, 0.8554216867469879, 0.7919463087248322, 0.8407643312101911, 0.7804878048780488]
# 0.8292078972797539
# -0.8292078972797539 -0.8429501649475462
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 10:52:08.984041
# [0.8280254777070064, 0.8395061728395061, 0.7894736842105262, 0.8354430379746836, 0.7453416149068324]
# 0.8075579975277108
# -0.8075579975277108 -0.8429501649475462
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 10:52:22.672758
# [0.8662420382165605, 0.8484848484848484, 0.7999999999999999, 0.8354430379746836, 0.7784431137724551]
# 0.8257226076897094
# -0.8257226076897094 -0.8429501649475462
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 10:52:37.078966
# [0.8749999999999999, 0.8571428571428572, 0.8163265306122449, 0.8789808917197451, 0.8148148148148148]
# 0.8484530188579325
# -0.8484530188579325 -0.8484530188579325
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 10:52:50.847578
# [0.8333333333333334, 0.8343558282208587, 0.7843137254901961, 0.8354430379746836, 0.7453416149068324]
# 0.8065575079851808
# -0.8065575079851808 -0.8484530188579325
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 10:53:03.520067
# [0.858974358974359, 0.8414634146341464, 0.7894736842105262, 0.8354430379746836, 0.7710843373493975]
# 0.8192877666286226
# -0.8192877666286226 -0.8484530188579325
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 10:53:16.745387
# [0.880503144654088, 0.8749999999999999, 0.8163265306122449, 0.8846153846153846, 0.8292682926829269]
# 0.8571426705129289
# -0.8571426705129289 -0.8571426705129289
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 10:53:29.785478
# [0.8888888888888888, 0.8553459119496856, 0.7999999999999999, 0.8789808917197451, 0.8235294117647058]
# 0.8493490208646051
# -0.8493490208646051 -0.8571426705129289
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa6527fab70>}
# 0.821256038647343
# outer fold
# 2019-08-22 10:53:47.448570
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 10:53:47.728900
# [0.8170731707317075, 0.8535031847133758, 0.8322981366459627, 0.8047337278106509, 0.7875]
# 0.8190216439803393
# -0.8190216439803393 -0.8190216439803393
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 10:54:01.205483
# [0.8098159509202455, 0.8535031847133758, 0.825, 0.8023952095808382, 0.7875]
# 0.815642869042892
# -0.815642869042892 -0.8190216439803393
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 10:54:14.381349
# [0.8121212121212122, 0.8366013071895425, 0.8152866242038217, 0.8047337278106509, 0.773006134969325]
# 0.8083498012589103
# -0.8083498012589103 -0.8190216439803393
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 10:54:28.281107
# [0.7721518987341771, 0.8258064516129032, 0.7532467532467533, 0.7953216374269005, 0.7453416149068324]
# 0.7783736711855134
# -0.7783736711855134 -0.8190216439803393
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 10:54:42.299655
# [0.7901234567901234, 0.8266666666666668, 0.8074534161490683, 0.8047337278106509, 0.7654320987654321]
# 0.7988818732363883
# -0.7988818732363883 -0.8190216439803393
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 10:54:57.120529
# [0.8414634146341464, 0.8500000000000001, 0.8333333333333334, 0.8292682926829269, 0.8205128205128205]
# 0.8349155722326455
# -0.8349155722326455 -0.8349155722326455
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 10:55:09.231300
# [0.7798742138364779, 0.8266666666666668, 0.7662337662337663, 0.783625730994152, 0.7484662576687118]
# 0.7809733270799549
# -0.7809733270799549 -0.8349155722326455
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 10:55:22.977083
# [0.782608695652174, 0.832214765100671, 0.7924528301886792, 0.8023952095808382, 0.7577639751552795]
# 0.7934870951355284
# -0.7934870951355284 -0.8349155722326455
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 10:55:36.769222
# [0.8322981366459627, 0.8481012658227849, 0.8354430379746836, 0.8292682926829269, 0.8280254777070064]
# 0.834627242166673
# -0.834627242166673 -0.8349155722326455
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 10:55:49.720893
# [0.8214285714285715, 0.8679245283018868, 0.8354430379746836, 0.8214285714285715, 0.7973856209150327]
# 0.8287220660097493
# -0.8287220660097493 -0.8349155722326455
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7fa654e209e8>}
# 0.8820512820512821
# outer fold
# 2019-08-22 10:56:06.469467
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 10:56:06.878521
# [0.7948717948717949, 0.8322981366459627, 0.830188679245283, 0.7733333333333333, 0.8395061728395061]
# 0.8140396233871761
# -0.8140396233871761 -0.8140396233871761
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 10:56:20.913436
# [0.7770700636942676, 0.8414634146341464, 0.8271604938271605, 0.7466666666666666, 0.8466257668711655]
# 0.8077972811386813
# -0.8077972811386813 -0.8140396233871761
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 10:56:33.606806
# [0.7770700636942676, 0.8414634146341464, 0.8125000000000001, 0.7549668874172185, 0.8292682926829269]
# 0.8030537316857119
# -0.8030537316857119 -0.8140396233871761
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 10:56:46.253945
# [0.7804878048780488, 0.8176100628930817, 0.7901234567901234, 0.7368421052631579, 0.8024691358024691]
# 0.7855065131253762
# -0.7855065131253762 -0.8140396233871761
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 10:56:59.906701
# [0.7777777777777778, 0.8395061728395061, 0.8220858895705522, 0.7320261437908497, 0.8292682926829269]
# 0.8001328553323226
# -0.8001328553323226 -0.8140396233871761
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 10:57:13.574593
# [0.8050314465408805, 0.8711656441717791, 0.8466257668711655, 0.7919463087248322, 0.8271604938271605]
# 0.8283859320271636
# -0.8283859320271636 -0.8283859320271636
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 10:57:26.481204
# [0.7852760736196319, 0.8176100628930817, 0.7975460122699387, 0.7320261437908497, 0.8024691358024691]
# 0.7869854856751942
# -0.7869854856751942 -0.8283859320271636
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 10:57:40.699998
# [0.7852760736196319, 0.8271604938271605, 0.8, 0.7368421052631579, 0.8271604938271605]
# 0.7952878333074221
# -0.7952878333074221 -0.8283859320271636
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 10:57:54.566570
# [0.8271604938271605, 0.8727272727272727, 0.8427672955974842, 0.7837837837837838, 0.8484848484848484]
# 0.8349847388841098
# -0.8349847388841098 -0.8349847388841098
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 10:58:07.695217
# [0.8098159509202455, 0.8622754491017963, 0.8624999999999999, 0.7973856209150327, 0.8588235294117647]
# 0.8381601100697678
# -0.8381601100697678 -0.8381601100697678
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7fa65eb0d668>}
# 0.83248730964467
# outer fold
# 2019-08-22 10:58:25.075152
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 10:58:25.359126
# [0.8354430379746836, 0.8322981366459627, 0.8313253012048193, 0.8198757763975155, 0.880503144654088]
# 0.8398890793754138
# -0.8398890793754138 -0.8398890793754138
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 10:58:39.736152
# [0.8125000000000001, 0.8148148148148148, 0.8263473053892216, 0.825, 0.860759493670886]
# 0.8278843227749846
# -0.8278843227749846 -0.8398890793754138
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 10:58:52.618881
# [0.8, 0.8170731707317075, 0.8170731707317075, 0.8176100628930817, 0.8553459119496856]
# 0.8214204632612365
# -0.8214204632612365 -0.8398890793754138
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 10:59:06.645170
# [0.7848101265822786, 0.8072289156626505, 0.7926829268292682, 0.8227848101265822, 0.8333333333333334]
# 0.8081680225068226
# -0.8081680225068226 -0.8398890793754138
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 10:59:18.768101
# [0.8, 0.8121212121212122, 0.8024691358024691, 0.8280254777070064, 0.8481012658227849]
# 0.8181434182906946
# -0.8181434182906946 -0.8398890793754138
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 10:59:33.658036
# [0.8427672955974842, 0.8271604938271605, 0.8363636363636364, 0.8606060606060606, 0.89171974522293]
# 0.8517234463234542
# -0.8517234463234542 -0.8517234463234542
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 10:59:46.765654
# [0.7898089171974522, 0.8023952095808382, 0.7975460122699387, 0.8205128205128205, 0.8333333333333334]
# 0.8087192585788765
# -0.8087192585788765 -0.8517234463234542
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 11:00:00.515362
# [0.7848101265822786, 0.8170731707317075, 0.7975460122699387, 0.810126582278481, 0.8333333333333334]
# 0.8085778450391479
# -0.8085778450391479 -0.8517234463234542
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 11:00:14.871166
# [0.8280254777070064, 0.8280254777070064, 0.8466257668711655, 0.8674698795180723, 0.903225806451613]
# 0.8546744816509728
# -0.8546744816509728 -0.8546744816509728
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 11:00:28.549151
# [0.8484848484848484, 0.8074534161490683, 0.8181818181818182, 0.8414634146341464, 0.8815789473684211]
# 0.8394324889636605
# -0.8394324889636605 -0.8546744816509728
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa66668fcf8>}
# 0.8527918781725888
# save to ../pickle/2019-08-22 11:00:45.957898.pickle
# save to ../csv/2019-08-22 11:00:45.978899.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.85    0.859          0.842       0.847         0.933    0.937
#
#   train_recall train_accuracy model1  \
# 0  0.929        0.932          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                 method  tag                                  pickle_path
# 0  [wc, nb, nu, scale]  AMT  ../pickle/2019-08-22 11:00:45.957898.pickle
# save to ../csv/2019-08-22 11:00:46.010297.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.85    0.859          0.842       0.847         0.933    0.937
#
#   train_recall train_accuracy model1  \
# 0  0.929        0.932          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                 method  tag                                  pickle_path
# 0  [wc, nb, nu, scale]  AMT  ../pickle/2019-08-22 11:00:45.957898.pickle
# time: 12min 2s

# %% [markdown]
# ### Combination2: Recipe1M word embedding and Nutritions

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
model1 = salvador_wrap()
for method in [['wv','nu','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-22 12:49:55.149257
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 12:49:55.399637
# [0.7948717948717949, 0.7798742138364779, 0.7928994082840236, 0.7901234567901234, 0.7891156462585034]
# 0.7893769040081847
# -0.7893769040081847 -0.7893769040081847
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 12:50:31.045960
# [0.8, 0.7975460122699387, 0.7784431137724551, 0.7975460122699387, 0.7724137931034483]
# 0.7891897862831561
# -0.7891897862831561 -0.7893769040081847
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 12:51:02.984173
# [0.7612903225806451, 0.7607361963190185, 0.7710843373493975, 0.7926829268292682, 0.7285714285714286]
# 0.7628730423299516
# -0.7628730423299516 -0.7893769040081847
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 12:51:35.225145
# [0.7564102564102564, 0.7317073170731708, 0.7544910179640719, 0.787878787878788, 0.7310344827586207]
# 0.7523043724169816
# -0.7523043724169816 -0.7893769040081847
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 12:52:08.014691
# [0.7483870967741936, 0.7607361963190185, 0.7636363636363638, 0.7926829268292682, 0.736111111111111]
# 0.760310738933991
# -0.760310738933991 -0.7893769040081847
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 12:52:41.835847
# [0.8205128205128205, 0.8125000000000001, 0.8198757763975155, 0.8214285714285715, 0.8366013071895425]
# 0.82218369510569
# -0.82218369510569 -0.82218369510569
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 12:53:14.320024
# [0.7483870967741936, 0.7317073170731708, 0.7544910179640719, 0.787878787878788, 0.726027397260274]
# 0.7496983233900997
# -0.7496983233900997 -0.82218369510569
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 12:53:47.567456
# [0.7483870967741936, 0.7361963190184049, 0.761904761904762, 0.787878787878788, 0.726027397260274]
# 0.7520788725672845
# -0.7520788725672845 -0.82218369510569
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 12:54:21.206016
# [0.7973856209150327, 0.8076923076923077, 0.8333333333333334, 0.8192771084337349, 0.8645161290322579]
# 0.8244408998813334
# -0.8244408998813334 -0.8244408998813334
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 12:54:55.681934
# [0.7814569536423841, 0.8258064516129032, 0.8366013071895425, 0.8441558441558442, 0.8435374149659864]
# 0.8263115943133321
# -0.8263115943133321 -0.8263115943133321
# {'model1': <models.features.salvador_wrap object at 0x7f9ec6133550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec7083e10>}
# 0.8653846153846154
# outer fold
# 2019-08-22 12:55:37.453670
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 12:55:37.630218
# [0.8466257668711655, 0.8148148148148148, 0.7770700636942676, 0.8606060606060606, 0.7953216374269005]
# 0.8188876686826418
# -0.8188876686826418 -0.8188876686826418
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 12:56:11.885067
# [0.8414634146341464, 0.8148148148148148, 0.7547169811320754, 0.8606060606060606, 0.7906976744186047]
# 0.8124597891211405
# -0.8124597891211405 -0.8188876686826418
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 12:56:41.755750
# [0.8047337278106509, 0.7999999999999999, 0.7329192546583853, 0.8502994011976048, 0.7764705882352941]
# 0.7928845943803869
# -0.7928845943803869 -0.8188876686826418
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 12:57:15.895658
# [0.7738095238095237, 0.7804878048780488, 0.7374999999999999, 0.8452380952380952, 0.7485380116959064]
# 0.7771146871243149
# -0.7771146871243149 -0.8188876686826418
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 12:57:48.770709
# [0.7857142857142857, 0.7951807228915663, 0.7453416149068324, 0.8452380952380952, 0.7647058823529411]
# 0.7872361202207442
# -0.7872361202207442 -0.8188876686826418
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 12:58:20.812739
# [0.8717948717948718, 0.8050314465408805, 0.7792207792207793, 0.8902439024390244, 0.8050314465408805]
# 0.8302644893072874
# -0.8302644893072874 -0.8302644893072874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 12:58:53.900320
# [0.7738095238095237, 0.7804878048780488, 0.7374999999999999, 0.8383233532934131, 0.7485380116959064]
# 0.7757317387353784
# -0.7757317387353784 -0.8302644893072874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 12:59:27.760745
# [0.7738095238095237, 0.787878787878788, 0.7421383647798742, 0.8402366863905325, 0.7529411764705881]
# 0.7794009078658612
# -0.7794009078658612 -0.8302644893072874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 12:59:59.274997
# [0.8717948717948718, 0.830188679245283, 0.7763157894736843, 0.9024390243902438, 0.8074534161490683]
# 0.8376383562106302
# -0.8376383562106302 -0.8376383562106302
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:00:29.449837
# [0.8774193548387097, 0.830188679245283, 0.7843137254901961, 0.8902439024390244, 0.8050314465408805]
# 0.8374394217108186
# -0.8374394217108186 -0.8376383562106302
# {'model1': <models.features.salvador_wrap object at 0x7f9ec6124b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f9ec66bb9b0>}
# 0.8285714285714286
# outer fold
# 2019-08-22 13:01:11.459837
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:01:11.747405
# [0.7468354430379747, 0.8383233532934131, 0.7710843373493975, 0.8402366863905325, 0.735483870967742]
# 0.7863927382078119
# -0.7863927382078119 -0.7863927382078119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:01:46.340742
# [0.7250000000000001, 0.8214285714285715, 0.7636363636363638, 0.8352941176470587, 0.735483870967742]
# 0.7761685847359472
# -0.7761685847359472 -0.7863927382078119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:02:18.172364
# [0.7250000000000001, 0.8, 0.7407407407407407, 0.8284023668639053, 0.7643312101910827]
# 0.7716948635591457
# -0.7716948635591457 -0.7863927382078119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:02:49.122410
# [0.7195121951219512, 0.7790697674418605, 0.7407407407407407, 0.8143712574850299, 0.7421383647798742]
# 0.7591664651138912
# -0.7591664651138912 -0.7863927382078119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:03:21.074620
# [0.7204968944099378, 0.8, 0.7453416149068324, 0.8383233532934131, 0.7547169811320754]
# 0.7717757687484517
# -0.7717757687484517 -0.7863927382078119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:03:49.788887
# [0.7798742138364779, 0.8518518518518519, 0.7870967741935484, 0.8383233532934131, 0.7741935483870969]
# 0.8062679483124777
# -0.8062679483124777 -0.8062679483124777
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:04:22.544560
# [0.7195121951219512, 0.7790697674418605, 0.7361963190184049, 0.8143712574850299, 0.7421383647798742]
# 0.7582575807694242
# -0.7582575807694242 -0.8062679483124777
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:04:56.285027
# [0.7239263803680983, 0.7790697674418605, 0.7407407407407407, 0.8192771084337349, 0.7421383647798742]
# 0.7610304723528618
# -0.7610304723528618 -0.8062679483124777
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:05:29.459245
# [0.7848101265822786, 0.8679245283018868, 0.8129032258064517, 0.8383233532934131, 0.7662337662337663]
# 0.8140390000435593
# -0.8140390000435593 -0.8140390000435593
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:06:03.542007
# [0.7848101265822786, 0.8695652173913043, 0.8181818181818182, 0.8571428571428572, 0.8]
# 0.8259400038596517
# -0.8259400038596517 -0.8259400038596517
# {'model1': <models.features.salvador_wrap object at 0x7f9ec69e4f28>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec702b240>}
# 0.8478260869565218
# outer fold
# 2019-08-22 13:06:47.001788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:06:47.256392
# [0.8076923076923077, 0.8187134502923977, 0.7870967741935484, 0.7741935483870969, 0.8502994011976048]
# 0.8075990963525911
# -0.8075990963525911 -0.8075990963525911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:07:19.934662
# [0.8050314465408805, 0.8304093567251462, 0.782051282051282, 0.7692307692307692, 0.8433734939759034]
# 0.8060192697047963
# -0.8060192697047963 -0.8075990963525911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:07:52.619383
# [0.7701863354037267, 0.8165680473372782, 0.7643312101910827, 0.7654320987654321, 0.8313253012048193]
# 0.7895685985804678
# -0.7895685985804678 -0.8075990963525911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:08:24.868304
# [0.7577639751552795, 0.7999999999999999, 0.7225806451612903, 0.7607361963190185, 0.8313253012048193]
# 0.7744812235680815
# -0.7744812235680815 -0.8075990963525911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:08:57.350996
# [0.7607361963190185, 0.8023952095808382, 0.7435897435897435, 0.7654320987654321, 0.8313253012048193]
# 0.7806957098919703
# -0.7806957098919703 -0.8075990963525911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:09:29.274624
# [0.8050314465408805, 0.8554216867469879, 0.7973856209150327, 0.7651006711409395, 0.8690476190476191]
# 0.8183974088782919
# -0.8183974088782919 -0.8183974088782919
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:10:01.553351
# [0.7654320987654321, 0.8072289156626505, 0.7225806451612903, 0.7682926829268293, 0.8313253012048193]
# 0.7789719287442043
# -0.7789719287442043 -0.8183974088782919
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:10:33.679011
# [0.7577639751552795, 0.8072289156626505, 0.7225806451612903, 0.7682926829268293, 0.8313253012048193]
# 0.7774383040221738
# -0.7774383040221738 -0.8183974088782919
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:11:07.244707
# [0.8466257668711655, 0.8520710059171598, 0.8205128205128205, 0.7870967741935484, 0.8690476190476191]
# 0.8350707973084628
# -0.8350707973084628 -0.8350707973084628
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:11:40.305805
# [0.830188679245283, 0.8433734939759034, 0.8441558441558442, 0.7922077922077922, 0.8502994011976048]
# 0.8320450421564856
# -0.8320450421564856 -0.8350707973084628
# {'model1': <models.features.salvador_wrap object at 0x7f9ec607cef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f9e05596eb8>}
# 0.8241206030150754
# outer fold
# 2019-08-22 13:12:23.122742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:12:23.375997
# [0.8343558282208587, 0.8023952095808382, 0.8, 0.8220858895705522, 0.9056603773584906]
# 0.832899460946148
# -0.832899460946148 -0.832899460946148
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:12:57.015777
# [0.8148148148148148, 0.8048780487804877, 0.8, 0.7950310559006211, 0.8944099378881988]
# 0.8218267714768244
# -0.8218267714768244 -0.832899460946148
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:13:30.667243
# [0.7951807228915663, 0.7625, 0.8, 0.7682926829268293, 0.8679245283018868]
# 0.7987795868240566
# -0.7987795868240566 -0.832899460946148
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:14:03.898549
# [0.8023255813953489, 0.7169811320754716, 0.8, 0.7664670658682634, 0.830188679245283]
# 0.7831924917168733
# -0.7831924917168733 -0.832899460946148
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:14:37.120522
# [0.7882352941176471, 0.7453416149068324, 0.8051948051948052, 0.7757575757575756, 0.8427672955974842]
# 0.7914593171148689
# -0.7914593171148689 -0.832899460946148
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:15:11.768957
# [0.8536585365853657, 0.8502994011976048, 0.8280254777070064, 0.8148148148148148, 0.9102564102564102]
# 0.8514109281122405
# -0.8514109281122405 -0.8514109281122405
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:15:47.274415
# [0.8023255813953489, 0.7169811320754716, 0.8051948051948052, 0.7664670658682634, 0.8354430379746836]
# 0.7852823245017145
# -0.7852823245017145 -0.8514109281122405
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:16:17.913192
# [0.8, 0.7250000000000001, 0.802547770700637, 0.761904761904762, 0.8354430379746836]
# 0.7849791141160165
# -0.7849791141160165 -0.8514109281122405
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:16:49.322395
# [0.8484848484848484, 0.8520710059171598, 0.8205128205128205, 0.8125000000000001, 0.9044585987261147]
# 0.8476054547281887
# -0.8476054547281887 -0.8514109281122405
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:17:16.747988
# [0.8271604938271605, 0.8402366863905325, 0.8258064516129032, 0.8387096774193549, 0.8961038961038961]
# 0.8456034410707695
# -0.8456034410707695 -0.8514109281122405
# {'model1': <models.features.salvador_wrap object at 0x7f9ec64df470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f9ec5bc7c88>}
# 0.8121827411167514
# save to ../pickle/2019-08-22 13:17:50.876077.pickle
# save to ../csv/2019-08-22 13:17:51.366627.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.836   0.851          0.824       0.834         0.906    0.923
#
#   train_recall train_accuracy  \
# 0  0.889        0.906
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9e0555b8d0>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#             method  tag                                  pickle_path
# 0  [wv, nu, scale]  AMT  ../pickle/2019-08-22 13:17:50.876077.pickle
# save to ../csv/2019-08-22 13:17:51.399916.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.836   0.851          0.824       0.834         0.906    0.923
#
#   train_recall train_accuracy  \
# 0  0.889        0.906
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9e0555b8d0>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#             method  tag                                  pickle_path
# 0  [wv, nu, scale]  AMT  ../pickle/2019-08-22 13:17:50.876077.pickle
# time: 28min 8s

# %% [markdown]
# ### Combinations: skipthoughts + nutritons

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', add_skip_thoughts='../data/X_skipthoughts_25k.pickle')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['skip','nu','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-23 16:38:37.499084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:38:37.773124
# [0.7777777777777778, 0.7664670658682634, 0.75, 0.7757575757575756, 0.8375]
# 0.7815004838807232
# -0.7815004838807232 -0.7815004838807232
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:38:46.620291
# [0.7701863354037267, 0.7590361445783134, 0.7594936708860759, 0.7710843373493975, 0.8343558282208589]
# 0.7788312632876745
# -0.7788312632876745 -0.7815004838807232
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:38:55.372599
# [0.7701863354037267, 0.7544910179640719, 0.7643312101910827, 0.7710843373493975, 0.8220858895705521]
# 0.7764357580957661
# -0.7764357580957661 -0.7815004838807232
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:39:03.993436
# [0.7594936708860759, 0.738095238095238, 0.7515923566878981, 0.7590361445783134, 0.8]
# 0.7616434820495052
# -0.7616434820495052 -0.7815004838807232
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:39:13.336077
# [0.7625, 0.757396449704142, 0.7564102564102564, 0.7757575757575756, 0.8148148148148149]
# 0.7733758193373579
# -0.7733758193373579 -0.7815004838807232
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:39:22.516740
# [0.7770700636942676, 0.7590361445783134, 0.7721518987341771, 0.7999999999999999, 0.8205128205128205]
# 0.7857541855039157
# -0.7857541855039157 -0.7857541855039157
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:39:30.880819
# [0.7594936708860759, 0.738095238095238, 0.7564102564102564, 0.7544910179640719, 0.8]
# 0.7616980366711283
# -0.7616980366711283 -0.7857541855039157
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:39:41.254540
# [0.7594936708860759, 0.7425149700598802, 0.7483870967741936, 0.7664670658682634, 0.8143712574850299]
# 0.7662468122146885
# -0.7662468122146885 -0.7857541855039157
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:39:51.577741
# [0.8, 0.7654320987654321, 0.7651006711409395, 0.8098159509202455, 0.8280254777070064]
# 0.7936748397067248
# -0.7936748397067248 -0.7936748397067248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:39:59.466588
# [0.7741935483870969, 0.7577639751552795, 0.7755102040816326, 0.8170731707317075, 0.8344370860927152]
# 0.7917955968896864
# -0.7917955968896864 -0.7936748397067248
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f9ec5c1a390>}
# 0.8300000000000002
# outer fold
# 2019-08-23 16:40:07.288171
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:40:07.565460
# [0.7757575757575756, 0.7701149425287357, 0.7297297297297297, 0.8374999999999999, 0.783625730994152]
# 0.7793455958020387
# -0.7793455958020387 -0.7793455958020387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:40:16.204829
# [0.7757575757575756, 0.7701149425287357, 0.7333333333333334, 0.8292682926829269, 0.783625730994152]
# 0.7784199750593448
# -0.7784199750593448 -0.7793455958020387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:40:24.767259
# [0.7831325301204819, 0.7657142857142857, 0.6986301369863014, 0.8220858895705522, 0.7692307692307692]
# 0.7677587223244781
# -0.7677587223244781 -0.7793455958020387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:40:33.982803
# [0.7630057803468208, 0.7514450867052024, 0.6933333333333332, 0.8121212121212122, 0.783625730994152]
# 0.7607062287001443
# -0.7607062287001443 -0.7793455958020387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:40:42.700872
# [0.7831325301204819, 0.7727272727272727, 0.6938775510204083, 0.8263473053892216, 0.7764705882352941]
# 0.7705110494985357
# -0.7705110494985357 -0.7793455958020387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:40:52.457551
# [0.7975460122699387, 0.773006134969325, 0.7534246575342466, 0.8500000000000001, 0.7544910179640719]
# 0.7856935645475164
# -0.7856935645475164 -0.7856935645475164
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:40:59.558482
# [0.7647058823529411, 0.7514450867052024, 0.697986577181208, 0.8121212121212122, 0.783625730994152]
# 0.7619768978709432
# -0.7619768978709432 -0.7856935645475164
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:41:08.120655
# [0.7544910179640719, 0.7558139534883721, 0.697986577181208, 0.8214285714285715, 0.7764705882352941]
# 0.7612381416595035
# -0.7612381416595035 -0.7856935645475164
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:41:17.306548
# [0.8098159509202455, 0.782608695652174, 0.7552447552447552, 0.860759493670886, 0.7654320987654321]
# 0.7947721988506986
# -0.7947721988506986 -0.7947721988506986
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:41:24.845956
# [0.8104575163398693, 0.7875, 0.7412587412587414, 0.8888888888888888, 0.8050314465408805]
# 0.806627318605676
# -0.806627318605676 -0.806627318605676
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec612dcf8>}
# 0.821256038647343
# outer fold
# 2019-08-23 16:41:33.091328
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:41:33.358004
# [0.7590361445783134, 0.8079470198675497, 0.7870967741935484, 0.7857142857142857, 0.7682119205298013]
# 0.7816012289766997
# -0.7816012289766997 -0.7816012289766997
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:41:41.700790
# [0.7590361445783134, 0.7922077922077922, 0.7770700636942676, 0.7857142857142857, 0.7682119205298013]
# 0.776448041344892
# -0.776448041344892 -0.7816012289766997
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:41:50.996790
# [0.7590361445783134, 0.7894736842105262, 0.7721518987341771, 0.757396449704142, 0.76]
# 0.7676116354454317
# -0.7676116354454317 -0.7816012289766997
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:42:00.852489
# [0.7425149700598802, 0.8, 0.7435897435897435, 0.7647058823529411, 0.7619047619047619]
# 0.7625430715814654
# -0.7625430715814654 -0.7816012289766997
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:42:09.837078
# [0.7590361445783134, 0.7922077922077922, 0.7672955974842767, 0.757396449704142, 0.7567567567567567]
# 0.7665385481462561
# -0.7665385481462561 -0.7816012289766997
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:42:18.978055
# [0.7682926829268293, 0.823529411764706, 0.7922077922077922, 0.8047337278106509, 0.7651006711409395]
# 0.7907728571701835
# -0.7907728571701835 -0.7907728571701835
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:42:26.330227
# [0.738095238095238, 0.8, 0.7515923566878981, 0.7647058823529411, 0.7534246575342466]
# 0.7615636269340648
# -0.7615636269340648 -0.7907728571701835
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:42:35.953365
# [0.75, 0.7870967741935484, 0.7594936708860759, 0.7602339181286549, 0.7567567567567567]
# 0.7627162239930072
# -0.7627162239930072 -0.7907728571701835
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:42:45.697767
# [0.7590361445783134, 0.8311688311688312, 0.8051948051948052, 0.8192771084337349, 0.7733333333333333]
# 0.7976020445418036
# -0.7976020445418036 -0.7976020445418036
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:42:52.580835
# [0.7852760736196319, 0.8407643312101911, 0.8157894736842104, 0.8242424242424242, 0.758169934640523]
# 0.8048484474793961
# -0.8048484474793961 -0.8048484474793961
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e05565978>}
# 0.8387096774193548
# outer fold
# 2019-08-23 16:43:00.524722
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:43:00.798012
# [0.8050314465408805, 0.7875, 0.7701863354037267, 0.7651006711409395, 0.8165680473372782]
# 0.788877300084565
# -0.788877300084565 -0.788877300084565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:43:11.106529
# [0.8, 0.7901234567901234, 0.7749999999999999, 0.7712418300653595, 0.8165680473372782]
# 0.7905866668385523
# -0.7905866668385523 -0.7905866668385523
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:43:20.161910
# [0.7924528301886792, 0.7852760736196319, 0.7749999999999999, 0.7792207792207793, 0.8165680473372782]
# 0.7897035460732736
# -0.7897035460732736 -0.7905866668385523
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:43:29.580566
# [0.7924528301886792, 0.7804878048780488, 0.7530864197530863, 0.7320261437908497, 0.8070175438596491]
# 0.7730141484940626
# -0.7730141484940626 -0.7905866668385523
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:43:39.077455
# [0.8, 0.7852760736196319, 0.7798742138364779, 0.7662337662337663, 0.8235294117647058]
# 0.7909826930909164
# -0.7909826930909164 -0.7909826930909164
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:43:48.828623
# [0.8227848101265822, 0.8074534161490683, 0.7922077922077922, 0.7651006711409395, 0.8372093023255814]
# 0.8049511983899927
# -0.8049511983899927 -0.8049511983899927
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:43:57.920182
# [0.7924528301886792, 0.7804878048780488, 0.7682926829268293, 0.7402597402597403, 0.8070175438596491]
# 0.7777021204225893
# -0.7777021204225893 -0.8049511983899927
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:44:07.153963
# [0.7848101265822786, 0.773006134969325, 0.7804878048780488, 0.7368421052631579, 0.8235294117647058]
# 0.7797351166915032
# -0.7797351166915032 -0.8049511983899927
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:44:16.594864
# [0.8152866242038217, 0.782608695652174, 0.7866666666666667, 0.7733333333333333, 0.8538011695906432]
# 0.8023392978893279
# -0.8023392978893279 -0.8049511983899927
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:44:23.799403
# [0.8, 0.7852760736196319, 0.8108108108108107, 0.7832167832167831, 0.8690476190476191]
# 0.8096702573389691
# -0.8096702573389691 -0.8096702573389691
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec703f550>}
# 0.7999999999999999
# outer fold
# 2019-08-23 16:44:32.224189
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:44:32.508475
# [0.8322981366459627, 0.7875, 0.7901234567901234, 0.7654320987654321, 0.8516129032258065]
# 0.805393319085465
# -0.805393319085465 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:44:41.368215
# [0.8220858895705522, 0.7749999999999999, 0.7643312101910827, 0.7577639751552795, 0.8516129032258065]
# 0.7941587956285441
# -0.7941587956285441 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:44:50.391939
# [0.8220858895705522, 0.7804878048780488, 0.7625, 0.7577639751552795, 0.8421052631578947]
# 0.7929885865523549
# -0.7929885865523549 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:45:00.134698
# [0.8024691358024691, 0.7590361445783134, 0.7469879518072289, 0.7283950617283951, 0.8053691275167785]
# 0.768451484286637
# -0.768451484286637 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:45:09.839711
# [0.8098159509202455, 0.7757575757575756, 0.7701863354037267, 0.7421383647798742, 0.8421052631578947]
# 0.7880006980038633
# -0.7880006980038633 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:45:19.736786
# [0.825, 0.7926829268292682, 0.7875, 0.7515923566878981, 0.8496732026143791]
# 0.801289697226309
# -0.801289697226309 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:45:28.315704
# [0.7975460122699387, 0.7590361445783134, 0.7469879518072289, 0.7204968944099378, 0.8187919463087249]
# 0.7685717898748287
# -0.7685717898748287 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:45:37.256661
# [0.7975460122699387, 0.7590361445783134, 0.7530864197530863, 0.7283950617283951, 0.8344370860927153]
# 0.7745001448844897
# -0.7745001448844897 -0.805393319085465
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:45:46.805264
# [0.830188679245283, 0.8048780487804877, 0.7770700636942676, 0.7749999999999999, 0.8662420382165605]
# 0.8106757659873198
# -0.8106757659873198 -0.8106757659873198
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:45:54.441291
# [0.7926829268292682, 0.8023952095808382, 0.7770700636942676, 0.8076923076923077, 0.8741721854304636]
# 0.8108025386454291
# -0.8108025386454291 -0.8108025386454291
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec612d4a8>}
# 0.8167539267015707
# save to ../pickle/2019-08-23 16:46:04.479503.pickle
# save to ../csv/2019-08-23 16:46:04.508850.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.821   0.857          0.79        0.824         0.931    0.956
#
#   train_recall train_accuracy model1  \
# 0  0.908        0.932          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#               method  tag                                  pickle_path
# 0  [skip, nu, scale]  AMT  ../pickle/2019-08-23 16:46:04.479503.pickle
# save to ../csv/2019-08-23 16:46:04.623991.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.821   0.857          0.79        0.824         0.931    0.956
#
#   train_recall train_accuracy model1  \
# 0  0.908        0.932          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#               method  tag                                  pickle_path
# 0  [skip, nu, scale]  AMT  ../pickle/2019-08-23 16:46:04.479503.pickle
# time: 7min 40s

# %% [markdown]
# ### combination: NB-BoW word2vec Nutritions

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
model1 = salvador_wrap()
for method in [['wc','nb','wv','nu','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-22 13:23:41.857154
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:23:42.069352
# [0.8227848101265822, 0.7926829268292682, 0.8023952095808382, 0.8433734939759034, 0.8079470198675496]
# 0.8138366920760284
# -0.8138366920760284 -0.8138366920760284
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:24:18.525362
# [0.8125000000000001, 0.787878787878788, 0.8048780487804877, 0.8433734939759034, 0.8108108108108107]
# 0.8118882282891979
# -0.8118882282891979 -0.8138366920760284
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:24:56.100181
# [0.810126582278481, 0.787878787878788, 0.7904191616766467, 0.8433734939759034, 0.794701986754967]
# 0.8053000025129572
# -0.8053000025129572 -0.8138366920760284
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:25:32.937189
# [0.7654320987654321, 0.7810650887573963, 0.7784431137724551, 0.8220858895705522, 0.8026315789473685]
# 0.7899315539626409
# -0.7899315539626409 -0.8138366920760284
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:26:11.602774
# [0.8125000000000001, 0.787878787878788, 0.7831325301204819, 0.8363636363636364, 0.7866666666666667]
# 0.8013083242059146
# -0.8013083242059146 -0.8138366920760284
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:26:47.875895
# [0.830188679245283, 0.7901234567901234, 0.8343558282208587, 0.8466257668711655, 0.821917808219178]
# 0.8246423078693217
# -0.8246423078693217 -0.8246423078693217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:27:28.429660
# [0.7654320987654321, 0.7810650887573963, 0.7784431137724551, 0.8220858895705522, 0.8026315789473685]
# 0.7899315539626409
# -0.7899315539626409 -0.8246423078693217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:28:08.993349
# [0.782608695652174, 0.7857142857142857, 0.7831325301204819, 0.8292682926829269, 0.8104575163398693]
# 0.7982362641019474
# -0.7982362641019474 -0.8246423078693217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:28:51.021762
# [0.8125000000000001, 0.8050314465408805, 0.830188679245283, 0.8518518518518519, 0.84]
# 0.827914395527603
# -0.827914395527603 -0.827914395527603
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:29:32.005658
# [0.8072289156626505, 0.8152866242038217, 0.8516129032258065, 0.8518518518518519, 0.8266666666666667]
# 0.8305293923221594
# -0.8305293923221594 -0.8305293923221594
# {'model1': <models.features.salvador_wrap object at 0x7f9e07f8cc88>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e0817d898>}
# 0.8720379146919431
# outer fold
# 2019-08-22 13:30:22.391420
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:30:22.642614
# [0.8727272727272727, 0.8176100628930817, 0.8104575163398693, 0.8711656441717791, 0.8165680473372782]
# 0.8377057086938562
# -0.8377057086938562 -0.8377057086938562
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:31:03.516270
# [0.8727272727272727, 0.8271604938271605, 0.8, 0.8641975308641975, 0.8214285714285715]
# 0.8371027737694405
# -0.8371027737694405 -0.8377057086938562
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:31:47.485181
# [0.8622754491017963, 0.8050314465408805, 0.7973856209150327, 0.8588957055214724, 0.8242424242424242]
# 0.8295661292643214
# -0.8295661292643214 -0.8377057086938562
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:32:30.011742
# [0.8484848484848484, 0.8074534161490683, 0.7792207792207793, 0.8395061728395061, 0.7976190476190476]
# 0.8144568528626499
# -0.8144568528626499 -0.8377057086938562
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:33:11.627508
# [0.8622754491017963, 0.8148148148148148, 0.7894736842105262, 0.8518518518518519, 0.8242424242424242]
# 0.8285316448442825
# -0.8285316448442825 -0.8377057086938562
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:33:53.307075
# [0.8749999999999999, 0.8518518518518519, 0.7973856209150327, 0.8624999999999999, 0.8170731707317075]
# 0.8407621286997184
# -0.8407621286997184 -0.8407621286997184
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:34:37.379736
# [0.8554216867469879, 0.8050314465408805, 0.7792207792207793, 0.8414634146341464, 0.7976190476190476]
# 0.8157512749523683
# -0.8157512749523683 -0.8407621286997184
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:35:19.381703
# [0.8554216867469879, 0.8074534161490683, 0.7712418300653595, 0.8313253012048193, 0.8192771084337349]
# 0.8169438685199939
# -0.8169438685199939 -0.8407621286997184
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:36:01.944077
# [0.8860759493670887, 0.8641975308641975, 0.794701986754967, 0.8819875776397514, 0.8125000000000001]
# 0.847892608925201
# -0.847892608925201 -0.847892608925201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:36:43.750227
# [0.8774193548387097, 0.8749999999999999, 0.8, 0.8944099378881988, 0.8205128205128205]
# 0.8534684226479458
# -0.8534684226479458 -0.8534684226479458
# {'model1': <models.features.salvador_wrap object at 0x7f9e08022e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e054df2b0>}
# 0.8450704225352113
# outer fold
# 2019-08-22 13:37:36.182187
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:37:36.440991
# [0.7560975609756098, 0.8860759493670887, 0.8333333333333334, 0.8192771084337349, 0.7625]
# 0.8114567904219534
# -0.8114567904219534 -0.8114567904219534
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:38:19.380122
# [0.7484662576687118, 0.8749999999999999, 0.8333333333333334, 0.8263473053892216, 0.7701863354037267]
# 0.8106666463589987
# -0.8106666463589987 -0.8114567904219534
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:39:01.201947
# [0.7530864197530863, 0.8711656441717791, 0.8284023668639053, 0.8333333333333334, 0.7749999999999999]
# 0.8121975528244209
# -0.8121975528244209 -0.8121975528244209
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:39:43.961742
# [0.7484662576687118, 0.8121212121212122, 0.8192771084337349, 0.8214285714285715, 0.7625]
# 0.792758629930446
# -0.792758629930446 -0.8121975528244209
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:40:24.511011
# [0.7484662576687118, 0.8433734939759034, 0.8313253012048193, 0.8284023668639053, 0.7777777777777778]
# 0.8058690394982235
# -0.8058690394982235 -0.8121975528244209
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:41:08.445061
# [0.7926829268292682, 0.89171974522293, 0.8076923076923077, 0.8242424242424242, 0.7950310559006211]
# 0.8222736919775102
# -0.8222736919775102 -0.8222736919775102
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:41:50.545577
# [0.7407407407407407, 0.8121212121212122, 0.8192771084337349, 0.8214285714285715, 0.7625]
# 0.7912135265448519
# -0.7912135265448519 -0.8222736919775102
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:42:33.090525
# [0.7439024390243902, 0.8271604938271605, 0.8242424242424242, 0.8214285714285715, 0.773006134969325]
# 0.7979480126983743
# -0.7979480126983743 -0.8222736919775102
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:43:16.801132
# [0.7926829268292682, 0.8819875776397514, 0.823529411764706, 0.8313253012048193, 0.7975460122699387]
# 0.8254142459416969
# -0.8254142459416969 -0.8254142459416969
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:43:58.775800
# [0.8048780487804877, 0.8834355828220859, 0.8205128205128205, 0.8518518518518519, 0.8026315789473684]
# 0.8326619765829228
# -0.8326619765829228 -0.8326619765829228
# {'model1': <models.features.salvador_wrap object at 0x7f9ec6151f28>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec75d1320>}
# 0.8783068783068783
# outer fold
# 2019-08-22 13:44:50.672204
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:44:50.991759
# [0.8176100628930817, 0.8220858895705522, 0.8125000000000001, 0.7594936708860759, 0.8117647058823529]
# 0.8046908658464126
# -0.8046908658464126 -0.8046908658464126
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:45:32.781522
# [0.8176100628930817, 0.8121212121212122, 0.810126582278481, 0.7672955974842767, 0.7951807228915663]
# 0.8004668355337236
# -0.8004668355337236 -0.8046908658464126
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:46:14.530677
# [0.8227848101265822, 0.8024691358024691, 0.810126582278481, 0.7672955974842767, 0.7852760736196319]
# 0.7975904398622882
# -0.7975904398622882 -0.8046908658464126
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:46:56.767669
# [0.7948717948717949, 0.8098159509202455, 0.7974683544303799, 0.7341772151898733, 0.782608695652174]
# 0.7837884022128935
# -0.7837884022128935 -0.8046908658464126
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:47:38.141477
# [0.8227848101265822, 0.8024691358024691, 0.810126582278481, 0.7672955974842767, 0.7852760736196319]
# 0.7975904398622882
# -0.7975904398622882 -0.8046908658464126
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:48:19.940773
# [0.830188679245283, 0.8606060606060606, 0.825, 0.7692307692307692, 0.8372093023255814]
# 0.8244469622815387
# -0.8244469622815387 -0.8244469622815387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:49:02.413438
# [0.7948717948717949, 0.8024691358024691, 0.7974683544303799, 0.7341772151898733, 0.7901234567901234]
# 0.7838219914169281
# -0.7838219914169281 -0.8244469622815387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:49:40.841840
# [0.810126582278481, 0.7975460122699387, 0.8050314465408805, 0.7672955974842767, 0.7901234567901234]
# 0.7940246190727401
# -0.7940246190727401 -0.8244469622815387
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:50:23.575195
# [0.8500000000000001, 0.874251497005988, 0.8354430379746836, 0.7848101265822786, 0.8352941176470587]
# 0.8359597558420019
# -0.8359597558420019 -0.8359597558420019
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:51:03.512830
# [0.8466257668711655, 0.8690476190476191, 0.8266666666666668, 0.7741935483870969, 0.8414634146341464]
# 0.831599403121339
# -0.831599403121339 -0.8359597558420019
# {'model1': <models.features.salvador_wrap object at 0x7f9e0816ea90>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f9e08049b38>}
# 0.8442211055276382
# outer fold
# 2019-08-22 13:51:54.617910
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-22 13:51:54.881780
# [0.8484848484848484, 0.8192771084337349, 0.8176100628930817, 0.810126582278481, 0.8930817610062893]
# 0.8377160726192872
# -0.8377160726192872 -0.8377160726192872
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-22 13:52:38.328006
# [0.8554216867469879, 0.8242424242424242, 0.825, 0.8074534161490683, 0.8819875776397514]
# 0.8388210209556464
# -0.8388210209556464 -0.8388210209556464
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-22 13:53:20.763565
# [0.8606060606060606, 0.8170731707317075, 0.8148148148148148, 0.7975460122699387, 0.880503144654088]
# 0.8341086406153219
# -0.8341086406153219 -0.8388210209556464
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-22 13:54:01.485006
# [0.8170731707317075, 0.8098159509202455, 0.8024691358024691, 0.7701863354037267, 0.8749999999999999]
# 0.8149089185716297
# -0.8149089185716297 -0.8388210209556464
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-22 13:54:42.324964
# [0.8588957055214724, 0.8170731707317075, 0.8220858895705522, 0.7901234567901234, 0.8749999999999999]
# 0.8326356445227712
# -0.8326356445227712 -0.8388210209556464
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-22 13:55:22.235614
# [0.8780487804878048, 0.8433734939759034, 0.8152866242038217, 0.830188679245283, 0.9113924050632912]
# 0.8556579965952208
# -0.8556579965952208 -0.8556579965952208
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-22 13:56:06.387350
# [0.8292682926829269, 0.8170731707317075, 0.8098159509202455, 0.7852760736196319, 0.8749999999999999]
# 0.8232866975909022
# -0.8232866975909022 -0.8556579965952208
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-22 13:56:46.412081
# [0.8466257668711655, 0.8220858895705522, 0.8098159509202455, 0.7901234567901234, 0.8749999999999999]
# 0.8287302128304173
# -0.8287302128304173 -0.8556579965952208
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-22 13:57:27.246364
# [0.8848484848484849, 0.8333333333333334, 0.8227848101265822, 0.8322981366459627, 0.9249999999999999]
# 0.8596529529908727
# -0.8596529529908727 -0.8596529529908727
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-22 13:58:07.815172
# [0.8571428571428572, 0.8170731707317075, 0.8333333333333334, 0.8466257668711655, 0.9240506329113924]
# 0.8556451521980912
# -0.8556451521980912 -0.8596529529908727
# {'model1': <models.features.salvador_wrap object at 0x7f9ec6d4eb38>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f9e08251ba8>}
# 0.8062827225130891
# save to ../pickle/2019-08-22 13:58:57.413917.pickle
# save to ../csv/2019-08-22 13:58:57.997331.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.849   0.861          0.842       0.847         0.933    0.939
#
#   train_recall train_accuracy  \
# 0  0.928        0.933
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9ef020b3c8>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                     method  tag                                  pickle_path
# 0  [wc, nb, wv, nu, scale]  AMT  ../pickle/2019-08-22 13:58:57.413917.pickle
# save to ../csv/2019-08-22 13:58:58.023957.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.849   0.861          0.842       0.847         0.933    0.939
#
#   train_recall train_accuracy  \
# 0  0.928        0.933
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9ef020b3c8>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                     method  tag                                  pickle_path
# 0  [wc, nb, wv, nu, scale]  AMT  ../pickle/2019-08-22 13:58:57.413917.pickle
# time: 35min 27s

# %% [markdown]
# ### everything

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', add_skip_thoughts='../data/X_skipthoughts_25k.pickle')
knowns = corp0.knowns
state = 2022
model1 = salvador_wrap()
for method in [['wc','nb','wv','nu','skip','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-23 16:57:16.679679
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:57:16.958524
# [0.8047337278106509, 0.7560975609756098, 0.7701863354037267, 0.8292682926829269, 0.8025477707006369]
# 0.7925667375147103
# -0.7925667375147103 -0.7925667375147103
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:58:08.376041
# [0.7976190476190476, 0.7636363636363638, 0.7654320987654321, 0.8214285714285715, 0.8025477707006369]
# 0.7901327704300104
# -0.7901327704300104 -0.7925667375147103
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:58:59.930365
# [0.7976190476190476, 0.7590361445783134, 0.75, 0.8263473053892216, 0.7974683544303798]
# 0.7860941704033925
# -0.7860941704033925 -0.7925667375147103
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:59:52.102435
# [0.7701863354037267, 0.757396449704142, 0.7295597484276728, 0.8095238095238094, 0.7898089171974523]
# 0.7712950520513606
# -0.7712950520513606 -0.7925667375147103
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 17:00:42.355988
# [0.787878787878788, 0.7590361445783134, 0.75, 0.8263473053892216, 0.7924528301886793]
# 0.7831430136070004
# -0.7831430136070004 -0.7925667375147103
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 17:01:34.485145
# [0.7804878048780488, 0.7636363636363638, 0.782051282051282, 0.8292682926829269, 0.8258064516129033]
# 0.7962500389723051
# -0.7962500389723051 -0.7962500389723051
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 17:02:26.402898
# [0.7777777777777778, 0.7647058823529411, 0.7295597484276728, 0.8095238095238094, 0.7974683544303798]
# 0.775807114502516
# -0.775807114502516 -0.7962500389723051
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 17:03:17.280208
# [0.787878787878788, 0.7664670658682634, 0.7374999999999999, 0.8165680473372782, 0.7848101265822786]
# 0.7786448055333216
# -0.7786448055333216 -0.7962500389723051
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 17:04:08.819550
# [0.8023952095808382, 0.7926829268292682, 0.7974683544303799, 0.8313253012048193, 0.8079470198675496]
# 0.8063637623825711
# -0.8063637623825711 -0.8063637623825711
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 17:04:59.620253
# [0.8170731707317075, 0.7974683544303799, 0.8258064516129032, 0.8433734939759034, 0.8427672955974843]
# 0.8252977532696757
# -0.8252977532696757 -0.8252977532696757
# {'model1': <models.features.salvador_wrap object at 0x7f9ec5b2b1d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9ec5b27cc0>}
# 0.8502415458937198
# outer fold
# 2019-08-23 17:06:00.769517
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 17:06:01.043548
# [0.8322981366459627, 0.8143712574850299, 0.7755102040816326, 0.8518518518518519, 0.75]
# 0.8048062900128954
# -0.8048062900128954 -0.8048062900128954
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 17:06:53.691863
# [0.8198757763975155, 0.8143712574850299, 0.7702702702702703, 0.8466257668711655, 0.757396449704142]
# 0.8017079041456248
# -0.8017079041456248 -0.8048062900128954
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 17:07:43.450742
# [0.8170731707317075, 0.8095238095238094, 0.7702702702702703, 0.8395061728395061, 0.7647058823529411]
# 0.800215861143647
# -0.800215861143647 -0.8048062900128954
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 17:08:33.802373
# [0.7951807228915663, 0.7784431137724551, 0.7671232876712328, 0.8242424242424242, 0.7810650887573963]
# 0.789210927467015
# -0.789210927467015 -0.8048062900128954
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 17:09:22.612147
# [0.8170731707317075, 0.7976190476190476, 0.7702702702702703, 0.8395061728395061, 0.7784431137724551]
# 0.8005823550465972
# -0.8005823550465972 -0.8048062900128954
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 17:10:14.136008
# [0.830188679245283, 0.8192771084337349, 0.7755102040816326, 0.8571428571428572, 0.7469879518072289]
# 0.8058213601421473
# -0.8058213601421473 -0.8058213601421473
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 17:11:03.393188
# [0.787878787878788, 0.787878787878788, 0.7671232876712328, 0.8074534161490683, 0.7882352941176471]
# 0.7877139147391048
# -0.7877139147391048 -0.8058213601421473
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 17:11:53.215260
# [0.8098159509202455, 0.8, 0.7733333333333333, 0.8343558282208587, 0.7810650887573963]
# 0.7997140402463668
# -0.7997140402463668 -0.8058213601421473
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 17:12:45.471241
# [0.825, 0.8242424242424242, 0.7651006711409395, 0.8536585365853657, 0.7664670658682634]
# 0.8068937395673986
# -0.8068937395673986 -0.8068937395673986
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 17:13:35.400982
# [0.8181818181818182, 0.8343558282208587, 0.7682119205298013, 0.8780487804878048, 0.7804878048780488]
# 0.8158572304596664
# -0.8158572304596664 -0.8158572304596664
# {'model1': <models.features.salvador_wrap object at 0x7f9e66a03fd0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9df41556d8>}
# 0.8431372549019608
# outer fold
# 2019-08-23 17:14:35.598111
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 17:14:35.978280
# [0.7607361963190185, 0.858974358974359, 0.7672955974842767, 0.8606060606060606, 0.7950310559006211]
# 0.808528653856867
# -0.808528653856867 -0.808528653856867
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 17:15:28.325385
# [0.7654320987654321, 0.858974358974359, 0.7672955974842767, 0.8606060606060606, 0.8050314465408805]
# 0.8114679124742017
# -0.8114679124742017 -0.8114679124742017
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 17:16:20.141697
# [0.7607361963190185, 0.858974358974359, 0.7672955974842767, 0.8536585365853657, 0.7974683544303799]
# 0.8076266087586799
# -0.8076266087586799 -0.8114679124742017
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 17:17:12.712672
# [0.7590361445783134, 0.8258064516129032, 0.7798742138364779, 0.8047337278106509, 0.7701863354037267]
# 0.7879273746484144
# -0.7879273746484144 -0.8114679124742017
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 17:18:04.569158
# [0.7607361963190185, 0.858974358974359, 0.7721518987341771, 0.8333333333333334, 0.8]
# 0.8050391574721777
# -0.8050391574721777 -0.8114679124742017
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 17:18:57.841832
# [0.7625, 0.8461538461538461, 0.7875, 0.8588957055214724, 0.8024691358024691]
# 0.8115037374955575
# -0.8115037374955575 -0.8115037374955575
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 17:19:50.183699
# [0.7590361445783134, 0.8461538461538461, 0.7798742138364779, 0.8117647058823529, 0.782608695652174]
# 0.7958875212206328
# -0.7958875212206328 -0.8115037374955575
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 17:20:41.938257
# [0.7852760736196319, 0.8535031847133758, 0.7770700636942676, 0.8192771084337349, 0.7692307692307692]
# 0.8008714399383561
# -0.8008714399383561 -0.8115037374955575
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 17:21:33.662665
# [0.7654320987654321, 0.8387096774193549, 0.8050314465408805, 0.8588957055214724, 0.7999999999999999]
# 0.813613785649428
# -0.813613785649428 -0.813613785649428
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 17:22:25.629817
# [0.7798742138364779, 0.8344370860927153, 0.8333333333333334, 0.8711656441717791, 0.7777777777777778]
# 0.8193176110424167
# -0.8193176110424167 -0.8193176110424167
# {'model1': <models.features.salvador_wrap object at 0x7f9e70dfe940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e669ec8d0>}
# 0.8526315789473684
# outer fold
# 2019-08-23 17:23:28.903501
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 17:23:29.194505
# [0.8, 0.8354430379746836, 0.8048780487804877, 0.7843137254901961, 0.8554913294797687]
# 0.8160252283450273
# -0.8160252283450273 -0.8160252283450273
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 17:24:23.211104
# [0.7948717948717949, 0.830188679245283, 0.8098159509202455, 0.7814569536423841, 0.8554913294797687]
# 0.8143649416318952
# -0.8143649416318952 -0.8160252283450273
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 17:25:18.295877
# [0.802547770700637, 0.8227848101265822, 0.8098159509202455, 0.7866666666666667, 0.8554913294797687]
# 0.81546130557878
# -0.81546130557878 -0.8160252283450273
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 17:26:09.551395
# [0.7875, 0.8050314465408805, 0.7975460122699387, 0.7516778523489933, 0.8095238095238094]
# 0.7902558241367243
# -0.7902558241367243 -0.8160252283450273
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 17:27:02.706252
# [0.802547770700637, 0.8152866242038217, 0.8170731707317075, 0.7814569536423841, 0.8554913294797687]
# 0.8143711697516638
# -0.8143711697516638 -0.8160252283450273
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 17:27:56.869041
# [0.8205128205128205, 0.8280254777070064, 0.8148148148148148, 0.7919463087248322, 0.8654970760233919]
# 0.8241592995565732
# -0.8241592995565732 -0.8241592995565732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 17:28:49.293840
# [0.7875, 0.8050314465408805, 0.8024691358024691, 0.76, 0.8165680473372782]
# 0.7943137259361256
# -0.7943137259361256 -0.8241592995565732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 17:29:42.019449
# [0.8050314465408805, 0.8205128205128205, 0.8098159509202455, 0.7682119205298013, 0.8470588235294118]
# 0.810126192406632
# -0.810126192406632 -0.8241592995565732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 17:30:34.646137
# [0.8311688311688312, 0.8354430379746836, 0.8220858895705522, 0.7919463087248322, 0.8639053254437871]
# 0.8289098785765372
# -0.8289098785765372 -0.8289098785765372
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 17:31:26.238108
# [0.8024691358024691, 0.8176100628930817, 0.8518518518518519, 0.8026315789473684, 0.8780487804878048]
# 0.830522281996515
# -0.830522281996515 -0.830522281996515
# {'model1': <models.features.salvador_wrap object at 0x7f9e7270c668>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e571d4978>}
# 0.83248730964467
# outer fold
# 2019-08-23 17:32:28.375945
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 17:32:28.715726
# [0.8214285714285715, 0.7976190476190476, 0.782608695652174, 0.7924528301886792, 0.880503144654088]
# 0.8149224579085119
# -0.8149224579085119 -0.8149224579085119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 17:33:22.514317
# [0.8214285714285715, 0.7976190476190476, 0.782608695652174, 0.7898089171974522, 0.880503144654088]
# 0.8143936753102666
# -0.8143936753102666 -0.8149224579085119
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 17:34:15.590477
# [0.8292682926829269, 0.7976190476190476, 0.7749999999999999, 0.8024691358024691, 0.880503144654088]
# 0.8169719241517063
# -0.8169719241517063 -0.8169719241517063
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 17:35:08.105330
# [0.8143712574850299, 0.787878787878788, 0.7577639751552795, 0.7875, 0.858974358974359]
# 0.8012976758986913
# -0.8012976758986913 -0.8169719241517063
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 17:36:00.972703
# [0.8214285714285715, 0.7928994082840236, 0.782608695652174, 0.7852760736196319, 0.880503144654088]
# 0.8125431787276979
# -0.8125431787276979 -0.8169719241517063
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 17:36:53.993552
# [0.8263473053892216, 0.8095238095238094, 0.8050314465408805, 0.8074534161490683, 0.8789808917197451]
# 0.8254673738645449
# -0.8254673738645449 -0.8254673738645449
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 17:37:47.491606
# [0.8143712574850299, 0.787878787878788, 0.7625, 0.7974683544303799, 0.858974358974359]
# 0.8042385517537113
# -0.8042385517537113 -0.8254673738645449
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 17:38:38.678758
# [0.8143712574850299, 0.7831325301204819, 0.7749999999999999, 0.7852760736196319, 0.8571428571428571]
# 0.8029845436736001
# -0.8029845436736001 -0.8254673738645449
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 17:39:30.255306
# [0.8313253012048193, 0.8117647058823529, 0.8152866242038217, 0.8074534161490683, 0.8846153846153846]
# 0.8300890864110894
# -0.8300890864110894 -0.8300890864110894
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 17:40:24.952044
# [0.8165680473372782, 0.8214285714285715, 0.8227848101265822, 0.8343558282208587, 0.8831168831168831]
# 0.8356508280460346
# -0.8356508280460346 -0.8356508280460346
# {'model1': <models.features.salvador_wrap object at 0x7f9e70ddcd30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'nb', 'wv', 'nu', 'skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f9e6d7264a8>}
# 0.8307692307692307
# save to ../pickle/2019-08-23 17:41:26.141749.pickle
# save to ../csv/2019-08-23 17:41:26.672168.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.842   0.86           0.826       0.841         0.953    0.964
#
#   train_recall train_accuracy  \
# 0  0.942        0.953
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9e07f8c0b8>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                           method  tag  \
# 0  [wc, nb, wv, nu, skip, scale]  AMT
#
#                                    pickle_path
# 0  ../pickle/2019-08-23 17:41:26.141749.pickle
# save to ../csv/2019-08-23 17:41:26.704592.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.842   0.86           0.826       0.841         0.953    0.964
#
#   train_recall train_accuracy  \
# 0  0.942        0.953
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f9e07f8c0b8>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#                           method  tag  \
# 0  [wc, nb, wv, nu, skip, scale]  AMT
#
#                                    pickle_path
# 0  ../pickle/2019-08-23 17:41:26.141749.pickle
# time: 44min 24s

# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap, doc2vec_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 6.91 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 16.8 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
model1s = [load_pickle('../data/doc2vec_%.2d'% (number)) for number in range(1,8+1,1)]

def inner_CV_for_model1(corp, model1, method):
    print('inner_CV_for_model1')
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    '''
    p2_lr = {'class_weight':'balanced','solver': 'liblinear', 'penalty':'l2'}
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning model1
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8)
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    print('inner_CV_for_model2')
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning p2: the params for model2
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 12:58:54.467966
# inner_CV_for_model1
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 12:58:54.752416
# [0.6540880503144653, 0.6265060240963856, 0.6962025316455697, 0.6538461538461539, 0.6582278481012659]
# 0.657774121600768
# -0.657774121600768 -0.657774121600768 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d303ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:00:39.949233
# [0.6871165644171778, 0.7044025157232704, 0.7594936708860759, 0.757396449704142, 0.7074829931972789]
# 0.723178438785589
# -0.723178438785589 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:01:15.706843
# [0.5280898876404495, 0.574585635359116, 0.5529411764705882, 0.6162162162162163, 0.5828571428571427]
# 0.5709380117087025
# -0.5709380117087025 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:01:48.313362
# [0.47560975609756095, 0.5317919075144509, 0.5257142857142857, 0.5934065934065934, 0.5524861878453039]
# 0.535801746115639
# -0.535801746115639 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:03:27.022123
# [0.6143790849673203, 0.6547619047619048, 0.7374999999999999, 0.5806451612903225, 0.6419753086419754]
# 0.6458522919323045
# -0.6458522919323045 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d30f470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:05:19.080337
# [0.5421686746987951, 0.544378698224852, 0.6127167630057804, 0.558139534883721, 0.5697674418604651]
# 0.5654342225347226
# -0.5654342225347226 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e9448d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:05:51.904842
# [0.536312849162011, 0.5604395604395604, 0.6455026455026455, 0.5762711864406779, 0.5380116959064327]
# 0.5713075874902656
# -0.5713075874902656 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dc53240>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:07:34.108898
# [0.5310734463276836, 0.5146198830409356, 0.5888888888888889, 0.4875, 0.5988700564971751]
# 0.5441904549509367
# -0.5441904549509367 -0.723178438785589 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d572080>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141ce3fe10>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 13:09:17.836739
# [0.6923076923076923, 0.7073170731707318, 0.7402597402597403, 0.757396449704142, 0.7346938775510204]
# 0.7263949665986653
# -0.7263949665986653 -0.7263949665986653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 13:09:56.912471
# [0.6871165644171778, 0.7044025157232704, 0.7594936708860759, 0.757396449704142, 0.7074829931972789]
# 0.723178438785589
# -0.723178438785589 -0.7263949665986653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 13:10:33.039824
# [0.6329113924050632, 0.6666666666666667, 0.7402597402597403, 0.7176470588235295, 0.7058823529411764]
# 0.6926734422192352
# -0.6926734422192352 -0.7263949665986653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 13:11:08.394483
# [0.5695364238410596, 0.5714285714285714, 0.6405228758169934, 0.6748466257668712, 0.5882352941176471]
# 0.6089139581942286
# -0.6089139581942286 -0.7263949665986653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 13:11:49.288310
# [0.6308724832214765, 0.6835443037974684, 0.7105263157894737, 0.6863905325443787, 0.6794871794871794]
# 0.6781641629679953
# -0.6781641629679953 -0.7263949665986653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 13:12:25.384534
# [0.6829268292682926, 0.7116564417177914, 0.7483870967741936, 0.7544910179640719, 0.7814569536423841]
# 0.7357836678733467
# -0.7357836678733467 -0.7357836678733467
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 13:13:01.347757
# [0.5733333333333334, 0.5810810810810811, 0.641025641025641, 0.6748466257668712, 0.6064516129032258]
# 0.6153476588220305
# -0.6153476588220305 -0.7357836678733467
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 13:13:42.930752
# [0.5599999999999999, 0.6092715231788078, 0.6623376623376623, 0.6946107784431137, 0.6103896103896105]
# 0.6273219148698388
# -0.6273219148698388 -0.7357836678733467
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 13:14:21.805559
# [0.6951219512195121, 0.7073170731707318, 0.7320261437908497, 0.7664670658682634, 0.8051948051948051]
# 0.7412254078488324
# -0.7412254078488324 -0.7412254078488324
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 13:14:58.860791
# [0.717948717948718, 0.7160493827160493, 0.7515151515151515, 0.7784431137724551, 0.794701986754967]
# 0.7517316705414683
# -0.7517316705414683 -0.7517316705414683
# {'model1': <models.features.doc2vec_wrap object at 0x7f141cf9ceb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f141db61e80>}
# 0.763819095477387
# outer fold
# 2019-08-21 13:15:44.286416
# inner_CV_for_model1
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:15:44.699016
# [0.6493506493506493, 0.7, 0.5866666666666667, 0.7261904761904762, 0.6503067484662577]
# 0.6625029081348099
# -0.6625029081348099 -0.6625029081348099 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d303ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:17:33.700488
# [0.7320261437908497, 0.7411764705882353, 0.6535947712418301, 0.8143712574850299, 0.7225806451612903]
# 0.732749857653447
# -0.732749857653447 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:18:10.123649
# [0.5795454545454546, 0.5714285714285714, 0.5146198830409356, 0.5662650602409638, 0.5783132530120482]
# 0.5620344444535947
# -0.5620344444535947 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:18:42.995788
# [0.5714285714285714, 0.6373626373626373, 0.5517241379310345, 0.5251396648044692, 0.5668449197860963]
# 0.5704999862625617
# -0.5704999862625617 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:20:23.039980
# [0.5827814569536424, 0.6956521739130435, 0.5675675675675675, 0.7133757961783439, 0.6582278481012659]
# 0.6435209685427725
# -0.6435209685427725 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d30f470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:22:08.872194
# [0.5454545454545455, 0.5608465608465609, 0.485207100591716, 0.5681818181818182, 0.5172413793103449]
# 0.535386280876997
# -0.535386280876997 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e9448d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:22:43.010725
# [0.5465116279069768, 0.5061728395061729, 0.5862068965517241, 0.5730337078651686, 0.5966850828729282]
# 0.561722030940594
# -0.561722030940594 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141dd15320>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:24:25.438910
# [0.5837837837837838, 0.5934065934065934, 0.5913978494623656, 0.5649717514124294, 0.5276073619631901]
# 0.5722334680056724
# -0.5722334680056724 -0.732749857653447 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d05fc18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141ce51a58>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 13:26:08.125343
# [0.7798742138364779, 0.7664670658682634, 0.6535947712418301, 0.8023952095808382, 0.7142857142857143]
# 0.7433233949626248
# -0.7433233949626248 -0.7433233949626248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 13:26:44.363129
# [0.7320261437908497, 0.7411764705882353, 0.6535947712418301, 0.8143712574850299, 0.7225806451612903]
# 0.732749857653447
# -0.732749857653447 -0.7433233949626248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 13:27:19.997313
# [0.7058823529411765, 0.7411764705882353, 0.6363636363636364, 0.8023255813953489, 0.7133757961783439]
# 0.7198247674933482
# -0.7198247674933482 -0.7433233949626248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 13:27:56.818414
# [0.6951219512195121, 0.7052023121387283, 0.6792452830188679, 0.7239263803680983, 0.6496815286624203]
# 0.6906354910815253
# -0.6906354910815253 -0.7433233949626248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 13:28:36.894473
# [0.7169811320754716, 0.7514450867052024, 0.6535947712418301, 0.7784431137724551, 0.7051282051282051]
# 0.7211184617846328
# -0.7211184617846328 -0.7433233949626248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 13:29:13.624115
# [0.7631578947368421, 0.7757575757575756, 0.6712328767123288, 0.7928994082840236, 0.7215189873417721]
# 0.7449133485665085
# -0.7449133485665085 -0.7449133485665085
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 13:29:49.533605
# [0.6993865030674846, 0.7093023255813952, 0.6708860759493671, 0.7239263803680983, 0.6496815286624203]
# 0.6906365627257531
# -0.6906365627257531 -0.7449133485665085
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 13:30:28.840596
# [0.6956521739130435, 0.7134502923976608, 0.6624203821656051, 0.7590361445783134, 0.6624203821656051]
# 0.6985958750440455
# -0.6985958750440455 -0.7449133485665085
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 13:31:06.937192
# [0.7792207792207793, 0.7682926829268293, 0.6714285714285715, 0.8170731707317075, 0.7283950617283951]
# 0.7528820532072567
# -0.7528820532072567 -0.7528820532072567
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 13:31:42.854781
# [0.7643312101910827, 0.7682926829268293, 0.697986577181208, 0.8143712574850299, 0.7349397590361447]
# 0.755984297364059
# -0.755984297364059 -0.755984297364059
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6e90f0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f141d5fff28>}
# 0.7464114832535885
# outer fold
# 2019-08-21 13:32:27.343792
# inner_CV_for_model1
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:32:27.615823
# [0.6341463414634146, 0.7037037037037037, 0.5974025974025974, 0.675, 0.6666666666666667]
# 0.6553838618472765
# -0.6553838618472765 -0.6553838618472765 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d303ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:34:18.654553
# [0.670807453416149, 0.76, 0.7314285714285713, 0.6875000000000001, 0.7261904761904762]
# 0.7151853002070393
# -0.7151853002070393 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:34:54.049951
# [0.5813953488372093, 0.6179775280898876, 0.5433526011560693, 0.4971751412429379, 0.5497076023391813]
# 0.5579216443330571
# -0.5579216443330571 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:35:28.474058
# [0.5057471264367815, 0.5333333333333333, 0.46540880503144655, 0.4819277108433735, 0.5029239766081872]
# 0.4978681904506244
# -0.4978681904506244 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:37:14.413940
# [0.6172839506172839, 0.7261146496815287, 0.6385542168674699, 0.6818181818181818, 0.6982248520710058]
# 0.672399170211094
# -0.672399170211094 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d30f470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:39:03.636933
# [0.4823529411764706, 0.5301204819277108, 0.5454545454545454, 0.4779874213836478, 0.535031847133758]
# 0.5141894474152264
# -0.5141894474152264 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e9448d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:39:38.017323
# [0.5555555555555556, 0.5084745762711864, 0.56, 0.5, 0.5333333333333333]
# 0.531472693032015
# -0.531472693032015 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f14d971fa90>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:41:23.764038
# [0.5681818181818182, 0.5966850828729282, 0.5487804878048781, 0.5402298850574713, 0.511904761904762]
# 0.5531564071643715
# -0.5531564071643715 -0.7151853002070393 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141ce089b0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d15df98>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 13:43:08.626109
# [0.6787878787878788, 0.7763157894736843, 0.7398843930635839, 0.7, 0.7485380116959064]
# 0.7287052146042108
# -0.7287052146042108 -0.7287052146042108
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 13:43:44.940120
# [0.670807453416149, 0.76, 0.7314285714285713, 0.6875000000000001, 0.7261904761904762]
# 0.7151853002070393
# -0.7151853002070393 -0.7287052146042108
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 13:44:22.015204
# [0.6545454545454545, 0.7210884353741497, 0.6904761904761905, 0.6751592356687897, 0.7307692307692308]
# 0.6944077093667631
# -0.6944077093667631 -0.7287052146042108
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 13:44:59.131271
# [0.6144578313253012, 0.6233766233766234, 0.5925925925925926, 0.606060606060606, 0.675]
# 0.6222975306710247
# -0.6222975306710247 -0.7287052146042108
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 13:45:41.134668
# [0.6419753086419753, 0.6973684210526315, 0.6909090909090909, 0.670807453416149, 0.6956521739130435]
# 0.6793424895865781
# -0.6793424895865781 -0.7287052146042108
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 13:46:19.397486
# [0.6987951807228916, 0.7973856209150327, 0.7250000000000001, 0.7261146496815287, 0.782051282051282]
# 0.7458693466741471
# -0.7458693466741471 -0.7458693466741471
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 13:46:56.094468
# [0.6227544910179641, 0.6363636363636364, 0.5925925925925926, 0.6097560975609756, 0.675]
# 0.6272933635070338
# -0.6272933635070338 -0.7458693466741471
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 13:47:36.759974
# [0.6097560975609756, 0.6184210526315791, 0.6086956521739131, 0.6335403726708074, 0.6871165644171778]
# 0.6315059478908907
# -0.6315059478908907 -0.7458693466741471
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 13:48:16.981907
# [0.7195121951219512, 0.7866666666666667, 0.7544910179640719, 0.7133757961783439, 0.7870967741935484]
# 0.7522284900249164
# -0.7522284900249164 -0.7522284900249164
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 13:48:52.750487
# [0.7142857142857143, 0.802547770700637, 0.7272727272727273, 0.7295597484276728, 0.7894736842105262]
# 0.7526279289794554
# -0.7526279289794554 -0.7526279289794554
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6b2f98>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f141ce61358>}
# 0.7434554973821988
# outer fold
# 2019-08-21 13:49:39.251138
# inner_CV_for_model1
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:49:39.588104
# [0.6506024096385542, 0.6549707602339181, 0.6347305389221557, 0.6163522012578617, 0.6666666666666667]
# 0.6446645153438313
# -0.6446645153438313 -0.6446645153438313 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d303ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:51:30.061024
# [0.7080745341614907, 0.7901234567901234, 0.717948717948718, 0.6753246753246753, 0.7484662576687118]
# 0.7279875283787438
# -0.7279875283787438 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:52:06.276493
# [0.6136363636363636, 0.4550898203592814, 0.5766871165644172, 0.535031847133758, 0.5325443786982248]
# 0.542597905278409
# -0.542597905278409 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:52:40.024055
# [0.6010928961748634, 0.5380116959064328, 0.5714285714285714, 0.5061728395061729, 0.6043956043956045]
# 0.5642203214823289
# -0.5642203214823289 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:54:24.976655
# [0.6265060240963856, 0.654320987654321, 0.6588235294117647, 0.6967741935483871, 0.7006369426751592]
# 0.6674123354772035
# -0.6674123354772035 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d30f470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:56:15.930461
# [0.5604395604395604, 0.5113636363636364, 0.509090909090909, 0.5185185185185185, 0.4795321637426901]
# 0.5157889576310628
# -0.5157889576310628 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e9448d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:56:50.547071
# [0.5454545454545455, 0.5093167701863354, 0.5476190476190477, 0.5100671140939597, 0.5930232558139535]
# 0.5410961466335683
# -0.5410961466335683 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d03fa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 13:58:36.161331
# [0.5202312138728324, 0.5795454545454546, 0.4585987261146497, 0.4651162790697674, 0.5257142857142857]
# 0.509841191863398
# -0.509841191863398 -0.7279875283787438 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c2ba8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d2072e8>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 14:00:20.056742
# [0.7151515151515152, 0.7749999999999999, 0.7388535031847134, 0.6967741935483871, 0.7407407407407407]
# 0.7333039905250713
# -0.7333039905250713 -0.7333039905250713
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 14:00:56.250062
# [0.7080745341614907, 0.7901234567901234, 0.717948717948718, 0.6753246753246753, 0.7484662576687118]
# 0.7279875283787438
# -0.7279875283787438 -0.7333039905250713
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 14:01:33.883696
# [0.6956521739130435, 0.7875, 0.7225806451612903, 0.6875000000000001, 0.7515151515151515]
# 0.7289495941178971
# -0.7289495941178971 -0.7333039905250713
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 14:02:11.272836
# [0.6419753086419753, 0.691358024691358, 0.6962025316455697, 0.6329113924050632, 0.7160493827160493]
# 0.6756993280200031
# -0.6756993280200031 -0.7333039905250713
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 14:02:53.170551
# [0.654320987654321, 0.7682926829268293, 0.7215189873417721, 0.6666666666666667, 0.7393939393939394]
# 0.7100386527967057
# -0.7100386527967057 -0.7333039905250713
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 14:03:30.249459
# [0.7719298245614035, 0.7484662576687118, 0.758169934640523, 0.7044025157232704, 0.7453416149068324]
# 0.7456620295001481
# -0.7456620295001481 -0.7456620295001481
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 14:04:05.713634
# [0.6419753086419753, 0.7037037037037037, 0.7044025157232704, 0.6496815286624203, 0.7160493827160493]
# 0.6831624878894839
# -0.6831624878894839 -0.7456620295001481
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 14:04:45.381125
# [0.6463414634146342, 0.7272727272727273, 0.6794871794871794, 0.6666666666666667, 0.7239263803680983]
# 0.6887388834418612
# -0.6887388834418612 -0.7456620295001481
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 14:05:24.176966
# [0.7882352941176471, 0.7515151515151515, 0.7549668874172185, 0.6792452830188679, 0.7515923566878981]
# 0.7451109945513567
# -0.7451109945513567 -0.7456620295001481
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 14:05:59.509985
# [0.8121212121212122, 0.7393939393939394, 0.7295597484276728, 0.697986577181208, 0.7453416149068324]
# 0.7448806184061729
# -0.7448806184061729 -0.7456620295001481
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d05b2e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f141d5fd080>}
# 0.746268656716418
# outer fold
# 2019-08-21 14:06:43.672567
# inner_CV_for_model1
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e80>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:06:44.034181
# [0.6025641025641025, 0.6951219512195121, 0.675, 0.6419753086419753, 0.6335403726708074]
# 0.6496403470192795
# -0.6496403470192795 -0.6496403470192795 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d303ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:08:33.200162
# [0.7006369426751592, 0.7848101265822786, 0.7453416149068324, 0.6967741935483871, 0.7469879518072289]
# 0.7349101659039772
# -0.7349101659039772 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:09:09.033686
# [0.5666666666666667, 0.5764705882352942, 0.6067415730337078, 0.6057142857142858, 0.49681528662420377]
# 0.5704816800548316
# -0.5704816800548316 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e944550>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:09:43.359421
# [0.5517241379310345, 0.572972972972973, 0.5747126436781608, 0.536312849162011, 0.562874251497006]
# 0.5597193710482371
# -0.5597193710482371 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:11:25.599421
# [0.6375, 0.670807453416149, 0.7515151515151515, 0.6385542168674699, 0.5786163522012578]
# 0.6553986348000056
# -0.6553986348000056 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f149d30f470>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:13:15.212360
# [0.5287356321839082, 0.5683060109289617, 0.550561797752809, 0.5398773006134969, 0.6067415730337078]
# 0.5588444629025767
# -0.5588444629025767 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e9448d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:13:48.637199
# [0.5303867403314917, 0.5730337078651686, 0.5798816568047338, 0.5116279069767442, 0.5485714285714286]
# 0.5487002881099133
# -0.5487002881099133 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14091a6eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d6bc6a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 14:15:31.091003
# [0.46540880503144655, 0.5989304812834225, 0.39751552795031053, 0.5084745762711864, 0.5833333333333334]
# 0.5107325447739399
# -0.5107325447739399 -0.7349101659039772 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d96c1a20>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f141d74b518>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 14:17:15.369019
# [0.6962025316455697, 0.7770700636942676, 0.7682119205298013, 0.7236842105263157, 0.7692307692307692]
# 0.7468798991253447
# -0.7468798991253447 -0.7468798991253447
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 14:17:51.244528
# [0.7006369426751592, 0.7848101265822786, 0.7453416149068324, 0.6967741935483871, 0.7469879518072289]
# 0.7349101659039772
# -0.7349101659039772 -0.7468798991253447
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 14:18:27.771202
# [0.7125, 0.7421383647798742, 0.7453416149068324, 0.6794871794871794, 0.7125]
# 0.7183934318347772
# -0.7183934318347772 -0.7468798991253447
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 14:19:03.829192
# [0.6666666666666667, 0.7037037037037037, 0.6829268292682926, 0.5866666666666667, 0.6871165644171778]
# 0.6654160861445015
# -0.6654160861445015 -0.7468798991253447
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 14:19:44.414582
# [0.6835443037974684, 0.7407407407407407, 0.7272727272727273, 0.6122448979591836, 0.6918238993710691]
# 0.6911253138282378
# -0.6911253138282378 -0.7468798991253447
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 14:20:21.786503
# [0.7088607594936708, 0.7466666666666666, 0.7948717948717949, 0.7757575757575756, 0.7590361445783134]
# 0.7570385882736042
# -0.7570385882736042 -0.7570385882736042
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 14:20:58.929449
# [0.6709677419354838, 0.7116564417177914, 0.6829268292682926, 0.5866666666666667, 0.6832298136645963]
# 0.6670894986505662
# -0.6670894986505662 -0.7570385882736042
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 14:21:39.800730
# [0.6709677419354838, 0.7195121951219512, 0.6790123456790124, 0.5866666666666667, 0.7037037037037037]
# 0.6719725306213635
# -0.6719725306213635 -0.7570385882736042
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 14:22:19.192870
# [0.7142857142857143, 0.7701863354037267, 0.7870967741935484, 0.7757575757575756, 0.7777777777777778]
# 0.7650208354836685
# -0.7650208354836685 -0.7650208354836685
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 14:22:54.972708
# [0.7421383647798742, 0.7643312101910827, 0.7798742138364779, 0.7484662576687118, 0.7974683544303799]
# 0.7664556801813054
# -0.7664556801813054 -0.7664556801813054
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d93f4160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f141d637a58>}
# 0.7253886010362693
# save to ../pickle/2019-08-21 14:23:39.084825.pickle
# save to ../csv/2019-08-21 14:23:43.623497.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.745   0.761          0.731       0.744         0.803    0.816
#
#   train_recall train_accuracy  \
# 0  0.79         0.802
#
#                                                     model1  \
# 0  <models.features.doc2vec_wrap object at 0x7f141d572080>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 14:23:39.084825.pickle
# save to ../csv/2019-08-21 14:23:43.682872.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.745   0.761          0.731       0.744         0.803    0.816
#
#   train_recall train_accuracy  \
# 0  0.79         0.802
#
#                                                     model1  \
# 0  <models.features.doc2vec_wrap object at 0x7f141d572080>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 14:23:39.084825.pickle
# time: 1h 25min 8s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
model1s = [load_pickle('../data/doc2vec_%.2d'% (number)) for number in range(1,8+1,1)]
def inner_CV_for_model1(corp, model1, method):
    p2_lgbm = {'class_weight':'balanced', 'boosting':'gbrt'}
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp} 
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8, field = 'model1')
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    from models.fmin2 import p2_lgbm
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 14:24:05.152741
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0dd8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:24:05.428710
# [0.670807453416149, 0.7337278106508877, 0.7439024390243902, 0.6982248520710058, 0.7469879518072289]
# 0.7187301013939325
# -0.7187301013939325 -0.7187301013939325 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0e48>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:27:48.253329
# [0.6909090909090909, 0.6792452830188679, 0.7402597402597403, 0.7647058823529411, 0.8051948051948051]
# 0.7360629603470891
# -0.7360629603470891 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbc18>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:30:15.054397
# [0.5263157894736842, 0.558659217877095, 0.5057471264367815, 0.6222222222222221, 0.5207100591715976]
# 0.546730883036276
# -0.546730883036276 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbb38>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:32:57.600535
# [0.47560975609756095, 0.5423728813559322, 0.4912280701754386, 0.5202312138728324, 0.5257142857142857]
# 0.51103124144321
# -0.51103124144321 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d77af98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:36:41.545267
# [0.6826347305389222, 0.6583850931677019, 0.691358024691358, 0.6927374301675978, 0.7073170731707318]
# 0.6864864703472623
# -0.6864864703472623 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0eb8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:40:53.875288
# [0.5625, 0.5294117647058825, 0.5180722891566264, 0.4772727272727273, 0.5595238095238095]
# 0.5293561181318092
# -0.5293561181318092 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbf28>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:43:20.615477
# [0.5698324022346369, 0.5888888888888889, 0.5176470588235293, 0.5517241379310345, 0.48148148148148145]
# 0.5419147938719142
# -0.5419147938719142 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d9649080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d572278>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 14:47:01.819390
# [0.5227272727272726, 0.5614035087719299, 0.5964912280701755, 0.5269461077844311, 0.5310734463276836]
# 0.5477283127362986
# -0.5477283127362986 -0.7360629603470891 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d615048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e509f60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 14:50:34.404747
# [0.7607361963190185, 0.7749999999999999, 0.7643312101910827, 0.7738095238095237, 0.8322981366459627]
# 0.7812350133931175
# -0.7812350133931175 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:10:10.202801
# [0.7329192546583853, 0.75, 0.7594936708860759, 0.7602339181286549, 0.8051948051948051]
# 0.7615683297735842
# -0.7615683297735842 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 15:26:11.425252
# [0.7421383647798742, 0.7329192546583853, 0.7594936708860759, 0.7710843373493975, 0.8076923076923076]
# 0.7626655870732081
# -0.7626655870732081 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 15:44:16.474286
# [0.7051282051282051, 0.7239263803680983, 0.7692307692307692, 0.7692307692307692, 0.7898089171974523]
# 0.7514650082310588
# -0.7514650082310588 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 15:58:07.559618
# [0.75, 0.7114093959731543, 0.7435897435897435, 0.7951807228915663, 0.8280254777070064]
# 0.7656410680322943
# -0.7656410680322943 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:11:29.883723
# [0.7361963190184049, 0.7421383647798742, 0.7594936708860759, 0.7674418604651162, 0.8176100628930818]
# 0.7645760556085106
# -0.7645760556085106 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:28:48.737331
# [0.7142857142857143, 0.7215189873417721, 0.7515923566878981, 0.761904761904762, 0.8025477707006369]
# 0.7503699181841565
# -0.7503699181841565 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 16:44:18.277102
# [0.7577639751552795, 0.7236842105263157, 0.7701863354037267, 0.7710843373493975, 0.8205128205128205]
# 0.768646335789508
# -0.768646335789508 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 17:01:02.438940
# [0.7169811320754716, 0.7421383647798742, 0.7450980392156864, 0.7515151515151515, 0.8129032258064516]
# 0.7537271826785271
# -0.7537271826785271 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:12:35.721796
# [0.7215189873417721, 0.7189542483660132, 0.7564102564102564, 0.7590361445783134, 0.8000000000000002]
# 0.7511839273392711
# -0.7511839273392711 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 17:25:32.941490
# [0.7483870967741936, 0.7421383647798742, 0.7798742138364779, 0.7777777777777778, 0.8205128205128205]
# 0.7737380547362287
# -0.7737380547362287 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:36:36.175364
# [0.7295597484276728, 0.7058823529411765, 0.75, 0.7831325301204819, 0.810126582278481]
# 0.7557402427535624
# -0.7557402427535624 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:47:58.015694
# [0.7329192546583853, 0.7133757961783439, 0.7643312101910827, 0.7738095238095237, 0.8205128205128205]
# 0.7609897210700313
# -0.7609897210700313 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 18:05:10.319576
# [0.7169811320754716, 0.7435897435897435, 0.7450980392156864, 0.7682926829268293, 0.8129032258064516]
# 0.7573729647228364
# -0.7573729647228364 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 18:14:44.730167
# [0.7368421052631579, 0.7532467532467533, 0.7612903225806451, 0.7692307692307692, 0.8205128205128205]
# 0.7682245541668292
# -0.7682245541668292 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 18:24:49.868252
# [0.7532467532467533, 0.7215189873417721, 0.7643312101910827, 0.7904191616766467, 0.7948717948717949]
# 0.7648775814656099
# -0.7648775814656099 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:38:47.573623
# [0.7530864197530863, 0.7407407407407407, 0.7577639751552795, 0.7636363636363638, 0.8333333333333334]
# 0.7697121665237607
# -0.7697121665237607 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 18:53:10.918078
# [0.6962025316455697, 0.7804878048780488, 0.7483870967741936, 0.7455621301775148, 0.7770700636942675]
# 0.7495419254339188
# -0.7495419254339188 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:02:52.610235
# [0.7374999999999999, 0.7051282051282051, 0.7388535031847134, 0.7757575757575756, 0.8152866242038217]
# 0.754505181654863
# -0.754505181654863 -0.7812350133931175
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 19:11:55.323730
# [0.7549668874172185, 0.7320261437908497, 0.7672955974842767, 0.7530864197530863, 0.8205128205128205]
# 0.7655775737916504
# -0.7655775737916504 -0.7812350133931175
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e6295c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f141e629b00>}
# 0.7783251231527093
# outer fold
# 2019-08-21 19:23:26.496776
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0dd8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:23:26.846790
# [0.6405228758169934, 0.7283950617283951, 0.6751592356687897, 0.7471264367816093, 0.6363636363636364]
# 0.6855134492718847
# -0.6855134492718847 -0.6855134492718847 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0e48>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:26:51.972006
# [0.7852760736196319, 0.7450980392156864, 0.6842105263157894, 0.8117647058823529, 0.717948717948718]
# 0.7488596125964356
# -0.7488596125964356 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbc18>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:29:03.151915
# [0.588235294117647, 0.5380116959064328, 0.49382716049382713, 0.6046511627906976, 0.6]
# 0.5649450626617208
# -0.5649450626617208 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbb38>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:31:06.209061
# [0.5764705882352942, 0.5465116279069768, 0.5245901639344261, 0.5402298850574713, 0.5402298850574713]
# 0.545606430038328
# -0.545606430038328 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d77af98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:34:19.763203
# [0.6962025316455697, 0.7080745341614907, 0.6233766233766234, 0.7398843930635839, 0.7283236994219653]
# 0.6991723563338466
# -0.6991723563338466 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0eb8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:37:31.937417
# [0.5810055865921788, 0.5698324022346369, 0.5698324022346369, 0.6043956043956045, 0.5681818181818182]
# 0.5786495627277751
# -0.5786495627277751 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbf28>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:39:26.979224
# [0.5649717514124294, 0.5185185185185185, 0.5485714285714286, 0.5828571428571429, 0.5257142857142857]
# 0.548126625414761
# -0.548126625414761 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d9649080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d287588>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 19:42:24.218669
# [0.5681818181818182, 0.574585635359116, 0.5317919075144509, 0.47904191616766467, 0.5088757396449705]
# 0.532495403373604
# -0.532495403373604 -0.7488596125964356 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d287d68>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d615d68>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:45:27.444937
# [0.7924528301886792, 0.7721518987341771, 0.7066666666666667, 0.8263473053892216, 0.7682926829268293]
# 0.7731822767811147
# -0.7731822767811147 -0.7731822767811147
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:57:15.821136
# [0.782608695652174, 0.7898089171974522, 0.7114093959731543, 0.8165680473372782, 0.7710843373493975]
# 0.7742958787018912
# -0.7742958787018912 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:07:13.097621
# [0.7898089171974522, 0.7515923566878981, 0.6944444444444444, 0.8117647058823529, 0.7590361445783134]
# 0.7613293137580922
# -0.7613293137580922 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 20:22:11.179424
# [0.7852760736196319, 0.75, 0.6986301369863014, 0.8095238095238094, 0.7607361963190185]
# 0.7608332432897522
# -0.7608332432897522 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 20:34:44.246468
# [0.7374999999999999, 0.7450980392156864, 0.7123287671232877, 0.8023255813953489, 0.782608695652174]
# 0.7559722166772993
# -0.7559722166772993 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:46:11.340905
# [0.7701863354037267, 0.7974683544303799, 0.684931506849315, 0.8214285714285715, 0.7469879518072289]
# 0.7642005439838444
# -0.7642005439838444 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:00:46.630961
# [0.7875, 0.7612903225806451, 0.6758620689655173, 0.8047337278106509, 0.7701863354037267]
# 0.7599144909521081
# -0.7599144909521081 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 21:12:41.212988
# [0.7721518987341771, 0.7483870967741936, 0.7027027027027027, 0.8187134502923977, 0.7594936708860759]
# 0.7602897638779094
# -0.7602897638779094 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 21:25:32.884054
# [0.7950310559006211, 0.7814569536423841, 0.7114093959731543, 0.8192771084337349, 0.7625]
# 0.7739349027899788
# -0.7739349027899788 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:34:24.312519
# [0.7749999999999999, 0.7712418300653595, 0.6758620689655173, 0.8165680473372782, 0.7749999999999999]
# 0.7627343892736309
# -0.7627343892736309 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:44:33.166502
# [0.7792207792207793, 0.7831325301204819, 0.6993006993006994, 0.8192771084337349, 0.7784431137724551]
# 0.7718748461696301
# -0.7718748461696301 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 21:53:28.538635
# [0.7798742138364779, 0.7654320987654321, 0.72, 0.8143712574850299, 0.7594936708860759]
# 0.7678342481946031
# -0.7678342481946031 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:04:07.522776
# [0.7975460122699387, 0.7712418300653595, 0.7123287671232877, 0.8095238095238094, 0.7594936708860759]
# 0.7700268179736943
# -0.7700268179736943 -0.7742958787018912
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:17:41.969275
# [0.7798742138364779, 0.825, 0.7074829931972788, 0.8192771084337349, 0.7701863354037267]
# 0.7803641301742437
# -0.7803641301742437 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 22:26:17.171564
# [0.7798742138364779, 0.7692307692307692, 0.7074829931972788, 0.8263473053892216, 0.7484662576687118]
# 0.7662803078644919
# -0.7662803078644919 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 22:36:10.835086
# [0.7852760736196319, 0.7643312101910827, 0.7248322147651006, 0.8187134502923977, 0.773006134969325]
# 0.7732318167675076
# -0.7732318167675076 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:49:17.022247
# [0.7594936708860759, 0.735483870967742, 0.684931506849315, 0.8187134502923977, 0.7654320987654321]
# 0.7528109195521926
# -0.7528109195521926 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 23:03:56.617191
# [0.7749999999999999, 0.7643312101910827, 0.7295597484276728, 0.8192771084337349, 0.75]
# 0.7676336134104981
# -0.7676336134104981 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 23:12:58.700571
# [0.8048780487804877, 0.7631578947368421, 0.7123287671232877, 0.8117647058823529, 0.773006134969325]
# 0.7730271102984592
# -0.7730271102984592 -0.7803641301742437
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 23:22:47.676266
# [0.7974683544303799, 0.782608695652174, 0.6901408450704226, 0.8170731707317075, 0.7453416149068324]
# 0.7665265361583032
# -0.7665265361583032 -0.7803641301742437
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e5eb2e8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f141e5f3518>}
# 0.7428571428571429
# outer fold
# 2019-08-21 23:32:51.675072
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0dd8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:32:52.106426
# [0.6451612903225807, 0.7160493827160493, 0.6946107784431137, 0.6982248520710058, 0.6863905325443787]
# 0.6880873672194256
# -0.6880873672194256 -0.6880873672194256 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0e48>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:36:01.343460
# [0.7239263803680983, 0.7763157894736843, 0.7096774193548386, 0.7515923566878981, 0.7654320987654321]
# 0.7453888089299902
# -0.7453888089299902 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbc18>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:37:54.380990
# [0.5212121212121211, 0.4914285714285714, 0.46052631578947373, 0.5217391304347826, 0.5238095238095238]
# 0.5037431325348944
# -0.5037431325348944 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbb38>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:39:54.071022
# [0.5030674846625767, 0.5, 0.5590062111801242, 0.4606060606060606, 0.5086705202312138]
# 0.5062700553359951
# -0.5062700553359951 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d77af98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:42:54.638728
# [0.6341463414634146, 0.7066666666666667, 0.7151515151515152, 0.7073170731707318, 0.6993865030674846]
# 0.6925336199039627
# -0.6925336199039627 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0eb8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:46:00.860433
# [0.558139534883721, 0.5057471264367815, 0.5625, 0.4216867469879517, 0.49411764705882355]
# 0.5084382110734555
# -0.5084382110734555 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbf28>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:47:53.700375
# [0.5086705202312138, 0.5766871165644172, 0.5029239766081872, 0.5698324022346369, 0.48837209302325585]
# 0.5292972217323422
# -0.5292972217323422 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d9649080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e4ed908>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 23:50:48.714824
# [0.5617977528089887, 0.5909090909090908, 0.5, 0.4585987261146497, 0.47619047619047616]
# 0.5174992092046411
# -0.5174992092046411 -0.7453888089299902 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e5f85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141e5f8470>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 23:53:44.453310
# [0.7329192546583853, 0.7792207792207793, 0.7169811320754716, 0.7133757961783439, 0.8205128205128205]
# 0.75260195652916
# -0.75260195652916 -0.75260195652916
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 00:05:58.598796
# [0.7169811320754716, 0.7483870967741936, 0.7169811320754716, 0.7607361963190185, 0.8051948051948052]
# 0.7496560724877921
# -0.7496560724877921 -0.75260195652916
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 00:16:10.516055
# [0.7006369426751592, 0.7792207792207793, 0.7421383647798742, 0.7215189873417721, 0.8104575163398693]
# 0.7507945180714908
# -0.7507945180714908 -0.75260195652916
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 00:31:47.422158
# [0.7283950617283951, 0.7712418300653595, 0.7105263157894737, 0.7547169811320754, 0.8152866242038217]
# 0.756033362583825
# -0.756033362583825 -0.756033362583825
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:44:10.878677
# [0.6923076923076923, 0.7870967741935484, 0.7133757961783439, 0.7341772151898733, 0.802547770700637]
# 0.7459010497140189
# -0.7459010497140189 -0.756033362583825
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 00:55:35.896598
# [0.7088607594936708, 0.7898089171974522, 0.7320261437908497, 0.7625, 0.8048780487804877]
# 0.7596147738524921
# -0.7596147738524921 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:10:37.843046
# [0.7225806451612903, 0.7814569536423841, 0.7125, 0.7560975609756098, 0.7948717948717949]
# 0.7535013909302158
# -0.7535013909302158 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 01:23:18.891669
# [0.6938775510204083, 0.7898089171974522, 0.7189542483660132, 0.7361963190184049, 0.802547770700637]
# 0.7482769612605832
# -0.7482769612605832 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 01:40:48.799628
# [0.7564102564102564, 0.758169934640523, 0.7051282051282051, 0.7453416149068324, 0.7922077922077922]
# 0.7514515606587218
# -0.7514515606587218 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:51:40.589761
# [0.717948717948718, 0.7870967741935484, 0.7088607594936708, 0.7329192546583853, 0.7898089171974522]
# 0.747326884698355
# -0.747326884698355 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:01:27.703067
# [0.7044025157232704, 0.7843137254901961, 0.7133757961783439, 0.7654320987654321, 0.7950310559006211]
# 0.7525110384115727
# -0.7525110384115727 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 02:09:21.731676
# [0.7012987012987013, 0.7999999999999999, 0.7189542483660132, 0.7169811320754716, 0.8258064516129032]
# 0.7526081066706178
# -0.7526081066706178 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 02:17:40.595143
# [0.7283950617283951, 0.7870967741935484, 0.7142857142857143, 0.7453416149068324, 0.810126582278481]
# 0.7570491494785943
# -0.7570491494785943 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 02:29:40.042637
# [0.6962025316455697, 0.76, 0.7435897435897435, 0.7577639751552795, 0.8050314465408805]
# 0.7525175393862946
# -0.7525175393862946 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 02:37:45.126511
# [0.6842105263157894, 0.7712418300653595, 0.717948717948718, 0.7453416149068324, 0.7974683544303799]
# 0.7432422087334158
# -0.7432422087334158 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 02:47:45.991617
# [0.6973684210526315, 0.7763157894736843, 0.7215189873417721, 0.7295597484276728, 0.7798742138364779]
# 0.7409274320264477
# -0.7409274320264477 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:01:34.779486
# [0.6962025316455697, 0.7870967741935484, 0.7133757961783439, 0.7577639751552795, 0.8176100628930817]
# 0.7544098280131646
# -0.7544098280131646 -0.7596147738524921
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 03:16:12.562387
# [0.7515923566878981, 0.7741935483870969, 0.7189542483660132, 0.7692307692307692, 0.7975460122699387]
# 0.7623033869883432
# -0.7623033869883432 -0.7623033869883432
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 03:24:56.473412
# [0.7320261437908497, 0.7792207792207793, 0.7307692307692308, 0.7125, 0.8152866242038217]
# 0.7539605555969363
# -0.7539605555969363 -0.7623033869883432
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 03:35:19.884203
# [0.6878980891719745, 0.7320261437908497, 0.7250000000000001, 0.7469879518072289, 0.7843137254901961]
# 0.7352451820520498
# -0.7352451820520498 -0.7623033869883432
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e75c908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f141d287208>}
# 0.7789473684210527
# outer fold
# 2019-08-22 03:47:47.794857
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0dd8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 03:47:48.225067
# [0.7251461988304092, 0.7441860465116279, 0.7515151515151515, 0.7080745341614907, 0.7185628742514969]
# 0.7294969610540352
# -0.7294969610540352 -0.7294969610540352 1
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0e48>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 03:51:09.653179
# [0.7831325301204819, 0.7701863354037267, 0.7922077922077922, 0.7763157894736843, 0.8072289156626505]
# 0.7858142725736671
# -0.7858142725736671 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbc18>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 03:53:17.600146
# [0.49056603773584906, 0.48554913294797686, 0.5357142857142857, 0.5696969696969697, 0.5269461077844311]
# 0.5216945067759025
# -0.5216945067759025 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbb38>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 03:55:23.457264
# [0.5263157894736842, 0.5032258064516129, 0.6097560975609756, 0.5680473372781065, 0.6081871345029239]
# 0.5631064330534608
# -0.5631064330534608 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d77af98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 03:58:40.950014
# [0.7344632768361582, 0.738095238095238, 0.6962025316455697, 0.6753246753246753, 0.782608695652174]
# 0.725338883510763
# -0.725338883510763 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0eb8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 04:01:52.614496
# [0.47398843930635837, 0.5795454545454546, 0.5408805031446542, 0.4550898203592814, 0.5340909090909091]
# 0.5167190252893314
# -0.5167190252893314 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbf28>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 04:03:47.934259
# [0.5614035087719299, 0.5348837209302326, 0.572972972972973, 0.6067415730337078, 0.6270270270270271]
# 0.5806057605471739
# -0.5806057605471739 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d9649080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141cfbbc50>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 04:06:53.623510
# [0.4606060606060606, 0.5217391304347826, 0.47560975609756095, 0.49382716049382713, 0.5433526011560693]
# 0.49902694175766016
# -0.49902694175766016 -0.7858142725736671 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f140eddc4a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f140eddc2e8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 04:09:59.291871
# [0.7692307692307692, 0.7283950617283951, 0.7432432432432432, 0.7272727272727273, 0.7904191616766467]
# 0.7517121926303564
# -0.7517121926303564 -0.7517121926303564
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 04:21:57.416168
# [0.8070175438596491, 0.75, 0.7692307692307692, 0.7770700636942676, 0.7882352941176471]
# 0.7783107341804666
# -0.7783107341804666 -0.7783107341804666
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 04:31:11.961622
# [0.7738095238095237, 0.7407407407407407, 0.8129032258064517, 0.7450980392156864, 0.7738095238095237]
# 0.7692722106763853
# -0.7692722106763853 -0.7783107341804666
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 04:45:15.552928
# [0.7682926829268293, 0.7468354430379747, 0.7770700636942676, 0.7468354430379747, 0.7951807228915663]
# 0.7668428711177225
# -0.7668428711177225 -0.7783107341804666
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 04:57:22.446011
# [0.7710843373493975, 0.7435897435897435, 0.7866666666666667, 0.7483870967741936, 0.7682926829268293]
# 0.7636041054613661
# -0.7636041054613661 -0.7783107341804666
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 05:07:01.974313
# [0.783625730994152, 0.75, 0.7973856209150327, 0.7483870967741936, 0.7777777777777778]
# 0.7714352452922312
# -0.7714352452922312 -0.7783107341804666
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 05:18:27.089494
# [0.75, 0.7577639751552795, 0.7837837837837838, 0.7333333333333334, 0.8048780487804877]
# 0.7659518282105768
# -0.7659518282105768 -0.7783107341804666
# ...
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:30:52.572400
# [0.7948717948717949, 0.7749999999999999, 0.7341772151898733, 0.7468354430379747, 0.7922077922077922]
# 0.7686184490614869
# -0.7686184490614869 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbc18>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:32:33.856932
# [0.5269461077844311, 0.5617977528089887, 0.5714285714285713, 0.5875706214689265, 0.45751633986928103]
# 0.5410518786720397
# -0.5410518786720397 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbb38>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:34:12.082414
# [0.6086956521739131, 0.5393258426966292, 0.5276073619631901, 0.5536723163841808, 0.5911949685534591]
# 0.5640992283542745
# -0.5640992283542745 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d77af98>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:37:01.335965
# [0.7560975609756098, 0.6753246753246753, 0.6863905325443787, 0.7664670658682634, 0.7484662576687118]
# 0.7265492184763278
# -0.7265492184763278 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6c0eb8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:39:53.304843
# [0.6101694915254238, 0.5680473372781065, 0.558139534883721, 0.5301204819277108, 0.595505617977528]
# 0.572396492718498
# -0.572396492718498 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141d6bbf28>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:41:28.968096
# [0.5652173913043479, 0.48148148148148145, 0.5030674846625767, 0.49056603773584906, 0.5595238095238095]
# 0.519971240941613
# -0.519971240941613 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f14d9649080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773a20>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 07:44:26.606073
# [0.518987341772152, 0.5402298850574713, 0.4848484848484848, 0.5058823529411766, 0.550561797752809]
# 0.5201019724744187
# -0.5201019724744187 -0.7686184490614869 2
# {'model1': <models.features.doc2vec_wrap object at 0x7f141e931b00>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f141d773860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:47:20.068348
# [0.8198757763975155, 0.7749999999999999, 0.758169934640523, 0.7654320987654321, 0.7898089171974522]
# 0.7816573454001845
# -0.7816573454001845 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:59:35.438251
# [0.7976190476190476, 0.7435897435897435, 0.7450980392156864, 0.787878787878788, 0.7792207792207793]
# 0.7706812795048089
# -0.7706812795048089 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:07:20.148893
# [0.7901234567901234, 0.7544910179640719, 0.7417218543046357, 0.7757575757575756, 0.7875]
# 0.7699187809632814
# -0.7699187809632814 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 08:17:54.997657
# [0.7975460122699387, 0.7682926829268293, 0.7307692307692308, 0.8, 0.7870967741935484]
# 0.7767409400319094
# -0.7767409400319094 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 08:27:18.685749
# [0.8048780487804877, 0.7654320987654321, 0.75, 0.7560975609756098, 0.782051282051282]
# 0.7716917981145622
# -0.7716917981145622 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:36:10.154437
# [0.7643312101910827, 0.7777777777777778, 0.7532467532467533, 0.7672955974842767, 0.8]
# 0.7725302677399781
# -0.7725302677399781 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:48:04.130208
# [0.8048780487804877, 0.7607361963190185, 0.7516778523489933, 0.7672955974842767, 0.8125000000000001]
# 0.7794175389865552
# -0.7794175389865552 -0.7816573454001845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 08:57:08.711260
# [0.7999999999999999, 0.773006134969325, 0.7712418300653595, 0.7682926829268293, 0.8152866242038217]
# 0.785565454433067
# -0.785565454433067 -0.785565454433067
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 09:07:31.856039
# [0.7924528301886792, 0.75, 0.7712418300653595, 0.7483870967741936, 0.7948717948717949]
# 0.7713907103800054
# -0.7713907103800054 -0.785565454433067
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 09:14:21.036906
# [0.7875, 0.7654320987654321, 0.76, 0.7721518987341771, 0.7924528301886792]
# 0.7755073655376576
# -0.7755073655376576 -0.785565454433067
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 09:22:09.827107
# [0.8047337278106509, 0.782608695652174, 0.7763157894736843, 0.7804878048780488, 0.794701986754967]
# 0.787769600913905
# -0.787769600913905 -0.787769600913905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:29:35.301007
# [0.7625, 0.7594936708860759, 0.7450980392156864, 0.782051282051282, 0.782051282051282]
# 0.7662388548408652
# -0.7662388548408652 -0.787769600913905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:40:03.715306
# [0.8, 0.7672955974842767, 0.7320261437908497, 0.7875, 0.8050314465408805]
# 0.7783706375632015
# -0.7783706375632015 -0.787769600913905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:53:45.203487
# [0.7784431137724551, 0.7721518987341771, 0.7549668874172185, 0.7757575757575756, 0.8051948051948052]
# 0.7773028561752463
# -0.7773028561752463 -0.787769600913905
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 10:02:29.235688
# [0.8242424242424242, 0.7950310559006211, 0.7466666666666666, 0.7777777777777778, 0.8125000000000001]
# 0.7912435849174979
# -0.7912435849174979 -0.7912435849174979
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:11:48.700745
# [0.8220858895705522, 0.7625, 0.7712418300653595, 0.7975460122699387, 0.8051948051948052]
# 0.791713707420131
# -0.791713707420131 -0.791713707420131
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 10:24:37.053403
# [0.8048780487804877, 0.7607361963190185, 0.758169934640523, 0.7710843373493975, 0.810126582278481]
# 0.7809990198735814
# -0.7809990198735814 -0.791713707420131
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 10:38:52.214442
# [0.8072289156626505, 0.7625, 0.7692307692307692, 0.7455621301775148, 0.7999999999999999]
# 0.776904363014187
# -0.776904363014187 -0.791713707420131
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 10:49:14.313456
# [0.782608695652174, 0.7950310559006211, 0.7662337662337663, 0.7770700636942676, 0.8129032258064517]
# 0.7867693614574562
# -0.7867693614574562 -0.791713707420131
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:59:37.774532
# [0.7607361963190185, 0.782051282051282, 0.7631578947368421, 0.7672955974842767, 0.7919463087248322]
# 0.7730374558632502
# -0.7730374558632502 -0.791713707420131
# {'model1': <models.features.doc2vec_wrap object at 0x7f140ef00a90>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f141e57f518>}
# 0.7593582887700535
# save to ../pickle/2019-08-22 11:09:31.083960.pickle
# save to ../csv/2019-08-22 11:09:36.531483.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.763   0.78           0.749       0.762         1        1
#
#   train_recall train_accuracy  \
# 0  1            0.999
#
#                                                     model1  \
# 0  <models.features.doc2vec_wrap object at 0x7f141d615048>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.5, gamma=0.65,\n        importance_type='split', lambda_l2=1, learning_rate=0.15,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=256,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 11:09:31.083960.pickle
# save to ../csv/2019-08-22 11:09:36.565984.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.763   0.78           0.749       0.762         1        1
#
#   train_recall train_accuracy  \
# 0  1            0.999
#
#                                                     model1  \
# 0  <models.features.doc2vec_wrap object at 0x7f141d615048>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.5, gamma=0.65,\n        importance_type='split', lambda_l2=1, learning_rate=0.15,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=256,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 11:09:31.083960.pickle
# time: 20h 45min 52s

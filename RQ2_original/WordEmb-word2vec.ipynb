# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.11 µs
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# time: 37.2 ms

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 15.3 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
model1s = [salvador_wrap('../data/word2vec_%.2d.bin'% (number)) for number in range(1,8+1,1)]

def inner_CV_for_model1(corp, model1, method):
    print('inner_CV_for_model1')
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    '''
    p2_lr = {'class_weight':'balanced','solver': 'liblinear', 'penalty':'l2'}
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning model1
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8)
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    print('inner_CV_for_model2')
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning p2: the params for model2
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 19:33:44.631081
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f83df6bdcf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:33:44.882386
# [0.7116564417177914, 0.6829268292682926, 0.7411764705882353, 0.7294117647058823, 0.7577639751552795]
# 0.7245870962870963
# -0.7245870962870963 -0.7245870962870963 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df913b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:34:16.645130
# [0.7388535031847134, 0.6875000000000001, 0.7349397590361447, 0.7674418604651162, 0.7577639751552795]
# 0.7372998195682509
# -0.7372998195682509 -0.7372998195682509 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df9caa58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:34:49.001350
# [0.6027397260273973, 0.6711409395973154, 0.6785714285714286, 0.659217877094972, 0.6706586826347305]
# 0.6564657307851688
# -0.6564657307851688 -0.7372998195682509 2
# {'model1': <models.features.salvador_wrap object at 0x7f83cc21b940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:35:19.739983
# [0.675, 0.6341463414634146, 0.6951219512195121, 0.686046511627907, 0.7176470588235294]
# 0.6815923726268726
# -0.6815923726268726 -0.7372998195682509 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df185828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:35:50.740744
# [0.7341772151898733, 0.7388535031847134, 0.7453416149068324, 0.7727272727272727, 0.7770700636942675]
# 0.7536339339405917
# -0.7536339339405917 -0.7536339339405917 5
# {'model1': <models.features.salvador_wrap object at 0x7f83defc5710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:36:21.462536
# [0.6790123456790124, 0.6415094339622641, 0.6540880503144653, 0.6976744186046511, 0.7388535031847133]
# 0.6822275503490213
# -0.6822275503490213 -0.7536339339405917 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dee065f8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:36:49.163050
# [0.6946107784431137, 0.6666666666666667, 0.7125, 0.7111111111111111, 0.6787878787878787]
# 0.692735287001754
# -0.692735287001754 -0.7536339339405917 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dec474e0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83dea886a0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:37:18.184397
# [0.6363636363636364, 0.6818181818181818, 0.654320987654321, 0.6936416184971098, 0.7602339181286549]
# 0.6852756684923808
# -0.6852756684923808 -0.7536339339405917 5
# {'model1': <models.features.salvador_wrap object at 0x7f83df6909e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df45a1d0>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 19:37:45.710414
# [0.7341772151898733, 0.7469879518072289, 0.7530864197530863, 0.7931034482758621, 0.7875]
# 0.7629710070052101
# -0.7629710070052101 -0.7629710070052101
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 19:38:14.227610
# [0.7341772151898733, 0.7388535031847134, 0.7453416149068324, 0.7727272727272727, 0.7770700636942675]
# 0.7536339339405917
# -0.7536339339405917 -0.7629710070052101
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 19:38:41.407010
# [0.7421383647798742, 0.7317073170731708, 0.7169811320754716, 0.7613636363636362, 0.7594936708860761]
# 0.7423368242356457
# -0.7423368242356457 -0.7629710070052101
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 19:39:09.126509
# [0.7329192546583853, 0.7283950617283951, 0.7, 0.7472527472527474, 0.7421383647798743]
# 0.7301410856838804
# -0.7301410856838804 -0.7629710070052101
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 19:39:38.049668
# [0.7250000000000001, 0.7374999999999999, 0.7125, 0.7513812154696133, 0.7388535031847133]
# 0.7330469437308652
# -0.7330469437308652 -0.7629710070052101
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 19:40:08.248511
# [0.7770700636942676, 0.7564102564102564, 0.7692307692307692, 0.7738095238095237, 0.8098159509202455]
# 0.7772673128130125
# -0.7772673128130125 -0.7772673128130125
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 19:40:35.786889
# [0.7283950617283951, 0.7295597484276728, 0.7044025157232704, 0.7403314917127072, 0.7421383647798743]
# 0.7289654364743839
# -0.7289654364743839 -0.7772673128130125
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 19:41:07.006525
# [0.7329192546583853, 0.7329192546583853, 0.7044025157232704, 0.7444444444444445, 0.7421383647798743]
# 0.731364766852872
# -0.731364766852872 -0.7772673128130125
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 19:41:35.887449
# [0.7643312101910827, 0.7453416149068324, 0.7692307692307692, 0.7674418604651162, 0.8292682926829269]
# 0.7751227494953454
# -0.7751227494953454 -0.7772673128130125
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 19:42:02.681932
# [0.7636363636363638, 0.7547169811320754, 0.7547169811320754, 0.782608695652174, 0.8157894736842106]
# 0.7742936990473799
# -0.7742936990473799 -0.7772673128130125
# {'model1': <models.features.salvador_wrap object at 0x7f83de78be10>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f83df45a320>}
# 0.8240740740740741
# outer fold
# 2019-08-20 19:42:35.468308
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f83df6bdcf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:42:35.891683
# [0.7295597484276728, 0.7125, 0.6451612903225807, 0.7643312101910827, 0.6863905325443787]
# 0.7075885562971429
# -0.7075885562971429 -0.7075885562971429 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df913b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:43:02.883866
# [0.7407407407407407, 0.7407407407407407, 0.7088607594936708, 0.7975460122699387, 0.7515151515151515]
# 0.7478806809520484
# -0.7478806809520484 -0.7478806809520484 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df9caa58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:43:30.883437
# [0.6785714285714286, 0.6705202312138728, 0.6335403726708074, 0.6705882352941176, 0.6887417218543046]
# 0.6683923979209062
# -0.6683923979209062 -0.7478806809520484 2
# {'model1': <models.features.salvador_wrap object at 0x7f83cc21b940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:44:00.470294
# [0.7011494252873562, 0.6823529411764707, 0.6871165644171778, 0.710059171597633, 0.6125]
# 0.6786356204957276
# -0.6786356204957276 -0.7478806809520484 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df185828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:44:27.947965
# [0.7948717948717949, 0.6962025316455697, 0.6967741935483871, 0.825, 0.7664670658682634]
# 0.7558631171868029
# -0.7558631171868029 -0.7558631171868029 5
# {'model1': <models.features.salvador_wrap object at 0x7f83defc5710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:44:55.436755
# [0.6792452830188679, 0.6787878787878788, 0.6794871794871794, 0.7195121951219512, 0.6590909090909091]
# 0.6832246891013574
# -0.6832246891013574 -0.7558631171868029 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dee065f8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:45:22.505184
# [0.7073170731707318, 0.710059171597633, 0.5942028985507246, 0.7167630057803468, 0.6875000000000001]
# 0.6831684298198872
# -0.6831684298198872 -0.7558631171868029 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dec474e0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83df9cc518>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:45:48.821477
# [0.6706586826347306, 0.6823529411764707, 0.7116564417177914, 0.7411764705882353, 0.6309523809523809]
# 0.6873593834139218
# -0.6873593834139218 -0.7558631171868029 5
# {'model1': <models.features.salvador_wrap object at 0x7f83df9cc358>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de68dc18>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 19:46:17.006381
# [0.7974683544303799, 0.7160493827160493, 0.7133757961783439, 0.8395061728395061, 0.7738095238095237]
# 0.7680418459947607
# -0.7680418459947607 -0.7680418459947607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 19:46:44.610120
# [0.7948717948717949, 0.6962025316455697, 0.6967741935483871, 0.825, 0.7664670658682634]
# 0.7558631171868029
# -0.7558631171868029 -0.7680418459947607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 19:47:10.806772
# [0.7777777777777778, 0.7169811320754716, 0.6967741935483871, 0.8220858895705522, 0.757396449704142]
# 0.7542030885352661
# -0.7542030885352661 -0.7680418459947607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 19:47:37.267147
# [0.7407407407407407, 0.7080745341614907, 0.6624203821656051, 0.8098159509202455, 0.7514450867052024]
# 0.7344993389386569
# -0.7344993389386569 -0.7680418459947607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 19:48:05.148050
# [0.7577639751552795, 0.7125, 0.6878980891719745, 0.8176100628930817, 0.7602339181286549]
# 0.7472012090697981
# -0.7472012090697981 -0.7680418459947607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 19:48:32.476220
# [0.8074534161490683, 0.75, 0.7483870967741936, 0.8433734939759034, 0.7904191616766467]
# 0.7879266337151625
# -0.7879266337151625 -0.7879266337151625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 19:48:59.624206
# [0.7407407407407407, 0.7080745341614907, 0.6624203821656051, 0.8148148148148148, 0.7471264367816093]
# 0.7346353817328521
# -0.7346353817328521 -0.7879266337151625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 19:49:28.254290
# [0.7484662576687118, 0.7125, 0.675, 0.8074534161490683, 0.7542857142857142]
# 0.7395410776206989
# -0.7395410776206989 -0.7879266337151625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 19:49:57.587652
# [0.810126582278481, 0.7560975609756098, 0.7323943661971831, 0.8271604938271605, 0.7810650887573963]
# 0.7813688184071662
# -0.7813688184071662 -0.7879266337151625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 19:50:24.113716
# [0.8181818181818182, 0.7741935483870969, 0.7532467532467533, 0.8192771084337349, 0.7425149700598802]
# 0.7814828396618567
# -0.7814828396618567 -0.7879266337151625
# {'model1': <models.features.salvador_wrap object at 0x7f83de740390>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f83de86a7b8>}
# 0.7465437788018433
# outer fold
# 2019-08-20 19:50:56.369277
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f83df6bdcf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:50:56.750711
# [0.632258064516129, 0.7625, 0.7515151515151515, 0.7204968944099378, 0.6707317073170732]
# 0.7075003635516584
# -0.7075003635516584 -0.7075003635516584 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df913b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:51:25.960529
# [0.7, 0.7804878048780488, 0.7636363636363638, 0.7590361445783134, 0.670807453416149]
# 0.734793553301775
# -0.734793553301775 -0.734793553301775 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df9caa58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:51:52.926831
# [0.6511627906976745, 0.6705202312138728, 0.6835443037974684, 0.6785714285714286, 0.7218934911242604]
# 0.681138449080941
# -0.681138449080941 -0.734793553301775 2
# {'model1': <models.features.salvador_wrap object at 0x7f83cc21b940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:52:20.722654
# [0.6629213483146067, 0.6395348837209301, 0.7305389221556886, 0.6125, 0.6867469879518073]
# 0.6664484284286065
# -0.6664484284286065 -0.734793553301775 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df185828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:52:48.441424
# [0.6871165644171778, 0.782608695652174, 0.7272727272727273, 0.7738095238095237, 0.7468354430379747]
# 0.7435285908379154
# -0.7435285908379154 -0.7435285908379154 5
# {'model1': <models.features.salvador_wrap object at 0x7f83defc5710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:53:18.691543
# [0.6589595375722543, 0.6918238993710691, 0.675, 0.7078651685393258, 0.7058823529411764]
# 0.6879061916847652
# -0.6879061916847652 -0.7435285908379154 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dee065f8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:53:47.687867
# [0.6516853932584269, 0.7185628742514969, 0.7133757961783439, 0.710059171597633, 0.7455621301775148]
# 0.7078490730926831
# -0.7078490730926831 -0.7435285908379154 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dec474e0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83d78dec50>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:54:14.296342
# [0.6390532544378698, 0.6586826347305389, 0.670807453416149, 0.627906976744186, 0.6927374301675978]
# 0.6578375498992683
# -0.6578375498992683 -0.7435285908379154 5
# {'model1': <models.features.salvador_wrap object at 0x7f83de3a9198>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de739b38>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 19:54:41.760386
# [0.7142857142857143, 0.7875, 0.7317073170731708, 0.7738095238095237, 0.7388535031847134]
# 0.7492312116706245
# -0.7492312116706245 -0.7492312116706245
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 19:55:09.024593
# [0.6871165644171778, 0.782608695652174, 0.7272727272727273, 0.7738095238095237, 0.7468354430379747]
# 0.7435285908379154
# -0.7435285908379154 -0.7492312116706245
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 19:55:38.166177
# [0.6549707602339181, 0.7654320987654321, 0.6987951807228916, 0.7544910179640719, 0.7374999999999999]
# 0.7222378115372626
# -0.7222378115372626 -0.7492312116706245
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 19:56:08.632157
# [0.6107784431137725, 0.7577639751552795, 0.674698795180723, 0.761904761904762, 0.7407407407407407]
# 0.7091773432190556
# -0.7091773432190556 -0.7492312116706245
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 19:56:37.995730
# [0.6390532544378698, 0.7607361963190185, 0.6946107784431137, 0.7469879518072289, 0.7329192546583853]
# 0.7148614871331233
# -0.7148614871331233 -0.7492312116706245
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 19:57:09.067903
# [0.7484662576687118, 0.8322981366459627, 0.773006134969325, 0.7901234567901234, 0.7831325301204819]
# 0.785405303238921
# -0.785405303238921 -0.785405303238921
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 19:57:35.995741
# [0.6144578313253012, 0.7625, 0.674698795180723, 0.761904761904762, 0.7407407407407407]
# 0.7108604258303053
# -0.7108604258303053 -0.785405303238921
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 19:58:03.996174
# [0.6144578313253012, 0.7701863354037267, 0.6867469879518073, 0.7469879518072289, 0.7361963190184049]
# 0.7109150851012938
# -0.7109150851012938 -0.785405303238921
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 19:58:32.314515
# [0.75, 0.8395061728395061, 0.7643312101910827, 0.7999999999999999, 0.7882352941176471]
# 0.7884145354296471
# -0.7884145354296471 -0.7884145354296471
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 19:59:00.872743
# [0.7544910179640719, 0.8322981366459627, 0.7924528301886792, 0.7976190476190476, 0.7798742138364779]
# 0.7913470492508478
# -0.7913470492508478 -0.7913470492508478
# {'model1': <models.features.salvador_wrap object at 0x7f83de74c940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f83dfa985c0>}
# 0.7849462365591399
# outer fold
# 2019-08-20 19:59:34.723258
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f83df6bdcf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 19:59:35.113870
# [0.7529411764705881, 0.7361963190184049, 0.7875, 0.7037037037037037, 0.6946107784431137]
# 0.7349903955271622
# -0.7349903955271622 -0.7349903955271622 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df913b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:00:05.312224
# [0.7325581395348836, 0.7577639751552795, 0.735483870967742, 0.7204968944099378, 0.7906976744186047]
# 0.7474001108972895
# -0.7474001108972895 -0.7474001108972895 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df9caa58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:00:35.568812
# [0.6785714285714286, 0.6557377049180328, 0.7023809523809522, 0.5987261146496815, 0.72]
# 0.671083240104019
# -0.671083240104019 -0.7474001108972895 2
# {'model1': <models.features.salvador_wrap object at 0x7f83cc21b940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:01:03.857153
# [0.6625766871165645, 0.7176470588235295, 0.7209302325581395, 0.6586826347305389, 0.7150837988826816]
# 0.6949840824222908
# -0.6949840824222908 -0.7474001108972895 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df185828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:01:31.217193
# [0.7317073170731708, 0.7607361963190185, 0.7625, 0.7204968944099378, 0.768361581920904]
# 0.7487603979446062
# -0.7487603979446062 -0.7487603979446062 5
# {'model1': <models.features.salvador_wrap object at 0x7f83defc5710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:02:01.350808
# [0.7261904761904762, 0.6787878787878788, 0.7337278106508877, 0.6163522012578617, 0.6904761904761905]
# 0.6891069114726591
# -0.6891069114726591 -0.7487603979446062 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dee065f8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:02:29.776847
# [0.6451612903225807, 0.6863905325443787, 0.7469879518072289, 0.6792452830188679, 0.7314285714285713]
# 0.6978427258243254
# -0.6978427258243254 -0.7487603979446062 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dec474e0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9dc438>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:02:59.201623
# [0.710059171597633, 0.6832298136645963, 0.6666666666666666, 0.6037735849056604, 0.7337278106508877]
# 0.6794914094970887
# -0.6794914094970887 -0.7487603979446062 5
# {'model1': <models.features.salvador_wrap object at 0x7f83de9cd0f0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de9cdc50>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 20:03:27.837636
# [0.7393939393939394, 0.7757575757575756, 0.7950310559006211, 0.7295597484276728, 0.7821229050279329]
# 0.7643730449015484
# -0.7643730449015484 -0.7643730449015484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 20:03:58.315192
# [0.7317073170731708, 0.7607361963190185, 0.7625, 0.7204968944099378, 0.768361581920904]
# 0.7487603979446062
# -0.7487603979446062 -0.7643730449015484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 20:04:27.423962
# [0.6918238993710691, 0.7204968944099378, 0.7547169811320754, 0.7116564417177914, 0.7630057803468208]
# 0.7283399993955388
# -0.7283399993955388 -0.7643730449015484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 20:04:55.324348
# [0.7250000000000001, 0.6946107784431137, 0.7515151515151515, 0.7073170731707318, 0.7428571428571429]
# 0.724260029197228
# -0.724260029197228 -0.7643730449015484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 20:05:24.045236
# [0.7, 0.710059171597633, 0.7439024390243902, 0.6956521739130435, 0.7500000000000001]
# 0.7199227569070132
# -0.7199227569070132 -0.7643730449015484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 20:05:52.628367
# [0.7852760736196319, 0.7901234567901234, 0.7875, 0.7329192546583853, 0.813953488372093]
# 0.7819544546880468
# -0.7819544546880468 -0.7819544546880468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 20:06:25.109363
# [0.7250000000000001, 0.6946107784431137, 0.7664670658682634, 0.7073170731707318, 0.7428571428571429]
# 0.7272504120678505
# -0.7272504120678505 -0.7819544546880468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 20:06:56.077484
# [0.7250000000000001, 0.6946107784431137, 0.7664670658682634, 0.7037037037037037, 0.7500000000000001]
# 0.7279563096030162
# -0.7279563096030162 -0.7819544546880468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 20:07:25.263883
# [0.7682926829268293, 0.8192771084337349, 0.7643312101910827, 0.7530864197530863, 0.8284023668639053]
# 0.7866779576337277
# -0.7866779576337277 -0.7866779576337277
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 20:07:53.539448
# [0.7784431137724551, 0.8125000000000001, 0.7843137254901961, 0.7407407407407407, 0.8284023668639053]
# 0.7888799893734595
# -0.7888799893734595 -0.7888799893734595
# {'model1': <models.features.salvador_wrap object at 0x7f83df581da0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f83de989828>}
# 0.7731958762886598
# outer fold
# 2019-08-20 20:08:30.144972
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f83df6bdcf8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:08:30.551106
# [0.7065868263473054, 0.7185628742514969, 0.7151515151515152, 0.6987951807228916, 0.7096774193548386]
# 0.7097547631656096
# -0.7097547631656096 -0.7097547631656096 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df913b70>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:08:58.194475
# [0.7349397590361447, 0.7058823529411764, 0.7329192546583853, 0.7471264367816093, 0.8125000000000001]
# 0.7466735606834631
# -0.7466735606834631 -0.7466735606834631 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df9caa58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:09:28.926247
# [0.6904761904761905, 0.6627906976744186, 0.6496815286624203, 0.5949367088607596, 0.7045454545454545]
# 0.6604861160438487
# -0.6604861160438487 -0.7466735606834631 2
# {'model1': <models.features.salvador_wrap object at 0x7f83cc21b940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:09:57.737723
# [0.7292817679558011, 0.7023809523809522, 0.5838509316770186, 0.6850828729281768, 0.7142857142857143]
# 0.6829764478455327
# -0.6829764478455327 -0.7466735606834631 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df185828>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:10:25.111260
# [0.75, 0.7471264367816093, 0.7374999999999999, 0.7636363636363638, 0.7662337662337663]
# 0.7528993133303479
# -0.7528993133303479 -0.7528993133303479 5
# {'model1': <models.features.salvador_wrap object at 0x7f83defc5710>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:10:53.974125
# [0.6900584795321638, 0.6347305389221557, 0.7515151515151515, 0.6781609195402298, 0.7471264367816093]
# 0.700318305258262
# -0.700318305258262 -0.7528993133303479 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dee065f8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:11:23.581253
# [0.6867469879518073, 0.7294117647058823, 0.6754966887417219, 0.7411764705882353, 0.654320987654321]
# 0.6974305799283936
# -0.6974305799283936 -0.7528993133303479 5
# {'model1': <models.features.salvador_wrap object at 0x7f83dec474e0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de3caa20>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-20 20:11:53.444758
# [0.6630434782608695, 0.641025641025641, 0.6832298136645963, 0.6705202312138728, 0.7441860465116279]
# 0.6804010421353215
# -0.6804010421353215 -0.7528993133303479 5
# {'model1': <models.features.salvador_wrap object at 0x7f83df82f6a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f83de7cf4a8>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 20:12:23.922991
# [0.8048780487804877, 0.7441860465116279, 0.7484662576687118, 0.7831325301204819, 0.76]
# 0.7681325766162619
# -0.7681325766162619 -0.7681325766162619
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 20:12:53.898441
# [0.75, 0.7471264367816093, 0.7374999999999999, 0.7636363636363638, 0.7662337662337663]
# 0.7528993133303479
# -0.7528993133303479 -0.7681325766162619
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 20:13:24.074017
# [0.7283950617283951, 0.7283236994219653, 0.7250000000000001, 0.7455621301775148, 0.7692307692307692]
# 0.7393023321117289
# -0.7393023321117289 -0.7681325766162619
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 20:13:52.712363
# [0.7250000000000001, 0.735632183908046, 0.7169811320754716, 0.7058823529411764, 0.7307692307692308]
# 0.7228529799387851
# -0.7228529799387851 -0.7681325766162619
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 20:14:20.681996
# [0.7407407407407407, 0.7325581395348836, 0.7204968944099378, 0.7195121951219512, 0.7721518987341771]
# 0.737091973708338
# -0.737091973708338 -0.7681325766162619
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 20:14:48.044225
# [0.8121212121212122, 0.7295597484276728, 0.7901234567901234, 0.8047337278106509, 0.802547770700637]
# 0.7878171831700593
# -0.7878171831700593 -0.7878171831700593
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 20:15:17.481197
# [0.7329192546583853, 0.735632183908046, 0.7169811320754716, 0.7058823529411764, 0.7261146496815287]
# 0.7235059146529217
# -0.7235059146529217 -0.7878171831700593
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 20:15:45.310144
# [0.7283950617283951, 0.735632183908046, 0.7169811320754716, 0.7017543859649122, 0.7483870967741936]
# 0.7262299720902037
# -0.7262299720902037 -0.7878171831700593
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 20:16:15.156713
# [0.8072289156626505, 0.7484662576687118, 0.7875, 0.8187134502923977, 0.7866666666666667]
# 0.7897150580580854
# -0.7897150580580854 -0.7897150580580854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 20:16:42.603807
# [0.7848101265822786, 0.7999999999999999, 0.7741935483870969, 0.8170731707317075, 0.7972972972972973]
# 0.7946748285996761
# -0.7946748285996761 -0.7946748285996761
# {'model1': <models.features.salvador_wrap object at 0x7f83de64fd68>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f849f7c0f60>}
# 0.7715736040609136
# save to ../pickle/2019-08-20 20:17:16.430164.pickle
# save to ../csv/2019-08-20 20:17:17.769591.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.78    0.787          0.778       0.776         0.865    0.883
#
#   train_recall train_accuracy  \
# 0  0.849        0.865
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f83df6909e8>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-20 20:17:16.430164.pickle
# save to ../csv/2019-08-20 20:17:17.822381.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.78    0.787          0.778       0.776         0.865    0.883
#
#   train_recall train_accuracy  \
# 0  0.849        0.865
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f83df6909e8>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-20 20:17:16.430164.pickle
# time: 43min 48s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
model1s = [salvador_wrap('../data/word2vec_%.2d.bin'% (number)) for number in range(1,8+1,1)]
def inner_CV_for_model1(corp, model1, method):
    p2_lgbm = {'class_weight':'balanced', 'boosting':'gbrt'}
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp} 
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8, field = 'model1')
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    from models.fmin2 import p2_lgbm
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 10:57:20.177598
# {'model1': <models.features.salvador_wrap object at 0x7f849f749828>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 10:57:21.685082
# [0.7483870967741936, 0.7654320987654321, 0.7662337662337663, 0.7857142857142857, 0.8292682926829269]
# 0.7790071080341209
# -0.7790071080341209 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83de2ad940>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:00:18.599753
# [0.7643312101910827, 0.7682926829268293, 0.7848101265822786, 0.7560975609756098, 0.7922077922077922]
# 0.7731478745767186
# -0.7731478745767186 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83defe85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:03:04.700249
# [0.5641025641025641, 0.6545454545454545, 0.6547619047619048, 0.7023809523809522, 0.5911949685534591]
# 0.6333971688688669
# -0.6333971688688669 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83dfb024a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:10:00.254331
# [0.7209302325581395, 0.6666666666666666, 0.6025641025641025, 0.6358381502890174, 0.6744186046511628]
# 0.6600835513458178
# -0.6600835513458178 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df213390>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:11:53.448792
# [0.7341772151898733, 0.7283950617283951, 0.782051282051282, 0.7738095238095237, 0.810126582278481]
# 0.765711933011511
# -0.765711933011511 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83debaf278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:13:28.248643
# [0.6219512195121951, 0.6335403726708074, 0.6075949367088607, 0.5960264900662252, 0.6835443037974683]
# 0.6285314645511113
# -0.6285314645511113 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83d7cd7160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:15:06.080847
# [0.6555555555555554, 0.6459627329192547, 0.7023809523809522, 0.6375, 0.6857142857142857]
# 0.6654227053140096
# -0.6654227053140096 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83d7b17048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de516c18>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:17:03.124906
# [0.6190476190476192, 0.6057142857142858, 0.6172839506172839, 0.6153846153846153, 0.7305389221556886]
# 0.6375938785838986
# -0.6375938785838986 -0.7790071080341209 1
# {'model1': <models.features.salvador_wrap object at 0x7f83de516668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de6ca2e8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:18:51.376645
# [0.735483870967742, 0.7515151515151515, 0.7785234899328859, 0.7857142857142857, 0.8170731707317073]
# 0.7736619937723545
# -0.7736619937723545 -0.7736619937723545
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:30:14.917490
# [0.7261146496815287, 0.7425149700598802, 0.7435897435897435, 0.7784431137724551, 0.8048780487804876]
# 0.759108105176819
# -0.759108105176819 -0.7736619937723545
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 11:38:48.392744
# [0.7272727272727273, 0.7544910179640719, 0.7894736842105262, 0.783625730994152, 0.8255813953488372]
# 0.776088911158063
# -0.776088911158063 -0.776088911158063
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 11:51:04.166757
# [0.7225806451612903, 0.7577639751552795, 0.7567567567567567, 0.8023952095808382, 0.85]
# 0.777899317330833
# -0.777899317330833 -0.777899317330833
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 12:01:16.596427
# [0.7189542483660132, 0.7560975609756098, 0.7792207792207793, 0.8, 0.8402366863905325]
# 0.778901854990587
# -0.778901854990587 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:11:50.362403
# [0.735483870967742, 0.7411764705882353, 0.7763157894736843, 0.7906976744186047, 0.8383233532934132]
# 0.7763994317483359
# -0.7763994317483359 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:25:08.448162
# [0.7261146496815287, 0.7469879518072289, 0.7848101265822786, 0.7975460122699387, 0.8313253012048193]
# 0.7773568083091589
# -0.7773568083091589 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 12:35:53.539385
# [0.7162162162162161, 0.7544910179640719, 0.7662337662337663, 0.7810650887573963, 0.8333333333333334]
# 0.7702678845009568
# -0.7702678845009568 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 12:49:15.314695
# [0.7388535031847134, 0.7469879518072289, 0.782051282051282, 0.7928994082840236, 0.8048780487804876]
# 0.7731340388215472
# -0.7731340388215472 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:58:20.391161
# [0.7272727272727273, 0.7560975609756098, 0.7594936708860759, 0.7882352941176471, 0.8383233532934132]
# 0.7738845213090947
# -0.7738845213090947 -0.778901854990587
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 13:08:22.761342
# [0.7407407407407407, 0.787878787878788, 0.7712418300653595, 0.7861271676300579, 0.8098159509202455]
# 0.7791608954470383
# -0.7791608954470383 -0.7791608954470383
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 13:23:27.826083
# [0.7388535031847134, 0.7607361963190185, 0.7515923566878981, 0.7790697674418605, 0.8292682926829269]
# 0.7719040232632836
# -0.7719040232632836 -0.7791608954470383
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 13:45:47.986504
# [0.7483870967741936, 0.7777777777777778, 0.7785234899328859, 0.7953216374269005, 0.8242424242424243]
# 0.7848504852308363
# -0.7848504852308363 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:08:27.201535
# [0.7468354430379747, 0.7654320987654321, 0.782051282051282, 0.7810650887573963, 0.8165680473372781]
# 0.7783903919898727
# -0.7783903919898727 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 14:23:58.127483
# [0.735483870967742, 0.7607361963190185, 0.758169934640523, 0.8047337278106509, 0.8363636363636364]
# 0.7790974732203142
# -0.7790974732203142 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 14:38:17.172580
# [0.735483870967742, 0.7560975609756098, 0.7792207792207793, 0.7882352941176471, 0.8502994011976048]
# 0.7818673812958765
# -0.7818673812958765 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 14:58:09.331818
# [0.7368421052631579, 0.7682926829268293, 0.7612903225806451, 0.7885714285714285, 0.8372093023255814]
# 0.7784411683335285
# -0.7784411683335285 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 15:21:03.091516
# [0.7169811320754716, 0.7625, 0.7417218543046357, 0.7857142857142857, 0.8176100628930818]
# 0.764905466997495
# -0.764905466997495 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:32:52.518214
# [0.7468354430379747, 0.7530864197530863, 0.7466666666666666, 0.7906976744186047, 0.8095238095238095]
# 0.7693620026800284
# -0.7693620026800284 -0.7848504852308363
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 15:46:02.117119
# [0.7374999999999999, 0.7469879518072289, 0.782608695652174, 0.7674418604651162, 0.7950310559006211]
# 0.765913912765028
# -0.765913912765028 -0.7848504852308363
# {'model1': <models.features.salvador_wrap object at 0x7f849f640d30>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f83df579550>}
# 0.7980769230769231
# outer fold
# 2019-08-21 16:00:40.695562
# {'model1': <models.features.salvador_wrap object at 0x7f849f749828>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:00:41.118760
# [0.7435897435897435, 0.7051282051282051, 0.7346938775510203, 0.8235294117647058, 0.7558139534883721]
# 0.7525510383044094
# -0.7525510383044094 -0.7525510383044094 1
# {'model1': <models.features.salvador_wrap object at 0x7f83de2ad940>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:02:44.125588
# [0.76, 0.7647058823529411, 0.7272727272727273, 0.7701863354037267, 0.735632183908046]
# 0.7515594257874882
# -0.7515594257874882 -0.7525510383044094 1
# {'model1': <models.features.salvador_wrap object at 0x7f83defe85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:04:55.536506
# [0.5771812080536912, 0.5974025974025974, 0.6627218934911243, 0.6496815286624203, 0.6265060240963856]
# 0.6226986503412437
# -0.6226986503412437 -0.7525510383044094 1
# {'model1': <models.features.salvador_wrap object at 0x7f83dfb024a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:07:09.748654
# [0.6511627906976745, 0.5838509316770186, 0.6357615894039735, 0.7159090909090908, 0.6551724137931035]
# 0.6483713632961722
# -0.6483713632961722 -0.7525510383044094 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df213390>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:09:13.287401
# [0.7814569536423841, 0.7764705882352941, 0.7417218543046357, 0.8187134502923977, 0.7374999999999999]
# 0.7711725692949423
# -0.7711725692949423 -0.7711725692949423 5
# {'model1': <models.features.salvador_wrap object at 0x7f83debaf278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:11:28.641212
# [0.6143790849673203, 0.6710526315789473, 0.6794871794871794, 0.6875000000000001, 0.5714285714285714]
# 0.6447694934924038
# -0.6447694934924038 -0.7711725692949423 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7cd7160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:13:48.658300
# [0.6578947368421051, 0.6419753086419753, 0.6459627329192547, 0.7386363636363638, 0.6832298136645963]
# 0.673539791140859
# -0.673539791140859 -0.7711725692949423 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7b17048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83df0a7e48>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:16:02.386471
# [0.650887573964497, 0.5853658536585366, 0.6211180124223602, 0.7176470588235295, 0.5595238095238095]
# 0.6269084616785465
# -0.6269084616785465 -0.7711725692949423 5
# {'model1': <models.features.salvador_wrap object at 0x7f849f6d0da0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f640da0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:18:15.110434
# [0.7631578947368421, 0.7951807228915663, 0.7466666666666666, 0.8070175438596491, 0.7425149700598802]
# 0.7709075596429209
# -0.7709075596429209 -0.7709075596429209
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:34:56.928890
# [0.7721518987341771, 0.7999999999999999, 0.7770700636942676, 0.8304093567251462, 0.7484662576687118]
# 0.7856195153644605
# -0.7856195153644605 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:47:28.220689
# [0.7785234899328859, 0.7804878048780488, 0.7763157894736843, 0.8235294117647058, 0.7283950617283951]
# 0.7774503115555439
# -0.7774503115555439 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 17:05:54.393702
# [0.7692307692307692, 0.773006134969325, 0.7682119205298013, 0.8470588235294118, 0.7204968944099378]
# 0.7756009085338491
# -0.7756009085338491 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:19:48.658114
# [0.7672955974842767, 0.7810650887573963, 0.7631578947368421, 0.8452380952380952, 0.7515923566878981]
# 0.7816698065809018
# -0.7816698065809018 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:34:06.250529
# [0.7741935483870969, 0.7857142857142857, 0.7516778523489933, 0.8187134502923977, 0.7349397590361447]
# 0.7730477791557837
# -0.7730477791557837 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:53:04.650560
# [0.7662337662337663, 0.7701863354037267, 0.76, 0.8284023668639053, 0.7530864197530863]
# 0.775581777650897
# -0.775581777650897 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 18:10:12.473411
# [0.7894736842105262, 0.7625, 0.7814569536423841, 0.8352941176470587, 0.7407407407407407]
# 0.781893099248142
# -0.781893099248142 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 18:33:44.951826
# [0.7612903225806451, 0.7421383647798742, 0.7417218543046357, 0.8165680473372782, 0.7407407407407407]
# 0.7604918659486348
# -0.7604918659486348 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:48:23.531385
# [0.7682119205298013, 0.7710843373493975, 0.7631578947368421, 0.8383233532934131, 0.7484662576687118]
# 0.7778487527156331
# -0.7778487527156331 -0.7856195153644605
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 19:04:37.073458
# [0.7733333333333333, 0.7901234567901234, 0.7631578947368421, 0.8402366863905325, 0.7636363636363638]
# 0.7860975469774389
# -0.7860975469774389 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:18:36.927708
# [0.7692307692307692, 0.7757575757575756, 0.7631578947368421, 0.8313253012048193, 0.7317073170731708]
# 0.7742357716006355
# -0.7742357716006355 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:34:17.774257
# [0.7755102040816326, 0.7831325301204819, 0.7814569536423841, 0.8143712574850299, 0.7272727272727273]
# 0.7763487345204512
# -0.7763487345204512 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:52:49.007368
# [0.7515923566878981, 0.7682926829268293, 0.7866666666666667, 0.8284023668639053, 0.7544910179640719]
# 0.7778890182218742
# -0.7778890182218742 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 20:06:18.296690
# [0.7843137254901961, 0.782608695652174, 0.7482993197278912, 0.8333333333333334, 0.7374999999999999]
# 0.777211014840719
# -0.777211014840719 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 20:23:50.578446
# [0.7922077922077922, 0.7757575757575756, 0.7651006711409395, 0.8214285714285715, 0.7283950617283951]
# 0.7765779344526549
# -0.7765779344526549 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:43:19.450558
# [0.7612903225806451, 0.7882352941176471, 0.7712418300653595, 0.8235294117647058, 0.7228915662650603]
# 0.7734376849586836
# -0.7734376849586836 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 21:03:47.388379
# [0.7612903225806451, 0.782608695652174, 0.75, 0.8263473053892216, 0.7625]
# 0.7765492647244081
# -0.7765492647244081 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:16:34.838765
# [0.7692307692307692, 0.7852760736196319, 0.7631578947368421, 0.813953488372093, 0.7361963190184049]
# 0.7735629089955482
# -0.7735629089955482 -0.7860975469774389
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 21:31:53.644442
# [0.7898089171974522, 0.7831325301204819, 0.8026315789473684, 0.7906976744186047, 0.7798742138364779]
# 0.789228982904077
# -0.789228982904077 -0.789228982904077
# {'model1': <models.features.salvador_wrap object at 0x7f849f7f7cc0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f849f722a90>}
# 0.7942583732057416
# outer fold
# 2019-08-21 21:45:52.930992
# {'model1': <models.features.salvador_wrap object at 0x7f849f749828>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:45:53.464624
# [0.738095238095238, 0.7777777777777778, 0.7307692307692308, 0.7757575757575756, 0.7320261437908497]
# 0.7508851932381344
# -0.7508851932381344 -0.7508851932381344 1
# {'model1': <models.features.salvador_wrap object at 0x7f83de2ad940>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:48:09.504144
# [0.7225806451612903, 0.7625, 0.7483870967741936, 0.7636363636363638, 0.7594936708860759]
# 0.7513195552915847
# -0.7513195552915847 -0.7513195552915847 2
# {'model1': <models.features.salvador_wrap object at 0x7f83defe85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:50:18.671579
# [0.6107784431137725, 0.6390532544378698, 0.7152317880794701, 0.6227544910179641, 0.6257668711656442]
# 0.6427169695629441
# -0.6427169695629441 -0.7513195552915847 2
# {'model1': <models.features.salvador_wrap object at 0x7f83dfb024a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:52:04.457736
# [0.6153846153846153, 0.5733333333333334, 0.6705202312138728, 0.5988023952095808, 0.5766871165644172]
# 0.6069455383411638
# -0.6069455383411638 -0.7513195552915847 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df213390>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:53:53.162991
# [0.7305389221556886, 0.7721518987341771, 0.8157894736842104, 0.7484662576687118, 0.7682926829268293]
# 0.7670478470339235
# -0.7670478470339235 -0.7670478470339235 5
# {'model1': <models.features.salvador_wrap object at 0x7f83debaf278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:56:19.717443
# [0.654320987654321, 0.6787878787878788, 0.6625, 0.6285714285714286, 0.6503067484662577]
# 0.6548974086959772
# -0.6548974086959772 -0.7670478470339235 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7cd7160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:58:48.032842
# [0.6242038216560509, 0.6627218934911243, 0.7295597484276728, 0.6390532544378698, 0.6900584795321638]
# 0.6691194395089763
# -0.6691194395089763 -0.7670478470339235 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7b17048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7145c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 22:00:37.969729
# [0.6190476190476192, 0.6823529411764707, 0.616279069767442, 0.6459627329192547, 0.6629213483146067]
# 0.6453127422450786
# -0.6453127422450786 -0.7670478470339235 5
# {'model1': <models.features.salvador_wrap object at 0x7f83de3e4278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f649fd0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 22:02:25.610601
# [0.7777777777777778, 0.7792207792207793, 0.782608695652174, 0.7607361963190185, 0.7749999999999999]
# 0.7750686897939498
# -0.7750686897939498 -0.7750686897939498
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 22:14:22.616172
# [0.7757575757575756, 0.8024691358024691, 0.8104575163398693, 0.7515151515151515, 0.7560975609756098]
# 0.779259388078135
# -0.779259388078135 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:22:56.459246
# [0.7625, 0.7770700636942676, 0.7654320987654321, 0.7453416149068324, 0.773006134969325]
# 0.7646699824671714
# -0.7646699824671714 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 22:36:39.471801
# [0.7484662576687118, 0.782051282051282, 0.7870967741935484, 0.7636363636363638, 0.773006134969325]
# 0.7708513625038462
# -0.7708513625038462 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:47:38.266730
# [0.7530864197530863, 0.7924528301886792, 0.7770700636942676, 0.7329192546583853, 0.7577639751552795]
# 0.7626585086899396
# -0.7626585086899396 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:59:13.503198
# [0.75, 0.782051282051282, 0.7777777777777778, 0.7607361963190185, 0.7749999999999999]
# 0.7691130512296156
# -0.7691130512296156 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:19:47.924262
# [0.7532467532467533, 0.758169934640523, 0.7924528301886792, 0.7831325301204819, 0.7469879518072289]
# 0.7667980000007332
# -0.7667980000007332 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 23:38:04.210522
# [0.7643312101910827, 0.7950310559006211, 0.7898089171974522, 0.7439024390243902, 0.7625]
# 0.7711147244627092
# -0.7711147244627092 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 23:53:16.644673
# [0.7749999999999999, 0.7741935483870969, 0.7804878048780488, 0.7654320987654321, 0.7560975609756098]
# 0.7702422026012374
# -0.7702422026012374 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 00:02:37.101831
# [0.7749999999999999, 0.7948717948717949, 0.7798742138364779, 0.7607361963190185, 0.7757575757575756]
# 0.7772479561569734
# -0.7772479561569734 -0.779259388078135
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 00:12:27.723769
# [0.7804878048780488, 0.782051282051282, 0.7948717948717949, 0.782608695652174, 0.7607361963190185]
# 0.7801511547544637
# -0.7801511547544637 -0.7801511547544637
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:21:08.422850
# [0.7612903225806451, 0.7798742138364779, 0.7798742138364779, 0.7560975609756098, 0.7682926829268293]
# 0.7690857988312081
# -0.7690857988312081 -0.7801511547544637
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:30:56.258660
# [0.7721518987341771, 0.8125000000000001, 0.7898089171974522, 0.773006134969325, 0.7547169811320754]
# 0.780436786406606
# -0.780436786406606 -0.780436786406606
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:44:23.454427
# [0.7770700636942676, 0.7662337662337663, 0.7515923566878981, 0.787878787878788, 0.7784431137724551]
# 0.7722436176534351
# -0.7722436176534351 -0.780436786406606
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 00:53:12.096655
# [0.7848101265822786, 0.7741935483870969, 0.7870967741935484, 0.7682926829268293, 0.7484662576687118]
# 0.772571877951693
# -0.772571877951693 -0.780436786406606
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:02:21.786587
# [0.7770700636942676, 0.7898089171974522, 0.8076923076923077, 0.7804878048780488, 0.7530864197530863]
# 0.7816291026430324
# -0.7816291026430324 -0.7816291026430324
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:15:00.606829
# [0.7798742138364779, 0.7770700636942676, 0.7777777777777778, 0.7407407407407407, 0.7547169811320754]
# 0.7660359554362678
# -0.7660359554362678 -0.7816291026430324
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 01:28:57.931123
# [0.7875, 0.782608695652174, 0.7701863354037267, 0.7701863354037267, 0.7738095238095237]
# 0.7768581780538303
# -0.7768581780538303 -0.7816291026430324
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 01:38:44.136624
# [0.7692307692307692, 0.7843137254901961, 0.7594936708860759, 0.75, 0.7757575757575756]
# 0.7677591482729234
# -0.7677591482729234 -0.7816291026430324
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:49:39.726908
# [0.7852760736196319, 0.7875, 0.802547770700637, 0.7250000000000001, 0.7664670658682634]
# 0.7733581820377065
# -0.7733581820377065 -0.7816291026430324
# {'model1': <models.features.salvador_wrap object at 0x7f83df0a34a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f83df26dd68>}
# 0.7553191489361702
# outer fold
# 2019-08-22 02:02:13.093152
# {'model1': <models.features.salvador_wrap object at 0x7f849f749828>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:02:13.526092
# [0.7928994082840236, 0.7741935483870969, 0.7973856209150327, 0.7297297297297297, 0.7976190476190476]
# 0.778365470986986
# -0.778365470986986 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83de2ad940>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:04:12.988103
# [0.7515151515151515, 0.7682926829268293, 0.7283950617283951, 0.735483870967742, 0.7857142857142857]
# 0.7538802105704807
# -0.7538802105704807 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83defe85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:06:11.709895
# [0.6666666666666667, 0.6436781609195402, 0.6282051282051282, 0.650887573964497, 0.6754966887417219]
# 0.6529868436995108
# -0.6529868436995108 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83dfb024a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:08:16.249210
# [0.6863905325443787, 0.7126436781609194, 0.6835443037974684, 0.6625, 0.6838709677419356]
# 0.6857898964489404
# -0.6857898964489404 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83df213390>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:10:07.396435
# [0.7749999999999999, 0.7636363636363638, 0.7564102564102564, 0.7341772151898733, 0.8313253012048193]
# 0.7721098272882625
# -0.7721098272882625 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83debaf278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:12:09.928868
# [0.641025641025641, 0.6583850931677019, 0.6745562130177515, 0.6282051282051282, 0.6419753086419753]
# 0.6488294768116395
# -0.6488294768116395 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83d7cd7160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:13:57.720724
# [0.6826347305389222, 0.6013071895424836, 0.6266666666666667, 0.6783625730994153, 0.6790123456790124]
# 0.6535967011053
# -0.6535967011053 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83d7b17048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83dfc609b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:15:53.044415
# [0.6586826347305389, 0.6436781609195402, 0.6107784431137725, 0.5925925925925926, 0.674698795180723]
# 0.6360861253074334
# -0.6360861253074334 -0.778365470986986 1
# {'model1': <models.features.salvador_wrap object at 0x7f83dfc606a0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f849f7f7b00>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:17:57.822023
# [0.7857142857142857, 0.7662337662337663, 0.7852760736196319, 0.7320261437908497, 0.7926829268292682]
# 0.7723866392375603
# -0.7723866392375603 -0.7723866392375603
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:32:29.077350
# [0.757396449704142, 0.782051282051282, 0.810126582278481, 0.7239263803680983, 0.8072289156626505]
# 0.7761459220129308
# -0.7761459220129308 -0.7761459220129308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:44:07.882925
# [0.7904191616766467, 0.7594936708860759, 0.810126582278481, 0.7096774193548386, 0.782608695652174]
# 0.7704651059696432
# -0.7704651059696432 -0.7761459220129308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 02:57:57.323665
# [0.7657142857142857, 0.7466666666666666, 0.7749999999999999, 0.7361963190184049, 0.8170731707317075]
# 0.7681300884262129
# -0.7681300884262129 -0.7761459220129308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 03:09:00.588621
# [0.7810650887573963, 0.717948717948718, 0.7625, 0.7160493827160493, 0.7710843373493975]
# 0.7497295053543123
# -0.7497295053543123 -0.7761459220129308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:20:14.421340
# [0.7784431137724551, 0.7483870967741936, 0.7922077922077922, 0.7195121951219512, 0.7975460122699387]
# 0.7672192420292662
# -0.7672192420292662 -0.7761459220129308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:35:13.863073
# [0.782608695652174, 0.7547169811320754, 0.7721518987341771, 0.7320261437908497, 0.7999999999999999]
# 0.7683007438618552
# -0.7683007438618552 -0.7761459220129308
# ...
# 0.7630206964025457
# -0.7630206964025457 -0.7630206964025457 2
# {'model1': <models.features.salvador_wrap object at 0x7f83defe85c0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:33:48.954008
# [0.6545454545454545, 0.650887573964497, 0.606060606060606, 0.6390532544378698, 0.6432748538011697]
# 0.6387643485619194
# -0.6387643485619194 -0.7630206964025457 2
# {'model1': <models.features.salvador_wrap object at 0x7f83dfb024a8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:35:55.165546
# [0.6589595375722543, 0.6190476190476192, 0.6628571428571428, 0.6627906976744186, 0.6265060240963856]
# 0.6460322042495641
# -0.6460322042495641 -0.7630206964025457 2
# {'model1': <models.features.salvador_wrap object at 0x7f83df213390>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:38:00.905846
# [0.7485380116959064, 0.7225806451612903, 0.7607361963190185, 0.810126582278481, 0.7770700636942676]
# 0.7638102998297928
# -0.7638102998297928 -0.7638102998297928 5
# {'model1': <models.features.salvador_wrap object at 0x7f83debaf278>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:39:54.130036
# [0.567741935483871, 0.6853932584269663, 0.632258064516129, 0.632258064516129, 0.6904761904761905]
# 0.6416255026838572
# -0.6416255026838572 -0.7638102998297928 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7cd7160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:41:58.092946
# [0.6585365853658536, 0.5903614457831325, 0.6455696202531646, 0.7037037037037037, 0.641025641025641]
# 0.6478393992262991
# -0.6478393992262991 -0.7638102998297928 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d7b17048>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83de280ef0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:43:58.969870
# [0.5939393939393939, 0.6704545454545455, 0.6399999999999999, 0.6227544910179641, 0.689655172413793]
# 0.6433607205651393
# -0.6433607205651393 -0.7638102998297928 5
# {'model1': <models.features.salvador_wrap object at 0x7f83d79a67b8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f83d79a6ba8>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 06:45:59.558966
# [0.7160493827160493, 0.773006134969325, 0.7564102564102564, 0.8280254777070064, 0.7741935483870969]
# 0.7695369600379468
# -0.7695369600379468 -0.7695369600379468
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:00:20.844972
# [0.7636363636363638, 0.7329192546583853, 0.7777777777777778, 0.8484848484848484, 0.8026315789473684]
# 0.7850899647009486
# -0.7850899647009486 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:12:07.427679
# [0.75, 0.7654320987654321, 0.7468354430379747, 0.7848101265822786, 0.7662337662337663]
# 0.7626622869238904
# -0.7626622869238904 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 07:29:16.209048
# [0.7283950617283951, 0.7453416149068324, 0.7547169811320754, 0.7950310559006211, 0.7532467532467533]
# 0.7553462933829354
# -0.7553462933829354 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:43:00.014537
# [0.7393939393939394, 0.7672955974842767, 0.75, 0.7804878048780488, 0.7682119205298013]
# 0.7610778524572133
# -0.7610778524572133 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:53:46.724206
# [0.7469879518072289, 0.7564102564102564, 0.7402597402597403, 0.7974683544303799, 0.7733333333333333]
# 0.7628919272481878
# -0.7628919272481878 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:10:30.015129
# [0.7484662576687118, 0.7594936708860759, 0.7547169811320754, 0.8050314465408805, 0.7368421052631579]
# 0.7609100922981804
# -0.7609100922981804 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 08:24:20.859232
# [0.7349397590361447, 0.7564102564102564, 0.7483870967741936, 0.7721518987341771, 0.75]
# 0.7523778021909544
# -0.7523778021909544 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 08:42:32.769460
# [0.7636363636363638, 0.7625, 0.7421383647798742, 0.8395061728395061, 0.7792207792207793]
# 0.7774003360953046
# -0.7774003360953046 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:54:59.679390
# [0.7469879518072289, 0.7770700636942676, 0.7770700636942676, 0.7950310559006211, 0.758169934640523]
# 0.7708658139473815
# -0.7708658139473815 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 09:07:46.881515
# [0.7590361445783134, 0.7564102564102564, 0.7564102564102564, 0.7950310559006211, 0.7898089171974522]
# 0.7713393260993799
# -0.7713393260993799 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:18:46.399359
# [0.7484662576687118, 0.7560975609756098, 0.7577639751552795, 0.8050314465408805, 0.7435897435897435]
# 0.762189796786045
# -0.762189796786045 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:33:05.791062
# [0.7710843373493975, 0.7804878048780488, 0.7547169811320754, 0.7975460122699387, 0.7712418300653595]
# 0.7750153931389641
# -0.7750153931389641 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:47:10.183962
# [0.7439024390243902, 0.7402597402597403, 0.7701863354037267, 0.8192771084337349, 0.802547770700637]
# 0.775234678764446
# -0.775234678764446 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 09:55:15.272825
# [0.782608695652174, 0.7654320987654321, 0.7435897435897435, 0.8152866242038217, 0.7466666666666666]
# 0.7707167657755675
# -0.7707167657755675 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:05:14.684675
# [0.7607361963190185, 0.7749999999999999, 0.75, 0.7950310559006211, 0.7741935483870969]
# 0.7709921601213473
# -0.7709921601213473 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 10:16:34.044488
# [0.7453416149068324, 0.7577639751552795, 0.7468354430379747, 0.7848101265822786, 0.7450980392156864]
# 0.7559698397796103
# -0.7559698397796103 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 10:26:52.160172
# [0.7564102564102564, 0.7435897435897435, 0.7654320987654321, 0.8098159509202455, 0.8176100628930817]
# 0.7785716225157518
# -0.7785716225157518 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 10:33:47.345197
# [0.7305389221556886, 0.7468354430379747, 0.75, 0.8152866242038217, 0.758169934640523]
# 0.7601661848076015
# -0.7601661848076015 -0.7850899647009486
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:42:53.819205
# [0.7439024390243902, 0.7547169811320754, 0.7564102564102564, 0.8271604938271605, 0.7594936708860759]
# 0.7683367682559917
# -0.7683367682559917 -0.7850899647009486
# {'model1': <models.features.salvador_wrap object at 0x7f83d79a6710>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f83d79a6208>}
# 0.7661691542288558
# save to ../pickle/2019-08-22 10:52:18.024686.pickle
# save to ../csv/2019-08-22 10:52:20.127012.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.779   0.78           0.781       0.775         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f83de516668>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 10:52:18.024686.pickle
# save to ../csv/2019-08-22 10:52:20.164045.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.779   0.78           0.781       0.775         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f83de516668>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 10:52:18.024686.pickle
# time: 23h 56min

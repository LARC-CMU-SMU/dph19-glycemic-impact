# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.87 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 15 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
model1s = [salvador_wrap('../data/fasttext_%.2d.bin'% (number)) for number in range(1,8+1,1)]

def inner_CV_for_model1(corp, model1, method):
    print('inner_CV_for_model1')
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    '''
    p2_lr = {'class_weight':'balanced','solver': 'liblinear', 'penalty':'l2'}
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning model1
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8)
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    print('inner_CV_for_model2')
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    # tuning p2: the params for model2
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 10:57:18.285148
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f330948feb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:57:18.544246
# [0.717948717948718, 0.7093023255813952, 0.7204968944099378, 0.735632183908046, 0.7594936708860761]
# 0.7285747585468345
# -0.7285747585468345 -0.7285747585468345 1
# {'model1': <models.features.salvador_wrap object at 0x7f331e2c4d30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:57:44.310388
# [0.7152317880794701, 0.7126436781609194, 0.6987951807228916, 0.75, 0.7950310559006211]
# 0.7343403405727804
# -0.7343403405727804 -0.7343403405727804 2
# {'model1': <models.features.salvador_wrap object at 0x7f331d974c18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:58:10.490395
# [0.6086956521739131, 0.6705202312138728, 0.627906976744186, 0.6781609195402298, 0.7074829931972789]
# 0.6585533545738962
# -0.6585533545738962 -0.7343403405727804 2
# {'model1': <models.features.salvador_wrap object at 0x7f331cfa5b00>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:58:37.085905
# [0.6818181818181818, 0.6931818181818182, 0.6470588235294118, 0.6627218934911243, 0.7272727272727272]
# 0.6824106888586526
# -0.6824106888586526 -0.7343403405727804 2
# {'model1': <models.features.salvador_wrap object at 0x7f331c6579e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:59:02.626071
# [0.7236842105263157, 0.7305389221556886, 0.7594936708860759, 0.7455621301775148, 0.7950310559006211]
# 0.7508619979292431
# -0.7508619979292431 -0.7508619979292431 5
# {'model1': <models.features.salvador_wrap object at 0x7f331bc878d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:59:29.633746
# [0.6010928961748634, 0.6850828729281768, 0.662251655629139, 0.6352941176470588, 0.7362637362637363]
# 0.6639970557285949
# -0.6639970557285949 -0.7508619979292431 5
# {'model1': <models.features.salvador_wrap object at 0x7f331b3387b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 10:59:55.508453
# [0.6011560693641618, 0.7032967032967031, 0.6585365853658536, 0.6263736263736264, 0.6779661016949152]
# 0.653465817219052
# -0.653465817219052 -0.7508619979292431 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a9696a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f340e9842e8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:00:21.056709
# [0.6595744680851063, 0.6748466257668712, 0.6250000000000001, 0.6549707602339181, 0.6832298136645963]
# 0.6595243335500984
# -0.6595243335500984 -0.7508619979292431 5
# {'model1': <models.features.salvador_wrap object at 0x7f33198eed30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319c65438>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:00:46.097943
# [0.7261146496815287, 0.7261904761904762, 0.7564102564102564, 0.7692307692307692, 0.8125]
# 0.7580892303026061
# -0.7580892303026061 -0.7580892303026061
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:01:11.646811
# [0.7236842105263157, 0.7305389221556886, 0.7594936708860759, 0.7455621301775148, 0.7950310559006211]
# 0.7508619979292431
# -0.7508619979292431 -0.7580892303026061
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:01:37.122809
# [0.7236842105263157, 0.7065868263473054, 0.7133757961783439, 0.7415730337078653, 0.7777777777777778]
# 0.7325995289075216
# -0.7325995289075216 -0.7580892303026061
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:02:04.244674
# [0.6933333333333332, 0.7023809523809522, 0.7195121951219512, 0.7241379310344828, 0.6918238993710691]
# 0.7062376622483576
# -0.7062376622483576 -0.7580892303026061
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:02:30.315639
# [0.7019867549668874, 0.703030303030303, 0.7169811320754716, 0.7272727272727273, 0.7407407407407408]
# 0.7180023316172262
# -0.7180023316172262 -0.7580892303026061
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:02:55.695299
# [0.7341772151898733, 0.7469879518072289, 0.7973856209150327, 0.7602339181286549, 0.8466257668711658]
# 0.7770820945823911
# -0.7770820945823911 -0.7770820945823911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:03:20.738407
# [0.6933333333333332, 0.6946107784431137, 0.7195121951219512, 0.7241379310344828, 0.6913580246913581]
# 0.7045904525248478
# -0.7045904525248478 -0.7770820945823911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:03:46.850881
# [0.6933333333333332, 0.6951219512195121, 0.7160493827160493, 0.7167630057803468, 0.7037037037037036]
# 0.704994275350589
# -0.704994275350589 -0.7770820945823911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:04:13.681040
# [0.7096774193548386, 0.7590361445783134, 0.7792207792207793, 0.7469879518072289, 0.825]
# 0.7639844589922319
# -0.7639844589922319 -0.7770820945823911
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:04:39.969509
# [0.7051282051282051, 0.7006369426751592, 0.7682926829268293, 0.75, 0.8104575163398693]
# 0.7469030694140125
# -0.7469030694140125 -0.7770820945823911
# {'model1': <models.features.salvador_wrap object at 0x7f3319a5b2e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f33195b40f0>}
# 0.7926267281105991
# outer fold
# 2019-08-21 11:05:09.481888
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f330948feb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:05:09.723633
# [0.7228915662650603, 0.7361963190184049, 0.7125, 0.7926829268292682, 0.7664670658682634]
# 0.7461475755961994
# -0.7461475755961994 -0.7461475755961994 1
# {'model1': <models.features.salvador_wrap object at 0x7f331e2c4d30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:05:34.761179
# [0.7283950617283951, 0.7738095238095237, 0.6624203821656051, 0.7738095238095237, 0.75]
# 0.7376868983026095
# -0.7376868983026095 -0.7461475755961994 1
# {'model1': <models.features.salvador_wrap object at 0x7f331d974c18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:06:00.062791
# [0.6627218934911243, 0.6385542168674699, 0.6163522012578617, 0.7032967032967031, 0.6625]
# 0.6566850029826319
# -0.6566850029826319 -0.7461475755961994 1
# {'model1': <models.features.salvador_wrap object at 0x7f331cfa5b00>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:06:25.023551
# [0.738095238095238, 0.7294117647058823, 0.6705202312138728, 0.711864406779661, 0.6347305389221557]
# 0.696924435943362
# -0.696924435943362 -0.7461475755961994 1
# {'model1': <models.features.salvador_wrap object at 0x7f331c6579e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:06:49.213254
# [0.7204968944099378, 0.7577639751552795, 0.6962025316455697, 0.7976878612716762, 0.7586206896551724]
# 0.7461543904275272
# -0.7461543904275272 -0.7461543904275272 5
# {'model1': <models.features.salvador_wrap object at 0x7f331bc878d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:07:14.814715
# [0.6335403726708074, 0.6815642458100559, 0.6923076923076923, 0.6779661016949152, 0.6033519553072626]
# 0.6577460735581466
# -0.6577460735581466 -0.7461543904275272 5
# {'model1': <models.features.salvador_wrap object at 0x7f331b3387b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:07:39.477126
# [0.6024096385542168, 0.6511627906976745, 0.5476190476190477, 0.6923076923076923, 0.6153846153846153]
# 0.6217767569126493
# -0.6217767569126493 -0.7461543904275272 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a9696a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319e27710>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:08:03.753992
# [0.7023809523809522, 0.7085714285714286, 0.6792452830188679, 0.6900584795321638, 0.7000000000000001]
# 0.6960512287006825
# -0.6960512287006825 -0.7461543904275272 5
# {'model1': <models.features.salvador_wrap object at 0x7f3319d04940>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319548e48>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:08:29.151743
# [0.75, 0.773006134969325, 0.6967741935483871, 0.8092485549132948, 0.7485380116959064]
# 0.7555133790253826
# -0.7555133790253826 -0.7555133790253826
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:08:54.267728
# [0.7204968944099378, 0.7577639751552795, 0.6962025316455697, 0.7976878612716762, 0.7586206896551724]
# 0.7461543904275272
# -0.7461543904275272 -0.7555133790253826
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:09:19.789079
# [0.6883116883116883, 0.7515923566878981, 0.6878980891719745, 0.8072289156626505, 0.7471264367816093]
# 0.7364314973231642
# -0.7364314973231642 -0.7555133790253826
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:09:45.023051
# [0.6875000000000001, 0.7435897435897435, 0.6883116883116883, 0.7857142857142857, 0.6976744186046511]
# 0.7205580272440737
# -0.7205580272440737 -0.7555133790253826
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:10:10.785116
# [0.6878980891719745, 0.7236842105263157, 0.6967741935483871, 0.7857142857142857, 0.7283236994219653]
# 0.7244788956765856
# -0.7244788956765856 -0.7555133790253826
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:10:35.045097
# [0.7643312101910827, 0.7757575757575756, 0.758169934640523, 0.8143712574850299, 0.7764705882352941]
# 0.777820113261901
# -0.777820113261901 -0.777820113261901
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:11:00.104584
# [0.6918238993710691, 0.7435897435897435, 0.6928104575163399, 0.7857142857142857, 0.7126436781609194]
# 0.7253164128704714
# -0.7253164128704714 -0.777820113261901
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:11:25.625324
# [0.6835443037974684, 0.735483870967742, 0.6928104575163399, 0.7976190476190476, 0.72]
# 0.7258915359801195
# -0.7258915359801195 -0.777820113261901
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:11:51.049994
# [0.7515923566878981, 0.7777777777777778, 0.7662337662337663, 0.8192771084337349, 0.7484662576687118]
# 0.7726694533603778
# -0.7726694533603778 -0.777820113261901
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:12:14.985257
# [0.7643312101910827, 0.7701863354037267, 0.7482993197278912, 0.7999999999999999, 0.7283236994219653]
# 0.7622281129489331
# -0.7622281129489331 -0.777820113261901
# {'model1': <models.features.salvador_wrap object at 0x7f3319d034a8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f3319548358>}
# 0.7788461538461539
# outer fold
# 2019-08-21 11:12:44.712199
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f330948feb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:12:44.949236
# [0.6666666666666667, 0.7468354430379747, 0.7317073170731708, 0.7484662576687118, 0.710843373493976]
# 0.7209038115880999
# -0.7209038115880999 -0.7209038115880999 1
# {'model1': <models.features.salvador_wrap object at 0x7f331e2c4d30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:13:09.831624
# [0.6748466257668712, 0.7515923566878981, 0.7204968944099378, 0.7469879518072289, 0.7228915662650603]
# 0.7233630789873993
# -0.7233630789873993 -0.7233630789873993 2
# {'model1': <models.features.salvador_wrap object at 0x7f331d974c18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:13:34.533702
# [0.6153846153846153, 0.7159090909090908, 0.7023809523809522, 0.6818181818181818, 0.6496815286624203]
# 0.6730348738310521
# -0.6730348738310521 -0.7233630789873993 2
# {'model1': <models.features.salvador_wrap object at 0x7f331cfa5b00>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:13:59.729695
# [0.6227544910179641, 0.7142857142857143, 0.674698795180723, 0.6783625730994153, 0.6781609195402298]
# 0.6736524986248094
# -0.6736524986248094 -0.7233630789873993 2
# {'model1': <models.features.salvador_wrap object at 0x7f331c6579e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:14:23.817131
# [0.7195121951219512, 0.7636363636363638, 0.7407407407407407, 0.7674418604651162, 0.7577639751552795]
# 0.7498190270238902
# -0.7498190270238902 -0.7498190270238902 5
# {'model1': <models.features.salvador_wrap object at 0x7f331bc878d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:14:48.608572
# [0.631578947368421, 0.6265060240963856, 0.7159090909090908, 0.6853932584269663, 0.7134502923976608]
# 0.6745675226397049
# -0.6745675226397049 -0.7498190270238902 5
# {'model1': <models.features.salvador_wrap object at 0x7f331b3387b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:15:13.537664
# [0.6737967914438502, 0.6628571428571428, 0.6352941176470588, 0.6703910614525139, 0.6477272727272727]
# 0.6580132772255677
# -0.6580132772255677 -0.7498190270238902 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a9696a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319982be0>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:15:38.063696
# [0.6666666666666666, 0.6853932584269663, 0.7073170731707318, 0.6390532544378698, 0.7386363636363638]
# 0.6874133232677196
# -0.6874133232677196 -0.7498190270238902 5
# {'model1': <models.features.salvador_wrap object at 0x7f33195c0f98>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f330634ddd8>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:16:02.846132
# [0.7305389221556886, 0.7625, 0.7261146496815287, 0.7738095238095237, 0.7544910179640719]
# 0.7494908227221625
# -0.7494908227221625 -0.7494908227221625
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:16:27.805271
# [0.7195121951219512, 0.7636363636363638, 0.7407407407407407, 0.7674418604651162, 0.7577639751552795]
# 0.7498190270238902
# -0.7498190270238902 -0.7498190270238902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:16:52.878890
# [0.7093023255813952, 0.7125, 0.7044025157232704, 0.7630057803468208, 0.7682926829268293]
# 0.7315006609156631
# -0.7315006609156631 -0.7498190270238902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:17:18.601517
# [0.6626506024096386, 0.6792452830188679, 0.6625, 0.7558139534883721, 0.7407407407407407]
# 0.7001901159315238
# -0.7001901159315238 -0.7498190270238902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:17:45.562382
# [0.7093023255813952, 0.7006369426751592, 0.675, 0.7602339181286549, 0.7515151515151515]
# 0.7193376675800721
# -0.7193376675800721 -0.7498190270238902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:18:12.584181
# [0.75, 0.7870967741935484, 0.7532467532467533, 0.7831325301204819, 0.7777777777777778]
# 0.7702507670677122
# -0.7702507670677122 -0.7702507670677122
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:18:37.604291
# [0.6626506024096386, 0.6878980891719745, 0.6666666666666667, 0.7558139534883721, 0.7484662576687118]
# 0.7042991138810728
# -0.7042991138810728 -0.7702507670677122
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:19:03.866450
# [0.6586826347305389, 0.6962025316455697, 0.6708860759493671, 0.7558139534883721, 0.7484662576687118]
# 0.706010290696512
# -0.706010290696512 -0.7702507670677122
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:19:30.492059
# [0.7560975609756098, 0.8076923076923077, 0.7692307692307692, 0.8143712574850299, 0.7594936708860759]
# 0.7813771132539584
# -0.7813771132539584 -0.7813771132539584
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:19:57.203066
# [0.7317073170731708, 0.7671232876712328, 0.7547169811320754, 0.782051282051282, 0.75]
# 0.7571197735855522
# -0.7571197735855522 -0.7813771132539584
# {'model1': <models.features.salvador_wrap object at 0x7f33199f8208>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f33197f91d0>}
# 0.8041237113402062
# outer fold
# 2019-08-21 11:20:28.398109
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f330948feb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:20:28.861532
# [0.72, 0.7701863354037267, 0.7682926829268293, 0.6918238993710691, 0.7857142857142857]
# 0.7472034406831821
# -0.7472034406831821 -0.7472034406831821 1
# {'model1': <models.features.salvador_wrap object at 0x7f331e2c4d30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:20:54.683659
# [0.7116564417177914, 0.7607361963190185, 0.7425149700598802, 0.6794871794871794, 0.7810650887573963]
# 0.7350919752682532
# -0.7350919752682532 -0.7472034406831821 1
# {'model1': <models.features.salvador_wrap object at 0x7f331d974c18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:21:20.368648
# [0.6951871657754011, 0.6588235294117647, 0.6626506024096386, 0.6404494382022472, 0.6857142857142857]
# 0.6685650043026674
# -0.6685650043026674 -0.7472034406831821 1
# {'model1': <models.features.salvador_wrap object at 0x7f331cfa5b00>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:21:45.224656
# [0.710843373493976, 0.7017543859649122, 0.6547619047619048, 0.6626506024096386, 0.7032967032967031]
# 0.6866613939854269
# -0.6866613939854269 -0.7472034406831821 1
# {'model1': <models.features.salvador_wrap object at 0x7f331c6579e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:22:10.305127
# [0.7590361445783134, 0.7975460122699387, 0.7951807228915663, 0.675, 0.7816091954022988]
# 0.7616744150284235
# -0.7616744150284235 -0.7616744150284235 5
# {'model1': <models.features.salvador_wrap object at 0x7f331bc878d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:22:34.985024
# [0.6850828729281768, 0.6931818181818182, 0.6779661016949152, 0.6250000000000001, 0.6748466257668712]
# 0.6712154837143564
# -0.6712154837143564 -0.7616744150284235 5
# {'model1': <models.features.salvador_wrap object at 0x7f331b3387b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:23:00.444049
# [0.7134502923976608, 0.6352941176470588, 0.6582278481012659, 0.6081871345029239, 0.6436781609195402]
# 0.6517675107136899
# -0.6517675107136899 -0.7616744150284235 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a9696a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f3319d013c8>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:23:24.738449
# [0.7111111111111111, 0.6956521739130435, 0.6303030303030304, 0.6385542168674699, 0.7322404371584699]
# 0.681572193870625
# -0.681572193870625 -0.7616744150284235 5
# {'model1': <models.features.salvador_wrap object at 0x7f3319ce8a58>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33198eeda0>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:23:50.936491
# [0.7875, 0.7875, 0.7976190476190476, 0.6878980891719745, 0.8068181818181818]
# 0.7734670637218407
# -0.7734670637218407 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:24:16.936736
# [0.7590361445783134, 0.7975460122699387, 0.7951807228915663, 0.675, 0.7816091954022988]
# 0.7616744150284235
# -0.7616744150284235 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:24:42.908506
# [0.7239263803680983, 0.7692307692307692, 0.7951807228915663, 0.6883116883116883, 0.7999999999999999]
# 0.7553299121604244
# -0.7553299121604244 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:25:07.797042
# [0.7044025157232704, 0.7261146496815287, 0.7515151515151515, 0.6875000000000001, 0.7666666666666667]
# 0.7272397967173234
# -0.7272397967173234 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:25:34.279118
# [0.7080745341614907, 0.7402597402597403, 0.7757575757575756, 0.6923076923076923, 0.7845303867403315]
# 0.7401859858453662
# -0.7401859858453662 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:26:00.940933
# [0.782608695652174, 0.7749999999999999, 0.7898089171974522, 0.7012987012987013, 0.813953488372093]
# 0.7725339605040841
# -0.7725339605040841 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:26:25.840194
# [0.7125, 0.7307692307692308, 0.7560975609756098, 0.6875000000000001, 0.7734806629834253]
# 0.7320694909456532
# -0.7320694909456532 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:26:53.652913
# [0.7125, 0.7468354430379747, 0.7530864197530863, 0.6875000000000001, 0.759776536312849]
# 0.7319396798207819
# -0.7319396798207819 -0.7734670637218407
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:27:21.417046
# [0.7749999999999999, 0.7857142857142857, 0.782051282051282, 0.7105263157894737, 0.8284023668639053]
# 0.7763388500837893
# -0.7763388500837893 -0.7763388500837893
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:27:46.903929
# [0.7484662576687118, 0.810126582278481, 0.7672955974842767, 0.6666666666666667, 0.7928994082840236]
# 0.7570909024764318
# -0.7570909024764318 -0.7763388500837893
# {'model1': <models.features.salvador_wrap object at 0x7f3319dbe7b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f33199f8438>}
# 0.7757009345794393
# outer fold
# 2019-08-21 11:28:18.285081
# inner_CV_for_model1
# {'model1': <models.features.salvador_wrap object at 0x7f330948feb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:28:18.575731
# [0.7134502923976608, 0.7337278106508877, 0.7374999999999999, 0.7142857142857143, 0.7532467532467533]
# 0.7304421141162032
# -0.7304421141162032 -0.7304421141162032 1
# {'model1': <models.features.salvador_wrap object at 0x7f331e2c4d30>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:28:45.407722
# [0.7570621468926554, 0.6835443037974684, 0.7329192546583853, 0.7469879518072289, 0.8]
# 0.7441027314311477
# -0.7441027314311477 -0.7441027314311477 2
# {'model1': <models.features.salvador_wrap object at 0x7f331d974c18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:12.257332
# [0.6779661016949152, 0.6206896551724138, 0.6585365853658536, 0.6549707602339181, 0.6900584795321638]
# 0.6604443163998528
# -0.6604443163998528 -0.7441027314311477 2
# {'model1': <models.features.salvador_wrap object at 0x7f331cfa5b00>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:29:38.944703
# [0.6779661016949152, 0.674698795180723, 0.7011494252873562, 0.7317073170731708, 0.7052023121387283]
# 0.6981447902749787
# -0.6981447902749787 -0.7441027314311477 2
# {'model1': <models.features.salvador_wrap object at 0x7f331c6579e8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:30:04.176381
# [0.7771428571428571, 0.7088607594936708, 0.7283950617283951, 0.7374999999999999, 0.7848101265822786]
# 0.7473417609894403
# -0.7473417609894403 -0.7473417609894403 5
# {'model1': <models.features.salvador_wrap object at 0x7f331bc878d0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:30:30.005088
# [0.6368715083798882, 0.7160493827160493, 0.6516853932584269, 0.7039106145251396, 0.6666666666666666]
# 0.6750367131092341
# -0.6750367131092341 -0.7473417609894403 5
# {'model1': <models.features.salvador_wrap object at 0x7f331b3387b8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:30:55.769577
# [0.6136363636363636, 0.6432748538011697, 0.5949367088607596, 0.6378378378378379, 0.6815642458100559]
# 0.6342500019892373
# -0.6342500019892373 -0.7473417609894403 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a9696a0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33d78c5c88>}
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}
# 2019-08-21 11:31:21.302424
# [0.6470588235294118, 0.686046511627907, 0.6586826347305389, 0.7073170731707318, 0.6823529411764707]
# 0.676291596847012
# -0.676291596847012 -0.7473417609894403 5
# {'model1': <models.features.salvador_wrap object at 0x7f33195c0f28>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2'}, 'corp': <models.features.fixed_makedata object at 0x7f33197fde80>}
# inner_CV_for_model2
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 11:31:47.438265
# [0.7745664739884394, 0.7125, 0.7607361963190185, 0.773006134969325, 0.8125000000000001]
# 0.7666617610553565
# -0.7666617610553565 -0.7666617610553565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 11:32:13.464464
# [0.7771428571428571, 0.7088607594936708, 0.7283950617283951, 0.7374999999999999, 0.7848101265822786]
# 0.7473417609894403
# -0.7473417609894403 -0.7666617610553565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 11:32:39.281108
# [0.7764705882352941, 0.7204968944099378, 0.7317073170731708, 0.7361963190184049, 0.7662337662337663]
# 0.7462209769941148
# -0.7462209769941148 -0.7666617610553565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 11:33:04.922605
# [0.7885714285714285, 0.703030303030303, 0.691358024691358, 0.7006369426751592, 0.7577639751552795]
# 0.7282721348247055
# -0.7282721348247055 -0.7666617610553565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 11:33:31.953492
# [0.7909604519774011, 0.7037037037037037, 0.7195121951219512, 0.7006369426751592, 0.7749999999999999]
# 0.737962658695643
# -0.737962658695643 -0.7666617610553565
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 11:33:57.020605
# [0.8, 0.7361963190184049, 0.7643312101910827, 0.7770700636942676, 0.8211920529801325]
# 0.7797579291767776
# -0.7797579291767776 -0.7797579291767776
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 11:34:23.322313
# [0.7885714285714285, 0.6951219512195121, 0.691358024691358, 0.7006369426751592, 0.7577639751552795]
# 0.7266904644625474
# -0.7266904644625474 -0.7797579291767776
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 11:34:49.264599
# [0.7885714285714285, 0.703030303030303, 0.6956521739130435, 0.6923076923076923, 0.7547169811320754]
# 0.7268557157909085
# -0.7268557157909085 -0.7797579291767776
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 11:35:15.239630
# [0.7719298245614035, 0.7402597402597403, 0.7564102564102564, 0.7798742138364779, 0.825]
# 0.7746948070135756
# -0.7746948070135756 -0.7797579291767776
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 11:35:40.068369
# [0.7529411764705881, 0.7530864197530863, 0.7672955974842767, 0.7560975609756098, 0.8170731707317075]
# 0.7692987850830537
# -0.7692987850830537 -0.7797579291767776
# {'model1': <models.features.salvador_wrap object at 0x7f3319dbe908>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f33d7735a90>}
# 0.7857142857142857
# save to ../pickle/2019-08-21 11:36:11.698018.pickle
# save to ../csv/2019-08-21 11:36:12.364139.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.787   0.778          0.8         0.779         0.887    0.894
#
#   train_recall train_accuracy  \
# 0  0.88         0.885
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f33198eed30>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 11:36:11.698018.pickle
# save to ../csv/2019-08-21 11:36:12.417320.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.787   0.778          0.8         0.779         0.887    0.894
#
#   train_recall train_accuracy  \
# 0  0.88         0.885
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f33198eed30>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 11:36:11.698018.pickle
# time: 39min 7s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
model1s = [salvador_wrap('../data/fasttext_%.2d.bin'% (number)) for number in range(1,8+1,1)]
def inner_CV_for_model1(corp, model1, method):
    p2_lgbm = {'class_weight':'balanced', 'boosting':'gbrt'}
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp} 
    best_space = fmin2_model1(fn = objective, space=spaces, max_evals = 8, field = 'model1')
    print(best_space)
    return best_space['model1']

def inner_CV_for_model2(corp, model1, method):
    from models.fmin2 import p2_lgbm
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wv','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model1 = inner_CV_for_model1(corp.replace(train_index), model1s, method)
        model2 = inner_CV_for_model2(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 11:36:28.557083
# {'model1': <models.features.salvador_wrap object at 0x7f33d7919908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:36:28.810454
# [0.6785714285714286, 0.7317073170731708, 0.7250000000000001, 0.7636363636363638, 0.7974683544303798]
# 0.7392766927422686
# -0.7392766927422686 -0.7392766927422686 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d76f0780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:38:24.595013
# [0.6875000000000001, 0.7388535031847134, 0.7058823529411765, 0.7840909090909091, 0.8407643312101911]
# 0.7514182192853982
# -0.7514182192853982 -0.7514182192853982 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5d2c668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:40:18.658793
# [0.6242774566473989, 0.6586826347305389, 0.6265060240963856, 0.6352941176470588, 0.6585365853658537]
# 0.6406593636974471
# -0.6406593636974471 -0.7514182192853982 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5b6d550>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:42:15.841764
# [0.6327683615819208, 0.6265060240963856, 0.5555555555555556, 0.5454545454545454, 0.6551724137931034]
# 0.6030913800963023
# -0.6030913800963023 -0.7514182192853982 2
# {'model1': <models.features.salvador_wrap object at 0x7f33183c4438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:44:06.945279
# [0.6790123456790124, 0.7485380116959064, 0.7515923566878981, 0.7764705882352941, 0.8280254777070064]
# 0.7567277560010235
# -0.7567277560010235 -0.7567277560010235 5
# {'model1': <models.features.salvador_wrap object at 0x7f3318205320>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:45:54.380590
# [0.5380116959064328, 0.6823529411764707, 0.6233766233766234, 0.6057142857142858, 0.6309523809523809]
# 0.6160815854252387
# -0.6160815854252387 -0.7567277560010235 5
# {'model1': <models.features.salvador_wrap object at 0x7f3318046208>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:47:49.509456
# [0.5421686746987951, 0.5394736842105263, 0.5217391304347826, 0.544378698224852, 0.5680473372781064]
# 0.5431615049694124
# -0.5431615049694124 -0.7567277560010235 5
# {'model1': <models.features.salvador_wrap object at 0x7f330ee5b0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f339780b2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 11:49:23.622876
# [0.6071428571428571, 0.6181818181818182, 0.5657894736842106, 0.5333333333333333, 0.7111111111111111]
# 0.607111718690666
# -0.607111718690666 -0.7567277560010235 5
# {'model1': <models.features.salvador_wrap object at 0x7f331a01a2e8>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d828>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 11:51:07.185902
# [0.6875000000000001, 0.7515151515151515, 0.7012987012987013, 0.7852760736196319, 0.8227848101265822]
# 0.7496749473120133
# -0.7496749473120133 -0.7496749473120133
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 12:02:56.690303
# [0.6826347305389222, 0.7294117647058823, 0.7236842105263157, 0.7757575757575756, 0.8198757763975155]
# 0.7462728115852423
# -0.7462728115852423 -0.7496749473120133
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:12:23.646233
# [0.6787878787878788, 0.7283950617283951, 0.7105263157894737, 0.7857142857142857, 0.8301886792452831]
# 0.7467224442530632
# -0.7467224442530632 -0.7496749473120133
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 12:26:19.498662
# [0.703030303030303, 0.7393939393939394, 0.7152317880794701, 0.7777777777777778, 0.8322981366459627]
# 0.7535463889854906
# -0.7535463889854906 -0.7535463889854906
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 12:37:51.152808
# [0.6583850931677019, 0.7515151515151515, 0.7320261437908497, 0.7393939393939394, 0.825]
# 0.7412640655735284
# -0.7412640655735284 -0.7535463889854906
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 12:48:33.431603
# [0.6787878787878788, 0.7305389221556886, 0.7096774193548386, 0.7577639751552795, 0.825]
# 0.7403536390907371
# -0.7403536390907371 -0.7535463889854906
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 13:03:01.663858
# [0.6666666666666667, 0.7272727272727273, 0.6933333333333332, 0.7738095238095237, 0.818181818181818]
# 0.7358528138528138
# -0.7358528138528138 -0.7535463889854906
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 13:18:47.841160
# [0.6871165644171778, 0.7407407407407407, 0.6973684210526315, 0.7757575757575756, 0.8301886792452831]
# 0.7462343962426816
# -0.7462343962426816 -0.7535463889854906
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 13:36:03.753146
# [0.6871165644171778, 0.761904761904762, 0.717948717948718, 0.7719298245614035, 0.8301886792452831]
# 0.7538177096154689
# -0.7538177096154689 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 13:50:05.824553
# [0.6706586826347306, 0.761904761904762, 0.7225806451612903, 0.7654320987654321, 0.8205128205128205]
# 0.748217801795807
# -0.748217801795807 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 14:03:53.112829
# [0.6835443037974684, 0.7393939393939394, 0.7051282051282051, 0.7906976744186047, 0.8301886792452831]
# 0.7497905603967002
# -0.7497905603967002 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:18:54.277149
# [0.6666666666666666, 0.75, 0.7058823529411765, 0.7719298245614035, 0.825]
# 0.7438957688338494
# -0.7438957688338494 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:32:30.724898
# [0.6829268292682926, 0.7544910179640719, 0.7388535031847134, 0.757396449704142, 0.8227848101265822]
# 0.7512905220495605
# -0.7512905220495605 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:49:11.020727
# [0.6871165644171778, 0.7218934911242604, 0.7341772151898733, 0.7882352941176471, 0.8354430379746836]
# 0.7533731205647284
# -0.7533731205647284 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 14:58:27.939640
# [0.6863905325443787, 0.7239263803680983, 0.728476821192053, 0.7906976744186047, 0.825]
# 0.750898281704627
# -0.750898281704627 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 15:09:10.203713
# [0.6826347305389222, 0.7393939393939394, 0.7320261437908497, 0.7804878048780488, 0.8227848101265822]
# 0.7514654857456685
# -0.7514654857456685 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 15:30:42.429715
# [0.6951219512195121, 0.7439024390243902, 0.7215189873417721, 0.7547169811320754, 0.8375]
# 0.7505520717435499
# -0.7505520717435499 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 15:49:17.240781
# [0.6941176470588235, 0.7250000000000001, 0.7006369426751592, 0.7777777777777778, 0.8414634146341463]
# 0.7477991564291814
# -0.7477991564291814 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:01:02.988879
# [0.6624203821656051, 0.7195121951219512, 0.6986301369863014, 0.7928994082840236, 0.84472049689441]
# 0.7436365238904583
# -0.7436365238904583 -0.7538177096154689
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 16:14:03.625313
# [0.6625766871165645, 0.7218934911242604, 0.7564102564102564, 0.8045977011494253, 0.7948717948717949]
# 0.7480699861344604
# -0.7480699861344604 -0.7538177096154689
# {'model1': <models.features.salvador_wrap object at 0x7f3319607710>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f3319cf4fd0>}
# 0.7439613526570047
# outer fold
# 2019-08-21 16:28:17.684966
# {'model1': <models.features.salvador_wrap object at 0x7f33d7919908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:28:18.188157
# [0.6918238993710691, 0.7317073170731708, 0.7152317880794701, 0.8068181818181818, 0.6787878787878788]
# 0.7248738130259541
# -0.7248738130259541 -0.7248738130259541 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d76f0780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:30:18.976569
# [0.7204968944099378, 0.7643312101910827, 0.7272727272727273, 0.773006134969325, 0.7218934911242604]
# 0.7414000915934668
# -0.7414000915934668 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5d2c668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:32:13.876459
# [0.6451612903225807, 0.6892655367231637, 0.6289308176100629, 0.688888888888889, 0.6583850931677019]
# 0.6621263253424796
# -0.6621263253424796 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5b6d550>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:34:12.204036
# [0.6878980891719745, 0.6989247311827957, 0.606060606060606, 0.6666666666666667, 0.6035502958579881]
# 0.6526200777880062
# -0.6526200777880062 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f33183c4438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:36:04.434989
# [0.7096774193548386, 0.7058823529411765, 0.7152317880794701, 0.7602339181286549, 0.6785714285714286]
# 0.7139193814151137
# -0.7139193814151137 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318205320>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:38:06.985950
# [0.6153846153846153, 0.6588235294117647, 0.6545454545454545, 0.6628571428571428, 0.6046511627906976]
# 0.639252380997935
# -0.639252380997935 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318046208>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:40:02.750319
# [0.5868263473053892, 0.5901639344262295, 0.6049382716049383, 0.6292134831460674, 0.6144578313253012]
# 0.6051199735615851
# -0.6051199735615851 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f330ee5b0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776ff60>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 16:42:00.702510
# [0.6091954022988506, 0.6352941176470588, 0.6666666666666667, 0.6626506024096386, 0.6265060240963856]
# 0.6400625626237201
# -0.6400625626237201 -0.7414000915934668 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d776fa58>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f33d776f5c0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:44:00.593221
# [0.7317073170731708, 0.7612903225806451, 0.7236842105263157, 0.7976190476190476, 0.7272727272727273]
# 0.7483147250143813
# -0.7483147250143813 -0.7483147250143813
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 16:57:37.282374
# [0.7169811320754716, 0.7898089171974522, 0.735483870967742, 0.8047337278106509, 0.7185628742514969]
# 0.7531141044605627
# -0.7531141044605627 -0.7531141044605627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:08:31.866042
# [0.7073170731707318, 0.7770700636942676, 0.7272727272727273, 0.8095238095238094, 0.7305389221556886]
# 0.750344519163445
# -0.750344519163445 -0.7531141044605627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 17:26:01.418987
# [0.7044025157232704, 0.7770700636942676, 0.7058823529411765, 0.8, 0.7368421052631577]
# 0.7448394075243744
# -0.7448394075243744 -0.7531141044605627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 17:39:42.839589
# [0.7044025157232704, 0.7654320987654321, 0.7341772151898733, 0.8023255813953489, 0.7325581395348836]
# 0.7477791101217617
# -0.7477791101217617 -0.7531141044605627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 17:51:37.473372
# [0.7044025157232704, 0.7484662576687118, 0.7307692307692308, 0.8117647058823529, 0.7337278106508877]
# 0.7458261041388907
# -0.7458261041388907 -0.7531141044605627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:07:51.902533
# [0.717948717948718, 0.7798742138364779, 0.7388535031847134, 0.7999999999999999, 0.7664670658682634]
# 0.7606287001676344
# -0.7606287001676344 -0.7606287001676344
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 18:20:08.376647
# [0.7, 0.7625, 0.735483870967742, 0.8072289156626505, 0.7485380116959064]
# 0.7507501596652598
# -0.7507501596652598 -0.7606287001676344
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 18:34:57.990178
# [0.6993865030674846, 0.7483870967741936, 0.7468354430379747, 0.7784431137724551, 0.7017543859649122]
# 0.7349613085234041
# -0.7349613085234041 -0.7606287001676344
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:44:52.192703
# [0.7080745341614907, 0.7631578947368421, 0.7142857142857143, 0.7976190476190476, 0.7251461988304092]
# 0.7416566779267008
# -0.7416566779267008 -0.7606287001676344
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 18:56:08.474242
# [0.7295597484276728, 0.7848101265822786, 0.7577639751552795, 0.8242424242424242, 0.7425149700598802]
# 0.7677782488935071
# -0.7677782488935071 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:05:26.905574
# [0.717948717948718, 0.7770700636942676, 0.7225806451612903, 0.8095238095238094, 0.7185628742514969]
# 0.7491372221159164
# -0.7491372221159164 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:14:49.958009
# [0.6956521739130435, 0.7643312101910827, 0.7225806451612903, 0.8, 0.7294117647058823]
# 0.7423951587942599
# -0.7423951587942599 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 19:30:57.182613
# [0.6875000000000001, 0.7612903225806451, 0.7453416149068324, 0.8214285714285715, 0.7228915662650603]
# 0.7476904150362219
# -0.7476904150362219 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 19:40:23.866918
# [0.7012987012987013, 0.735483870967742, 0.7142857142857143, 0.8143712574850299, 0.7261904761904762]
# 0.7383260040455328
# -0.7383260040455328 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 19:50:25.650855
# [0.7125, 0.7516778523489933, 0.7272727272727273, 0.8023952095808382, 0.7455621301775148]
# 0.7478815838760149
# -0.7478815838760149 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 20:04:23.865508
# [0.7195121951219512, 0.7564102564102564, 0.7307692307692308, 0.8048780487804877, 0.7185628742514969]
# 0.7460265210666847
# -0.7460265210666847 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 20:27:52.566474
# [0.717948717948718, 0.7721518987341771, 0.7388535031847134, 0.8176100628930817, 0.7317073170731708]
# 0.7556542999667721
# -0.7556542999667721 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 20:39:55.168119
# [0.6871165644171778, 0.7770700636942676, 0.7012987012987013, 0.7810650887573963, 0.7514450867052024]
# 0.7395991009745491
# -0.7395991009745491 -0.7677782488935071
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 20:53:50.691933
# [0.7317073170731708, 0.7672955974842767, 0.7215189873417721, 0.8048780487804877, 0.7218934911242604]
# 0.7494586883607935
# -0.7494586883607935 -0.7677782488935071
# {'model1': <models.features.salvador_wrap object at 0x7f331bcf9080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f33d78f15f8>}
# 0.7830188679245282
# outer fold
# 2019-08-21 21:09:10.024986
# {'model1': <models.features.salvador_wrap object at 0x7f33d7919908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:09:10.472301
# [0.738095238095238, 0.6951219512195121, 0.7439024390243902, 0.7349397590361447, 0.7283950617283951]
# 0.728090889820736
# -0.728090889820736 -0.728090889820736 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d76f0780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:11:18.273525
# [0.7151515151515152, 0.7393939393939394, 0.7577639751552795, 0.7810650887573963, 0.7544910179640719]
# 0.7495731072844405
# -0.7495731072844405 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5d2c668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:13:15.154727
# [0.6172839506172839, 0.6748466257668712, 0.6341463414634146, 0.6971428571428572, 0.6666666666666667]
# 0.6580172883314187
# -0.6580172883314187 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5b6d550>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:15:44.242795
# [0.6369426751592356, 0.6549707602339181, 0.7017543859649122, 0.6704545454545455, 0.6583850931677019]
# 0.6645014919960627
# -0.6645014919960627 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f33183c4438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:18:13.478343
# [0.7204968944099378, 0.7764705882352941, 0.7261146496815287, 0.7810650887573963, 0.7215189873417721]
# 0.7451332416851859
# -0.7451332416851859 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318205320>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:20:36.774355
# [0.5696969696969697, 0.6419753086419753, 0.6503067484662577, 0.5802469135802469, 0.659217877094972]
# 0.6202887634960843
# -0.6202887634960843 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318046208>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:23:05.348866
# [0.5952380952380951, 0.5766871165644172, 0.6705882352941176, 0.5939393939393939, 0.595505617977528]
# 0.6063916918027104
# -0.6063916918027104 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f330ee5b0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9898>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-21 21:25:31.587750
# [0.654320987654321, 0.5609756097560975, 0.5696202531645569, 0.5964912280701755, 0.6506024096385542]
# 0.606402097656741
# -0.606402097656741 -0.7495731072844405 2
# {'model1': <models.features.salvador_wrap object at 0x7f331bcf9358>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331bcf9c88>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:27:56.393857
# [0.76, 0.7643312101910827, 0.7701863354037267, 0.7798742138364779, 0.7770700636942676]
# 0.770292364625111
# -0.770292364625111 -0.770292364625111
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:45:26.141532
# [0.7250000000000001, 0.7374999999999999, 0.7922077922077922, 0.7607361963190185, 0.7875]
# 0.7605887977053621
# -0.7605887977053621 -0.770292364625111
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:59:25.903209
# [0.7484662576687118, 0.735483870967742, 0.7749999999999999, 0.782608695652174, 0.8125000000000001]
# 0.7708117648577255
# -0.7708117648577255 -0.7708117648577255
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 22:20:11.024519
# [0.7564102564102564, 0.7307692307692308, 0.7770700636942676, 0.7757575757575756, 0.7974683544303799]
# 0.7674950962123421
# -0.7674950962123421 -0.7708117648577255
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:35:59.511179
# [0.7421383647798742, 0.7564102564102564, 0.8, 0.7857142857142857, 0.7973856209150327]
# 0.7763297055638898
# -0.7763297055638898 -0.7763297055638898
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:51:38.425663
# [0.7547169811320754, 0.7532467532467533, 0.7777777777777778, 0.7607361963190185, 0.8]
# 0.769295541695125
# -0.769295541695125 -0.7763297055638898
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:11:03.999517
# [0.7468354430379747, 0.7594936708860759, 0.7875, 0.7901234567901234, 0.7532467532467533]
# 0.7674398647921855
# -0.7674398647921855 -0.7763297055638898
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 23:29:41.348064
# [0.7564102564102564, 0.7453416149068324, 0.7804878048780488, 0.7831325301204819, 0.8076923076923077]
# 0.7746129028015855
# -0.7746129028015855 -0.7763297055638898
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 23:47:35.505277
# [0.7105263157894737, 0.7515923566878981, 0.7625, 0.7682926829268293, 0.773006134969325]
# 0.7531834980747053
# -0.7531834980747053 -0.7763297055638898
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:57:25.759044
# [0.7515923566878981, 0.75, 0.7798742138364779, 0.7999999999999999, 0.802547770700637]
# 0.7768028682450027
# -0.7768028682450027 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 00:07:51.217047
# [0.72, 0.8, 0.782608695652174, 0.7577639751552795, 0.7770700636942676]
# 0.7674885469003442
# -0.7674885469003442 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:16:29.964036
# [0.7701863354037267, 0.7672955974842767, 0.7770700636942676, 0.7784431137724551, 0.7749999999999999]
# 0.7735990220709452
# -0.7735990220709452 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:25:58.822461
# [0.7388535031847134, 0.7577639751552795, 0.7721518987341771, 0.7901234567901234, 0.7712418300653595]
# 0.7660269327859306
# -0.7660269327859306 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:39:21.518337
# [0.7152317880794701, 0.7721518987341771, 0.7804878048780488, 0.7682926829268293, 0.7948717948717949]
# 0.766207193898064
# -0.766207193898064 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 00:48:16.874501
# [0.7225806451612903, 0.7594936708860759, 0.8024691358024691, 0.7926829268292682, 0.7848101265822786]
# 0.7724073010522764
# -0.7724073010522764 -0.7768028682450027
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 00:57:58.524605
# [0.7625, 0.7393939393939394, 0.7848101265822786, 0.7950310559006211, 0.8024691358024691]
# 0.7768408515358617
# -0.7768408515358617 -0.7768408515358617
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:10:32.628299
# [0.7625, 0.75, 0.7798742138364779, 0.7682926829268293, 0.7792207792207793]
# 0.7679775351968173
# -0.7679775351968173 -0.7768408515358617
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 01:24:24.006149
# [0.7169811320754716, 0.75, 0.7924528301886792, 0.7852760736196319, 0.7798742138364779]
# 0.7649168499440521
# -0.7649168499440521 -0.7768408515358617
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 01:33:59.696367
# [0.717948717948718, 0.7672955974842767, 0.7922077922077922, 0.773006134969325, 0.7974683544303799]
# 0.7695853194080984
# -0.7695853194080984 -0.7768408515358617
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:45:36.678761
# [0.7307692307692308, 0.787878787878788, 0.7625, 0.7361963190184049, 0.7924528301886792]
# 0.7619594335710207
# -0.7619594335710207 -0.7768408515358617
# {'model1': <models.features.salvador_wrap object at 0x7f331e825630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f331bcee080>}
# 0.7659574468085106
# outer fold
# 2019-08-22 01:57:51.894928
# {'model1': <models.features.salvador_wrap object at 0x7f33d7919908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:57:52.365403
# [0.7441860465116279, 0.757396449704142, 0.7560975609756098, 0.6875000000000001, 0.7590361445783134]
# 0.7408432403539386
# -0.7408432403539386 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d76f0780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 01:59:21.082315
# [0.7647058823529411, 0.7333333333333334, 0.7654320987654321, 0.7080745341614907, 0.7088607594936708]
# 0.7360813216213736
# -0.7360813216213736 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d5d2c668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:01:01.772590
# [0.6590909090909091, 0.710843373493976, 0.5694444444444445, 0.6125, 0.6707317073170732]
# 0.6445220868692806
# -0.6445220868692806 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d5b6d550>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:03:02.198497
# [0.6829268292682926, 0.6097560975609756, 0.5949367088607596, 0.6585365853658536, 0.6971428571428572]
# 0.6486598156397476
# -0.6486598156397476 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f33183c4438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:05:00.306753
# [0.738095238095238, 0.7019867549668874, 0.7784431137724551, 0.6883116883116883, 0.7721518987341771]
# 0.7357977387760892
# -0.7357977387760892 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f3318205320>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:06:53.719473
# [0.6826347305389222, 0.6395348837209301, 0.5641025641025641, 0.6705202312138728, 0.6181818181818182]
# 0.6349948455516216
# -0.6349948455516216 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f3318046208>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:08:57.497051
# [0.6470588235294118, 0.6285714285714286, 0.5555555555555556, 0.6419753086419753, 0.6585365853658536]
# 0.6263395403328449
# -0.6263395403328449 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f330ee5b0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319a0d2b0>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 02:10:51.090547
# [0.6516853932584269, 0.5806451612903225, 0.6585365853658536, 0.5949367088607596, 0.5542168674698795]
# 0.6080041432490484
# -0.6080041432490484 -0.7408432403539386 1
# {'model1': <models.features.salvador_wrap object at 0x7f3319a0de80>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331e825828>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:12:52.863590
# [0.738095238095238, 0.7564102564102564, 0.7777777777777778, 0.6623376623376623, 0.7682926829268293]
# 0.7405827235095528
# -0.7405827235095528 -0.7405827235095528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:27:18.991707
# [0.7261904761904762, 0.7612903225806451, 0.7329192546583853, 0.7169811320754716, 0.7848101265822786]
# 0.7444382624174514
# -0.7444382624174514 -0.7444382624174514
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:40:13.352605
# [0.7393939393939394, 0.7577639751552795, 0.773006134969325, 0.6451612903225807, 0.7701863354037267]
# 0.7371023350489703
# -0.7371023350489703 -0.7444382624174514
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 02:54:25.468567
# [0.7560975609756098, 0.7530864197530863, 0.7831325301204819, 0.6835443037974684, 0.8074534161490683]
# 0.7566628461591429
# -0.7566628461591429 -0.7566628461591429
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 03:06:18.179684
# [0.7590361445783134, 0.7421383647798742, 0.7682926829268293, 0.6624203821656051, 0.787878787878788]
# 0.7439532724658819
# -0.7439532724658819 -0.7566628461591429
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:17:16.952587
# [0.7439024390243902, 0.7625, 0.7607361963190185, 0.6748466257668712, 0.7804878048780488]
# 0.7444946131976657
# -0.7444946131976657 -0.7566628461591429
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:32:36.634059
# [0.7544910179640719, 0.8050314465408805, 0.7654320987654321, 0.6751592356687897, 0.7643312101910827]
# 0.7528890018260513
# -0.7528890018260513 -0.7566628461591429
# ...
# 2019-08-22 05:53:24.970030
# [0.7425149700598802, 0.7515923566878981, 0.7453416149068324, 0.7261146496815287, 0.7777777777777778]
# 0.7486682738227834
# -0.7486682738227834 -0.7566628461591429
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 06:04:24.118342
# [0.7441860465116279, 0.7317073170731708, 0.7682926829268293, 0.6871165644171778, 0.7804878048780488]
# 0.7423580831613711
# -0.7423580831613711 -0.7566628461591429
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 06:16:32.301533
# [0.7455621301775148, 0.7798742138364779, 0.7439024390243902, 0.7169811320754716, 0.7904191616766467]
# 0.7553478153581002
# -0.7553478153581002 -0.7566628461591429
# {'model1': <models.features.salvador_wrap object at 0x7f331e675a90>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f331bd90f28>}
# 0.7264150943396227
# outer fold
# 2019-08-22 06:30:03.580727
# {'model1': <models.features.salvador_wrap object at 0x7f33d7919908>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:30:03.954128
# [0.7142857142857143, 0.7560975609756098, 0.6711409395973154, 0.7261904761904762, 0.802547770700637]
# 0.7340524923499505
# -0.7340524923499505 -0.7340524923499505 1
# {'model1': <models.features.salvador_wrap object at 0x7f33d76f0780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:31:59.766282
# [0.7388535031847134, 0.7305389221556886, 0.7096774193548386, 0.7560975609756098, 0.7843137254901961]
# 0.7438962262322093
# -0.7438962262322093 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5d2c668>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:34:08.838889
# [0.6590909090909091, 0.5895953757225434, 0.5810810810810811, 0.6415094339622641, 0.7093023255813952]
# 0.6361158250876386
# -0.6361158250876386 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f33d5b6d550>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:36:07.872419
# [0.6064516129032258, 0.6097560975609756, 0.6506024096385542, 0.654320987654321, 0.6628571428571428]
# 0.6367976501228438
# -0.6367976501228438 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f33183c4438>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:38:04.897407
# [0.6666666666666667, 0.6909090909090909, 0.7317073170731708, 0.7329192546583853, 0.7368421052631579]
# 0.7118088869140944
# -0.7118088869140944 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318205320>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:40:05.525279
# [0.6369426751592356, 0.6419753086419753, 0.64, 0.6408839779005524, 0.6823529411764707]
# 0.648430980575647
# -0.648430980575647 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f3318046208>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:42:11.689241
# [0.5375000000000001, 0.6127167630057804, 0.5833333333333334, 0.5869565217391304, 0.64]
# 0.5921013236156488
# -0.5921013236156488 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f330ee5b0f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f3319dab860>}
# {'class_weight': 'balanced', 'boosting': 'gbrt'}
# 2019-08-22 06:44:15.321119
# [0.5185185185185185, 0.6586826347305389, 0.6404494382022472, 0.6172839506172839, 0.6787878787878788]
# 0.6227444841712935
# -0.6227444841712935 -0.7438962262322093 2
# {'model1': <models.features.salvador_wrap object at 0x7f331e675160>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt'}, 'corp': <models.features.fixed_makedata object at 0x7f331e675048>}
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 06:46:11.501614
# [0.7374999999999999, 0.7515923566878981, 0.7402597402597403, 0.783625730994152, 0.7712418300653595]
# 0.7568439316014299
# -0.7568439316014299 -0.7568439316014299
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:00:51.195660
# [0.7349397590361447, 0.7547169811320754, 0.75, 0.8092485549132948, 0.7875]
# 0.7672810590163031
# -0.7672810590163031 -0.7672810590163031
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:12:41.905869
# [0.7612903225806451, 0.7577639751552795, 0.7307692307692308, 0.7664670658682634, 0.7567567567567567]
# 0.7546094702260351
# -0.7546094702260351 -0.7672810590163031
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 07:30:16.100001
# [0.7349397590361447, 0.7407407407407407, 0.758169934640523, 0.7810650887573963, 0.8133333333333332]
# 0.7656497713016275
# -0.7656497713016275 -0.7672810590163031
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:43:45.864803
# [0.7337278106508877, 0.7515923566878981, 0.7453416149068324, 0.7831325301204819, 0.8050314465408805]
# 0.763765151781396
# -0.763765151781396 -0.7672810590163031
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:54:28.885679
# [0.7515151515151515, 0.7577639751552795, 0.735483870967742, 0.7710843373493975, 0.7898089171974522]
# 0.7611312504370045
# -0.7611312504370045 -0.7672810590163031
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:11:39.071252
# [0.7250000000000001, 0.7453416149068324, 0.7662337662337663, 0.8, 0.8104575163398693]
# 0.7694065794960936
# -0.7694065794960936 -0.7694065794960936
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 08:25:45.609503
# [0.7160493827160493, 0.7594936708860759, 0.7515923566878981, 0.7613636363636362, 0.7948717948717949]
# 0.7566741683050908
# -0.7566741683050908 -0.7694065794960936
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 08:44:16.948393
# [0.7564102564102564, 0.7547169811320754, 0.7594936708860759, 0.7738095238095237, 0.7898089171974522]
# 0.7668478698870766
# -0.7668478698870766 -0.7694065794960936
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:56:43.454153
# [0.7421383647798742, 0.7341772151898733, 0.7402597402597403, 0.7906976744186047, 0.7848101265822786]
# 0.7584166242460741
# -0.7584166242460741 -0.7694065794960936
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 09:09:15.689190
# [0.7439024390243902, 0.7560975609756098, 0.7875, 0.7906976744186047, 0.8026315789473684]
# 0.7761658506731945
# -0.7761658506731945 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:20:31.738885
# [0.7439024390243902, 0.7361963190184049, 0.758169934640523, 0.8, 0.7973856209150327]
# 0.7671308627196701
# -0.7671308627196701 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:34:55.454206
# [0.7654320987654321, 0.7530864197530863, 0.7594936708860759, 0.7790697674418605, 0.7814569536423841]
# 0.7677077820977678
# -0.7677077820977678 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 09:49:28.934569
# [0.7261904761904762, 0.7852760736196319, 0.7450980392156864, 0.8023255813953489, 0.7894736842105262]
# 0.7696727709263339
# -0.7696727709263339 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 09:57:22.238126
# [0.787878787878788, 0.7329192546583853, 0.7435897435897435, 0.7657142857142857, 0.7948717948717949]
# 0.7649947733425995
# -0.7649947733425995 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:07:43.370343
# [0.773006134969325, 0.7407407407407407, 0.7612903225806451, 0.7544910179640719, 0.8104575163398693]
# 0.7679971465189304
# -0.7679971465189304 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 10:20:29.546226
# [0.75, 0.7564102564102564, 0.7468354430379747, 0.7810650887573963, 0.8227848101265822]
# 0.7714191196664419
# -0.7714191196664419 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 10:33:56.349307
# [0.7088607594936708, 0.7560975609756098, 0.7625, 0.7738095238095237, 0.802547770700637]
# 0.7607631229958883
# -0.7607631229958883 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 10:43:47.619384
# [0.7547169811320754, 0.7421383647798742, 0.782608695652174, 0.7810650887573963, 0.8]
# 0.7721058260643041
# -0.7721058260643041 -0.7761658506731945
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 10:55:04.150497
# [0.7530864197530863, 0.75, 0.7672955974842767, 0.783625730994152, 0.717948717948718]
# 0.7543912932360466
# -0.7543912932360466 -0.7761658506731945
# {'model1': <models.features.salvador_wrap object at 0x7f331c623470>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7f33195d7748>}
# 0.7539267015706805
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-08209b9986d7> in <module>()
#      61         print(result['test_f1'])
#      62
# ---> 63     pickle_path = auto_save_pickle(results)
#      64     df = pickle2df(results, pickle_path)
#      65     dfs.append(df)
#
# ~/DPH_AllrecipesAnalytics_v4/utils/save.py in auto_save_pickle(obj, dir_path)
#      21     filename = str(datetime.now())+'.pickle'
#      22     path_ = os.path.join(dir_path,filename)
# ---> 23     save_pickle(path_, obj)
#      24     print('save to ' + path_)
#      25     return path_
#
# ~/DPH_AllrecipesAnalytics_v4/utils/save.py in save_pickle(filename, obj, overwrite)
#      31     else:
#      32         with open(filename, 'wb') as gfp:
# ---> 33             pickle.dump(obj, gfp, protocol=2)
#      34             gfp.close()
#      35
#
# OSError: [Errno 28] No space left on device
# time: 23h 28min 48s

# %% [markdown]
# ### Run additional commands to save the results

# %%
df = pickle2df(results, 'cannot save')
dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# save to ../csv/2019-08-22 11:13:27.076694.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.76           0.753       0.75          1        1
#
#   train_recall train_accuracy  \
# 0  1            0.999
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f331a01a2e8>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag  pickle_path
# 0  [wv, scale]  AMT  cannot save
# save to ../csv/2019-08-22 11:13:27.118675.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.76           0.753       0.75          1        1
#
#   train_recall train_accuracy  \
# 0  1            0.999
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f331a01a2e8>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag  pickle_path
# 0  [wv, scale]  AMT  cannot save
# time: 130 ms

# %%
pickle_path = auto_save_pickle(results)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-9-3e1426608233> in <module>()
# ----> 1 pickle_path = auto_save_pickle(results)
#
# ~/DPH_AllrecipesAnalytics_v4/utils/save.py in auto_save_pickle(obj, dir_path)
#      21     filename = str(datetime.now())+'.pickle'
#      22     path_ = os.path.join(dir_path,filename)
# ---> 23     save_pickle(path_, obj)
#      24     print('save to ' + path_)
#      25     return path_
#
# ~/DPH_AllrecipesAnalytics_v4/utils/save.py in save_pickle(filename, obj, overwrite)
#      31     else:
#      32         with open(filename, 'wb') as gfp:
# ---> 33             pickle.dump(obj, gfp, protocol=2)
#      34             gfp.close()
#      35
#
# PicklingError: Can't pickle <class 'models.features.salvador_wrap'>: it's not the same object as models.features.salvador_wrap
# time: 223 ms

# %%
for result in results:
    result['model1'] = None
# Out:
# time: 29.9 ms

# %%
pickle_path = auto_save_pickle(results)
df = pickle2df(results, pickle_path)
dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# save to ../pickle/2019-08-22 11:20:02.849255.pickle
# save to ../csv/2019-08-22 11:20:03.443018.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.76           0.753       0.75          1        1
#
#   train_recall train_accuracy model1  \
# 0  1            0.999          None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 11:20:02.849255.pickle
# save to ../csv/2019-08-22 11:20:03.538590.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.76           0.753       0.75          1        1
# 0  0.755   0.76           0.753       0.75          1        1
#
#   train_recall train_accuracy  \
# 0  1            0.999
# 0  1            0.999
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f331a01a2e8>
# 0  None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.7, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  cannot save
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 11:20:02.849255.pickle
# time: 748 ms

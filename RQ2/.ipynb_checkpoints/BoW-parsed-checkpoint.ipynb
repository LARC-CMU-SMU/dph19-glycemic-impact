# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.15 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 15.7 s

# %% [markdown]
# ### 1. BoW-parsed and LR

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', tags = ['name_UNK2_none','ingred_ny','directions_UNK2_none'])
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 16:37:41.163978
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:37:41.349258
# [0.6621621621621622, 0.6878980891719745, 0.735483870967742, 0.7594936708860759, 0.7236842105263157]
# 0.713744400742854
# -0.713744400742854 -0.713744400742854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:37:56.219199
# [0.6711409395973154, 0.6918238993710691, 0.7272727272727273, 0.7594936708860759, 0.7189542483660132]
# 0.7137370970986402
# -0.7137370970986402 -0.713744400742854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:38:10.694416
# [0.6887417218543046, 0.7006369426751592, 0.7225806451612903, 0.7515923566878981, 0.7189542483660132]
# 0.7165011829489331
# -0.7165011829489331 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:38:25.323463
# [0.6711409395973154, 0.6878980891719745, 0.7012987012987013, 0.7272727272727273, 0.7105263157894738]
# 0.6996273546260384
# -0.6996273546260384 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:38:40.101180
# [0.6887417218543046, 0.6923076923076923, 0.7105263157894737, 0.7435897435897435, 0.7142857142857143]
# 0.7098902375653857
# -0.7098902375653857 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:38:55.174326
# [0.6712328767123288, 0.6883116883116883, 0.7272727272727273, 0.735483870967742, 0.7320261437908496]
# 0.7108654614110671
# -0.7108654614110671 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:39:08.390151
# [0.6711409395973154, 0.6878980891719745, 0.7012987012987013, 0.7272727272727273, 0.7105263157894738]
# 0.6996273546260384
# -0.6996273546260384 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:39:23.280793
# [0.68, 0.6923076923076923, 0.7058823529411765, 0.7272727272727273, 0.7189542483660132]
# 0.7048834041775219
# -0.7048834041775219 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:39:39.784651
# [0.6754966887417219, 0.6838709677419356, 0.7272727272727273, 0.735483870967742, 0.7435897435897436]
# 0.713142799662774
# -0.713142799662774 -0.7165011829489331
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:39:52.880865
# [0.6618705035971224, 0.7142857142857143, 0.7368421052631579, 0.7710843373493975, 0.7792207792207791]
# 0.7326606879432342
# -0.7326606879432342 -0.7326606879432342
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f69444a7b70>}
# 0.8042328042328043
# outer fold
# 2019-08-20 16:40:08.407500
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:40:08.671706
# [0.7382550335570469, 0.7619047619047619, 0.7083333333333334, 0.8076923076923077, 0.7152317880794701]
# 0.746283444913384
# -0.746283444913384 -0.746283444913384
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:40:22.401848
# [0.7382550335570469, 0.7619047619047619, 0.7083333333333334, 0.8152866242038217, 0.7105263157894737]
# 0.7468612137576874
# -0.7468612137576874 -0.7468612137576874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:40:36.493932
# [0.7236842105263157, 0.7702702702702703, 0.7034482758620689, 0.802547770700637, 0.697986577181208]
# 0.7395874209081
# -0.7395874209081 -0.7468612137576874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:40:50.428886
# [0.7105263157894737, 0.7448275862068966, 0.7066666666666667, 0.7848101265822786, 0.6933333333333332]
# 0.7280328057157297
# -0.7280328057157297 -0.7468612137576874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:41:05.877217
# [0.7019867549668874, 0.7651006711409395, 0.7034482758620689, 0.7924528301886792, 0.6891891891891893]
# 0.7304355442695529
# -0.7304355442695529 -0.7468612137576874
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:41:20.106605
# [0.7466666666666666, 0.7733333333333333, 0.6993006993006994, 0.8129032258064517, 0.7142857142857143]
# 0.7492979278785732
# -0.7492979278785732 -0.7492979278785732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:41:32.804712
# [0.7105263157894737, 0.7448275862068966, 0.697986577181208, 0.7770700636942676, 0.697986577181208]
# 0.7256794240106107
# -0.7256794240106107 -0.7492979278785732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:41:47.760156
# [0.7066666666666667, 0.7448275862068966, 0.6938775510204083, 0.7898089171974522, 0.697986577181208]
# 0.7266334596545263
# -0.7266334596545263 -0.7492979278785732
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:42:02.559505
# [0.758169934640523, 0.7763157894736843, 0.7346938775510203, 0.7974683544303799, 0.7105263157894737]
# 0.7554348543770162
# -0.7554348543770162 -0.7554348543770162
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:42:15.462535
# [0.7549668874172185, 0.7974683544303799, 0.7, 0.8050314465408805, 0.7105263157894737]
# 0.7535986008355904
# -0.7535986008355904 -0.7554348543770162
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f694408a588>}
# 0.7589743589743589
# outer fold
# 2019-08-20 16:42:31.026976
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:42:31.253798
# [0.7453416149068324, 0.7999999999999999, 0.7172413793103448, 0.7483870967741936, 0.7515151515151515]
# 0.7524970485013045
# -0.7524970485013045 -0.7524970485013045
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:42:45.024340
# [0.7329192546583853, 0.8027210884353742, 0.7172413793103448, 0.7402597402597403, 0.7515151515151515]
# 0.7489313228357992
# -0.7489313228357992 -0.7524970485013045
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:42:58.616787
# [0.7374999999999999, 0.7972972972972973, 0.7172413793103448, 0.7368421052631579, 0.7560975609756098]
# 0.7489956685692819
# -0.7489956685692819 -0.7524970485013045
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:43:13.634560
# [0.7044025157232704, 0.7763157894736843, 0.7162162162162161, 0.7058823529411765, 0.7654320987654321]
# 0.733649794623956
# -0.733649794623956 -0.7524970485013045
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:43:28.716583
# [0.7261146496815287, 0.7866666666666667, 0.7123287671232877, 0.7225806451612903, 0.7607361963190185]
# 0.7416853849903584
# -0.7416853849903584 -0.7524970485013045
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:43:43.296938
# [0.7654320987654321, 0.8219178082191781, 0.726027397260274, 0.7532467532467533, 0.7804878048780488]
# 0.7694223724739373
# -0.7694223724739373 -0.7694223724739373
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:43:57.050079
# [0.7044025157232704, 0.7763157894736843, 0.7162162162162161, 0.7189542483660132, 0.7654320987654321]
# 0.7362641737089233
# -0.7362641737089233 -0.7694223724739373
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:44:13.017264
# [0.7169811320754716, 0.7712418300653595, 0.7123287671232877, 0.7225806451612903, 0.7607361963190185]
# 0.7367737141488855
# -0.7367737141488855 -0.7694223724739373
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:44:27.912893
# [0.7530864197530863, 0.8163265306122449, 0.726027397260274, 0.7368421052631579, 0.7852760736196319]
# 0.7635117053016789
# -0.7635117053016789 -0.7694223724739373
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:44:40.976860
# [0.773006134969325, 0.8082191780821918, 0.75, 0.7549668874172185, 0.7950310559006211]
# 0.7762446512738712
# -0.7762446512738712 -0.7762446512738712
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6944094320>}
# 0.7643979057591622
# outer fold
# 2019-08-20 16:44:56.345609
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:44:56.681739
# [0.6666666666666667, 0.7382550335570469, 0.7516778523489933, 0.6666666666666667, 0.810126582278481]
# 0.7266785603035709
# -0.7266785603035709 -0.7266785603035709
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:45:10.588957
# [0.6986301369863014, 0.7417218543046357, 0.7516778523489933, 0.6619718309859155, 0.810126582278481]
# 0.7328256513808653
# -0.7328256513808653 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:45:24.741628
# [0.6805555555555557, 0.7402597402597403, 0.7466666666666666, 0.6619718309859155, 0.810126582278481]
# 0.7279160751492718
# -0.7279160751492718 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:45:39.872656
# [0.6577181208053691, 0.7114093959731543, 0.7417218543046357, 0.6805555555555557, 0.802547770700637]
# 0.7187905394678703
# -0.7187905394678703 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:45:54.857908
# [0.6853146853146853, 0.7320261437908497, 0.7417218543046357, 0.6666666666666667, 0.810126582278481]
# 0.7271711864710637
# -0.7271711864710637 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:46:09.131648
# [0.6714285714285715, 0.7549668874172185, 0.7368421052631579, 0.6619718309859155, 0.8051948051948052]
# 0.7260808400579337
# -0.7260808400579337 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:46:21.653106
# [0.6666666666666666, 0.7066666666666667, 0.7417218543046357, 0.6805555555555557, 0.802547770700637]
# 0.7196317027788324
# -0.7196317027788324 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:46:36.544753
# [0.6756756756756757, 0.7189542483660132, 0.7333333333333334, 0.6713286713286712, 0.8125000000000001]
# 0.7223583857407386
# -0.7223583857407386 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:46:51.104760
# [0.6666666666666667, 0.7671232876712328, 0.7432432432432432, 0.6713286713286712, 0.8129032258064517]
# 0.7322530189432531
# -0.7322530189432531 -0.7328256513808653
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:47:03.569095
# [0.7320261437908497, 0.7702702702702703, 0.782051282051282, 0.7162162162162161, 0.8]
# 0.7601127824657237
# -0.7601127824657237 -0.7601127824657237
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6943ea0f60>}
# 0.7524752475247525
# outer fold
# 2019-08-20 16:47:18.637877
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:47:18.959835
# [0.7417218543046357, 0.7320261437908497, 0.7382550335570469, 0.76, 0.8333333333333334]
# 0.7610672729971731
# -0.7610672729971731 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:47:32.999199
# [0.7368421052631579, 0.728476821192053, 0.7333333333333334, 0.76, 0.794701986754967]
# 0.7506708493087022
# -0.7506708493087022 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:47:47.713859
# [0.7368421052631579, 0.7435897435897435, 0.7382550335570469, 0.7549668874172185, 0.7919463087248322]
# 0.7531200157103998
# -0.7531200157103998 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:48:02.144724
# [0.7152317880794701, 0.7564102564102564, 0.72, 0.75, 0.7733333333333333]
# 0.742995075564612
# -0.742995075564612 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:48:17.748449
# [0.7162162162162161, 0.7435897435897435, 0.728476821192053, 0.758169934640523, 0.794701986754967]
# 0.7482309404787004
# -0.7482309404787004 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:48:33.324665
# [0.7417218543046357, 0.7320261437908497, 0.75, 0.7549668874172185, 0.8258064516129032]
# 0.7609042674251214
# -0.7609042674251214 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:48:46.320134
# [0.7152317880794701, 0.7564102564102564, 0.72, 0.75, 0.7814569536423841]
# 0.7446197996264221
# -0.7446197996264221 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:49:02.175174
# [0.7152317880794701, 0.7564102564102564, 0.72, 0.758169934640523, 0.7894736842105262]
# 0.7478571326681551
# -0.7478571326681551 -0.7610672729971731
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:49:16.733353
# [0.7450980392156864, 0.7721518987341771, 0.75, 0.7631578947368421, 0.8205128205128205]
# 0.7701841306399052
# -0.7701841306399052 -0.7701841306399052
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:49:30.835660
# [0.7435897435897435, 0.7712418300653595, 0.758169934640523, 0.7919463087248322, 0.8074534161490683]
# 0.7744802466339052
# -0.7744802466339052 -0.7744802466339052
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6944691e10>}
# 0.7384615384615384
# save to ../pickle/2019-08-20 16:49:46.192620.pickle
# save to ../csv/2019-08-20 16:49:46.211634.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.764   0.798          0.733       0.768         0.997    0.999
#
#   train_recall train_accuracy model1  \
# 0  0.996        0.997          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-20 16:49:46.192620.pickle
# save to ../csv/2019-08-20 16:49:46.286243.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.764   0.798          0.733       0.768         0.997    0.999
#
#   train_recall train_accuracy model1  \
# 0  0.996        0.997          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-20 16:49:46.192620.pickle
# time: 12min 17s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lgbm
    
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', tags = ['name_UNK2_none','ingred_ny','directions_UNK2_none'])
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 16:49:58.050439
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 16:49:58.275599
# [0.631578947368421, 0.6883116883116883, 0.703030303030303, 0.7337278106508877, 0.697986577181208]
# 0.6909270653085017
# -0.6909270653085017 -0.6909270653085017
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 17:12:34.546429
# [0.6451612903225807, 0.627450980392157, 0.6666666666666667, 0.7241379310344828, 0.7044025157232704]
# 0.6735638768278316
# -0.6735638768278316 -0.6909270653085017
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 17:18:52.405028
# [0.6064516129032258, 0.7530864197530863, 0.6909090909090909, 0.7251461988304092, 0.7516778523489933]
# 0.705454234948961
# -0.705454234948961 -0.705454234948961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 17:28:06.610385
# [0.6233766233766234, 0.7051282051282051, 0.6503067484662577, 0.7485380116959064, 0.7074829931972789]
# 0.6869665163728543
# -0.6869665163728543 -0.705454234948961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 17:37:04.034820
# [0.6143790849673203, 0.7261146496815287, 0.6751592356687897, 0.7272727272727273, 0.7450980392156863]
# 0.6976047473612106
# -0.6976047473612106 -0.705454234948961
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 17:43:25.903364
# [0.6329113924050632, 0.7261146496815287, 0.7151515151515152, 0.7116564417177914, 0.7532467532467533]
# 0.7078161504405304
# -0.7078161504405304 -0.7078161504405304
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 17:53:37.325830
# [0.6493506493506493, 0.7073170731707318, 0.6909090909090909, 0.7471264367816093, 0.726027397260274]
# 0.7041461294944711
# -0.7041461294944711 -0.7078161504405304
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 18:02:35.049470
# [0.6193548387096774, 0.7225806451612903, 0.7073170731707318, 0.7142857142857143, 0.728476821192053]
# 0.6984030185038934
# -0.6984030185038934 -0.7078161504405304
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-20 18:13:35.809264
# [0.6233766233766234, 0.7250000000000001, 0.6875000000000001, 0.7558139534883721, 0.7162162162162162]
# 0.7015813586162424
# -0.7015813586162424 -0.7078161504405304
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 18:20:11.052694
# [0.6266666666666667, 0.7484662576687118, 0.7317073170731708, 0.7368421052631577, 0.7123287671232875]
# 0.7112022227589988
# -0.7112022227589988 -0.7112022227589988
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 18:26:37.196948
# [0.6064516129032258, 0.6583850931677019, 0.691358024691358, 0.72, 0.6835443037974683]
# 0.6719478069119509
# -0.6719478069119509 -0.7112022227589988
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 18:33:08.540895
# [0.6193548387096774, 0.6918238993710691, 0.6455696202531646, 0.7485380116959064, 0.7066666666666666]
# 0.6823906073392968
# -0.6823906073392968 -0.7112022227589988
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 18:39:31.696897
# [0.6143790849673203, 0.7421383647798742, 0.7239263803680983, 0.7317073170731708, 0.7248322147651006]
# 0.7073966723907128
# -0.7073966723907128 -0.7112022227589988
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 18:51:12.241076
# [0.6172839506172839, 0.6624203821656051, 0.6871165644171778, 0.7023809523809522, 0.6887417218543047]
# 0.6715887142870647
# -0.6715887142870647 -0.7112022227589988
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-20 18:58:35.181745
# [0.6184210526315791, 0.7560975609756098, 0.6835443037974684, 0.7630057803468208, 0.7397260273972603]
# 0.7121589450297476
# -0.7121589450297476 -0.7121589450297476
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 19:04:22.952488
# [0.5866666666666667, 0.7547169811320754, 0.7080745341614907, 0.757396449704142, 0.7210884353741497]
# 0.705588613407705
# -0.705588613407705 -0.7121589450297476
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 19:15:01.248594
# [0.6103896103896104, 0.761904761904762, 0.6993865030674846, 0.7195121951219512, 0.7402597402597403]
# 0.7062905621487097
# -0.7062905621487097 -0.7121589450297476
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-20 19:24:57.596008
# [0.6405228758169934, 0.6792452830188679, 0.641025641025641, 0.7045454545454545, 0.6751592356687898]
# 0.6680996980151492
# -0.6680996980151492 -0.7121589450297476
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 19:32:20.867849
# [0.6233766233766234, 0.7116564417177914, 0.6545454545454545, 0.7368421052631577, 0.7114093959731543]
# 0.6875660041752363
# -0.6875660041752363 -0.7121589450297476
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 19:39:27.139727
# [0.5906040268456375, 0.6666666666666667, 0.6625, 0.7126436781609194, 0.6754966887417218]
# 0.6615822120829891
# -0.6615822120829891 -0.7121589450297476
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f694467ec50>}
# 0.7864077669902914
# outer fold
# 2019-08-20 19:46:42.313198
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 19:46:42.731073
# [0.6578947368421051, 0.703030303030303, 0.6405228758169934, 0.7329192546583853, 0.7073170731707318]
# 0.6883368487037037
# -0.6883368487037037 -0.6883368487037037
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 19:56:29.952899
# [0.6143790849673203, 0.7151515151515152, 0.6143790849673203, 0.7017543859649122, 0.6455696202531646]
# 0.6582467382608466
# -0.6582467382608466 -0.6883368487037037
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 20:04:41.966576
# [0.7051282051282051, 0.7337278106508877, 0.6666666666666667, 0.7215189873417721, 0.7151515151515152]
# 0.7084386369878093
# -0.7084386369878093 -0.7084386369878093
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 20:15:55.535920
# [0.6405228758169934, 0.7065868263473054, 0.6405228758169934, 0.7151515151515152, 0.710059171597633]
# 0.6825686529460882
# -0.6825686529460882 -0.7084386369878093
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 20:25:13.860859
# [0.6666666666666667, 0.7151515151515152, 0.6533333333333334, 0.7307692307692308, 0.7065868263473054]
# 0.6945015144536103
# -0.6945015144536103 -0.7084386369878093
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 20:31:55.312871
# [0.6878980891719745, 0.7529411764705881, 0.6621621621621622, 0.7283950617283951, 0.7261904761904762]
# 0.7115173931447193
# -0.7115173931447193 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 20:42:26.773202
# [0.6623376623376623, 0.6790123456790124, 0.6538461538461539, 0.7329192546583853, 0.7023809523809522]
# 0.6860992737804332
# -0.6860992737804332 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 20:55:56.647427
# [0.6708860759493671, 0.7349397590361447, 0.6535947712418301, 0.7250000000000001, 0.7151515151515152]
# 0.6999144242757714
# -0.6999144242757714 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-20 21:12:53.927528
# [0.6666666666666667, 0.7151515151515152, 0.6451612903225807, 0.7096774193548386, 0.6904761904761905]
# 0.6854266163943583
# -0.6854266163943583 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 21:24:05.096608
# [0.6794871794871794, 0.7261904761904762, 0.6493506493506493, 0.7307692307692308, 0.7407407407407407]
# 0.7053076553076553
# -0.7053076553076553 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 21:34:08.288129
# [0.6490066225165563, 0.6904761904761905, 0.6451612903225807, 0.6976744186046511, 0.6455696202531646]
# 0.6655776284346286
# -0.6655776284346286 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 21:45:25.790769
# [0.6578947368421051, 0.6993865030674846, 0.6363636363636364, 0.7080745341614907, 0.7073170731707318]
# 0.6818072967210898
# -0.6818072967210898 -0.7115173931447193
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 21:51:52.233766
# [0.6962025316455697, 0.7261904761904762, 0.662251655629139, 0.7564102564102564, 0.7185628742514969]
# 0.7119235588253876
# -0.7119235588253876 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 22:03:23.576125
# [0.670807453416149, 0.7185628742514969, 0.6134969325153374, 0.7185628742514969, 0.6706586826347306]
# 0.6784177634138422
# -0.6784177634138422 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-20 22:10:53.861582
# [0.6582278481012659, 0.7239263803680983, 0.6490066225165563, 0.7450980392156864, 0.7116564417177914]
# 0.6975830663838797
# -0.6975830663838797 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 22:17:15.144699
# [0.691358024691358, 0.7305389221556886, 0.6666666666666667, 0.7058823529411765, 0.7228915662650603]
# 0.70346750654399
# -0.70346750654399 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 22:27:51.705435
# [0.6842105263157894, 0.7393939393939394, 0.6490066225165563, 0.7272727272727273, 0.7228915662650603]
# 0.7045550763528146
# -0.7045550763528146 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-20 22:37:30.013411
# [0.6369426751592356, 0.7294117647058823, 0.6153846153846153, 0.710059171597633, 0.6624203821656051]
# 0.6708437218025942
# -0.6708437218025942 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 22:44:13.925791
# [0.6623376623376623, 0.7195121951219512, 0.6451612903225807, 0.7096774193548386, 0.6863905325443787]
# 0.6846158199362823
# -0.6846158199362823 -0.7119235588253876
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 22:49:57.027255
# [0.6250000000000001, 0.6993865030674846, 0.6266666666666667, 0.7023809523809522, 0.6335403726708074]
# 0.6573948989571823
# -0.6573948989571823 -0.7119235588253876
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f694440c2b0>}
# 0.7684729064039408
# outer fold
# 2019-08-20 22:58:32.930893
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 22:58:33.327957
# [0.6933333333333332, 0.7468354430379747, 0.6666666666666667, 0.6918238993710691, 0.7393939393939394]
# 0.7076106563605966
# -0.7076106563605966 -0.7076106563605966
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 23:07:23.750199
# [0.7133757961783439, 0.7169811320754716, 0.6624203821656051, 0.6211180124223602, 0.7529411764705881]
# 0.6933672998624738
# -0.6933672998624738 -0.7076106563605966
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 23:14:29.146959
# [0.6666666666666666, 0.7374999999999999, 0.6797385620915033, 0.7215189873417721, 0.7636363636363638]
# 0.7138121159472611
# -0.7138121159472611 -0.7138121159472611
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 23:24:39.760390
# [0.6933333333333332, 0.7421383647798742, 0.6623376623376623, 0.6832298136645963, 0.7636363636363638]
# 0.708935107550366
# -0.708935107550366 -0.7138121159472611
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 23:37:45.683508
# [0.7012987012987013, 0.7421383647798742, 0.6973684210526315, 0.7116564417177914, 0.7590361445783134]
# 0.7222996146854623
# -0.7222996146854623 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 23:44:07.451093
# [0.6962025316455697, 0.7450980392156864, 0.6918238993710691, 0.7160493827160493, 0.761904761904762]
# 0.7222157229706273
# -0.7222157229706273 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 23:54:09.813448
# [0.6887417218543046, 0.7421383647798742, 0.6792452830188679, 0.7151515151515152, 0.7560975609756098]
# 0.7162748891560342
# -0.7162748891560342 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 00:03:27.513953
# [0.6797385620915033, 0.7407407407407407, 0.7012987012987013, 0.7, 0.7804878048780488]
# 0.7204531618017989
# -0.7204531618017989 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 00:13:49.593739
# [0.6928104575163399, 0.7169811320754716, 0.6282051282051282, 0.7080745341614907, 0.7590361445783134]
# 0.7010214793073488
# -0.7010214793073488 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 00:20:23.760092
# [0.6842105263157894, 0.7341772151898733, 0.6666666666666667, 0.7215189873417721, 0.7784431137724551]
# 0.7170033018573113
# -0.7170033018573113 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 00:26:14.200911
# [0.675, 0.717948717948718, 0.6496815286624203, 0.6867469879518073, 0.7349397590361447]
# 0.6928633987198181
# -0.6928633987198181 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 00:32:38.687110
# [0.6938775510204083, 0.7215189873417721, 0.670807453416149, 0.675, 0.75]
# 0.702240798355666
# -0.702240798355666 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 00:38:50.006108
# [0.6887417218543046, 0.7215189873417721, 0.6928104575163399, 0.7361963190184049, 0.7710843373493975]
# 0.7220703646160438
# -0.7220703646160438 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 00:50:59.847510
# [0.6709677419354838, 0.7125, 0.6790123456790124, 0.6826347305389222, 0.7904191616766467]
# 0.7071067959660129
# -0.7071067959660129 -0.7222996146854623
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 00:58:33.438867
# [0.6710526315789473, 0.7388535031847134, 0.6883116883116883, 0.7560975609756098, 0.757396449704142]
# 0.7223423667510201
# -0.7223423667510201 -0.7223423667510201
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 01:04:57.604223
# [0.6967741935483871, 0.7225806451612903, 0.717948717948718, 0.7250000000000001, 0.7831325301204819]
# 0.7290872173557755
# -0.7290872173557755 -0.7290872173557755
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 01:14:56.513057
# [0.6938775510204083, 0.7283950617283951, 0.6923076923076923, 0.7006369426751592, 0.7469879518072289]
# 0.7124410399077767
# -0.7124410399077767 -0.7290872173557755
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 01:24:10.625741
# [0.6708860759493671, 0.7317073170731708, 0.675, 0.6748466257668712, 0.757396449704142]
# 0.7019672936987102
# -0.7019672936987102 -0.7290872173557755
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 01:30:48.686618
# [0.7006369426751592, 0.7169811320754716, 0.6582278481012659, 0.6918238993710691, 0.7784431137724551]
# 0.7092225871990843
# -0.7092225871990843 -0.7290872173557755
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 01:36:33.830949
# [0.6496815286624203, 0.7, 0.6375, 0.6626506024096386, 0.7529411764705881]
# 0.6805546615085294
# -0.6805546615085294 -0.7290872173557755
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f6943e93978>}
# 0.7244897959183674
# outer fold
# 2019-08-21 01:44:12.426738
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 01:44:12.636919
# [0.75, 0.7261904761904762, 0.7692307692307692, 0.670807453416149, 0.7407407407407407]
# 0.731393887915627
# -0.731393887915627 -0.731393887915627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 01:52:37.734604
# [0.7151515151515152, 0.7469879518072289, 0.7770700636942676, 0.641025641025641, 0.7636363636363638]
# 0.7287743070630033
# -0.7287743070630033 -0.731393887915627
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 01:59:27.557918
# [0.691358024691358, 0.7485380116959064, 0.7924528301886792, 0.6993865030674846, 0.7654320987654321]
# 0.739433493681772
# -0.739433493681772 -0.739433493681772
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 02:08:58.402019
# [0.7407407407407407, 0.7469879518072289, 0.7948717948717949, 0.6832298136645963, 0.7283950617283951]
# 0.7388450725625513
# -0.7388450725625513 -0.739433493681772
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 02:17:42.661451
# [0.7439024390243902, 0.7393939393939394, 0.7848101265822786, 0.710059171597633, 0.761904761904762]
# 0.7480140877006006
# -0.7480140877006006 -0.7480140877006006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 02:23:28.059870
# [0.7125, 0.7674418604651162, 0.782051282051282, 0.674698795180723, 0.7664670658682634]
# 0.7406318007130769
# -0.7406318007130769 -0.7480140877006006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 02:33:06.061997
# [0.7329192546583853, 0.7393939393939394, 0.7848101265822786, 0.6202531645569621, 0.7305389221556886]
# 0.7215830814694508
# -0.7215830814694508 -0.7480140877006006
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 02:41:12.708442
# [0.7295597484276728, 0.7719298245614035, 0.7875, 0.6904761904761905, 0.7738095238095237]
# 0.750655057454958
# -0.750655057454958 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 02:51:04.491762
# [0.7295597484276728, 0.7455621301775148, 0.7741935483870969, 0.6918238993710691, 0.7349397590361447]
# 0.7352158170798997
# -0.7352158170798997 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 02:57:20.455338
# [0.717948717948718, 0.7857142857142857, 0.7898089171974522, 0.6832298136645963, 0.7607361963190185]
# 0.7474875861688142
# -0.7474875861688142 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 03:03:01.347889
# [0.6956521739130435, 0.7151515151515152, 0.75, 0.6369426751592356, 0.7515151515151515]
# 0.7098523031477891
# -0.7098523031477891 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 03:09:05.211578
# [0.7341772151898733, 0.7305389221556886, 0.7924528301886792, 0.6585365853658536, 0.7374999999999999]
# 0.7306411105800189
# -0.7306411105800189 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 03:15:36.282442
# [0.7248322147651006, 0.761904761904762, 0.7770700636942676, 0.6792452830188679, 0.7682926829268293]
# 0.7422690012619654
# -0.7422690012619654 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 03:25:58.454921
# [0.7116564417177914, 0.7218934911242604, 0.7484662576687118, 0.6289308176100629, 0.7317073170731708]
# 0.7085308650387995
# -0.7085308650387995 -0.750655057454958
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 03:32:38.487365
# [0.7272727272727273, 0.7738095238095237, 0.8076923076923077, 0.7272727272727273, 0.7560975609756098]
# 0.7584289694045792
# -0.7584289694045792 -0.7584289694045792
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 03:37:55.173018
# [0.7142857142857143, 0.7664670658682634, 0.7974683544303799, 0.6956521739130435, 0.7710843373493975]
# 0.7489915291693597
# -0.7489915291693597 -0.7584289694045792
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 03:47:37.945041
# [0.7283950617283951, 0.7602339181286549, 0.8, 0.6909090909090909, 0.7701863354037267]
# 0.7499448812339735
# -0.7499448812339735 -0.7584289694045792
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 03:57:18.454179
# [0.703030303030303, 0.7185628742514969, 0.7484662576687118, 0.641025641025641, 0.7204968944099378]
# 0.7063163940772181
# -0.7063163940772181 -0.7584289694045792
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 04:04:02.640652
# [0.7215189873417721, 0.7469879518072289, 0.810126582278481, 0.654320987654321, 0.7421383647798742]
# 0.7350185747723355
# -0.7350185747723355 -0.7584289694045792
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 04:10:12.253816
# [0.7218934911242604, 0.6982248520710058, 0.7421383647798742, 0.6369426751592356, 0.7636363636363638]
# 0.7125671493541479
# -0.7125671493541479 -0.7584289694045792
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f6943e933c8>}
# 0.7177033492822966
# outer fold
# 2019-08-21 04:17:47.825685
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 04:17:48.227993
# [0.6666666666666667, 0.6842105263157894, 0.75, 0.7361963190184049, 0.7577639751552795]
# 0.7189674974312281
# -0.7189674974312281 -0.7189674974312281
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 04:27:57.010193
# [0.6625, 0.6962025316455697, 0.7239263803680983, 0.7044025157232704, 0.7215189873417721]
# 0.701710083015742
# -0.701710083015742 -0.7189674974312281
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 04:36:03.766798
# [0.6875000000000001, 0.6754966887417219, 0.7721518987341771, 0.7439024390243902, 0.7710843373493975]
# 0.7300270727699374
# -0.7300270727699374 -0.7300270727699374
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 04:47:26.412850
# [0.6875000000000001, 0.7114093959731543, 0.7453416149068324, 0.75, 0.7577639751552795]
# 0.7304029972070533
# -0.7304029972070533 -0.7304029972070533
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 04:58:08.596992
# [0.6946107784431137, 0.7051282051282051, 0.7636363636363638, 0.7341772151898733, 0.7784431137724551]
# 0.7351991352340022
# -0.7351991352340022 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 05:05:33.644691
# [0.7073170731707318, 0.6842105263157894, 0.7590361445783134, 0.7349397590361447, 0.75]
# 0.7271007006201959
# -0.7271007006201959 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 05:16:17.920546
# [0.7073170731707318, 0.7006369426751592, 0.7701863354037267, 0.7204968944099378, 0.7439024390243902]
# 0.7285079369367893
# -0.7285079369367893 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 05:26:21.406330
# [0.6790123456790124, 0.6842105263157894, 0.7701863354037267, 0.7329192546583853, 0.7664670658682634]
# 0.7265591055850354
# -0.7265591055850354 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 05:37:46.521407
# [0.703030303030303, 0.6535947712418301, 0.761904761904762, 0.7349397590361447, 0.7721518987341771]
# 0.7251242987894434
# -0.7251242987894434 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 05:44:57.181438
# [0.7073170731707318, 0.6530612244897959, 0.773006134969325, 0.7577639751552795, 0.7672955974842767]
# 0.7316888010538818
# -0.7316888010538818 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 05:52:03.267082
# [0.6923076923076923, 0.7, 0.7317073170731708, 0.7261904761904762, 0.7439024390243902]
# 0.7188215849191459
# -0.7188215849191459 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 05:59:22.344053
# [0.6867469879518073, 0.68, 0.7577639751552795, 0.7204968944099378, 0.7453416149068324]
# 0.7180698944847714
# -0.7180698944847714 -0.7351991352340022
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 06:07:01.004522
# [0.7228915662650603, 0.7019867549668874, 0.7625, 0.7439024390243902, 0.773006134969325]
# 0.7408573790451326
# -0.7408573790451326 -0.7408573790451326
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 06:19:36.268397
# [0.6875000000000001, 0.7160493827160493, 0.7337278106508877, 0.7195121951219512, 0.7590361445783134]
# 0.7231651066134404
# -0.7231651066134404 -0.7408573790451326
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 06:27:42.315450
# [0.757396449704142, 0.6973684210526315, 0.7590361445783134, 0.7515151515151515, 0.7625]
# 0.7455632333700477
# -0.7455632333700477 -0.7455632333700477
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 06:34:30.404492
# [0.7, 0.6486486486486487, 0.7625, 0.7439024390243902, 0.7547169811320754]
# 0.7219536137610228
# -0.7219536137610228 -0.7455632333700477
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 06:45:47.190185
# [0.7037037037037037, 0.6938775510204083, 0.7577639751552795, 0.7515151515151515, 0.7757575757575756]
# 0.7365235914304238
# -0.7365235914304238 -0.7455632333700477
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 06:57:45.565293
# [0.6626506024096386, 0.6993865030674846, 0.6987951807228916, 0.7051282051282051, 0.7530864197530863]
# 0.7038093822162612
# -0.7038093822162612 -0.7455632333700477
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 07:05:50.130867
# [0.6993865030674846, 0.6623376623376623, 0.7607361963190185, 0.7195121951219512, 0.7453416149068324]
# 0.7174628343505899
# -0.7174628343505899 -0.7455632333700477
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 07:12:47.465462
# [0.6871165644171778, 0.7, 0.6875000000000001, 0.6946107784431137, 0.7295597484276728]
# 0.6997574182575927
# -0.6997574182575927 -0.7455632333700477
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f69442ae518>}
# 0.7755102040816327
# save to ../pickle/2019-08-21 07:20:42.142532.pickle
# save to ../csv/2019-08-21 07:20:43.051676.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.757          0.753       0.749         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=20, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.5, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.1,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=256,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-21 07:20:42.142532.pickle
# save to ../csv/2019-08-21 07:20:43.162296.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.755   0.757          0.753       0.749         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=20, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.5, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.1,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=256,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-21 07:20:42.142532.pickle
# time: 14h 30min 56s

# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.39 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 14.2 s

# %% [markdown]
# ### 1. BoW-NB and LR

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 16:06:14.554860
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:06:14.848914
# [0.6887417218543046, 0.697986577181208, 0.7333333333333334, 0.7329192546583853, 0.7368421052631577]
# 0.7179645984580778
# -0.7179645984580778 -0.7179645984580778
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:06:31.814969
# [0.6887417218543046, 0.6973684210526315, 0.7333333333333334, 0.7341772151898733, 0.728476821192053]
# 0.7164195025244392
# -0.7164195025244392 -0.7179645984580778
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:06:47.796961
# [0.6933333333333332, 0.6887417218543046, 0.7333333333333334, 0.7341772151898733, 0.72]
# 0.713917120742169
# -0.713917120742169 -0.7179645984580778
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:07:04.940530
# [0.7019867549668874, 0.7058823529411765, 0.72, 0.7374999999999999, 0.7058823529411764]
# 0.7142502921698481
# -0.7142502921698481 -0.7179645984580778
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:07:20.895608
# [0.6933333333333332, 0.6973684210526315, 0.7248322147651006, 0.7421383647798742, 0.7152317880794701]
# 0.7145808244020818
# -0.7145808244020818 -0.7179645984580778
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:07:36.072143
# [0.68, 0.7019867549668874, 0.7333333333333334, 0.7435897435897435, 0.7432432432432432]
# 0.7204306150266415
# -0.7204306150266415 -0.7204306150266415
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:07:49.862804
# [0.7019867549668874, 0.7133757961783439, 0.72, 0.7468354430379747, 0.7058823529411764]
# 0.7176160694248764
# -0.7176160694248764 -0.7204306150266415
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:08:05.922410
# [0.6933333333333332, 0.6973684210526315, 0.728476821192053, 0.7564102564102564, 0.7105263157894738]
# 0.7172230295555496
# -0.7172230295555496 -0.7204306150266415
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:08:20.770627
# [0.6973684210526315, 0.7074829931972788, 0.7333333333333334, 0.7388535031847134, 0.7333333333333334]
# 0.7220743168202581
# -0.7220743168202581 -0.7220743168202581
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:08:33.516917
# [0.6861313868613139, 0.7066666666666667, 0.7482993197278912, 0.7439024390243902, 0.728476821192053]
# 0.7226953266944631
# -0.7226953266944631 -0.7226953266944631
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f7453352128>}
# 0.8282828282828283
# outer fold
# 2019-08-20 16:08:50.681314
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:08:50.910175
# [0.7777777777777778, 0.75, 0.7034482758620689, 0.8407643312101911, 0.7142857142857143]
# 0.7572552198271504
# -0.7572552198271504 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:09:04.895506
# [0.773006134969325, 0.7549668874172185, 0.7034482758620689, 0.8421052631578947, 0.7012987012987013]
# 0.7549650525410417
# -0.7549650525410417 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:09:19.824858
# [0.7654320987654321, 0.7682119205298013, 0.7034482758620689, 0.8366013071895425, 0.7012987012987013]
# 0.7549984607291093
# -0.7549984607291093 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:09:36.023360
# [0.7577639751552795, 0.7631578947368421, 0.684931506849315, 0.8024691358024691, 0.6973684210526315]
# 0.7411381867193074
# -0.7411381867193074 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:09:50.275033
# [0.7654320987654321, 0.758169934640523, 0.7034482758620689, 0.8227848101265822, 0.68]
# 0.7459670238789212
# -0.7459670238789212 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:10:04.962077
# [0.7577639751552795, 0.7532467532467533, 0.7034482758620689, 0.8441558441558442, 0.7058823529411765]
# 0.7528994402722244
# -0.7528994402722244 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:10:18.048900
# [0.7672955974842767, 0.7631578947368421, 0.684931506849315, 0.8024691358024691, 0.6973684210526315]
# 0.7430445111851068
# -0.7430445111851068 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:10:34.048175
# [0.7625, 0.7631578947368421, 0.684931506849315, 0.8074534161490683, 0.68]
# 0.7396085635470452
# -0.7396085635470452 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:10:49.608321
# [0.75, 0.7515923566878981, 0.7123287671232877, 0.8366013071895425, 0.7058823529411765]
# 0.751280956788381
# -0.751280956788381 -0.7572552198271504
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:11:02.529841
# [0.7721518987341771, 0.7564102564102564, 0.7248322147651006, 0.8378378378378379, 0.7435897435897435]
# 0.7669643902674231
# -0.7669643902674231 -0.7669643902674231
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f7453363630>}
# 0.7187499999999999
# outer fold
# 2019-08-20 16:11:18.037151
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:11:18.354076
# [0.6962025316455697, 0.811188811188811, 0.7382550335570469, 0.7439024390243902, 0.7625]
# 0.7504097630831635
# -0.7504097630831635 -0.7504097630831635
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:11:32.955291
# [0.6967741935483871, 0.811188811188811, 0.728476821192053, 0.7349397590361447, 0.7547169811320754]
# 0.7452193132194942
# -0.7452193132194942 -0.7504097630831635
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:11:47.671600
# [0.7012987012987013, 0.811188811188811, 0.6993006993006994, 0.7425149700598802, 0.7388535031847134]
# 0.7386313370065611
# -0.7386313370065611 -0.7504097630831635
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:12:01.924427
# [0.6666666666666667, 0.7916666666666667, 0.7066666666666667, 0.7361963190184049, 0.7388535031847134]
# 0.7280099644406237
# -0.7280099644406237 -0.7504097630831635
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:12:16.140519
# [0.6973684210526315, 0.7972027972027971, 0.6993006993006994, 0.7239263803680983, 0.7388535031847134]
# 0.7313303602217879
# -0.7313303602217879 -0.7504097630831635
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:12:31.508863
# [0.7088607594936708, 0.8251748251748251, 0.7382550335570469, 0.7407407407407407, 0.7852760736196319]
# 0.759661486517183
# -0.759661486517183 -0.759661486517183
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:12:45.190031
# [0.6666666666666667, 0.7916666666666667, 0.7066666666666667, 0.7407407407407407, 0.7388535031847134]
# 0.7289188487850907
# -0.7289188487850907 -0.759661486517183
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:13:00.240037
# [0.6883116883116883, 0.7972027972027971, 0.7162162162162161, 0.7361963190184049, 0.7468354430379747]
# 0.7369524927574163
# -0.7369524927574163 -0.759661486517183
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:13:16.208606
# [0.7044025157232704, 0.8251748251748251, 0.7382550335570469, 0.7484662576687118, 0.7777777777777778]
# 0.7588152819803263
# -0.7588152819803263 -0.759661486517183
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:13:30.595101
# [0.7453416149068324, 0.8137931034482758, 0.7483870967741936, 0.7530864197530863, 0.7721518987341771]
# 0.766552026723313
# -0.766552026723313 -0.766552026723313
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f7452c35080>}
# 0.7597765363128492
# outer fold
# 2019-08-20 16:13:47.710034
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:13:47.993863
# [0.7132867132867133, 0.7132867132867133, 0.7733333333333333, 0.6382978723404256, 0.7870967741935484]
# 0.7250602812881468
# -0.7250602812881468 -0.7250602812881468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:14:02.612499
# [0.7132867132867133, 0.7132867132867133, 0.7894736842105262, 0.6187050359712232, 0.7870967741935484]
# 0.7243697841897448
# -0.7243697841897448 -0.7250602812881468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:14:17.325547
# [0.7083333333333334, 0.7172413793103448, 0.7712418300653595, 0.6187050359712232, 0.7898089171974522]
# 0.7210660991755427
# -0.7210660991755427 -0.7250602812881468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:14:31.018142
# [0.689655172413793, 0.7114093959731543, 0.7612903225806451, 0.6388888888888888, 0.7721518987341771]
# 0.7146791357181318
# -0.7146791357181318 -0.7250602812881468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:14:47.096631
# [0.6986301369863014, 0.7034482758620689, 0.7662337662337663, 0.5985401459854014, 0.7798742138364779]
# 0.7093453077808032
# -0.7093453077808032 -0.7250602812881468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:15:01.852281
# [0.7222222222222222, 0.7172413793103448, 0.7733333333333333, 0.647887323943662, 0.7848101265822786]
# 0.7290988770783682
# -0.7290988770783682 -0.7290988770783682
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:15:15.818504
# [0.684931506849315, 0.7114093959731543, 0.7612903225806451, 0.6388888888888888, 0.7672955974842767]
# 0.712763142355256
# -0.712763142355256 -0.7290988770783682
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:15:31.286847
# [0.689655172413793, 0.7114093959731543, 0.7612903225806451, 0.6293706293706294, 0.7672955974842767]
# 0.7118042235644997
# -0.7118042235644997 -0.7290988770783682
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:15:47.090199
# [0.7210884353741497, 0.7482993197278912, 0.7733333333333333, 0.647887323943662, 0.782051282051282]
# 0.7345319388860636
# -0.7345319388860636 -0.7345319388860636
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:16:00.517494
# [0.758169934640523, 0.7755102040816326, 0.7866666666666667, 0.6805555555555557, 0.7898089171974522]
# 0.758142255628366
# -0.758142255628366 -0.758142255628366
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f7452c575f8>}
# 0.7537688442211056
# outer fold
# 2019-08-20 16:16:16.446196
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-20 16:16:16.754388
# [0.7692307692307692, 0.7898089171974522, 0.7397260273972603, 0.7785234899328859, 0.8051948051948052]
# 0.7764968017906346
# -0.7764968017906346 -0.7764968017906346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-20 16:16:31.670065
# [0.7594936708860759, 0.7898089171974522, 0.7397260273972603, 0.7702702702702703, 0.8051948051948052]
# 0.7728987381891728
# -0.7728987381891728 -0.7764968017906346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-20 16:16:46.145854
# [0.7594936708860759, 0.7848101265822786, 0.7310344827586207, 0.7671232876712328, 0.8051948051948052]
# 0.7695312746186026
# -0.7695312746186026 -0.7764968017906346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-20 16:17:00.682581
# [0.7643312101910827, 0.7749999999999999, 0.7346938775510203, 0.7417218543046357, 0.782051282051282]
# 0.759559644819604
# -0.759559644819604 -0.7764968017906346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-20 16:17:15.188237
# [0.7594936708860759, 0.7798742138364779, 0.7397260273972603, 0.7586206896551724, 0.8051948051948052]
# 0.7685818813939583
# -0.7685818813939583 -0.7764968017906346
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-20 16:17:29.700287
# [0.75, 0.7974683544303799, 0.7448275862068966, 0.7866666666666667, 0.8157894736842104]
# 0.7789504161976307
# -0.7789504161976307 -0.7789504161976307
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-20 16:17:43.459772
# [0.7643312101910827, 0.7749999999999999, 0.7346938775510203, 0.7417218543046357, 0.782051282051282]
# 0.759559644819604
# -0.759559644819604 -0.7789504161976307
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-20 16:17:57.992017
# [0.7643312101910827, 0.7749999999999999, 0.7397260273972603, 0.7516778523489933, 0.7973856209150327]
# 0.7656241421704737
# -0.7656241421704737 -0.7789504161976307
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-20 16:18:11.968031
# [0.75, 0.7974683544303799, 0.7534246575342466, 0.794701986754967, 0.8157894736842104]
# 0.7822768944807608
# -0.7822768944807608 -0.7822768944807608
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-20 16:18:25.316674
# [0.7439024390243902, 0.7924528301886792, 0.7549668874172185, 0.7999999999999999, 0.8205128205128205]
# 0.7823669954286216
# -0.7823669954286216 -0.7823669954286216
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f74533ddb70>}
# 0.7379679144385027
# save to ../pickle/2019-08-20 16:18:42.425389.pickle
# save to ../csv/2019-08-20 16:18:42.446752.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.81           0.717       0.769         0.997    1
#
#   train_recall train_accuracy model1  \
# 0  0.994        0.997          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-20 16:18:42.425389.pickle
# save to ../csv/2019-08-20 16:18:42.533625.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.81           0.717       0.769         0.997    1
#
#   train_recall train_accuracy model1  \
# 0  0.994        0.997          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-20 16:18:42.425389.pickle
# time: 12min 39s

# %% [markdown]
# ### 2. BoW-NB and LGBM

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lgbm
    
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2

'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
model1 = None
state = 2022
for method in [['wc','scale']]:
    print('state', state)
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2), method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-20 16:18:54.352030
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 16:18:54.633991
# [0.7044025157232704, 0.7261146496815287, 0.7215189873417721, 0.7664670658682634, 0.7142857142857143]
# 0.7265577865801098
# -0.7265577865801098 -0.7265577865801098
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 16:26:14.459015
# [0.6708860759493671, 0.6923076923076923, 0.7051282051282051, 0.7325581395348836, 0.7307692307692308]
# 0.7063298687378758
# -0.7063298687378758 -0.7265577865801098
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 16:32:12.975354
# [0.7006369426751592, 0.7283950617283951, 0.7612903225806451, 0.7810650887573963, 0.7612903225806452]
# 0.7465355476644482
# -0.7465355476644482 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 16:40:55.279825
# [0.7080745341614907, 0.7236842105263157, 0.7250000000000001, 0.7906976744186047, 0.7204968944099378]
# 0.7335906627032698
# -0.7335906627032698 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 16:48:31.417865
# [0.7239263803680983, 0.7012987012987013, 0.7547169811320754, 0.7586206896551724, 0.7019867549668874]
# 0.728109901484187
# -0.728109901484187 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 16:53:35.222485
# [0.7133757961783439, 0.7169811320754716, 0.6967741935483871, 0.7664670658682634, 0.7333333333333334]
# 0.7253863042007598
# -0.7253863042007598 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 17:04:01.103241
# [0.7051282051282051, 0.7105263157894737, 0.6962025316455697, 0.7630057803468208, 0.7142857142857143]
# 0.7178297094391567
# -0.7178297094391567 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 17:14:52.163329
# [0.7250000000000001, 0.7439024390243902, 0.7250000000000001, 0.7586206896551724, 0.7272727272727273]
# 0.7359591711904582
# -0.7359591711904582 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-20 17:24:08.281479
# [0.7329192546583853, 0.7341772151898733, 0.7341772151898733, 0.7602339181286549, 0.7515923566878983]
# 0.7426199919709371
# -0.7426199919709371 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 17:30:02.162102
# [0.7133757961783439, 0.75, 0.735483870967742, 0.7529411764705881, 0.7515923566878983]
# 0.7406786400609144
# -0.7406786400609144 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 17:36:31.270379
# [0.6625, 0.6918238993710691, 0.6794871794871794, 0.7529411764705881, 0.7250000000000001]
# 0.7023504510657673
# -0.7023504510657673 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 17:43:06.551400
# [0.7125, 0.6928104575163399, 0.7283950617283951, 0.7602339181286549, 0.717948717948718]
# 0.7223776310644217
# -0.7223776310644217 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 17:49:37.821570
# [0.7250000000000001, 0.7692307692307692, 0.7114093959731543, 0.761904761904762, 0.7450980392156863]
# 0.7425285932648744
# -0.7425285932648744 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 18:00:55.514241
# [0.6455696202531646, 0.6962025316455697, 0.7044025157232704, 0.7167630057803468, 0.7012987012987014]
# 0.6928472749402105
# -0.6928472749402105 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-20 18:08:20.056807
# [0.7407407407407407, 0.7421383647798742, 0.7612903225806451, 0.7745664739884394, 0.7058823529411764]
# 0.7449236510061752
# -0.7449236510061752 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 18:14:59.798745
# [0.7044025157232704, 0.7421383647798742, 0.7320261437908497, 0.7515151515151515, 0.7272727272727273]
# 0.7314709806163746
# -0.7314709806163746 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 18:25:34.955469
# [0.6709677419354838, 0.7374999999999999, 0.7169811320754716, 0.7647058823529411, 0.72]
# 0.7220309512727793
# -0.7220309512727793 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-20 18:35:42.646565
# [0.6496815286624203, 0.6878980891719745, 0.6838709677419356, 0.7411764705882353, 0.7250000000000001]
# 0.6975254112329131
# -0.6975254112329131 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 18:42:58.938459
# [0.7088607594936708, 0.7225806451612903, 0.7435897435897435, 0.7861271676300579, 0.7272727272727273]
# 0.737686208629498
# -0.737686208629498 -0.7465355476644482
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 18:49:44.021697
# [0.6666666666666667, 0.7125, 0.7215189873417721, 0.6832298136645963, 0.7133757961783439]
# 0.6994582527702758
# -0.6994582527702758 -0.7465355476644482
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f7452c5a518>}
# 0.7904761904761904
# outer fold
# 2019-08-20 18:58:25.976989
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 18:58:26.365878
# [0.6875000000000001, 0.7602339181286549, 0.6442953020134228, 0.7721518987341771, 0.7407407407407407]
# 0.720984371923399
# -0.720984371923399 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 19:07:53.422785
# [0.6455696202531646, 0.7485380116959064, 0.6447368421052632, 0.7544910179640719, 0.6666666666666667]
# 0.6920004317370145
# -0.6920004317370145 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 19:15:17.132207
# [0.6751592356687897, 0.7636363636363638, 0.6802721088435375, 0.7594936708860759, 0.7250000000000001]
# 0.7207122758069534
# -0.7207122758069534 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 19:25:50.741193
# [0.675, 0.7361963190184049, 0.6751592356687897, 0.7594936708860759, 0.7283950617283951]
# 0.7148488574603331
# -0.7148488574603331 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 19:35:50.871224
# [0.6751592356687897, 0.75, 0.6623376623376623, 0.7515923566878981, 0.7228915662650603]
# 0.7123961641918821
# -0.7123961641918821 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 19:43:45.292188
# [0.7, 0.7647058823529411, 0.6580645161290323, 0.7468354430379747, 0.710843373493976]
# 0.7160898430027848
# -0.7160898430027848 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 19:54:39.612863
# [0.6792452830188679, 0.7469879518072289, 0.6710526315789473, 0.7654320987654321, 0.7341772151898733]
# 0.7193790360720699
# -0.7193790360720699 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-20 20:04:54.483747
# [0.7, 0.7329192546583853, 0.6666666666666666, 0.7577639751552795, 0.7407407407407407]
# 0.7196181274442143
# -0.7196181274442143 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-20 20:16:16.820483
# [0.6583850931677019, 0.7073170731707318, 0.6442953020134228, 0.7643312101910827, 0.7195121951219512]
# 0.698768174732978
# -0.698768174732978 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 20:22:57.981558
# [0.6540880503144653, 0.7544910179640719, 0.6530612244897959, 0.7594936708860759, 0.7151515151515152]
# 0.7072570957611848
# -0.7072570957611848 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-20 20:29:40.019388
# [0.6835443037974684, 0.7398843930635839, 0.6405228758169934, 0.7590361445783134, 0.6490066225165563]
# 0.694398867954583
# -0.694398867954583 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 20:36:50.927637
# [0.7012987012987013, 0.7239263803680983, 0.6623376623376623, 0.7594936708860759, 0.7160493827160493]
# 0.7126211595213175
# -0.7126211595213175 -0.720984371923399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 20:43:37.995556
# [0.6666666666666667, 0.7682926829268293, 0.6805555555555557, 0.7625, 0.7530864197530863]
# 0.7262202649804277
# -0.7262202649804277 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-20 22:21:16.824555
# [0.6405228758169934, 0.7558139534883721, 0.6578947368421051, 0.7484662576687118, 0.6666666666666667]
# 0.6938728980965699
# -0.6938728980965699 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-20 23:24:47.470270
# [0.6790123456790124, 0.761904761904762, 0.6845637583892616, 0.7672955974842767, 0.7185628742514969]
# 0.7222678675417619
# -0.7222678675417619 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-20 23:34:38.199283
# [0.6625, 0.7469879518072289, 0.6621621621621622, 0.7532467532467533, 0.7239263803680983]
# 0.7097646495168486
# -0.7097646495168486 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-20 23:44:18.720533
# [0.6835443037974684, 0.7439024390243902, 0.6711409395973154, 0.7515923566878981, 0.7439024390243902]
# 0.7188164956262926
# -0.7188164956262926 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-20 23:54:37.135018
# [0.6583850931677019, 0.7469879518072289, 0.6266666666666667, 0.7710843373493975, 0.703030303030303]
# 0.7012308704042596
# -0.7012308704042596 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 00:01:32.451469
# [0.6792452830188679, 0.7349397590361447, 0.6753246753246753, 0.7594936708860759, 0.7261904761904762]
# 0.715038772891248
# -0.715038772891248 -0.7262202649804277
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 00:07:56.189510
# [0.6753246753246753, 0.7218934911242604, 0.6114649681528662, 0.7654320987654321, 0.6582278481012659]
# 0.6864686162936999
# -0.6864686162936999 -0.7262202649804277
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7f74532fc1d0>}
# 0.7999999999999999
# outer fold
# 2019-08-21 00:16:43.726818
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 00:16:44.141348
# [0.654320987654321, 0.7096774193548386, 0.6923076923076923, 0.7151515151515152, 0.7484662576687118]
# 0.7039847744274158
# -0.7039847744274158 -0.7039847744274158
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 00:25:50.892979
# [0.6419753086419753, 0.7169811320754716, 0.6918238993710691, 0.6956521739130435, 0.7393939393939394]
# 0.6971652906790997
# -0.6971652906790997 -0.7039847744274158
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 00:32:42.819540
# [0.6753246753246753, 0.7058823529411765, 0.6962025316455697, 0.7484662576687118, 0.7341772151898733]
# 0.7120106065540013
# -0.7120106065540013 -0.7120106065540013
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 00:42:54.859665
# [0.6832298136645963, 0.7421383647798742, 0.6878980891719745, 0.7643312101910827, 0.7295597484276728]
# 0.7214314452470401
# -0.7214314452470401 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 00:53:12.198470
# [0.6835443037974684, 0.7204968944099378, 0.7080745341614907, 0.7261904761904762, 0.7361963190184049]
# 0.7149005055155557
# -0.7149005055155557 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 01:00:19.789156
# [0.6790123456790124, 0.735483870967742, 0.6883116883116883, 0.7349397590361447, 0.7374999999999999]
# 0.7150495327989175
# -0.7150495327989175 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 01:11:01.492261
# [0.6459627329192547, 0.7105263157894737, 0.6918238993710691, 0.7317073170731708, 0.7407407407407407]
# 0.7041522011787418
# -0.7041522011787418 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 01:19:51.622319
# [0.6666666666666667, 0.7051282051282051, 0.6751592356687897, 0.7469879518072289, 0.7125]
# 0.701288411854178
# -0.701288411854178 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 01:29:39.211613
# [0.6792452830188679, 0.717948717948718, 0.6878980891719745, 0.691358024691358, 0.7407407407407407]
# 0.7034381711143318
# -0.7034381711143318 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 01:35:39.877038
# [0.6845637583892616, 0.7307692307692308, 0.7044025157232704, 0.7388535031847134, 0.7215189873417721]
# 0.7160215990816498
# -0.7160215990816498 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 01:41:38.566359
# [0.6341463414634146, 0.7169811320754716, 0.6792452830188679, 0.7088607594936708, 0.7393939393939394]
# 0.6957254910890728
# -0.6957254910890728 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 01:47:55.077401
# [0.6540880503144653, 0.7388535031847134, 0.6709677419354838, 0.7037037037037037, 0.7453416149068324]
# 0.7025909228090397
# -0.7025909228090397 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 01:54:24.678237
# [0.6751592356687897, 0.7307692307692308, 0.7051282051282051, 0.7317073170731708, 0.7468354430379747]
# 0.7179198863354742
# -0.7179198863354742 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 02:04:56.507965
# [0.6303030303030304, 0.7261146496815287, 0.6540880503144653, 0.7037037037037037, 0.703030303030303]
# 0.6834479474066062
# -0.6834479474066062 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 02:11:37.718762
# [0.6792452830188679, 0.7468354430379747, 0.7044025157232704, 0.7439024390243902, 0.7283950617283951]
# 0.7205561485065796
# -0.7205561485065796 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 02:17:29.497073
# [0.6753246753246753, 0.7388535031847134, 0.7105263157894737, 0.7439024390243902, 0.7341772151898733]
# 0.7205568297026252
# -0.7205568297026252 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 02:27:03.841284
# [0.6540880503144653, 0.7058823529411765, 0.6838709677419356, 0.7590361445783134, 0.7088607594936708]
# 0.7023476550139123
# -0.7023476550139123 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 02:36:45.227987
# [0.6390532544378698, 0.7261146496815287, 0.6707317073170732, 0.7195121951219512, 0.75]
# 0.7010823613116847
# -0.7010823613116847 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 02:43:30.350289
# [0.670807453416149, 0.717948717948718, 0.7, 0.6956521739130435, 0.7204968944099378]
# 0.7009810479375698
# -0.7009810479375698 -0.7214314452470401
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 02:49:36.991670
# [0.6075949367088607, 0.7105263157894737, 0.6583850931677019, 0.7393939393939394, 0.7484662576687118]
# 0.6928733085457375
# -0.6928733085457375 -0.7214314452470401
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f7452c34550>}
# 0.7487179487179487
# outer fold
# 2019-08-21 02:57:23.856179
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 02:57:24.281711
# [0.7607361963190185, 0.7469879518072289, 0.7483870967741936, 0.6451612903225807, 0.7804878048780488]
# 0.7363520680202141
# -0.7363520680202141 -0.7363520680202141
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 03:05:48.817643
# [0.7349397590361447, 0.7209302325581395, 0.782608695652174, 0.6363636363636364, 0.7411764705882353]
# 0.7232037588396659
# -0.7232037588396659 -0.7363520680202141
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 03:12:51.584214
# [0.7594936708860759, 0.7529411764705881, 0.7924528301886792, 0.6754966887417219, 0.7975460122699387]
# 0.7555860757114008
# -0.7555860757114008 -0.7555860757114008
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 03:22:43.193937
# [0.7483870967741936, 0.7455621301775148, 0.7483870967741936, 0.6580645161290323, 0.7654320987654321]
# 0.7331665877240733
# -0.7331665877240733 -0.7555860757114008
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 03:31:24.749429
# [0.7439024390243902, 0.7757575757575756, 0.782608695652174, 0.6883116883116883, 0.8023952095808382]
# 0.7585951216653333
# -0.7585951216653333 -0.7585951216653333
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 03:37:46.843795
# [0.7654320987654321, 0.7999999999999999, 0.8, 0.6933333333333332, 0.8072289156626505]
# 0.7731988695522831
# -0.7731988695522831 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 03:47:19.914149
# [0.7453416149068324, 0.738095238095238, 0.7450980392156864, 0.6666666666666667, 0.7547169811320754]
# 0.7299837080032997
# -0.7299837080032997 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 03:55:47.999131
# [0.7594936708860759, 0.7885714285714285, 0.8074534161490683, 0.6754966887417219, 0.8023952095808382]
# 0.7666820827858265
# -0.7666820827858265 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 04:05:41.758307
# [0.7421383647798742, 0.7261904761904762, 0.7402597402597403, 0.6666666666666667, 0.7484662576687118]
# 0.7247443011130938
# -0.7247443011130938 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 04:12:29.889665
# [0.7361963190184049, 0.7719298245614035, 0.7950310559006211, 0.7133757961783439, 0.7798742138364779]
# 0.7592814418990501
# -0.7592814418990501 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 04:19:27.927659
# [0.7469879518072289, 0.6706586826347306, 0.7777777777777778, 0.627450980392157, 0.7710843373493975]
# 0.7187919459922583
# -0.7187919459922583 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 04:27:19.543863
# [0.7388535031847134, 0.7272727272727273, 0.7848101265822786, 0.6540880503144653, 0.7682926829268293]
# 0.7346634180562027
# -0.7346634180562027 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 04:34:55.309541
# [0.7636363636363638, 0.783625730994152, 0.7870967741935484, 0.6928104575163399, 0.7875]
# 0.7629338652680808
# -0.7629338652680808 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 04:48:06.500945
# [0.7349397590361447, 0.710059171597633, 0.7804878048780488, 0.6490066225165563, 0.7757575757575756]
# 0.7300501867571917
# -0.7300501867571917 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 04:56:12.333803
# [0.7407407407407407, 0.7745664739884394, 0.7875, 0.7133757961783439, 0.7560975609756098]
# 0.7544561143766269
# -0.7544561143766269 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 05:03:01.093690
# [0.75, 0.7745664739884394, 0.7848101265822786, 0.6887417218543046, 0.7924528301886792]
# 0.7581142305227403
# -0.7581142305227403 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 05:14:25.169506
# [0.7421383647798742, 0.7790697674418605, 0.7950310559006211, 0.6797385620915033, 0.8098159509202455]
# 0.761158740226821
# -0.761158740226821 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 05:25:31.254887
# [0.7577639751552795, 0.7065868263473054, 0.7564102564102564, 0.6405228758169934, 0.7719298245614035]
# 0.7266427516582477
# -0.7266427516582477 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 05:33:27.530681
# [0.7361963190184049, 0.7176470588235295, 0.7662337662337663, 0.6538461538461539, 0.7798742138364779]
# 0.7307595023516664
# -0.7307595023516664 -0.7731988695522831
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 05:41:05.616692
# [0.7261904761904762, 0.6506024096385542, 0.7320261437908497, 0.6447368421052632, 0.7710843373493975]
# 0.7049280418149082
# -0.7049280418149082 -0.7731988695522831
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f7452c343c8>}
# 0.7562189054726369
# outer fold
# 2019-08-21 05:49:58.616694
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 05:49:59.075002
# [0.7195121951219512, 0.6838709677419356, 0.6928104575163399, 0.7169811320754716, 0.7547169811320754]
# 0.7135783467175547
# -0.7135783467175547 -0.7135783467175547
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 06:00:07.796429
# [0.6871165644171778, 0.7160493827160493, 0.6878980891719745, 0.6792452830188679, 0.761904761904762]
# 0.7064428162457663
# -0.7064428162457663 -0.7135783467175547
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 06:08:26.875440
# [0.7239263803680983, 0.6842105263157894, 0.7317073170731708, 0.7295597484276728, 0.7692307692307692]
# 0.7277269482831001
# -0.7277269482831001 -0.7277269482831001
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 06:20:05.522063
# [0.7073170731707318, 0.7051282051282051, 0.7096774193548386, 0.7125, 0.7654320987654321]
# 0.7200109592838414
# -0.7200109592838414 -0.7277269482831001
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 06:30:52.058120
# [0.6829268292682926, 0.6918238993710691, 0.7393939393939394, 0.7361963190184049, 0.7810650887573963]
# 0.7262812151618205
# -0.7262812151618205 -0.7277269482831001
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 06:38:23.886011
# [0.7151515151515152, 0.7080745341614907, 0.7329192546583853, 0.7361963190184049, 0.7590361445783134]
# 0.7302755535136218
# -0.7302755535136218 -0.7302755535136218
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 06:50:47.585781
# [0.7037037037037037, 0.7204968944099378, 0.7096774193548386, 0.7088607594936708, 0.7515923566878981]
# 0.7188662267300098
# -0.7188662267300098 -0.7302755535136218
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 07:01:08.201694
# [0.7142857142857143, 0.7125, 0.7283950617283951, 0.7407407407407407, 0.7701863354037267]
# 0.7332215704317153
# -0.7332215704317153 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 07:12:15.702150
# [0.710843373493976, 0.7, 0.7283950617283951, 0.7151515151515152, 0.7654320987654321]
# 0.7239644098278637
# -0.7239644098278637 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 07:19:36.074805
# [0.670807453416149, 0.6753246753246753, 0.7349397590361447, 0.7393939393939394, 0.7636363636363638]
# 0.7168204381614544
# -0.7168204381614544 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 07:26:40.536271
# [0.6918238993710691, 0.7169811320754716, 0.6756756756756757, 0.7116564417177914, 0.75]
# 0.7092274297680016
# -0.7092274297680016 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 07:33:19.203978
# [0.6867469879518073, 0.7236842105263157, 0.7133757961783439, 0.7361963190184049, 0.7625]
# 0.7245006627349744
# -0.7245006627349744 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 07:39:37.558220
# [0.7204968944099378, 0.7051282051282051, 0.7341772151898733, 0.7361963190184049, 0.7682926829268293]
# 0.7328582633346501
# -0.7328582633346501 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 07:50:13.960405
# [0.7080745341614907, 0.7151515151515152, 0.6535947712418301, 0.6909090909090909, 0.7305389221556886]
# 0.6996537667239231
# -0.6996537667239231 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 07:57:37.238704
# [0.7116564417177914, 0.7096774193548386, 0.7515151515151515, 0.7407407407407407, 0.7329192546583853]
# 0.7293018015973816
# -0.7293018015973816 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 08:03:51.632713
# [0.7515151515151515, 0.7006369426751592, 0.7125, 0.7374999999999999, 0.7594936708860759]
# 0.7323291530152772
# -0.7323291530152772 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 08:14:17.922568
# [0.7116564417177914, 0.6883116883116883, 0.7037037037037037, 0.7116564417177914, 0.7951807228915663]
# 0.7221017996685082
# -0.7221017996685082 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 08:24:55.804485
# [0.675, 0.7374999999999999, 0.7272727272727273, 0.6829268292682926, 0.7407407407407407]
# 0.712688059456352
# -0.712688059456352 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 08:32:49.839055
# [0.691358024691358, 0.7044025157232704, 0.7096774193548386, 0.7204968944099378, 0.7407407407407407]
# 0.713335118984029
# -0.713335118984029 -0.7332215704317153
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 08:39:48.969490
# [0.6666666666666667, 0.7283950617283951, 0.7044025157232704, 0.7, 0.7295597484276728]
# 0.705804798509201
# -0.705804798509201 -0.7332215704317153
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wc', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7f7452c5a400>}
# 0.7046632124352332
# save to ../pickle/2019-08-21 08:47:59.860537.pickle
# save to ../csv/2019-08-21 08:48:00.854580.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.77           0.751       0.759         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=64,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-21 08:47:59.860537.pickle
# save to ../csv/2019-08-21 08:48:00.938174.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.77           0.751       0.759         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 model2  \
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=64,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wc, scale]  AMT  ../pickle/2019-08-21 08:47:59.860537.pickle
# time: 16h 29min 18s

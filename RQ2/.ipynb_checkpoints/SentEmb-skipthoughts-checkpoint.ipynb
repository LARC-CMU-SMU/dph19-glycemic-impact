# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.78 µs
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# time: 41.7 ms

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 17.3 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', add_skip_thoughts='../data/X_skipthoughts_6k.pickle')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['skip','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-23 15:42:35.969484
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 15:42:36.287518
# [0.7590361445783134, 0.735632183908046, 0.7105263157894737, 0.7757575757575756, 0.7567567567567567]
# 0.747541795358033
# -0.747541795358033 -0.747541795358033
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 15:42:45.684730
# [0.7804878048780488, 0.7398843930635839, 0.7189542483660132, 0.7547169811320754, 0.7532467532467533]
# 0.7494580361372949
# -0.7494580361372949 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 15:42:54.854820
# [0.7682926829268293, 0.7441860465116279, 0.7058823529411765, 0.7453416149068324, 0.7222222222222223]
# 0.7371849839017377
# -0.7371849839017377 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 15:43:07.314464
# [0.7577639751552795, 0.72, 0.6962025316455697, 0.7272727272727273, 0.7189542483660132]
# 0.724038696487918
# -0.724038696487918 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 15:43:20.344430
# [0.7757575757575756, 0.7344632768361582, 0.6962025316455697, 0.7594936708860759, 0.7248322147651006]
# 0.738149853978096
# -0.738149853978096 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 15:43:33.743598
# [0.7388535031847134, 0.710843373493976, 0.7320261437908497, 0.7738095238095237, 0.7843137254901962]
# 0.7479692539538518
# -0.7479692539538518 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 15:43:40.919178
# [0.7654320987654321, 0.7231638418079096, 0.6962025316455697, 0.7272727272727273, 0.7189542483660132]
# 0.7262050895715303
# -0.7262050895715303 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 15:43:53.633549
# [0.7577639751552795, 0.735632183908046, 0.6962025316455697, 0.7453416149068324, 0.728476821192053]
# 0.7326834253615562
# -0.7326834253615562 -0.7494580361372949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 15:44:07.730885
# [0.7283950617283951, 0.7209302325581395, 0.726027397260274, 0.782608695652174, 0.818181818181818]
# 0.7552286410761601
# -0.7552286410761601 -0.7552286410761601
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 15:44:14.131294
# [0.7073170731707318, 0.7228915662650603, 0.7468354430379747, 0.761904761904762, 0.778523489932886]
# 0.7434944668622829
# -0.7434944668622829 -0.7552286410761601
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5af3fa470>}
# 0.7582938388625594
# outer fold
# 2019-08-23 15:44:21.661951
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 15:44:22.011348
# [0.7560975609756098, 0.7176470588235295, 0.7402597402597403, 0.7926829268292682, 0.7250000000000001]
# 0.7463374573776296
# -0.7463374573776296 -0.7463374573776296
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 15:44:31.004952
# [0.7530864197530863, 0.7261904761904762, 0.7333333333333334, 0.8095238095238094, 0.7305389221556886]
# 0.7505345921912788
# -0.7505345921912788 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 15:44:40.457906
# [0.7239263803680983, 0.7142857142857143, 0.7320261437908497, 0.7857142857142857, 0.7151515151515152]
# 0.7342208078620927
# -0.7342208078620927 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 15:44:52.249964
# [0.7073170731707318, 0.6904761904761905, 0.7320261437908497, 0.7425149700598802, 0.6993865030674846]
# 0.7143441761130274
# -0.7143441761130274 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 15:45:05.874011
# [0.7204968944099378, 0.7294117647058823, 0.7307692307692308, 0.7636363636363638, 0.6993865030674846]
# 0.7287401513177799
# -0.7287401513177799 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 15:45:19.441429
# [0.7295597484276728, 0.7294117647058823, 0.7310344827586207, 0.787878787878788, 0.7368421052631577]
# 0.7429453778068243
# -0.7429453778068243 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 15:45:26.686283
# [0.6993865030674846, 0.6904761904761905, 0.7320261437908497, 0.7393939393939394, 0.6951219512195121]
# 0.7112809455895952
# -0.7112809455895952 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 15:45:40.618999
# [0.7073170731707318, 0.6867469879518073, 0.7320261437908497, 0.7469879518072289, 0.6993865030674846]
# 0.7144929319576205
# -0.7144929319576205 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 15:45:56.005400
# [0.7189542483660132, 0.7349397590361447, 0.7631578947368421, 0.7804878048780488, 0.6624203821656051]
# 0.7319920178365308
# -0.7319920178365308 -0.7505345921912788
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 15:46:01.451219
# [0.7183098591549297, 0.7544910179640719, 0.7172413793103448, 0.7976190476190476, 0.7116564417177914]
# 0.739863549153237
# -0.739863549153237 -0.7505345921912788
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}, 'corp': <models.features.fixed_makedata object at 0x7fa5af0fa978>}
# 0.7655502392344496
# outer fold
# 2019-08-23 15:46:10.603909
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 15:46:11.038857
# [0.7, 0.7368421052631579, 0.7272727272727273, 0.7228915662650603, 0.7848101265822786]
# 0.7343633050766448
# -0.7343633050766448 -0.7343633050766448
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 15:46:20.620256
# [0.703030303030303, 0.728476821192053, 0.7185628742514969, 0.7209302325581395, 0.7721518987341771]
# 0.728630425953234
# -0.728630425953234 -0.7343633050766448
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 15:46:30.117818
# [0.6951219512195121, 0.7215189873417721, 0.6871165644171778, 0.6941176470588235, 0.7547169811320754]
# 0.7105184262338723
# -0.7105184262338723 -0.7343633050766448
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 15:46:40.916309
# [0.6787878787878788, 0.6967741935483871, 0.6951219512195121, 0.7017543859649122, 0.7341772151898733]
# 0.7013231249421127
# -0.7013231249421127 -0.7343633050766448
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 15:46:55.401283
# [0.6867469879518073, 0.7096774193548386, 0.6909090909090909, 0.7093023255813952, 0.7341772151898733]
# 0.706162607797401
# -0.706162607797401 -0.7343633050766448
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 15:47:07.825046
# [0.7044025157232704, 0.7749999999999999, 0.7329192546583853, 0.7361963190184049, 0.7792207792207793]
# 0.7455477737241679
# -0.7455477737241679 -0.7455477737241679
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 15:47:15.188582
# [0.6787878787878788, 0.6967741935483871, 0.6951219512195121, 0.7065868263473054, 0.7261146496815287]
# 0.7006770999169223
# -0.7006770999169223 -0.7455477737241679
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 15:47:27.327912
# [0.6787878787878788, 0.7012987012987013, 0.6951219512195121, 0.7023809523809522, 0.7261146496815287]
# 0.7007408266737146
# -0.7007408266737146 -0.7455477737241679
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 15:47:40.358495
# [0.6993865030674846, 0.7798742138364779, 0.735483870967742, 0.738095238095238, 0.7567567567567567]
# 0.7419193165447399
# -0.7419193165447399 -0.7455477737241679
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 15:47:47.507848
# [0.7176470588235295, 0.7317073170731708, 0.7544910179640719, 0.7215189873417721, 0.7712418300653595]
# 0.7393212422535808
# -0.7393212422535808 -0.7455477737241679
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7fa5af3d9d68>}
# 0.7487179487179487
# outer fold
# 2019-08-23 15:47:55.127249
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 15:47:55.488427
# [0.7870967741935484, 0.6878980891719745, 0.7469879518072289, 0.6933333333333332, 0.7738095238095237]
# 0.7378251344631217
# -0.7378251344631217 -0.7378251344631217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 15:48:04.304212
# [0.7721518987341771, 0.6918238993710691, 0.7151515151515152, 0.6838709677419356, 0.7613636363636362]
# 0.7248723834724667
# -0.7248723834724667 -0.7378251344631217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 15:48:13.168504
# [0.7402597402597403, 0.6794871794871794, 0.7073170731707318, 0.7088607594936708, 0.735632183908046]
# 0.7143113872638736
# -0.7143113872638736 -0.7378251344631217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 15:48:23.856834
# [0.7096774193548386, 0.6832298136645963, 0.6982248520710058, 0.6710526315789473, 0.7294117647058823]
# 0.6983192962750542
# -0.6983192962750542 -0.7378251344631217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 15:48:38.957489
# [0.7225806451612903, 0.6875000000000001, 0.7037037037037037, 0.6838709677419356, 0.7398843930635839]
# 0.7075079419341027
# -0.7075079419341027 -0.7378251344631217
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 15:48:51.521749
# [0.8129032258064517, 0.6951219512195121, 0.7852760736196319, 0.6933333333333332, 0.75]
# 0.7473269167957859
# -0.7473269167957859 -0.7473269167957859
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 15:48:59.005387
# [0.7096774193548386, 0.6790123456790124, 0.6982248520710058, 0.6710526315789473, 0.7294117647058823]
# 0.6974758026779373
# -0.6974758026779373 -0.7473269167957859
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 15:49:13.287152
# [0.7096774193548386, 0.6751592356687897, 0.7023809523809522, 0.6838709677419356, 0.7368421052631577]
# 0.7015861360819347
# -0.7015861360819347 -0.7473269167957859
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 15:49:27.536338
# [0.8053691275167785, 0.6993865030674846, 0.8048780487804877, 0.7088607594936708, 0.7777777777777778]
# 0.7592544433272399
# -0.7592544433272399 -0.7592544433272399
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 15:49:34.908867
# [0.8053691275167785, 0.6754966887417219, 0.8143712574850299, 0.6933333333333332, 0.783625730994152]
# 0.7544392276142032
# -0.7544392276142032 -0.7592544433272399
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5af3f75f8>}
# 0.782608695652174
# outer fold
# 2019-08-23 15:49:41.258322
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 15:49:41.824170
# [0.7630057803468208, 0.7515151515151515, 0.7204968944099378, 0.7407407407407407, 0.7450980392156864]
# 0.7441713212456674
# -0.7441713212456674 -0.7441713212456674
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 15:49:51.651514
# [0.7701149425287357, 0.7455621301775148, 0.7283950617283951, 0.7105263157894737, 0.7361963190184049]
# 0.7381589538485048
# -0.7381589538485048 -0.7441713212456674
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 15:50:02.130246
# [0.7674418604651162, 0.7469879518072289, 0.7195121951219512, 0.7012987012987013, 0.7547169811320754]
# 0.7379915379650146
# -0.7379915379650146 -0.7441713212456674
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 15:50:14.146442
# [0.7558139534883721, 0.7692307692307692, 0.710843373493976, 0.7006369426751592, 0.7421383647798742]
# 0.7357326807336301
# -0.7357326807336301 -0.7441713212456674
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 15:50:29.164567
# [0.7602339181286549, 0.7692307692307692, 0.7228915662650603, 0.7125, 0.7421383647798742]
# 0.7413989236808717
# -0.7413989236808717 -0.7441713212456674
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 15:50:42.238648
# [0.7602339181286549, 0.7329192546583853, 0.7374999999999999, 0.7450980392156864, 0.7532467532467533]
# 0.745799593049896
# -0.745799593049896 -0.745799593049896
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 15:50:48.806436
# [0.7558139534883721, 0.7647058823529411, 0.710843373493976, 0.6962025316455697, 0.7421383647798742]
# 0.7339408211521465
# -0.7339408211521465 -0.745799593049896
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 15:51:03.177841
# [0.7602339181286549, 0.7692307692307692, 0.7151515151515152, 0.6923076923076923, 0.7421383647798742]
# 0.7358124519197011
# -0.7358124519197011 -0.745799593049896
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 15:51:18.861496
# [0.7757575757575756, 0.7215189873417721, 0.7225806451612903, 0.7564102564102564, 0.7643312101910827]
# 0.7481197349723955
# -0.7481197349723955 -0.7481197349723955
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 15:51:25.659972
# [0.7388535031847134, 0.7283236994219653, 0.7222222222222222, 0.7741935483870969, 0.7692307692307692]
# 0.7465647484893534
# -0.7465647484893534 -0.7481197349723955
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5af3d5240>}
# 0.7434554973821988
# save to ../pickle/2019-08-23 15:51:33.633757.pickle
# save to ../csv/2019-08-23 15:51:33.647320.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.761          0.761       0.755         0.891    0.896
#
#   train_recall train_accuracy model1  \
# 0  0.886        0.889          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-23 15:51:33.633757.pickle
# save to ../csv/2019-08-23 15:51:33.681916.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.76    0.761          0.761       0.755         0.891    0.896
#
#   train_recall train_accuracy model1  \
# 0  0.886        0.889          None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-23 15:51:33.633757.pickle
# time: 9min 9s

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', add_skip_thoughts='../data/X_skipthoughts_25k.pickle')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['skip','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-23 16:11:40.470544
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:11:40.797945
# [0.7307692307692308, 0.7, 0.717948717948718, 0.75, 0.7594936708860761]
# 0.731642323920805
# -0.731642323920805 -0.731642323920805
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:11:49.525289
# [0.7225806451612903, 0.691358024691358, 0.7051282051282051, 0.7455621301775148, 0.7594936708860761]
# 0.7248245352088888
# -0.7248245352088888 -0.731642323920805
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:11:57.580493
# [0.7236842105263157, 0.6832298136645963, 0.6835443037974684, 0.738095238095238, 0.7594936708860761]
# 0.717609447393939
# -0.717609447393939 -0.731642323920805
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:12:06.559060
# [0.6891891891891893, 0.6666666666666667, 0.6835443037974684, 0.7337278106508877, 0.7453416149068324]
# 0.703693917042209
# -0.703693917042209 -0.731642323920805
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:12:15.428084
# [0.7152317880794701, 0.6871165644171778, 0.6875000000000001, 0.738095238095238, 0.7730061349693251]
# 0.7201899451122422
# -0.7201899451122422 -0.731642323920805
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:12:23.884184
# [0.7435897435897435, 0.7044025157232704, 0.7733333333333333, 0.7749999999999999, 0.7672955974842767]
# 0.7527242380261248
# -0.7527242380261248 -0.7527242380261248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:12:31.507995
# [0.6891891891891893, 0.6666666666666667, 0.6666666666666667, 0.7411764705882353, 0.7530864197530863]
# 0.7033570825727689
# -0.7033570825727689 -0.7527242380261248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:12:40.500441
# [0.697986577181208, 0.6666666666666667, 0.6794871794871794, 0.738095238095238, 0.7560975609756099]
# 0.7076666444811804
# -0.7076666444811804 -0.7527242380261248
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:12:48.831768
# [0.7515923566878981, 0.7, 0.7843137254901961, 0.7875, 0.7594936708860761]
# 0.756579950612834
# -0.756579950612834 -0.756579950612834
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:12:55.694813
# [0.735483870967742, 0.7051282051282051, 0.7712418300653595, 0.7951807228915663, 0.7755102040816327]
# 0.7565089666269011
# -0.7565089666269011 -0.756579950612834
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5af1d85c0>}
# 0.7860696517412936
# outer fold
# 2019-08-23 16:13:03.218087
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:13:03.527698
# [0.75, 0.7425149700598802, 0.7132867132867133, 0.7924528301886792, 0.7337278106508877]
# 0.7463964648372321
# -0.7463964648372321 -0.7463964648372321
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:13:11.292942
# [0.75, 0.7425149700598802, 0.704225352112676, 0.7950310559006211, 0.7613636363636362]
# 0.7506270028873627
# -0.7506270028873627 -0.7506270028873627
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:13:19.755022
# [0.757396449704142, 0.7228915662650603, 0.6901408450704226, 0.782608695652174, 0.7796610169491525]
# 0.7465397147281901
# -0.7465397147281901 -0.7506270028873627
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:13:28.252068
# [0.7283236994219653, 0.6993865030674846, 0.7123287671232877, 0.7654320987654321, 0.7570621468926554]
# 0.732506643054165
# -0.732506643054165 -0.7506270028873627
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:13:36.399634
# [0.7558139534883721, 0.7228915662650603, 0.6901408450704226, 0.773006134969325, 0.768361581920904]
# 0.7420428163428168
# -0.7420428163428168 -0.7506270028873627
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:13:45.943723
# [0.761904761904762, 0.7349397590361447, 0.7310344827586207, 0.8292682926829269, 0.7361963190184049]
# 0.7586687230801719
# -0.7586687230801719 -0.7586687230801719
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:13:52.614739
# [0.7209302325581395, 0.6993865030674846, 0.7123287671232877, 0.7607361963190185, 0.7570621468926554]
# 0.7300887691921172
# -0.7300887691921172 -0.7586687230801719
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:14:01.567101
# [0.7471264367816093, 0.7228915662650603, 0.6993006993006994, 0.7654320987654321, 0.7570621468926554]
# 0.7383625896010912
# -0.7383625896010912 -0.7586687230801719
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:14:10.621583
# [0.7564102564102564, 0.7407407407407407, 0.7571428571428572, 0.8407643312101911, 0.7261904761904762]
# 0.7642497323389044
# -0.7642497323389044 -0.7642497323389044
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:14:16.952656
# [0.7421383647798742, 0.782608695652174, 0.7142857142857142, 0.8624999999999999, 0.7195121951219512]
# 0.7642089939679426
# -0.7642089939679426 -0.7642497323389044
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5aea59f98>}
# 0.7830188679245282
# outer fold
# 2019-08-23 16:14:24.845265
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:14:25.071104
# [0.7294117647058823, 0.7417218543046357, 0.7692307692307692, 0.7455621301775148, 0.7402597402597403]
# 0.7452372517357084
# -0.7452372517357084 -0.7452372517357084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:14:33.284327
# [0.7294117647058823, 0.7368421052631579, 0.7450980392156864, 0.738095238095238, 0.7402597402597403]
# 0.737941377507941
# -0.737941377507941 -0.7452372517357084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:14:41.004303
# [0.7176470588235295, 0.7368421052631579, 0.7532467532467533, 0.7305389221556886, 0.758169934640523]
# 0.7392889548259305
# -0.7392889548259305 -0.7452372517357084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:14:50.522349
# [0.6823529411764707, 0.7402597402597403, 0.7096774193548386, 0.7261904761904762, 0.7402597402597403]
# 0.7197480634482532
# -0.7197480634482532 -0.7452372517357084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:14:57.423005
# [0.710059171597633, 0.7368421052631579, 0.7368421052631579, 0.7228915662650603, 0.7631578947368421]
# 0.7339585686251702
# -0.7339585686251702 -0.7452372517357084
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:15:07.001708
# [0.757396449704142, 0.7417218543046357, 0.7549668874172185, 0.7636363636363638, 0.7435897435897435]
# 0.7522622597304207
# -0.7522622597304207 -0.7522622597304207
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:15:14.302297
# [0.6823529411764707, 0.7402597402597403, 0.717948717948718, 0.7261904761904762, 0.7368421052631579]
# 0.7207187961677126
# -0.7207187961677126 -0.7522622597304207
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:15:22.946656
# [0.7017543859649122, 0.7450980392156864, 0.7272727272727273, 0.7065868263473054, 0.7333333333333334]
# 0.7228090624267929
# -0.7228090624267929 -0.7522622597304207
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:15:32.012690
# [0.7425149700598802, 0.7612903225806451, 0.7733333333333333, 0.7710843373493975, 0.7483870967741936]
# 0.75932201201949
# -0.75932201201949 -0.75932201201949
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:15:37.721635
# [0.7421383647798742, 0.7692307692307692, 0.75177304964539, 0.7549668874172185, 0.7248322147651006]
# 0.7485882571676704
# -0.7485882571676704 -0.75932201201949
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7fa5af1eba20>}
# 0.8040201005025126
# outer fold
# 2019-08-23 16:15:44.950325
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:15:45.448394
# [0.7763157894736843, 0.7435897435897435, 0.7453416149068324, 0.7236842105263157, 0.8023255813953489]
# 0.7582513879783849
# -0.7582513879783849 -0.7582513879783849
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:15:53.772149
# [0.7631578947368421, 0.7388535031847134, 0.7250000000000001, 0.7236842105263157, 0.7906976744186047]
# 0.7482786565732952
# -0.7482786565732952 -0.7582513879783849
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:16:01.821659
# [0.7792207792207793, 0.7329192546583853, 0.7204968944099378, 0.7236842105263157, 0.7816091954022988]
# 0.7475860668435433
# -0.7475860668435433 -0.7582513879783849
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:16:10.858891
# [0.7848101265822786, 0.7195121951219512, 0.7195121951219512, 0.6973684210526315, 0.7586206896551724]
# 0.7359647255067969
# -0.7359647255067969 -0.7582513879783849
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:16:17.881133
# [0.782051282051282, 0.7283950617283951, 0.7361963190184049, 0.7152317880794701, 0.7745664739884394]
# 0.7472881849731983
# -0.7472881849731983 -0.7582513879783849
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:16:27.391566
# [0.7712418300653595, 0.7421383647798742, 0.75, 0.7402597402597403, 0.7976190476190476]
# 0.7602517965448043
# -0.7602517965448043 -0.7602517965448043
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:16:34.875227
# [0.7848101265822786, 0.7239263803680983, 0.7305389221556886, 0.6973684210526315, 0.7701149425287357]
# 0.7413517585374866
# -0.7413517585374866 -0.7602517965448043
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:16:42.250320
# [0.782051282051282, 0.7195121951219512, 0.7228915662650603, 0.7019867549668874, 0.7745664739884394]
# 0.7402016544787241
# -0.7402016544787241 -0.7602517965448043
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:16:52.021441
# [0.7643312101910827, 0.7577639751552795, 0.7530864197530863, 0.7450980392156864, 0.8117647058823529]
# 0.7664088700394975
# -0.7664088700394975 -0.7664088700394975
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:16:58.876372
# [0.773006134969325, 0.7643312101910827, 0.7875, 0.7516778523489933, 0.8383233532934131]
# 0.7829677101605629
# -0.7829677101605629 -0.7829677101605629
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7fa5aea5da90>}
# 0.7897435897435897
# outer fold
# 2019-08-23 16:17:06.503472
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-23 16:17:06.881035
# [0.75, 0.7607361963190185, 0.7317073170731708, 0.7484662576687118, 0.7894736842105262]
# 0.7560766910542854
# -0.7560766910542854 -0.7560766910542854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-23 16:17:14.528195
# [0.7590361445783134, 0.7560975609756098, 0.7393939393939394, 0.7484662576687118, 0.7733333333333333]
# 0.7552654471899816
# -0.7552654471899816 -0.7560766910542854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-23 16:17:21.894524
# [0.7544910179640719, 0.7515151515151515, 0.7393939393939394, 0.7317073170731708, 0.7973856209150327]
# 0.7548986093722732
# -0.7548986093722732 -0.7560766910542854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-23 16:17:30.561195
# [0.7544910179640719, 0.7469879518072289, 0.738095238095238, 0.7329192546583853, 0.7785234899328859]
# 0.750203390491562
# -0.750203390491562 -0.7560766910542854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-23 16:17:40.231672
# [0.7544910179640719, 0.7607361963190185, 0.7469879518072289, 0.7329192546583853, 0.7733333333333333]
# 0.7536935508164075
# -0.7536935508164075 -0.7560766910542854
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-23 16:17:49.920310
# [0.773006134969325, 0.773006134969325, 0.75, 0.7577639751552795, 0.7741935483870969]
# 0.7655939586962053
# -0.7655939586962053 -0.7655939586962053
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-23 16:17:58.288456
# [0.7469879518072289, 0.7515151515151515, 0.738095238095238, 0.7329192546583853, 0.7702702702702703]
# 0.7479575732692548
# -0.7479575732692548 -0.7655939586962053
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-23 16:18:05.771071
# [0.7544910179640719, 0.7654320987654321, 0.75, 0.7407407407407407, 0.7702702702702703]
# 0.7561868255481029
# -0.7561868255481029 -0.7655939586962053
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-23 16:18:14.271506
# [0.7710843373493975, 0.7831325301204819, 0.7374999999999999, 0.7701863354037267, 0.7922077922077922]
# 0.7708221990162796
# -0.7708221990162796 -0.7708221990162796
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-23 16:18:20.512017
# [0.7810650887573963, 0.7857142857142857, 0.7516778523489933, 0.7450980392156864, 0.802547770700637]
# 0.7732206073473998
# -0.7732206073473998 -0.7732206073473998
# {'model1': None, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7fa5af519e80>}
# 0.7853403141361257
# save to ../pickle/2019-08-23 16:18:27.590588.pickle
# save to ../csv/2019-08-23 16:18:27.608560.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.79    0.803          0.779       0.788         0.941    0.949
#
#   train_recall train_accuracy model1  \
# 0  0.933        0.94           None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-23 16:18:27.590588.pickle
# save to ../csv/2019-08-23 16:18:27.648576.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.79    0.803          0.779       0.788         0.941    0.949
#
#   train_recall train_accuracy model1  \
# 0  0.933        0.94           None
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-23 16:18:27.590588.pickle
# time: 6min 59s

# %% [markdown]
# ### LGBM

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lgbm
    
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT', add_skip_thoughts='../data/X_skipthoughts_25k.pickle')
knowns = corp0.knowns
state = 2022
model1 = None
for method in [['skip','scale']]:
    corp = copy.deepcopy(corp0)
    results = []
    model2, fold_count = '', 0
    print('state', state)
    ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
    for train_index, test_index in ss.split(corp.ls, corp.y):
        print('outer fold')
        print_time()
        '''
        1. model selection
        ::: model1 is for feature engineering
            e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
            e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
        ::: model2 is a classifier
            e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
        '''
        model2 = inner_CV(corp.replace(train_index), model1, method)
        '''
        2. build X
        '''
        data = inputs_generater(corp.replace(train_index), model1, method)
        '''
        3. run and find the best prob threshold
        '''
        threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
        '''
        4. run again and evaluate on the real test set
        ''' 
        data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
        result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
        result.update({'model1': model1,'tag': corp.tag, 'method':method})
        results.append(result)
        print(result['test_f1'])

    pickle_path = auto_save_pickle(results)
    df = pickle2df(results, pickle_path)
    dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-23 16:20:21.896676
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 16:20:22.228319
# [0.7515923566878981, 0.75, 0.7785234899328859, 0.8313253012048193, 0.7894736842105262]
# 0.780182966407226
# -0.780182966407226 -0.780182966407226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 16:32:04.146564
# [0.7560975609756098, 0.717948717948718, 0.7712418300653595, 0.8, 0.7922077922077922]
# 0.7674991802394958
# -0.7674991802394958 -0.780182966407226
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 16:42:49.994157
# [0.7692307692307692, 0.735483870967742, 0.7702702702702703, 0.8165680473372782, 0.8211920529801324]
# 0.7825490021572385
# -0.7825490021572385 -0.7825490021572385
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 16:59:34.102133
# [0.7770700636942676, 0.7547169811320754, 0.8129032258064517, 0.8117647058823529, 0.8079470198675496]
# 0.7928803992765395
# -0.7928803992765395 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 17:15:44.938099
# [0.7402597402597403, 0.7682926829268293, 0.7662337662337663, 0.8117647058823529, 0.7972972972972973]
# 0.7767696385199973
# -0.7767696385199973 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 17:38:27.436883
# [0.7692307692307692, 0.7515923566878981, 0.7843137254901961, 0.8284023668639053, 0.8053691275167786]
# 0.7877816691579095
# -0.7877816691579095 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 17:59:19.464098
# [0.7435897435897435, 0.7701863354037267, 0.7651006711409395, 0.8117647058823529, 0.7973856209150326]
# 0.7776054153863591
# -0.7776054153863591 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 18:16:18.990923
# [0.7741935483870969, 0.7577639751552795, 0.7973856209150327, 0.8187134502923977, 0.8157894736842106]
# 0.7927692136868035
# -0.7927692136868035 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-23 18:32:42.872033
# [0.7468354430379747, 0.7453416149068324, 0.7922077922077922, 0.7861271676300579, 0.8108108108108107]
# 0.7762645657186935
# -0.7762645657186935 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 18:43:24.768022
# [0.7532467532467533, 0.7515923566878981, 0.7866666666666667, 0.8235294117647058, 0.7973856209150326]
# 0.7824841618562113
# -0.7824841618562113 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 18:57:35.800054
# [0.75, 0.7530864197530863, 0.782051282051282, 0.8284023668639053, 0.8157894736842106]
# 0.7858659084704968
# -0.7858659084704968 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 19:07:22.671538
# [0.7577639751552795, 0.7875, 0.7567567567567567, 0.813953488372093, 0.7837837837837837]
# 0.7799516008135826
# -0.7799516008135826 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 19:19:47.287446
# [0.7435897435897435, 0.7654320987654321, 0.794701986754967, 0.813953488372093, 0.8289473684210527]
# 0.7893249371806577
# -0.7893249371806577 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 19:34:25.903296
# [0.7484662576687118, 0.7577639751552795, 0.7770700636942676, 0.7906976744186047, 0.8129032258064516]
# 0.777380239348663
# -0.777380239348663 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-23 19:45:06.946814
# [0.7483870967741936, 0.7577639751552795, 0.7682119205298013, 0.8117647058823529, 0.8076923076923076]
# 0.778764001206787
# -0.778764001206787 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 19:56:06.422135
# [0.7532467532467533, 0.7169811320754716, 0.7973856209150327, 0.8284023668639053, 0.818181818181818]
# 0.782839538256596
# -0.782839538256596 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 20:09:13.579493
# [0.7662337662337663, 0.735483870967742, 0.7651006711409395, 0.8383233532934131, 0.8053691275167786]
# 0.7821021578305279
# -0.7821021578305279 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-23 20:24:37.484695
# [0.7483870967741936, 0.782608695652174, 0.7631578947368421, 0.7906976744186047, 0.794701986754967]
# 0.7759106696673562
# -0.7759106696673562 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 20:32:15.672516
# [0.7532467532467533, 0.7749999999999999, 0.7870967741935484, 0.8235294117647058, 0.8053691275167786]
# 0.7888484133443572
# -0.7888484133443572 -0.7928803992765395
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 20:42:29.105537
# [0.7468354430379747, 0.7421383647798742, 0.7450980392156864, 0.7951807228915663, 0.8129032258064516]
# 0.7684311591463107
# -0.7684311591463107 -0.7928803992765395
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7fa5aea5d2e8>}
# 0.7960199004975124
# outer fold
# 2019-08-23 20:52:19.309541
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 20:52:19.972094
# [0.7770700636942676, 0.8227848101265822, 0.7643312101910827, 0.8433734939759034, 0.7530864197530863]
# 0.7921291995481845
# -0.7921291995481845 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 21:03:02.246866
# [0.7798742138364779, 0.782051282051282, 0.7450980392156864, 0.8502994011976048, 0.7468354430379747]
# 0.7808316758678052
# -0.7808316758678052 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 21:13:27.468083
# [0.7798742138364779, 0.7974683544303799, 0.7532467532467533, 0.8395061728395061, 0.7515923566878981]
# 0.7843375702082032
# -0.7843375702082032 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 21:28:25.528043
# [0.7612903225806451, 0.782051282051282, 0.7450980392156864, 0.8363636363636364, 0.7515923566878981]
# 0.7752791273798296
# -0.7752791273798296 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 21:39:24.124297
# [0.7770700636942676, 0.7875, 0.7532467532467533, 0.8284023668639053, 0.7388535031847134]
# 0.7770145373979279
# -0.7770145373979279 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 21:51:55.431200
# [0.7770700636942676, 0.7950310559006211, 0.7672955974842767, 0.8313253012048193, 0.7549668874172185]
# 0.7851377811402406
# -0.7851377811402406 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 22:07:18.342986
# [0.7612903225806451, 0.7875, 0.7435897435897435, 0.8313253012048193, 0.7421383647798742]
# 0.7731687464310164
# -0.7731687464310164 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 22:20:17.125102
# [0.7749999999999999, 0.7901234567901234, 0.7483870967741936, 0.8402366863905325, 0.7547169811320754]
# 0.7816928442173849
# -0.7816928442173849 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-23 22:35:06.331884
# [0.7547169811320754, 0.8, 0.7402597402597403, 0.8484848484848484, 0.7564102564102564]
# 0.7799743652573842
# -0.7799743652573842 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 22:45:15.786295
# [0.7515923566878981, 0.782608695652174, 0.735483870967742, 0.8343558282208587, 0.7515923566878981]
# 0.7711266216433141
# -0.7711266216433141 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 22:57:27.215197
# [0.7898089171974522, 0.7757575757575756, 0.7417218543046357, 0.8622754491017963, 0.7530864197530863]
# 0.7845300432229092
# -0.7845300432229092 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 23:06:23.441311
# [0.7594936708860759, 0.8050314465408805, 0.7843137254901961, 0.8143712574850299, 0.7484662576687118]
# 0.7823352716141787
# -0.7823352716141787 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 23:18:14.707962
# [0.7898089171974522, 0.782608695652174, 0.7320261437908497, 0.8414634146341464, 0.7643312101910827]
# 0.782047676293141
# -0.782047676293141 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 23:30:18.492180
# [0.7643312101910827, 0.8, 0.7564102564102564, 0.8433734939759034, 0.7341772151898733]
# 0.7796584351534233
# -0.7796584351534233 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-23 23:38:50.893254
# [0.782051282051282, 0.7901234567901234, 0.7417218543046357, 0.8292682926829269, 0.7564102564102564]
# 0.7799150284478449
# -0.7799150284478449 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 23:47:46.415394
# [0.7770700636942676, 0.8024691358024691, 0.7368421052631579, 0.8271604938271605, 0.7631578947368421]
# 0.7813399386647795
# -0.7813399386647795 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 23:58:56.560793
# [0.7612903225806451, 0.7924528301886792, 0.728476821192053, 0.8414634146341464, 0.7564102564102564]
# 0.776018729001156
# -0.776018729001156 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-24 00:12:17.460909
# [0.7421383647798742, 0.7654320987654321, 0.7058823529411765, 0.8292682926829269, 0.7654320987654321]
# 0.7616306415869684
# -0.7616306415869684 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 00:19:59.074663
# [0.7515923566878981, 0.8125000000000001, 0.75, 0.8536585365853657, 0.7374999999999999]
# 0.7810501786546528
# -0.7810501786546528 -0.7921291995481845
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 00:30:10.047134
# [0.7374999999999999, 0.782051282051282, 0.7368421052631579, 0.8433734939759034, 0.7532467532467533]
# 0.7706027269074193
# -0.7706027269074193 -0.7921291995481845
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7fa5af00f0b8>}
# 0.821256038647343
# outer fold
# 2019-08-24 00:40:16.070403
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 00:40:16.489122
# [0.7848101265822786, 0.7466666666666666, 0.8026315789473684, 0.7721518987341771, 0.7792207792207793]
# 0.7770962100302539
# -0.7770962100302539 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 00:50:49.611948
# [0.7484662576687118, 0.728476821192053, 0.7702702702702703, 0.7701863354037267, 0.7594936708860759]
# 0.7553786710841676
# -0.7553786710841676 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 01:00:18.866661
# [0.7643312101910827, 0.7388535031847134, 0.8157894736842104, 0.7625, 0.7948717948717949]
# 0.7752691963863603
# -0.7752691963863603 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 01:14:05.039875
# [0.7594936708860759, 0.75, 0.8079470198675497, 0.782608695652174, 0.7594936708860759]
# 0.7719086114583751
# -0.7719086114583751 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 01:23:48.877866
# [0.7798742138364779, 0.7532467532467533, 0.8076923076923077, 0.7692307692307692, 0.7701863354037267]
# 0.776046075882007
# -0.776046075882007 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 01:35:02.923145
# [0.7564102564102564, 0.7435897435897435, 0.8051948051948052, 0.7770700636942676, 0.8]
# 0.7764529737778145
# -0.7764529737778145 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 01:49:21.326520
# [0.7453416149068324, 0.7712418300653595, 0.7973856209150327, 0.7515923566878981, 0.7870967741935484]
# 0.7705316393537343
# -0.7705316393537343 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 02:01:32.611050
# [0.7721518987341771, 0.7672955974842767, 0.7973856209150327, 0.7654320987654321, 0.7770700636942676]
# 0.7758670559186372
# -0.7758670559186372 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-24 02:14:55.484819
# [0.7682926829268293, 0.7721518987341771, 0.8076923076923077, 0.7577639751552795, 0.7388535031847134]
# 0.7689508735386614
# -0.7689508735386614 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 02:24:15.579256
# [0.7530864197530863, 0.7333333333333334, 0.8, 0.7643312101910827, 0.7560975609756098]
# 0.7613697048506223
# -0.7613697048506223 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 02:35:11.076124
# [0.7721518987341771, 0.7320261437908497, 0.7972972972972973, 0.7904191616766467, 0.7721518987341771]
# 0.7728092800466296
# -0.7728092800466296 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 02:44:06.833694
# [0.7612903225806451, 0.75, 0.7870967741935484, 0.7848101265822786, 0.7612903225806451]
# 0.7688975091874235
# -0.7688975091874235 -0.7770962100302539
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 02:57:28.067154
# [0.7692307692307692, 0.7450980392156864, 0.8026315789473684, 0.7875, 0.782051282051282]
# 0.7773023338890211
# -0.7773023338890211 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 03:11:04.976545
# [0.7662337662337663, 0.7692307692307692, 0.7999999999999999, 0.7654320987654321, 0.782608695652174]
# 0.7767010659764282
# -0.7767010659764282 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-24 03:22:10.029850
# [0.7625, 0.7320261437908497, 0.8053691275167785, 0.7749999999999999, 0.735483870967742]
# 0.762075828455074
# -0.762075828455074 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 03:32:19.027742
# [0.7898089171974522, 0.72, 0.794701986754967, 0.7875, 0.7612903225806451]
# 0.7706602453066129
# -0.7706602453066129 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 03:43:30.867111
# [0.7643312101910827, 0.728476821192053, 0.7682119205298013, 0.7721518987341771, 0.7974683544303799]
# 0.7661280410154988
# -0.7661280410154988 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-24 03:56:37.150261
# [0.7577639751552795, 0.7549668874172185, 0.7919463087248322, 0.782608695652174, 0.7898089171974522]
# 0.7754189568293912
# -0.7754189568293912 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 04:04:06.857741
# [0.7594936708860759, 0.75, 0.8026315789473684, 0.7898089171974522, 0.7631578947368421]
# 0.7730184123535477
# -0.7730184123535477 -0.7773023338890211
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 04:14:15.551154
# [0.7749999999999999, 0.7421383647798742, 0.7894736842105262, 0.7777777777777778, 0.7662337662337663]
# 0.7701247186003888
# -0.7701247186003888 -0.7773023338890211
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7fa5af0fac18>}
# 0.7999999999999999
# outer fold
# 2019-08-24 04:24:21.487883
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 04:24:21.977329
# [0.7950310559006211, 0.782051282051282, 0.7866666666666667, 0.7612903225806451, 0.8284023668639053]
# 0.7906883388126241
# -0.7906883388126241 -0.7906883388126241
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 04:35:11.506565
# [0.7950310559006211, 0.7672955974842767, 0.7837837837837838, 0.7515923566878981, 0.8304093567251462]
# 0.7856224301163451
# -0.7856224301163451 -0.7906883388126241
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 04:44:20.613420
# [0.7924528301886792, 0.7672955974842767, 0.7763157894736843, 0.7402597402597403, 0.8143712574850299]
# 0.7781390429782821
# -0.7781390429782821 -0.7906883388126241
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 04:57:54.577709
# [0.7924528301886792, 0.7898089171974522, 0.7973856209150327, 0.7532467532467533, 0.8502994011976048]
# 0.7966387045491045
# -0.7966387045491045 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 05:07:43.445471
# [0.8050314465408805, 0.773006134969325, 0.8129032258064517, 0.7402597402597403, 0.8333333333333334]
# 0.7929067761819462
# -0.7929067761819462 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 05:18:36.543781
# [0.782051282051282, 0.7643312101910827, 0.7785234899328859, 0.7515923566878981, 0.8165680473372782]
# 0.7786132772400854
# -0.7786132772400854 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 05:32:29.863413
# [0.8074534161490683, 0.7770700636942676, 0.7870967741935484, 0.76, 0.8192771084337349]
# 0.7901794724941238
# -0.7901794724941238 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 05:44:51.467675
# [0.8074534161490683, 0.7672955974842767, 0.794701986754967, 0.7643312101910827, 0.8284023668639053]
# 0.79243691548866
# -0.79243691548866 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-24 05:58:29.647629
# [0.802547770700637, 0.7848101265822786, 0.8258064516129032, 0.7297297297297297, 0.8187134502923977]
# 0.7923215057835893
# -0.7923215057835893 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 06:07:39.516349
# [0.7950310559006211, 0.7654320987654321, 0.794701986754967, 0.7402597402597403, 0.8433734939759034]
# 0.7877596751313327
# -0.7877596751313327 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 06:19:06.207767
# [0.7777777777777778, 0.782608695652174, 0.7866666666666667, 0.75, 0.8284023668639053]
# 0.7850911013921047
# -0.7850911013921047 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 06:27:32.347857
# [0.8074534161490683, 0.7792207792207793, 0.7999999999999999, 0.7320261437908497, 0.8402366863905325]
# 0.7917874051102459
# -0.7917874051102459 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 06:38:25.544002
# [0.782051282051282, 0.7682926829268293, 0.794701986754967, 0.7417218543046357, 0.8117647058823529]
# 0.7797065023840133
# -0.7797065023840133 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 06:51:20.130680
# [0.7924528301886792, 0.7741935483870969, 0.7919463087248322, 0.7450980392156864, 0.8352941176470587]
# 0.7877969688326706
# -0.7877969688326706 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-24 07:01:44.627966
# [0.802547770700637, 0.7798742138364779, 0.7763157894736843, 0.7368421052631579, 0.8214285714285715]
# 0.7834016901405058
# -0.7834016901405058 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 07:12:46.209401
# [0.7948717948717949, 0.7721518987341771, 0.8133333333333332, 0.7402597402597403, 0.8192771084337349]
# 0.787978775126556
# -0.787978775126556 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 07:25:31.221495
# [0.7848101265822786, 0.7749999999999999, 0.8104575163398693, 0.7672955974842767, 0.8117647058823529]
# 0.7898655892577555
# -0.7898655892577555 -0.7966387045491045
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-24 07:39:51.966759
# [0.810126582278481, 0.7924528301886792, 0.7999999999999999, 0.7662337662337663, 0.8383233532934131]
# 0.8014273063988678
# -0.8014273063988678 -0.8014273063988678
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 07:47:08.270524
# [0.7875, 0.7924528301886792, 0.7972972972972973, 0.7417218543046357, 0.8095238095238094]
# 0.7856991582628843
# -0.7856991582628843 -0.8014273063988678
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 07:57:17.806956
# [0.7798742138364779, 0.782608695652174, 0.7866666666666667, 0.7189542483660132, 0.8304093567251462]
# 0.7797026362492956
# -0.7797026362492956 -0.8014273063988678
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7fa5af0fa550>}
# 0.7715736040609136
# outer fold
# 2019-08-24 08:06:04.930307
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 08:06:05.433562
# [0.7784431137724551, 0.7469879518072289, 0.7466666666666666, 0.782051282051282, 0.8104575163398693]
# 0.7729213061275004
# -0.7729213061275004 -0.7729213061275004
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 08:16:45.623411
# [0.787878787878788, 0.7515151515151515, 0.7692307692307692, 0.7792207792207793, 0.7866666666666667]
# 0.7749024309024309
# -0.7749024309024309 -0.7749024309024309
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 08:26:05.869405
# [0.7804878048780488, 0.7484662576687118, 0.758169934640523, 0.8198757763975155, 0.7919463087248322]
# 0.7797892164619262
# -0.7797892164619262 -0.7797892164619262
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 08:39:26.169185
# [0.7439024390243902, 0.7407407407407407, 0.7368421052631579, 0.7792207792207793, 0.8053691275167785]
# 0.7612150383531693
# -0.7612150383531693 -0.7797892164619262
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 08:48:51.655569
# [0.757396449704142, 0.7647058823529411, 0.7368421052631579, 0.8, 0.7973856209150327]
# 0.7712660116470547
# -0.7712660116470547 -0.7797892164619262
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 08:59:34.298937
# [0.7710843373493975, 0.7361963190184049, 0.7435897435897435, 0.7924528301886792, 0.8157894736842104]
# 0.771822540766087
# -0.771822540766087 -0.7797892164619262
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 09:13:19.717852
# [0.7777777777777778, 0.7590361445783134, 0.7450980392156864, 0.7662337662337663, 0.7866666666666667]
# 0.766962478894442
# -0.766962478894442 -0.7797892164619262
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-24 09:24:56.263501
# [0.8121212121212122, 0.7810650887573963, 0.7848101265822786, 0.802547770700637, 0.794701986754967]
# 0.7950492369832982
# -0.7950492369832982 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-24 09:37:33.666702
# [0.75, 0.7590361445783134, 0.7564102564102564, 0.7898089171974522, 0.8266666666666668]
# 0.7763843969705377
# -0.7763843969705377 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 09:46:06.139818
# [0.7515151515151515, 0.7590361445783134, 0.7549668874172185, 0.8076923076923077, 0.7999999999999999]
# 0.7746420982405982
# -0.7746420982405982 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 09:56:24.040788
# [0.7453416149068324, 0.787878787878788, 0.7532467532467533, 0.7792207792207793, 0.8205128205128205]
# 0.7772401511531946
# -0.7772401511531946 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 10:04:40.711699
# [0.7674418604651162, 0.7636363636363638, 0.75, 0.8050314465408805, 0.8157894736842104]
# 0.7803798288653143
# -0.7803798288653143 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 10:14:39.609464
# [0.7607361963190185, 0.7530864197530863, 0.7549668874172185, 0.7922077922077922, 0.7999999999999999]
# 0.772199459139423
# -0.772199459139423 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-24 10:26:38.099266
# [0.7710843373493975, 0.7560975609756098, 0.7594936708860759, 0.8050314465408805, 0.8129032258064517]
# 0.7809220483116831
# -0.7809220483116831 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-24 10:35:13.624065
# [0.7664670658682634, 0.7664670658682634, 0.7466666666666666, 0.8076923076923077, 0.8133333333333332]
# 0.780125287885767
# -0.780125287885767 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 10:43:06.662700
# [0.7560975609756098, 0.7636363636363638, 0.758169934640523, 0.8280254777070064, 0.7999999999999999]
# 0.7811858673919005
# -0.7811858673919005 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-24 10:51:50.004203
# [0.7852760736196319, 0.7757575757575756, 0.7692307692307692, 0.7922077922077922, 0.7866666666666667]
# 0.7818277754964871
# -0.7818277754964871 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-24 11:02:05.668358
# [0.7594936708860759, 0.7530864197530863, 0.7341772151898733, 0.7612903225806451, 0.7999999999999999]
# 0.7616095256819361
# -0.7616095256819361 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-24 11:08:05.518129
# [0.7469879518072289, 0.7544910179640719, 0.7594936708860759, 0.8051948051948052, 0.823529411764706]
# 0.7779393715233776
# -0.7779393715233776 -0.7950492369832982
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-24 11:16:11.975716
# [0.7692307692307692, 0.761904761904762, 0.7612903225806451, 0.7612903225806451, 0.8129032258064517]
# 0.7733238804206546
# -0.7733238804206546 -0.7950492369832982
# {'model1': None, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['skip', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7fa5aee3b358>}
# 0.7634408602150539
# save to ../pickle/2019-08-24 11:24:27.687884.pickle
# save to ../csv/2019-08-24 11:24:28.114687.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.79    0.818          0.767       0.793         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-24 11:24:27.687884.pickle
# save to ../csv/2019-08-24 11:24:28.152424.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.79    0.818          0.767       0.793         1        1
#
#   train_recall train_accuracy model1  \
# 0  1            1              None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.15,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#           method  tag                                  pickle_path
# 0  [skip, scale]  AMT  ../pickle/2019-08-24 11:24:27.687884.pickle
# time: 19h 4min 18s

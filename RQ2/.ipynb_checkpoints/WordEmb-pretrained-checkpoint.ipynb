# %%
# %time
# %load_ext autotime
# %load_ext autoreload
# %autoreload 2

import os
import sys
parent_dir = os.path.abspath(os.getcwd()+'/..')+'/' 
sys.path.append(parent_dir) 

import pandas as pd
import numpy as np
from copy import deepcopy

from utils.path import dir_HugeFiles
from utils.preprocessing import load
from utils.save import make_dir, save_pickle, load_pickle, auto_save_csv, print_time, auto_save_pickle

from models.fmin2 import fmin2, fmin2_model1
from models.nested_validation import *
from models.features import fixed_makedata, salvador_wrap, pretrained_wrap
from models.display import pickle2df

# models
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings("ignore")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.87 µs

# %%
dir_save = os.path.normpath('../data/dic_20190819.pickle')
dic = load(dir_save)

amt_GI = load_pickle('../data/amt_hGI_pos.pickle')
for i, v in dic.items():
    if i in amt_GI.keys():
        v['AMT'] = amt_GI[i]
amt_ls = list(amt_GI.keys())
ls = amt_ls
# Out:
# exist
# time: 15.9 s

# %% [markdown]
# ### 1. word2vec and LR

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lr
    
    spaces = {'model1': model1, 'model2': LogisticRegression,'method': method,
              'p2': p2_lr, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 10)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
for model1 in [salvador_wrap(), 
               pretrained_wrap(knowns, 'word2vec-google-news-300'),
               pretrained_wrap(knowns, 'glove-wiki-gigaword-300'),
               pretrained_wrap(knowns, 'fasttext-wiki-news-subwords-300')]:
    for method in [['wv','scale']]:
        corp = copy.deepcopy(corp0)
        results = []
        model2, fold_count = '', 0
        print('state', state)
        ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
        for train_index, test_index in ss.split(corp.ls, corp.y):
            print('outer fold')
            print_time()
            '''
            1. model selection
            ::: model1 is for feature engineering
                e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
                e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
            ::: model2 is a classifier
                e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
            '''
            model2 = inner_CV(corp.replace(train_index), model1, method)
            '''
            2. build X
            '''
            data = inputs_generater(corp.replace(train_index), model1, method)
            '''
            3. run and find the best prob threshold
            '''
            threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
            '''
            4. run again and evaluate on the real test set
            ''' 
            data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
            result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
            result.update({'model1': model1,'tag': corp.tag, 'method':method})
            results.append(result)
            print(result['test_f1'])

        pickle_path = auto_save_pickle(results)
        df = pickle2df(results, pickle_path)
        dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 04:49:23.349586
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 04:49:23.799693
# [0.7662337662337663, 0.7625, 0.7764705882352941, 0.7904191616766467, 0.7612903225806452]
# 0.7713827677452704
# -0.7713827677452704 -0.7713827677452704
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 04:50:03.590824
# [0.7515923566878981, 0.7453416149068324, 0.7764705882352941, 0.7951807228915663, 0.7468354430379747]
# 0.7630841451519131
# -0.7630841451519131 -0.7713827677452704
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 04:50:42.319113
# [0.7236842105263157, 0.7283950617283951, 0.7745664739884394, 0.7738095238095237, 0.7236842105263157]
# 0.7448278961157978
# -0.7448278961157978 -0.7713827677452704
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 04:51:20.746447
# [0.717948717948718, 0.6832298136645963, 0.7457627118644067, 0.7469879518072289, 0.7261146496815287]
# 0.7240087689932958
# -0.7240087689932958 -0.7713827677452704
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 04:51:59.429938
# [0.6973684210526315, 0.6832298136645963, 0.7657142857142857, 0.7784431137724551, 0.7341772151898733]
# 0.7317865698787684
# -0.7317865698787684 -0.7713827677452704
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 04:52:38.491718
# [0.7721518987341771, 0.7852760736196319, 0.7975460122699387, 0.7784431137724551, 0.7837837837837837]
# 0.7834401764359974
# -0.7834401764359974 -0.7834401764359974
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 04:53:18.559912
# [0.717948717948718, 0.6832298136645963, 0.7500000000000001, 0.7469879518072289, 0.7261146496815287]
# 0.7248562266204145
# -0.7248562266204145 -0.7834401764359974
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 04:53:54.818729
# [0.7133757961783439, 0.6875000000000001, 0.759776536312849, 0.7393939393939394, 0.7388535031847133]
# 0.7277799550139691
# -0.7277799550139691 -0.7834401764359974
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 04:54:31.488427
# [0.7547169811320754, 0.7701863354037267, 0.7950310559006211, 0.7904191616766467, 0.7999999999999999]
# 0.7820707068226139
# -0.7820707068226139 -0.7834401764359974
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 04:55:06.701027
# [0.7672955974842767, 0.7607361963190185, 0.7770700636942676, 0.7848101265822786, 0.8]
# 0.7779823968159683
# -0.7779823968159683 -0.7834401764359974
# {'model1': <models.features.salvador_wrap object at 0x7f6c185a2eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6c198785f8>}
# 0.8396226415094339
# outer fold
# 2019-08-21 04:55:52.693971
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 04:55:53.087551
# [0.8076923076923077, 0.7749999999999999, 0.7421383647798742, 0.8292682926829269, 0.761904761904762]
# 0.7832007454119742
# -0.7832007454119742 -0.7832007454119742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 04:56:31.677631
# [0.7898089171974522, 0.7901234567901234, 0.7283950617283951, 0.8363636363636364, 0.7544910179640719]
# 0.7798364180087358
# -0.7798364180087358 -0.7832007454119742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 04:57:08.909648
# [0.7924528301886792, 0.7926829268292682, 0.7160493827160493, 0.8192771084337349, 0.7368421052631577]
# 0.7714608706861779
# -0.7714608706861779 -0.7832007454119742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 04:57:45.860236
# [0.7749999999999999, 0.7857142857142857, 0.7133757961783439, 0.8170731707317075, 0.7142857142857143]
# 0.7610897933820102
# -0.7610897933820102 -0.7832007454119742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 04:58:23.200008
# [0.7875, 0.7926829268292682, 0.7204968944099378, 0.8263473053892216, 0.738095238095238]
# 0.7730244729447332
# -0.7730244729447332 -0.7832007454119742
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 04:59:00.175920
# [0.8535031847133758, 0.7672955974842767, 0.7692307692307692, 0.8374999999999999, 0.7590361445783134]
# 0.797313139201347
# -0.797313139201347 -0.797313139201347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 04:59:37.733727
# [0.7749999999999999, 0.7857142857142857, 0.7088607594936708, 0.8170731707317075, 0.7142857142857143]
# 0.7601867860450756
# -0.7601867860450756 -0.797313139201347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:00:15.794330
# [0.7749999999999999, 0.7857142857142857, 0.7250000000000001, 0.8170731707317075, 0.7305389221556886]
# 0.7666652757203364
# -0.7666652757203364 -0.797313139201347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:00:53.611482
# [0.8211920529801325, 0.7777777777777778, 0.7662337662337663, 0.8500000000000001, 0.7664670658682634]
# 0.796334132571988
# -0.796334132571988 -0.797313139201347
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:01:29.808875
# [0.823529411764706, 0.7924528301886792, 0.75, 0.8466257668711655, 0.7530864197530863]
# 0.7931388857155274
# -0.7931388857155274 -0.797313139201347
# {'model1': <models.features.salvador_wrap object at 0x7f6c185d8e10>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6c1aa17dd8>}
# 0.7941176470588236
# outer fold
# 2019-08-21 05:02:16.197624
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:02:16.553393
# [0.7317073170731708, 0.7804878048780488, 0.7484662576687118, 0.7784431137724551, 0.7421383647798742]
# 0.7562485716344521
# -0.7562485716344521 -0.7562485716344521
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:02:55.595300
# [0.7204968944099378, 0.7710843373493975, 0.7250000000000001, 0.7810650887573963, 0.7341772151898733]
# 0.7463647071413211
# -0.7463647071413211 -0.7562485716344521
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:03:33.527690
# [0.7080745341614907, 0.7485380116959064, 0.7073170731707318, 0.7664670658682634, 0.7051282051282051]
# 0.7271049780049195
# -0.7271049780049195 -0.7562485716344521
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:04:12.902808
# [0.6909090909090909, 0.7126436781609194, 0.6993865030674846, 0.7485380116959064, 0.6878980891719745]
# 0.7078750746010751
# -0.7078750746010751 -0.7562485716344521
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:04:50.637447
# [0.7, 0.7398843930635839, 0.7151515151515152, 0.7455621301775148, 0.6878980891719745]
# 0.7176992255129176
# -0.7176992255129176 -0.7562485716344521
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:05:27.992873
# [0.7307692307692308, 0.8198757763975155, 0.7798742138364779, 0.8023952095808382, 0.7450980392156864]
# 0.7756024939599497
# -0.7756024939599497 -0.7756024939599497
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:06:06.183805
# [0.6909090909090909, 0.7126436781609194, 0.6956521739130435, 0.7485380116959064, 0.6878980891719745]
# 0.7071282087701869
# -0.7071282087701869 -0.7756024939599497
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:06:46.362797
# [0.6871165644171778, 0.7052023121387283, 0.7037037037037037, 0.7411764705882353, 0.6794871794871794]
# 0.7033372460670049
# -0.7033372460670049 -0.7756024939599497
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:07:23.793066
# [0.735483870967742, 0.8176100628930817, 0.810126582278481, 0.8143712574850299, 0.7770700636942676]
# 0.7909323674637205
# -0.7909323674637205 -0.7909323674637205
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:08:02.520053
# [0.7549668874172185, 0.802547770700637, 0.7843137254901961, 0.8, 0.7870967741935484]
# 0.78578503156032
# -0.78578503156032 -0.7909323674637205
# {'model1': <models.features.salvador_wrap object at 0x7f6b1d94c668>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c185c3668>}
# 0.839378238341969
# outer fold
# 2019-08-21 05:08:49.785896
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:08:50.152383
# [0.830188679245283, 0.7999999999999999, 0.7926829268292682, 0.7421383647798742, 0.8023952095808382]
# 0.7934810360870527
# -0.7934810360870527 -0.7934810360870527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:09:29.527693
# [0.7924528301886792, 0.8072289156626505, 0.787878787878788, 0.7453416149068324, 0.7999999999999999]
# 0.78658042972739
# -0.78658042972739 -0.7934810360870527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:10:07.380809
# [0.7549668874172185, 0.7831325301204819, 0.7664670658682634, 0.7305389221556886, 0.7926829268292682]
# 0.7655576664781841
# -0.7655576664781841 -0.7934810360870527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:10:46.427124
# [0.7417218543046357, 0.7439024390243902, 0.7738095238095237, 0.7349397590361447, 0.7999999999999999]
# 0.7588747152349389
# -0.7588747152349389 -0.7934810360870527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:11:23.814293
# [0.75, 0.7857142857142857, 0.761904761904762, 0.738095238095238, 0.7926829268292682]
# 0.7656794425087108
# -0.7656794425087108 -0.7934810360870527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:12:01.184941
# [0.8535031847133758, 0.7999999999999999, 0.7898089171974522, 0.7950310559006211, 0.8148148148148148]
# 0.8106315945252527
# -0.8106315945252527 -0.8106315945252527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:12:40.227422
# [0.7417218543046357, 0.7439024390243902, 0.7664670658682634, 0.7425149700598802, 0.7926829268292682]
# 0.7574578512172876
# -0.7574578512172876 -0.8106315945252527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:13:18.609745
# [0.7417218543046357, 0.7484662576687118, 0.7636363636363638, 0.75, 0.7926829268292682]
# 0.7593014804877958
# -0.7593014804877958 -0.8106315945252527
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:13:58.211686
# [0.8481012658227849, 0.8170731707317075, 0.794701986754967, 0.7749999999999999, 0.825]
# 0.811975284661892
# -0.811975284661892 -0.811975284661892
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:14:36.956645
# [0.8076923076923077, 0.8170731707317075, 0.7948717948717949, 0.7515923566878981, 0.8227848101265822]
# 0.7988028880220581
# -0.7988028880220581 -0.811975284661892
# {'model1': <models.features.salvador_wrap object at 0x7f6c1a9dc518>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c185d0710>}
# 0.8056872037914691
# outer fold
# 2019-08-21 05:15:22.610454
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:15:22.965497
# [0.7577639751552795, 0.7664670658682634, 0.7564102564102564, 0.8024691358024691, 0.84472049689441]
# 0.7855661860261357
# -0.7855661860261357 -0.7855661860261357
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:16:02.298043
# [0.7530864197530863, 0.7469879518072289, 0.7483870967741936, 0.8292682926829269, 0.8374999999999999]
# 0.783045952203487
# -0.783045952203487 -0.7855661860261357
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:16:39.998021
# [0.7421383647798742, 0.7439024390243902, 0.7612903225806451, 0.8313253012048193, 0.7975460122699387]
# 0.7752404879719336
# -0.7752404879719336 -0.7855661860261357
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:17:18.505753
# [0.7484662576687118, 0.7283950617283951, 0.75, 0.773006134969325, 0.7875]
# 0.7574734908732864
# -0.7574734908732864 -0.7855661860261357
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:17:55.855609
# [0.7283950617283951, 0.7272727272727273, 0.75, 0.8048780487804877, 0.7901234567901234]
# 0.7601338589143467
# -0.7601338589143467 -0.7855661860261357
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:18:33.508510
# [0.782608695652174, 0.8047337278106509, 0.7974683544303799, 0.8050314465408805, 0.864516129032258]
# 0.8108716706932686
# -0.8108716706932686 -0.8108716706932686
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:19:12.175761
# [0.7169811320754716, 0.7204968944099378, 0.75, 0.7777777777777778, 0.782608695652174]
# 0.7495728999830722
# -0.7495728999830722 -0.8108716706932686
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:19:49.700951
# [0.7329192546583853, 0.7204968944099378, 0.75, 0.7852760736196319, 0.7875]
# 0.7552384445375909
# -0.7552384445375909 -0.8108716706932686
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:20:27.300611
# [0.7901234567901234, 0.8070175438596491, 0.7763157894736843, 0.8313253012048193, 0.8875]
# 0.8184564182656551
# -0.8184564182656551 -0.8184564182656551
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:21:06.679922
# [0.7852760736196319, 0.8176100628930817, 0.7870967741935484, 0.8148148148148148, 0.8481012658227849]
# 0.8105797982687724
# -0.8105797982687724 -0.8184564182656551
# {'model1': <models.features.salvador_wrap object at 0x7f6b1d93b668>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c1be8d7b8>}
# 0.7938144329896908
# save to ../pickle/2019-08-21 05:21:53.462225.pickle
# save to ../csv/2019-08-21 05:21:54.603578.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.815   0.815          0.816       0.81          0.905    0.918
#
#   train_recall train_accuracy  \
# 0  0.893        0.904
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7f6c0a593fd0>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 05:21:53.462225.pickle
# state 2022
# outer fold
# 2019-08-21 05:21:54.843589
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:21:55.209848
# [0.7450980392156864, 0.7272727272727273, 0.7692307692307692, 0.7411764705882353, 0.7973856209150326]
# 0.7560327254444902
# -0.7560327254444902 -0.7560327254444902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:23:07.592795
# [0.7468354430379747, 0.7261904761904762, 0.757396449704142, 0.7272727272727273, 0.7870967741935484]
# 0.7489583740797737
# -0.7489583740797737 -0.7560327254444902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:24:17.076413
# [0.7692307692307692, 0.7294117647058823, 0.7251461988304092, 0.7185628742514969, 0.7612903225806452]
# 0.7407283859198406
# -0.7407283859198406 -0.7560327254444902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:25:26.895963
# [0.7792207792207793, 0.7251461988304092, 0.6706586826347306, 0.7058823529411764, 0.7105263157894738]
# 0.7182868658833139
# -0.7182868658833139 -0.7560327254444902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:26:39.612063
# [0.7692307692307692, 0.7218934911242604, 0.6976744186046511, 0.7228915662650603, 0.7435897435897436]
# 0.731055997762897
# -0.731055997762897 -0.7560327254444902
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:27:49.027336
# [0.7924528301886792, 0.7590361445783134, 0.7831325301204819, 0.7857142857142857, 0.8266666666666667]
# 0.7894004914536853
# -0.7894004914536853 -0.7894004914536853
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:28:59.365060
# [0.782051282051282, 0.7294117647058823, 0.6706586826347306, 0.7065868263473054, 0.7105263157894738]
# 0.7198469743057349
# -0.7198469743057349 -0.7894004914536853
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:30:10.385824
# [0.782051282051282, 0.7218934911242604, 0.6785714285714286, 0.7142857142857143, 0.7105263157894738]
# 0.7214656463644318
# -0.7214656463644318 -0.7894004914536853
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:31:20.210520
# [0.7662337662337663, 0.7636363636363638, 0.7975460122699387, 0.7975460122699387, 0.8516129032258064]
# 0.7953150115271628
# -0.7953150115271628 -0.7953150115271628
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:32:29.246628
# [0.7712418300653595, 0.7547169811320754, 0.8148148148148148, 0.8023255813953489, 0.8552631578947368]
# 0.7996724730604671
# -0.7996724730604671 -0.7996724730604671
# {'model1': <models.features.pretrained_wrap object at 0x7f6b1d946e48>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6b1d946128>}
# 0.7706422018348623
# outer fold
# 2019-08-21 05:33:57.445922
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:33:57.898230
# [0.7185628742514969, 0.757396449704142, 0.7402597402597403, 0.7701863354037267, 0.738095238095238]
# 0.7449001275428688
# -0.7449001275428688 -0.7449001275428688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:35:07.800501
# [0.6987951807228916, 0.7425149700598802, 0.7320261437908497, 0.7374999999999999, 0.7142857142857143]
# 0.7250244017718671
# -0.7250244017718671 -0.7449001275428688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:36:16.599157
# [0.6867469879518073, 0.7142857142857143, 0.7105263157894737, 0.7239263803680983, 0.6982248520710058]
# 0.70674205009322
# -0.70674205009322 -0.7449001275428688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:37:27.338747
# [0.6744186046511628, 0.6547619047619048, 0.6711409395973154, 0.7037037037037037, 0.6820809248554912]
# 0.6772212155139157
# -0.6772212155139157 -0.7449001275428688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:38:37.194162
# [0.6783625730994153, 0.6871165644171778, 0.68, 0.7160493827160493, 0.6745562130177515]
# 0.6872169466500788
# -0.6872169466500788 -0.7449001275428688
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:39:46.912146
# [0.7901234567901234, 0.7926829268292682, 0.7346938775510203, 0.810126582278481, 0.7590361445783134]
# 0.7773325976054413
# -0.7773325976054413 -0.7773325976054413
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:40:55.851809
# [0.6823529411764707, 0.6547619047619048, 0.6711409395973154, 0.7037037037037037, 0.6820809248554912]
# 0.6788080828189772
# -0.6788080828189772 -0.7773325976054413
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:42:06.718547
# [0.6744186046511628, 0.6627218934911243, 0.6711409395973154, 0.6993865030674846, 0.6823529411764707]
# 0.6780041763967116
# -0.6780041763967116 -0.7773325976054413
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:43:19.173131
# [0.7798742138364779, 0.7898089171974522, 0.7132867132867133, 0.8125000000000001, 0.7453416149068324]
# 0.7681622918454951
# -0.7681622918454951 -0.7773325976054413
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:44:29.002523
# [0.7749999999999999, 0.7948717948717949, 0.7534246575342466, 0.8048780487804877, 0.7607361963190185]
# 0.7777821395011095
# -0.7777821395011095 -0.7777821395011095
# {'model1': <models.features.pretrained_wrap object at 0x7f6b1d938f98>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6b1d9384a8>}
# 0.7939698492462313
# outer fold
# 2019-08-21 05:45:55.153281
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:45:55.552135
# [0.6871165644171778, 0.7757575757575756, 0.75, 0.7425149700598802, 0.6823529411764707]
# 0.727548410282221
# -0.727548410282221 -0.727548410282221
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:47:05.880810
# [0.6792452830188679, 0.7904191616766467, 0.7439024390243902, 0.7239263803680983, 0.686046511627907]
# 0.724707955143182
# -0.724707955143182 -0.727548410282221
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 05:48:15.070709
# [0.6499999999999999, 0.7607361963190185, 0.738095238095238, 0.7425149700598802, 0.6347305389221557]
# 0.7052153886792585
# -0.7052153886792585 -0.727548410282221
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 05:49:24.994557
# [0.6545454545454545, 0.7088607594936708, 0.7337278106508877, 0.7250000000000001, 0.6181818181818182]
# 0.6880631685743663
# -0.6880631685743663 -0.727548410282221
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 05:50:37.058751
# [0.6626506024096386, 0.7295597484276728, 0.7337278106508877, 0.7439024390243902, 0.6012269938650306]
# 0.694213518875524
# -0.694213518875524 -0.727548410282221
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 05:51:48.730511
# [0.7239263803680983, 0.7901234567901234, 0.761904761904762, 0.761904761904762, 0.7142857142857143]
# 0.750429015050692
# -0.750429015050692 -0.750429015050692
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 05:52:59.154143
# [0.6424242424242423, 0.7133757961783439, 0.7218934911242604, 0.7407407407407407, 0.6181818181818182]
# 0.6873232177298811
# -0.6873232177298811 -0.750429015050692
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 05:54:09.973764
# [0.6506024096385542, 0.7169811320754716, 0.7368421052631577, 0.7453416149068324, 0.6097560975609756]
# 0.6919046718889984
# -0.6919046718889984 -0.750429015050692
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 05:55:19.564481
# [0.6993865030674846, 0.8048780487804877, 0.761904761904762, 0.7810650887573963, 0.7393939393939394]
# 0.7573256683808139
# -0.7573256683808139 -0.7573256683808139
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 05:56:30.901287
# [0.7295597484276728, 0.7926829268292682, 0.7484662576687118, 0.7701863354037267, 0.7647058823529411]
# 0.7611202301364641
# -0.7611202301364641 -0.7611202301364641
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1a9e1198>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c1a9e1048>}
# 0.7717391304347826
# outer fold
# 2019-08-21 05:57:57.543156
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 05:57:58.042873
# [0.7590361445783134, 0.7485380116959064, 0.787878787878788, 0.7329192546583853, 0.7848101265822786]
# 0.7626364650787344
# -0.7626364650787344 -0.7626364650787344
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 05:59:09.989669
# [0.7407407407407407, 0.7441860465116279, 0.7951807228915663, 0.7169811320754716, 0.7875]
# 0.7569177284438813
# -0.7569177284438813 -0.7626364650787344
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:00:23.137383
# [0.7250000000000001, 0.7209302325581395, 0.7710843373493975, 0.6962025316455697, 0.7607361963190185]
# 0.734790659574425
# -0.734790659574425 -0.7626364650787344
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 06:01:32.804786
# [0.7044025157232704, 0.6987951807228916, 0.7407407407407407, 0.6956521739130435, 0.7439024390243902]
# 0.7166986100248673
# -0.7166986100248673 -0.7626364650787344
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 06:02:43.673570
# [0.7125, 0.7176470588235295, 0.7682926829268293, 0.7125, 0.7590361445783134]
# 0.7339951772657344
# -0.7339951772657344 -0.7626364650787344
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 06:03:53.139765
# [0.7692307692307692, 0.7719298245614035, 0.8170731707317075, 0.7453416149068324, 0.8220858895705522]
# 0.785132253800253
# -0.785132253800253 -0.785132253800253
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 06:05:02.599730
# [0.7044025157232704, 0.6987951807228916, 0.7361963190184049, 0.691358024691358, 0.7484662576687118]
# 0.7158436595649273
# -0.7158436595649273 -0.785132253800253
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 06:06:13.326944
# [0.7, 0.6987951807228916, 0.7484662576687118, 0.6993865030674846, 0.7560975609756098]
# 0.7205491004869395
# -0.7205491004869395 -0.785132253800253
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 06:07:24.828789
# [0.7974683544303799, 0.7816091954022988, 0.8048780487804877, 0.7374999999999999, 0.8313253012048193]
# 0.7905561799635972
# -0.7905561799635972 -0.7905561799635972
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 06:08:34.428097
# [0.8023952095808382, 0.7821229050279329, 0.8198757763975155, 0.735483870967742, 0.8192771084337349]
# 0.7918309740815526
# -0.7918309740815526 -0.7918309740815526
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1991cc18>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c1991c940>}
# 0.7904761904761906
# outer fold
# 2019-08-21 06:09:59.942764
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 06:10:00.304607
# [0.7529411764705881, 0.7441860465116279, 0.7407407407407407, 0.7515151515151515, 0.7741935483870969]
# 0.7527153327250411
# -0.7527153327250411 -0.7527153327250411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 06:11:11.788682
# [0.7529411764705881, 0.7241379310344828, 0.7317073170731708, 0.7425149700598802, 0.7643312101910827]
# 0.743126520965841
# -0.743126520965841 -0.7527153327250411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:12:22.154330
# [0.7485380116959064, 0.7085714285714286, 0.6826347305389222, 0.6909090909090909, 0.7402597402597403]
# 0.7141826003950177
# -0.7141826003950177 -0.7527153327250411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 06:13:32.282480
# [0.7337278106508877, 0.7241379310344828, 0.6666666666666667, 0.6583850931677019, 0.7012987012987013]
# 0.6968432405636881
# -0.6968432405636881 -0.7527153327250411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 06:14:42.837176
# [0.7337278106508877, 0.7052023121387283, 0.6586826347305389, 0.6790123456790124, 0.7261146496815287]
# 0.7005479505761392
# -0.7005479505761392 -0.7527153327250411
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 06:15:53.713259
# [0.7857142857142857, 0.7647058823529411, 0.7798742138364779, 0.8121212121212122, 0.782051282051282]
# 0.7848933752152398
# -0.7848933752152398 -0.7848933752152398
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 06:17:02.227533
# [0.7337278106508877, 0.7241379310344828, 0.6707317073170732, 0.6583850931677019, 0.7012987012987013]
# 0.6976562486937694
# -0.6976562486937694 -0.7848933752152398
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 06:18:12.653602
# [0.7337278106508877, 0.7167630057803468, 0.674698795180723, 0.6666666666666666, 0.7096774193548386]
# 0.7003067395266924
# -0.7003067395266924 -0.7848933752152398
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 06:19:24.867387
# [0.7857142857142857, 0.7602339181286549, 0.7950310559006211, 0.8121212121212122, 0.810126582278481]
# 0.792645410828651
# -0.792645410828651 -0.792645410828651
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 06:20:35.439123
# [0.8023952095808382, 0.761904761904762, 0.7901234567901234, 0.8395061728395061, 0.7866666666666667]
# 0.7961192535563792
# -0.7961192535563792 -0.7961192535563792
# {'model1': <models.features.pretrained_wrap object at 0x7f6b1d94d6d8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6b1d94d438>}
# 0.7684210526315789
# save to ../pickle/2019-08-21 06:22:02.296261.pickle
# save to ../csv/2019-08-21 06:22:02.385742.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.779   0.793          0.771       0.777         0.857    0.876
#
#   train_recall train_accuracy  \
# 0  0.84         0.857
#
#                                                        model1  \
# 0  <models.features.pretrained_wrap object at 0x7f6c11757fd0>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 06:22:02.296261.pickle
# state 2022
# outer fold
# 2019-08-21 06:22:02.682380
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 06:22:03.039953
# [0.7544910179640719, 0.7329192546583853, 0.7710843373493975, 0.7586206896551724, 0.7672955974842767]
# 0.7568821794222607
# -0.7568821794222607 -0.7568821794222607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 06:23:14.338438
# [0.7560975609756098, 0.7169811320754716, 0.7738095238095237, 0.7542857142857142, 0.7484662576687117]
# 0.7499280377630063
# -0.7499280377630063 -0.7568821794222607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:24:26.562635
# [0.7647058823529411, 0.7169811320754716, 0.7425149700598802, 0.7411764705882353, 0.7349397590361445]
# 0.7400636428225346
# -0.7400636428225346 -0.7568821794222607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 06:25:36.796352
# [0.7647058823529411, 0.6956521739130435, 0.7349397590361447, 0.7439024390243902, 0.7228915662650603]
# 0.732418364118316
# -0.732418364118316 -0.7568821794222607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 06:26:46.924149
# [0.757396449704142, 0.7044025157232704, 0.7425149700598802, 0.738095238095238, 0.7239263803680982]
# 0.7332671107901257
# -0.7332671107901257 -0.7568821794222607
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 06:27:58.654406
# [0.782608695652174, 0.7421383647798742, 0.787878787878788, 0.761904761904762, 0.8076923076923076]
# 0.7764445835815811
# -0.7764445835815811 -0.7764445835815811
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 06:29:09.394107
# [0.7647058823529411, 0.6956521739130435, 0.7349397590361447, 0.7439024390243902, 0.7228915662650603]
# 0.732418364118316
# -0.732418364118316 -0.7764445835815811
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 06:30:21.625763
# [0.761904761904762, 0.6918238993710691, 0.7425149700598802, 0.7393939393939394, 0.7317073170731706]
# 0.7334689775605642
# -0.7334689775605642 -0.7764445835815811
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 06:31:33.116914
# [0.7625, 0.75, 0.7804878048780488, 0.7664670658682634, 0.8280254777070064]
# 0.7774960696906638
# -0.7774960696906638 -0.7774960696906638
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 06:32:42.338399
# [0.7701863354037267, 0.7594936708860759, 0.7843137254901961, 0.7590361445783134, 0.8]
# 0.7746059752716624
# -0.7746059752716624 -0.7774960696906638
# {'model1': <models.features.pretrained_wrap object at 0x7f6c185d0eb8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c185d0390>}
# 0.7909090909090909
# outer fold
# 2019-08-21 06:34:07.681001
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 06:34:08.081139
# [0.7393939393939394, 0.7804878048780488, 0.7092198581560284, 0.7976190476190476, 0.7577639751552795]
# 0.7568969250404687
# -0.7568969250404687 -0.7568969250404687
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 06:35:13.544896
# [0.7283950617283951, 0.7777777777777778, 0.7382550335570469, 0.7719298245614035, 0.7636363636363638]
# 0.7559988122521973
# -0.7559988122521973 -0.7568969250404687
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:36:21.880850
# [0.7151515151515152, 0.7738095238095237, 0.7297297297297297, 0.7586206896551724, 0.7349397590361447]
# 0.7424502434764172
# -0.7424502434764172 -0.7568969250404687
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 06:37:33.689459
# [0.7317073170731708, 0.7393939393939394, 0.6388888888888888, 0.7500000000000001, 0.6987951807228916]
# 0.7117570652157781
# -0.7117570652157781 -0.7568969250404687
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 06:38:45.494098
# [0.7160493827160493, 0.7692307692307692, 0.6573426573426573, 0.7485380116959064, 0.7305389221556886]
# 0.7243399486282142
# -0.7243399486282142 -0.7568969250404687
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 06:39:56.605465
# [0.7625, 0.787878787878788, 0.75, 0.8333333333333334, 0.7577639751552795]
# 0.7782952192734801
# -0.7782952192734801 -0.7782952192734801
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 06:41:06.595153
# [0.7317073170731708, 0.7393939393939394, 0.6388888888888888, 0.7500000000000001, 0.6987951807228916]
# 0.7117570652157781
# -0.7117570652157781 -0.7782952192734801
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 06:42:18.354557
# [0.7317073170731708, 0.7393939393939394, 0.6527777777777778, 0.7514450867052024, 0.7151515151515152]
# 0.7180951272203211
# -0.7180951272203211 -0.7782952192734801
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 06:43:22.589864
# [0.7654320987654321, 0.8198757763975155, 0.75, 0.8117647058823529, 0.75]
# 0.7794145162090601
# -0.7794145162090601 -0.7794145162090601
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 06:44:25.889980
# [0.7483870967741936, 0.8148148148148148, 0.75, 0.7976190476190476, 0.7564102564102564]
# 0.7734462431236624
# -0.7734462431236624 -0.7794145162090601
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1a9e1ba8>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c1a9e1668>}
# 0.7788461538461539
# outer fold
# 2019-08-21 06:45:46.471890
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 06:45:46.843155
# [0.6993865030674846, 0.7560975609756098, 0.7080745341614907, 0.75, 0.7151515151515152]
# 0.7257420226712201
# -0.7257420226712201 -0.7257420226712201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 06:46:50.059961
# [0.675, 0.7272727272727273, 0.7204968944099378, 0.7469879518072289, 0.7195121951219512]
# 0.717853953722369
# -0.717853953722369 -0.7257420226712201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:47:52.059120
# [0.6499999999999999, 0.6946107784431137, 0.7080745341614907, 0.7368421052631577, 0.7151515151515152]
# 0.7009357866038555
# -0.7009357866038555 -0.7257420226712201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 06:49:03.177242
# [0.6163522012578617, 0.6792452830188679, 0.6863905325443787, 0.6818181818181818, 0.6625766871165645]
# 0.665276577151171
# -0.665276577151171 -0.7257420226712201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 06:50:08.397155
# [0.6242038216560509, 0.7037037037037037, 0.6987951807228916, 0.7167630057803468, 0.6987951807228916]
# 0.6884521785171769
# -0.6884521785171769 -0.7257420226712201
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 06:51:12.478246
# [0.7204968944099378, 0.7672955974842767, 0.7272727272727273, 0.7560975609756098, 0.7151515151515152]
# 0.7372628590588133
# -0.7372628590588133 -0.7372628590588133
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 06:52:23.301168
# [0.6163522012578617, 0.6832298136645963, 0.6863905325443787, 0.6966292134831461, 0.6625766871165645]
# 0.6690356896133094
# -0.6690356896133094 -0.7372628590588133
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 06:53:37.933155
# [0.6202531645569621, 0.6792452830188679, 0.6863905325443787, 0.6966292134831461, 0.654320987654321]
# 0.6673678362515352
# -0.6673678362515352 -0.7372628590588133
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 06:54:52.080827
# [0.7625, 0.7798742138364779, 0.7532467532467533, 0.7682926829268293, 0.738095238095238]
# 0.7604017776210596
# -0.7604017776210596 -0.7604017776210596
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 06:56:02.668337
# [0.7549668874172185, 0.7757575757575756, 0.7792207792207793, 0.7975460122699387, 0.7469879518072289]
# 0.7708958412945482
# -0.7708958412945482 -0.7708958412945482
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1be7c780>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c1be7c630>}
# 0.8105263157894738
# outer fold
# 2019-08-21 06:57:29.515098
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 06:57:29.873810
# [0.7745664739884394, 0.7530864197530863, 0.7162162162162161, 0.7393939393939394, 0.7904191616766467]
# 0.7547364422056655
# -0.7547364422056655 -0.7547364422056655
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 06:58:39.496513
# [0.7361963190184049, 0.738095238095238, 0.7066666666666667, 0.7317073170731708, 0.7710843373493975]
# 0.7367499756405755
# -0.7367499756405755 -0.7547364422056655
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 06:59:51.427879
# [0.7294117647058823, 0.6976744186046511, 0.728476821192053, 0.7228915662650603, 0.7393939393939394]
# 0.7235697020323173
# -0.7235697020323173 -0.7547364422056655
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 07:01:01.771900
# [0.6956521739130435, 0.6900584795321638, 0.7297297297297297, 0.7065868263473054, 0.75]
# 0.7144054419044485
# -0.7144054419044485 -0.7547364422056655
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 07:02:14.518189
# [0.7239263803680983, 0.6900584795321638, 0.6986301369863014, 0.7151515151515152, 0.757396449704142]
# 0.7170325923484442
# -0.7170325923484442 -0.7547364422056655
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 07:03:25.677672
# [0.7931034482758621, 0.8047337278106509, 0.7435897435897435, 0.7692307692307692, 0.8242424242424242]
# 0.78698002262989
# -0.78698002262989 -0.78698002262989
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 07:04:37.428813
# [0.6956521739130435, 0.6823529411764707, 0.7210884353741497, 0.710843373493976, 0.75]
# 0.7119873847915279
# -0.7119873847915279 -0.78698002262989
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 07:05:49.701960
# [0.7195121951219512, 0.6745562130177515, 0.7297297297297297, 0.7065868263473054, 0.7529411764705881]
# 0.7166652281374652
# -0.7166652281374652 -0.78698002262989
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 07:07:00.919096
# [0.7926829268292682, 0.8095238095238094, 0.7516778523489933, 0.7468354430379747, 0.8313253012048193]
# 0.786409066588973
# -0.786409066588973 -0.78698002262989
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 07:08:10.019767
# [0.7857142857142857, 0.8125000000000001, 0.802547770700637, 0.7692307692307692, 0.8414634146341464]
# 0.8022912480559677
# -0.8022912480559677 -0.8022912480559677
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1be76ef0>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c1be762e8>}
# 0.7843137254901961
# outer fold
# 2019-08-21 07:09:37.111107
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 07:09:37.492471
# [0.7560975609756098, 0.7398843930635839, 0.7272727272727273, 0.7142857142857143, 0.8211920529801325]
# 0.7517464897155536
# -0.7517464897155536 -0.7517464897155536
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 07:10:48.450504
# [0.7636363636363638, 0.7398843930635839, 0.7307692307692308, 0.7325581395348836, 0.8157894736842104]
# 0.7565275201376546
# -0.7565275201376546 -0.7565275201376546
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 07:11:51.152370
# [0.7195121951219512, 0.7176470588235295, 0.7469879518072289, 0.7294117647058823, 0.8]
# 0.7427117940917183
# -0.7427117940917183 -0.7565275201376546
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 07:12:54.923798
# [0.7544910179640719, 0.6707317073170732, 0.75, 0.7011494252873562, 0.7272727272727273]
# 0.7207289755682458
# -0.7207289755682458 -0.7565275201376546
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 07:14:08.840777
# [0.7469879518072289, 0.7337278106508877, 0.7484662576687118, 0.7052023121387283, 0.7712418300653595]
# 0.7411252324661832
# -0.7411252324661832 -0.7565275201376546
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 07:15:21.298866
# [0.7926829268292682, 0.7647058823529411, 0.782608695652174, 0.7425149700598802, 0.8571428571428571]
# 0.7879310664074242
# -0.7879310664074242 -0.7879310664074242
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 07:16:32.111240
# [0.7544910179640719, 0.6625766871165645, 0.75, 0.7011494252873562, 0.7272727272727273]
# 0.719097971528144
# -0.719097971528144 -0.7879310664074242
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 07:17:44.675296
# [0.7469879518072289, 0.6946107784431137, 0.761904761904762, 0.7085714285714286, 0.735483870967742]
# 0.7295117583388551
# -0.7295117583388551 -0.7879310664074242
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 07:18:59.361728
# [0.7976190476190476, 0.7857142857142857, 0.7721518987341771, 0.7777777777777778, 0.8535031847133758]
# 0.7973532389117327
# -0.7973532389117327 -0.7973532389117327
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 07:20:11.644149
# [0.7790697674418605, 0.7560975609756098, 0.8050314465408805, 0.7901234567901234, 0.8219178082191781]
# 0.7904480079935305
# -0.7904480079935305 -0.7973532389117327
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1abb7978>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}, 'corp': <models.features.fixed_makedata object at 0x7f6c1abb73c8>}
# 0.7578947368421052
# save to ../pickle/2019-08-21 07:21:41.507134.pickle
# save to ../csv/2019-08-21 07:21:41.677309.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.784   0.789          0.784       0.78          0.874    0.876
#
#   train_recall train_accuracy  \
# 0  0.872        0.871
#
#                                                        model1  \
# 0  <models.features.pretrained_wrap object at 0x7f6c98911390>
#
# ...
# 0.7864077669902914
# outer fold
# 2019-08-21 07:33:21.742080
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 07:33:22.269970
# [0.7228915662650603, 0.7468354430379747, 0.7019867549668874, 0.7976190476190476, 0.7624309392265193]
# 0.7463527502230979
# -0.7463527502230979 -0.7463527502230979
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 07:34:23.667210
# [0.7185628742514969, 0.75, 0.7142857142857143, 0.7857142857142857, 0.7303370786516855]
# 0.7397799905806365
# -0.7397799905806365 -0.7463527502230979
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 07:35:24.070541
# [0.6909090909090909, 0.728476821192053, 0.7189542483660132, 0.7544910179640719, 0.7085714285714286]
# 0.7202805214005316
# -0.7202805214005316 -0.7463527502230979
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 07:36:24.974778
# [0.6871165644171778, 0.6933333333333332, 0.6883116883116883, 0.7239263803680983, 0.6783625730994153]
# 0.6942101079059426
# -0.6942101079059426 -0.7463527502230979
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 07:37:27.098701
# [0.703030303030303, 0.7320261437908497, 0.7006369426751592, 0.7272727272727273, 0.6900584795321638]
# 0.7106049192602406
# -0.7106049192602406 -0.7463527502230979
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 07:38:28.036893
# [0.7407407407407407, 0.7712418300653595, 0.7417218543046357, 0.8095238095238094, 0.7657142857142857]
# 0.7657885040697662
# -0.7657885040697662 -0.7657885040697662
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 07:39:29.446710
# [0.6871165644171778, 0.6933333333333332, 0.6838709677419356, 0.7239263803680983, 0.6783625730994153]
# 0.6933219637919921
# -0.6933219637919921 -0.7657885040697662
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 07:40:33.145961
# [0.6829268292682926, 0.7058823529411765, 0.6923076923076923, 0.7317073170731708, 0.6820809248554912]
# 0.6989810232891648
# -0.6989810232891648 -0.7657885040697662
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 07:41:36.236837
# [0.7421383647798742, 0.7901234567901234, 0.7432432432432432, 0.8143712574850299, 0.761904761904762]
# 0.7703562168406066
# -0.7703562168406066 -0.7703562168406066
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 07:42:38.163272
# [0.7636363636363638, 0.8, 0.7808219178082192, 0.8143712574850299, 0.7468354430379747]
# 0.7811329963935175
# -0.7811329963935175 -0.7811329963935175
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1a9eb860>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c1a9ebb00>}
# 0.7924528301886792
# outer fold
# 2019-08-21 07:43:54.215558
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 07:43:54.600280
# [0.7185628742514969, 0.7361963190184049, 0.7225806451612903, 0.7719298245614035, 0.7125]
# 0.732353932598519
# -0.732353932598519 -0.732353932598519
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 07:44:56.921583
# [0.7228915662650603, 0.7305389221556886, 0.7204968944099378, 0.7602339181286549, 0.7080745341614907]
# 0.7284471670241665
# -0.7284471670241665 -0.732353932598519
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 07:46:08.787728
# [0.6875000000000001, 0.7185628742514969, 0.691358024691358, 0.7719298245614035, 0.7080745341614907]
# 0.7154850515331498
# -0.7154850515331498 -0.732353932598519
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 07:47:20.896959
# [0.670807453416149, 0.6625, 0.6424242424242423, 0.75, 0.6946107784431137]
# 0.684068494856701
# -0.684068494856701 -0.732353932598519
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 07:48:24.174807
# [0.6835443037974684, 0.6987951807228916, 0.6707317073170732, 0.7692307692307692, 0.691358024691358]
# 0.702731997151912
# -0.702731997151912 -0.732353932598519
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 07:49:27.073827
# [0.7023809523809522, 0.7607361963190185, 0.7530864197530863, 0.7790697674418605, 0.7295597484276728]
# 0.744966616864518
# -0.744966616864518 -0.744966616864518
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 07:50:29.823542
# [0.675, 0.6625, 0.6424242424242423, 0.7425149700598802, 0.6946107784431137]
# 0.6834099981854471
# -0.6834099981854471 -0.744966616864518
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 07:51:44.201714
# [0.6792452830188679, 0.6790123456790124, 0.6424242424242423, 0.75, 0.6987951807228916]
# 0.6898954103690029
# -0.6898954103690029 -0.744966616864518
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 07:52:57.344408
# [0.7283950617283951, 0.7701863354037267, 0.7672955974842767, 0.7804878048780488, 0.7329192546583853]
# 0.7558568108305666
# -0.7558568108305666 -0.7558568108305666
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 07:54:08.567159
# [0.7515923566878981, 0.7594936708860759, 0.7975460122699387, 0.7636363636363638, 0.7469879518072289]
# 0.763851271057501
# -0.763851271057501 -0.763851271057501
# {'model1': <models.features.pretrained_wrap object at 0x7f6b1d922d68>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6b1d9229b0>}
# 0.814070351758794
# outer fold
# 2019-08-21 07:55:37.814603
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 07:55:38.283200
# [0.7607361963190185, 0.7810650887573963, 0.75, 0.6962025316455697, 0.8143712574850299]
# 0.7604750148414029
# -0.7604750148414029 -0.7604750148414029
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 07:56:41.386924
# [0.7544910179640719, 0.7738095238095237, 0.7295597484276728, 0.6666666666666667, 0.7999999999999999]
# 0.744905391373587
# -0.744905391373587 -0.7604750148414029
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 07:57:44.313546
# [0.7305389221556886, 0.7558139534883721, 0.7088607594936708, 0.6666666666666666, 0.7810650887573963]
# 0.728589078112359
# -0.728589078112359 -0.7604750148414029
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 07:58:45.692608
# [0.7261904761904762, 0.7337278106508877, 0.6624203821656051, 0.6708860759493671, 0.7239263803680983]
# 0.703430225064887
# -0.703430225064887 -0.7604750148414029
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 07:59:48.897271
# [0.7337278106508877, 0.7455621301775148, 0.6923076923076923, 0.6792452830188679, 0.761904761904762]
# 0.7225495356119449
# -0.7225495356119449 -0.7604750148414029
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 08:00:51.192630
# [0.7515151515151515, 0.8, 0.8, 0.7417218543046357, 0.8263473053892216]
# 0.7839168622418018
# -0.7839168622418018 -0.7839168622418018
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 08:01:54.306930
# [0.7261904761904762, 0.7251461988304092, 0.6624203821656051, 0.6625, 0.7239263803680983]
# 0.7000366875109177
# -0.7000366875109177 -0.7839168622418018
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 08:03:08.527943
# [0.7218934911242604, 0.7283236994219653, 0.6708860759493671, 0.6708860759493671, 0.7469879518072289]
# 0.7077954588504378
# -0.7077954588504378 -0.7839168622418018
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 08:04:21.617701
# [0.7577639751552795, 0.8076923076923077, 0.8125000000000001, 0.7417218543046357, 0.8214285714285715]
# 0.7882213417161589
# -0.7882213417161589 -0.7882213417161589
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 08:05:30.895627
# [0.7790697674418605, 0.8076923076923077, 0.8395061728395061, 0.7532467532467533, 0.8072289156626505]
# 0.7973487833766156
# -0.7973487833766156 -0.7973487833766156
# {'model1': <models.features.pretrained_wrap object at 0x7f6c196ad160>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}, 'corp': <models.features.fixed_makedata object at 0x7f6c196ad438>}
# 0.731958762886598
# outer fold
# 2019-08-21 08:06:50.646426
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.5}
# 2019-08-21 08:06:51.119870
# [0.7647058823529411, 0.7544910179640719, 0.7388535031847134, 0.7719298245614035, 0.8074534161490683]
# 0.7674867288424395
# -0.7674867288424395 -0.7674867288424395
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1.0}
# 2019-08-21 08:07:55.023016
# [0.735632183908046, 0.7142857142857143, 0.7341772151898733, 0.7674418604651162, 0.7950310559006211]
# 0.7493136059498742
# -0.7493136059498742 -0.7674867288424395
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 3.0}
# 2019-08-21 08:08:57.102160
# [0.7283236994219653, 0.6946107784431137, 0.7204968944099378, 0.7325581395348836, 0.7625]
# 0.7276979023619801
# -0.7276979023619801 -0.7674867288424395
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# 2019-08-21 08:09:59.844749
# [0.710843373493976, 0.6909090909090909, 0.6835443037974684, 0.7325581395348836, 0.7483870967741936]
# 0.7132484009019225
# -0.7132484009019225 -0.7674867288424395
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 2019-08-21 08:11:01.416490
# [0.7218934911242604, 0.6987951807228916, 0.7, 0.7337278106508877, 0.7547169811320754]
# 0.721826692726023
# -0.721826692726023 -0.7674867288424395
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# 2019-08-21 08:12:05.344384
# [0.8, 0.7745664739884394, 0.773006134969325, 0.7664670658682634, 0.823529411764706]
# 0.7875138173181468
# -0.7875138173181468 -0.7875138173181468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 500}
# 2019-08-21 08:13:09.630716
# [0.7073170731707318, 0.6909090909090909, 0.6835443037974684, 0.7368421052631577, 0.7483870967741936]
# 0.7133999339829284
# -0.7133999339829284 -0.7875138173181468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# 2019-08-21 08:14:13.482560
# [0.703030303030303, 0.6909090909090909, 0.6835443037974684, 0.7368421052631577, 0.735483870967742]
# 0.7099619347935524
# -0.7099619347935524 -0.7875138173181468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.05}
# 2019-08-21 08:15:18.491896
# [0.783625730994152, 0.7745664739884394, 0.7682926829268293, 0.7804878048780488, 0.8079470198675497]
# 0.7829839425310038
# -0.7829839425310038 -0.7875138173181468
# {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.01}
# 2019-08-21 08:16:20.255060
# [0.7701149425287357, 0.7607361963190185, 0.7388535031847134, 0.7950310559006211, 0.8050314465408805]
# 0.7739534288947938
# -0.7739534288947938 -0.7875138173181468
# {'model1': <models.features.pretrained_wrap object at 0x7f6c1abd6e10>, 'model2': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}, 'corp': <models.features.fixed_makedata object at 0x7f6b1d95bef0>}
# 0.7766990291262137
# save to ../pickle/2019-08-21 08:17:40.395519.pickle
# save to ../csv/2019-08-21 08:17:40.536466.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.78    0.777          0.785       0.775         0.872    0.877
#
#   train_recall train_accuracy  \
# 0  0.868        0.87
#
#                                                        model1  \
# 0  <models.features.pretrained_wrap object at 0x7f6c20947208>
#
#                                                                                                                                                                                                                                                                               model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 08:17:40.395519.pickle
# save to ../csv/2019-08-21 08:17:40.580092.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.815   0.815          0.816       0.81          0.905    0.918
# 0  0.779   0.793          0.771       0.777         0.857    0.876
# 0  0.784   0.789          0.784       0.78          0.874    0.876
# 0  0.78    0.777          0.785       0.775         0.872    0.877
#
#   train_recall train_accuracy  \
# 0  0.893        0.904
# 0  0.84         0.857
# 0  0.872        0.871
# 0  0.868        0.87
#
#                                                        model1  \
# 0  <models.features.salvador_wrap object at 0x7f6c0a593fd0>
# 0  <models.features.pretrained_wrap object at 0x7f6c11757fd0>
# 0  <models.features.pretrained_wrap object at 0x7f6c98911390>
# 0  <models.features.pretrained_wrap object at 0x7f6c20947208>
#
#                                                                                                                                                                                                                                                                                model2  \
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0  LogisticRegression(C=0.01, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0  LogisticRegression(C=0.05, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0  LogisticRegression(C=0.1, class_weight='balanced', dual=False,\n          fit_intercept=True, intercept_scaling=1, max_iter=100,\n          multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,\n          solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 05:21:53.462225.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 06:22:02.296261.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 07:21:41.507134.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-21 08:17:40.395519.pickle
# time: 3h 53min 38s

# %% [markdown]
# ### 2. pretrained word embeddings and LGBM

# %%
def inner_CV(corp, medel1, method):
    '''
    should speficify the parameters here
    '''
    from models.fmin2 import p2_lgbm
    
    spaces = {'model1': model1, 'model2': LGBMClassifier,'method': method,
              'p2': p2_lgbm, 'corp': corp}
    
    ''' fmin from hyperopt
    Args:
        fn: model to run, in the form of function
        space: dict of potential parameters
    Return:
        best: dict of best parameters
    ''' 
    best_space = fmin2(fn = objective, space=spaces, max_evals = 20)
    print(best_space)
    model2 = best_space['model2'](**best_space['p2'])
    return model2


'''
0. start the model selection and evaluation
'''
dfs = []
corp0 = fixed_makedata(dic, ls, tag='AMT')
knowns = corp0.knowns
state = 2022
for model1 in [salvador_wrap(), 
               pretrained_wrap(knowns, 'word2vec-google-news-300'),
               pretrained_wrap(knowns, 'glove-wiki-gigaword-300'),
               pretrained_wrap(knowns, 'fasttext-wiki-news-subwords-300')]:
    for method in [['wv','scale']]:
        corp = copy.deepcopy(corp0)
        results = []
        model2, fold_count = '', 0
        print('state', state)
        ss = StratifiedKFold(n_splits = 5, shuffle = True, random_state = state)
        for train_index, test_index in ss.split(corp.ls, corp.y):
            print('outer fold')
            print_time()
            '''
            1. model selection
            ::: model1 is for feature engineering
                e.g. model1 = pretrained_wrap(corp.knowns, 'glove-wiki-gigaword-300')
                e.g. model1 = gensim_wrap(corp.knowns, Word2Vec, params = {})
            ::: model2 is a classifier
                e.g. model2 = copy.deepcopy(classifier['default_Logistic'])
            '''
            model2 = inner_CV(corp.replace(train_index), model1, method)
            '''
            2. build X
            '''
            data = inputs_generater(corp.replace(train_index), model1, method)
            '''
            3. run and find the best prob threshold
            '''
            threshold = clf_running_search(data, model1, copy.deepcopy(model2), method)
            '''
            4. run again and evaluate on the real test set
            ''' 
            data = inputs_generater(corp.add_train_test(train_index, test_index), model1, method)
            result = clf_running(data, model1, copy.deepcopy(model2) ,method, threshold).result
            result.update({'model1': model1,'tag': corp.tag, 'method':method})
            results.append(result)
            print(result['test_f1'])

        pickle_path = auto_save_pickle(results)
        df = pickle2df(results, pickle_path)
        dfs.append(df)
auto_save_csv(pd.concat(dfs))
# Out:
# state 2022
# outer fold
# 2019-08-21 13:12:50.257816
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 13:12:50.481682
# [0.75, 0.7453416149068324, 0.7837837837837838, 0.7875, 0.8051948051948051]
# 0.7743640407770843
# -0.7743640407770843 -0.7743640407770843
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 13:34:34.474934
# [0.7515151515151515, 0.7560975609756098, 0.7417218543046357, 0.8024691358024691, 0.8129032258064516]
# 0.7729413856808636
# -0.7729413856808636 -0.7743640407770843
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 13:55:02.880341
# [0.7407407407407407, 0.7515151515151515, 0.7733333333333333, 0.8074534161490683, 0.8129032258064516]
# 0.7771891735089491
# -0.7771891735089491 -0.7771891735089491
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 14:09:38.942394
# [0.7515923566878981, 0.7636363636363638, 0.7866666666666667, 0.8170731707317075, 0.8104575163398693]
# 0.7858852148125012
# -0.7858852148125012 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 14:21:04.905041
# [0.7654320987654321, 0.7469879518072289, 0.7755102040816326, 0.7926829268292682, 0.7922077922077922]
# 0.7745641947382708
# -0.7745641947382708 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 14:33:03.257373
# [0.7453416149068324, 0.7341772151898733, 0.7702702702702703, 0.7701863354037267, 0.8051948051948051]
# 0.7650340481931016
# -0.7650340481931016 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 14:48:36.429876
# [0.7453416149068324, 0.7515923566878981, 0.7671232876712328, 0.7784431137724551, 0.8053691275167786]
# 0.7695739001110395
# -0.7695739001110395 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 15:01:13.023463
# [0.7530864197530863, 0.7361963190184049, 0.7891156462585033, 0.782608695652174, 0.8104575163398693]
# 0.7742929194044075
# -0.7742929194044075 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 15:15:23.008141
# [0.7468354430379747, 0.7530864197530863, 0.7843137254901961, 0.8048780487804877, 0.794701986754967]
# 0.7767631247633423
# -0.7767631247633423 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 15:26:10.162775
# [0.7421383647798742, 0.7349397590361447, 0.794701986754967, 0.8048780487804877, 0.7973856209150326]
# 0.7748087560533012
# -0.7748087560533012 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 15:39:00.439130
# [0.7515923566878981, 0.7625, 0.7792207792207793, 0.8165680473372782, 0.7999999999999999]
# 0.7819762366491911
# -0.7819762366491911 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 15:49:25.498934
# [0.7625, 0.7530864197530863, 0.7516778523489933, 0.7926829268292682, 0.7894736842105262]
# 0.7698841766283747
# -0.7698841766283747 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 16:01:22.060983
# [0.7577639751552795, 0.7590361445783134, 0.8026315789473684, 0.7901234567901234, 0.7894736842105262]
# 0.7798057679363221
# -0.7798057679363221 -0.7858852148125012
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 16:17:21.283189
# [0.7848101265822786, 0.782608695652174, 0.8211920529801325, 0.8098159509202455, 0.8026315789473685]
# 0.8002116810164399
# -0.8002116810164399 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 16:27:52.740959
# [0.7361963190184049, 0.7515151515151515, 0.8129032258064517, 0.8072289156626505, 0.8026315789473685]
# 0.7820950381900055
# -0.7820950381900055 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 16:39:52.104304
# [0.7388535031847134, 0.7515151515151515, 0.7894736842105262, 0.8048780487804877, 0.7948717948717949]
# 0.7759184365125348
# -0.7759184365125348 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 16:54:54.455814
# [0.7654320987654321, 0.7215189873417721, 0.7866666666666667, 0.8125000000000001, 0.818181818181818]
# 0.7808599141911378
# -0.7808599141911378 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 17:10:16.109698
# [0.7701863354037267, 0.7951807228915663, 0.7651006711409395, 0.7784431137724551, 0.7999999999999999]
# 0.7817821686417374
# -0.7817821686417374 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 17:20:48.533346
# [0.7577639751552795, 0.7664670658682634, 0.7651006711409395, 0.8098159509202455, 0.8053691275167786]
# 0.7809033581203013
# -0.7809033581203013 -0.8002116810164399
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 17:31:52.877546
# [0.7483870967741936, 0.7435897435897435, 0.7948717948717949, 0.8023952095808382, 0.8157894736842106]
# 0.7810066637001561
# -0.7810066637001561 -0.8002116810164399
# {'model1': <models.features.salvador_wrap object at 0x7eff0c5dc7f0>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7eff0b587128>}
# 0.8097560975609757
# outer fold
# 2019-08-21 17:43:39.944048
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 17:43:40.358743
# [0.7974683544303799, 0.810126582278481, 0.7516778523489933, 0.8484848484848484, 0.7530864197530863]
# 0.7921688114591579
# -0.7921688114591579 -0.7921688114591579
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 17:59:36.277737
# [0.7612903225806451, 0.8176100628930817, 0.7712418300653595, 0.8466257668711655, 0.782608695652174]
# 0.7958753356124851
# -0.7958753356124851 -0.7958753356124851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:09:54.256408
# [0.7948717948717949, 0.8198757763975155, 0.7516778523489933, 0.8292682926829269, 0.7682926829268293]
# 0.792797279845612
# -0.792797279845612 -0.7958753356124851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 18:23:46.563429
# [0.7792207792207793, 0.825, 0.7631578947368421, 0.8588957055214724, 0.7701863354037267]
# 0.799292142976564
# -0.799292142976564 -0.799292142976564
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 18:34:27.917265
# [0.8157894736842104, 0.8322981366459627, 0.75, 0.8363636363636364, 0.773006134969325]
# 0.8014914763326269
# -0.8014914763326269 -0.8014914763326269
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:45:34.871028
# [0.7870967741935484, 0.8280254777070064, 0.7417218543046357, 0.8433734939759034, 0.7664670658682634]
# 0.7933369332098714
# -0.7933369332098714 -0.8014914763326269
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 18:59:38.758110
# [0.7894736842105262, 0.830188679245283, 0.7466666666666666, 0.8395061728395061, 0.7636363636363638]
# 0.7938943133196691
# -0.7938943133196691 -0.8014914763326269
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 19:18:58.765186
# [0.8026315789473684, 0.8500000000000001, 0.7516778523489933, 0.8433734939759034, 0.7804878048780488]
# 0.8056341460300628
# -0.8056341460300628 -0.8056341460300628
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 19:40:15.204183
# [0.8026315789473684, 0.8322981366459627, 0.7567567567567567, 0.84472049689441, 0.7701863354037267]
# 0.8013186609296449
# -0.8013186609296449 -0.8056341460300628
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 19:52:24.349087
# [0.8157894736842104, 0.8176100628930817, 0.7466666666666666, 0.8727272727272727, 0.7798742138364779]
# 0.8065335379615419
# -0.8065335379615419 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 20:08:03.339207
# [0.7924528301886792, 0.8148148148148148, 0.7402597402597403, 0.8466257668711655, 0.7607361963190185]
# 0.7909778696906836
# -0.7909778696906836 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 20:23:19.172539
# [0.8104575163398693, 0.8374999999999999, 0.7402597402597403, 0.8466257668711655, 0.7636363636363638]
# 0.7996958774214278
# -0.7996958774214278 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 20:33:53.145691
# [0.794701986754967, 0.8148148148148148, 0.7297297297297297, 0.8313253012048193, 0.7577639751552795]
# 0.7856671615319221
# -0.7856671615319221 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 20:47:26.185114
# [0.7973856209150327, 0.8198757763975155, 0.7466666666666666, 0.8343558282208587, 0.7577639751552795]
# 0.7912095734710707
# -0.7912095734710707 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-21 20:57:02.766796
# [0.8051948051948052, 0.8148148148148148, 0.7682119205298013, 0.8484848484848484, 0.7951807228915663]
# 0.8063774223831672
# -0.8063774223831672 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 21:06:23.134445
# [0.7999999999999999, 0.8125000000000001, 0.7549668874172185, 0.8414634146341464, 0.7804878048780488]
# 0.7978836213858826
# -0.7978836213858826 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 21:18:29.192805
# [0.7894736842105262, 0.830188679245283, 0.7382550335570469, 0.8484848484848484, 0.7784431137724551]
# 0.796969071854032
# -0.796969071854032 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-21 21:31:02.845620
# [0.7843137254901961, 0.8074534161490683, 0.7662337662337663, 0.8271604938271605, 0.7560975609756098]
# 0.7882517925351602
# -0.7882517925351602 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:39:12.437033
# [0.8104575163398693, 0.8148148148148148, 0.794701986754967, 0.8363636363636364, 0.7757575757575756]
# 0.8064191060061725
# -0.8064191060061725 -0.8065335379615419
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-21 21:49:03.144219
# [0.8, 0.8, 0.7612903225806451, 0.8622754491017963, 0.7530864197530863]
# 0.7953304382871055
# -0.7953304382871055 -0.8065335379615419
# {'model1': <models.features.salvador_wrap object at 0x7eff0c222358>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7eff0b534048>}
# 0.7941176470588236
# outer fold
# 2019-08-21 21:59:22.002465
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 21:59:22.454915
# [0.7692307692307692, 0.7999999999999999, 0.7922077922077922, 0.7848101265822786, 0.8242424242424242]
# 0.7940982224526528
# -0.7940982224526528 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-21 22:16:05.011676
# [0.7450980392156864, 0.8181818181818182, 0.7692307692307692, 0.7547169811320754, 0.8098159509202455]
# 0.7794087117361189
# -0.7794087117361189 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 22:28:26.082136
# [0.7483870967741936, 0.7999999999999999, 0.758169934640523, 0.782051282051282, 0.787878787878788]
# 0.7752974202689573
# -0.7752974202689573 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 22:47:59.615845
# [0.735483870967742, 0.7785234899328859, 0.7763157894736843, 0.7848101265822786, 0.782608695652174]
# 0.771548394521753
# -0.771548394521753 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-21 22:58:58.547106
# [0.7333333333333334, 0.8050314465408805, 0.782051282051282, 0.7692307692307692, 0.8292682926829269]
# 0.7837830247678385
# -0.7837830247678385 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:09:37.784580
# [0.7368421052631579, 0.8, 0.7763157894736843, 0.7798742138364779, 0.7975460122699387]
# 0.7781156241686518
# -0.7781156241686518 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:23:37.976976
# [0.7435897435897435, 0.7792207792207793, 0.7770700636942676, 0.7777777777777778, 0.782608695652174]
# 0.7720534119869484
# -0.7720534119869484 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-21 23:35:39.651073
# [0.75, 0.7948717948717949, 0.7741935483870969, 0.782051282051282, 0.8024691358024691]
# 0.7807171522225286
# -0.7807171522225286 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-21 23:49:39.605095
# [0.7333333333333334, 0.8051948051948052, 0.7870967741935484, 0.7950310559006211, 0.8098159509202455]
# 0.7860943839085107
# -0.7860943839085107 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-21 23:59:04.539038
# [0.7450980392156864, 0.8152866242038217, 0.7948717948717949, 0.7612903225806451, 0.8023952095808382]
# 0.7837883980905573
# -0.7837883980905573 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 00:09:29.774316
# [0.7152317880794701, 0.7763157894736843, 0.7692307692307692, 0.7388535031847134, 0.8148148148148148]
# 0.7628893329566904
# -0.7628893329566904 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:18:59.252673
# [0.7516778523489933, 0.7919463087248322, 0.7948717948717949, 0.782051282051282, 0.8095238095238094]
# 0.7860142095041424
# -0.7860142095041424 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:29:38.646293
# [0.7320261437908497, 0.7843137254901961, 0.7866666666666667, 0.8050314465408805, 0.8170731707317075]
# 0.7850222306440602
# -0.7850222306440602 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 00:43:59.425282
# [0.7435897435897435, 0.7948717948717949, 0.7924528301886792, 0.7468354430379747, 0.8072289156626505]
# 0.7769957454701685
# -0.7769957454701685 -0.7940982224526528
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 00:53:45.438559
# [0.7763157894736843, 0.8258064516129032, 0.7763157894736843, 0.7898089171974522, 0.8048780487804877]
# 0.7946249993076423
# -0.7946249993076423 -0.7946249993076423
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:04:20.116994
# [0.7402597402597403, 0.8181818181818182, 0.7763157894736843, 0.8050314465408805, 0.8072289156626505]
# 0.7894035420237547
# -0.7894035420237547 -0.7946249993076423
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 01:17:33.182173
# [0.7320261437908497, 0.7922077922077922, 0.7712418300653595, 0.7848101265822786, 0.7926829268292682]
# 0.7745937638951096
# -0.7745937638951096 -0.7946249993076423
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 01:33:25.497048
# [0.7058823529411765, 0.8280254777070064, 0.7843137254901961, 0.7777777777777778, 0.7784431137724551]
# 0.7748884895377224
# -0.7748884895377224 -0.7946249993076423
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 01:43:44.298025
# [0.7272727272727273, 0.7763157894736843, 0.7973856209150327, 0.7749999999999999, 0.8192771084337349]
# 0.7790502492190358
# -0.7790502492190358 -0.7946249993076423
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 01:54:45.863257
# [0.7682119205298013, 0.7682119205298013, 0.7672955974842767, 0.7741935483870969, 0.787878787878788]
# 0.7731583549619528
# -0.7731583549619528 -0.7946249993076423
# {'model1': <models.features.salvador_wrap object at 0x7eff0fe45780>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}, 'corp': <models.features.fixed_makedata object at 0x7efe21ec9e80>}
# 0.8064516129032258
# outer fold
# 2019-08-22 02:03:33.703174
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:03:34.120158
# [0.8205128205128205, 0.7924528301886792, 0.8152866242038217, 0.7549668874172185, 0.8363636363636364]
# 0.8039165597372353
# -0.8039165597372353 -0.8039165597372353
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 02:13:08.651185
# [0.7843137254901961, 0.782608695652174, 0.7898089171974522, 0.7162162162162161, 0.8220858895705522]
# 0.7790066888253182
# -0.7790066888253182 -0.8039165597372353
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:20:46.348930
# [0.7741935483870969, 0.7625, 0.8, 0.7210884353741497, 0.8242424242424242]
# 0.7764048816007342
# -0.7764048816007342 -0.8039165597372353
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 02:32:03.936782
# [0.8050314465408805, 0.8050314465408805, 0.8343558282208587, 0.7346938775510203, 0.8484848484848484]
# 0.8055194894676978
# -0.8055194894676978 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 02:45:03.620744
# [0.7870967741935484, 0.8048780487804877, 0.8170731707317075, 0.72, 0.8354430379746836]
# 0.7928982063360854
# -0.7928982063360854 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 02:55:02.138282
# [0.7672955974842767, 0.7926829268292682, 0.7870967741935484, 0.7123287671232877, 0.8363636363636364]
# 0.7791535403988035
# -0.7791535403988035 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:09:11.436695
# [0.7792207792207793, 0.7975460122699387, 0.830188679245283, 0.7483870967741936, 0.8363636363636364]
# 0.7983412407747662
# -0.7983412407747662 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 03:22:01.505726
# [0.7972972972972973, 0.8024691358024691, 0.8292682926829269, 0.726027397260274, 0.8414634146341464]
# 0.7993051075354227
# -0.7993051075354227 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 03:36:25.523971
# [0.7770700636942676, 0.8292682926829269, 0.802547770700637, 0.7432432432432432, 0.8502994011976048]
# 0.8004857543037358
# -0.8004857543037358 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 03:47:27.656112
# [0.7792207792207793, 0.8098159509202455, 0.8098159509202455, 0.7123287671232877, 0.8363636363636364]
# 0.7895090169096389
# -0.7895090169096389 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 03:59:45.119580
# [0.8079470198675497, 0.8121212121212122, 0.8053691275167785, 0.7516778523489933, 0.8414634146341464]
# 0.803715725297736
# -0.803715725297736 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 04:09:21.210103
# [0.7792207792207793, 0.8363636363636364, 0.8170731707317075, 0.7482993197278912, 0.8271604938271605]
# 0.801623479974235
# -0.801623479974235 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 04:19:16.226041
# [0.7749999999999999, 0.8074534161490683, 0.7843137254901961, 0.7172413793103448, 0.8242424242424242]
# 0.7816501890384067
# -0.7816501890384067 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 04:32:54.906486
# [0.7692307692307692, 0.7924528301886792, 0.7999999999999999, 0.7549668874172185, 0.8333333333333334]
# 0.789996764034
# -0.789996764034 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 04:42:43.631389
# [0.7814569536423841, 0.7643312101910827, 0.830188679245283, 0.7346938775510203, 0.8395061728395061]
# 0.7900353786938552
# -0.7900353786938552 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 04:53:05.071885
# [0.7662337662337663, 0.8048780487804877, 0.802547770700637, 0.7651006711409395, 0.8263473053892216]
# 0.7930215124490104
# -0.7930215124490104 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 05:05:13.524824
# [0.7792207792207793, 0.7875, 0.825, 0.7172413793103448, 0.8571428571428572]
# 0.7932210031347962
# -0.7932210031347962 -0.8055194894676978
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 05:16:14.257488
# [0.8227848101265822, 0.7901234567901234, 0.8205128205128205, 0.7651006711409395, 0.8333333333333334]
# 0.8063710183807598
# -0.8063710183807598 -0.8063710183807598
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 05:23:24.178832
# [0.7763157894736843, 0.8220858895705522, 0.8198757763975155, 0.7346938775510203, 0.8363636363636364]
# 0.7978669938712817
# -0.7978669938712817 -0.8063710183807598
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 05:31:38.070839
# [0.7922077922077922, 0.7870967741935484, 0.8076923076923077, 0.7432432432432432, 0.8192771084337349]
# 0.7899034451541251
# -0.7899034451541251 -0.8063710183807598
# {'model1': <models.features.salvador_wrap object at 0x7eff0fe45898>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7eff0b528320>}
# 0.7638190954773869
# outer fold
# 2019-08-22 05:40:10.809924
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 05:40:11.182022
# [0.7974683544303799, 0.7515151515151515, 0.7532467532467533, 0.8074534161490683, 0.7999999999999999]
# 0.7819367350682705
# -0.7819367350682705 -0.7819367350682705
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 05:50:33.084157
# [0.7643312101910827, 0.7529411764705881, 0.7612903225806451, 0.8198757763975155, 0.8266666666666668]
# 0.7850210304612996
# -0.7850210304612996 -0.7850210304612996
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 05:58:07.005842
# [0.7749999999999999, 0.7484662576687118, 0.7792207792207793, 0.8292682926829269, 0.7972972972972973]
# 0.7858505253739431
# -0.7858505253739431 -0.7858505253739431
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 06:09:28.288861
# [0.810126582278481, 0.7453416149068324, 0.782051282051282, 0.830188679245283, 0.8187919463087249]
# 0.7973000209581206
# -0.7973000209581206 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 06:18:25.989259
# [0.7974683544303799, 0.7393939393939394, 0.7631578947368421, 0.8322981366459627, 0.8133333333333332]
# 0.7891303317080915
# -0.7891303317080915 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 06:26:39.649161
# [0.7701863354037267, 0.7590361445783134, 0.7631578947368421, 0.810126582278481, 0.7999999999999999]
# 0.7805013913994726
# -0.7805013913994726 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 06:38:00.998223
# [0.7926829268292682, 0.761904761904762, 0.7643312101910827, 0.8125000000000001, 0.8108108108108107]
# 0.7884459419471848
# -0.7884459419471848 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-22 06:47:17.848358
# [0.782608695652174, 0.7469879518072289, 0.7483870967741936, 0.8343558282208587, 0.7973856209150327]
# 0.7819450386738975
# -0.7819450386738975 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-22 06:58:17.806652
# [0.7898089171974522, 0.7544910179640719, 0.7450980392156864, 0.8148148148148148, 0.7972972972972973]
# 0.7803020172978645
# -0.7803020172978645 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 07:06:00.808357
# [0.7804878048780488, 0.7453416149068324, 0.7612903225806451, 0.8374999999999999, 0.8133333333333332]
# 0.7875906151397718
# -0.7875906151397718 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 07:14:24.243202
# [0.7852760736196319, 0.7544910179640719, 0.7643312101910827, 0.8466257668711655, 0.8053691275167785]
# 0.7912186392325461
# -0.7912186392325461 -0.7973000209581206
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:21:52.463945
# [0.802547770700637, 0.7664670658682634, 0.782051282051282, 0.8414634146341464, 0.8243243243243243]
# 0.8033707715157308
# -0.8033707715157308 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:29:44.681112
# [0.7974683544303799, 0.7317073170731708, 0.7368421052631579, 0.8322981366459627, 0.8133333333333332]
# 0.7823298493492009
# -0.7823298493492009 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-22 07:40:41.423751
# [0.7804878048780488, 0.7682926829268293, 0.7625, 0.8407643312101911, 0.8108108108108107]
# 0.792571125965176
# -0.792571125965176 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-22 07:49:54.417446
# [0.7848101265822786, 0.738095238095238, 0.7564102564102564, 0.825, 0.8366013071895425]
# 0.7881833856554631
# -0.7881833856554631 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 07:59:39.712301
# [0.7974683544303799, 0.7349397590361447, 0.7417218543046357, 0.8148148148148148, 0.8211920529801325]
# 0.7820273671132216
# -0.7820273671132216 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-22 08:10:10.209116
# [0.7701863354037267, 0.7560975609756098, 0.7662337662337663, 0.8395061728395061, 0.8053691275167785]
# 0.7874785925938774
# -0.7874785925938774 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-22 08:20:28.029339
# [0.7974683544303799, 0.7607361963190185, 0.7236842105263157, 0.8121212121212122, 0.8053691275167785]
# 0.7798758201827409
# -0.7798758201827409 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 08:27:34.606509
# [0.7898089171974522, 0.7682926829268293, 0.7532467532467533, 0.8414634146341464, 0.823529411764706]
# 0.7952682359539774
# -0.7952682359539774 -0.8033707715157308
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-22 08:35:51.263766
# [0.7898089171974522, 0.8024691358024691, 0.7402597402597403, 0.8263473053892216, 0.8079470198675497]
# 0.7933664237032866
# -0.7933664237032866 -0.8033707715157308
# {'model1': <models.features.salvador_wrap object at 0x7eff0cae0080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7eff0c33beb8>}
# 0.7624309392265194
# save to ../pickle/2019-08-22 08:44:59.922065.pickle
# save to ../csv/2019-08-22 08:45:01.716825.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.787   0.823          0.759       0.791         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                      model1  \
# 0  <models.features.salvador_wrap object at 0x7eff0be8a5f8>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   model2  \
# 0  LGBMClassifier(bagging_fraction=0.5, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 08:44:59.922065.pickle
# state 2022
# outer fold
# 2019-08-22 08:45:02.016909
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-22 08:45:02.244391
# [0.7741935483870969, 0.7151515151515152, 0.8024691358024691, 0.7515151515151515, 0.8000000000000002]
# ...
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 16:13:10.115599
# [0.7195121951219512, 0.7721518987341771, 0.7848101265822786, 0.7320261437908497, 0.8023952095808382]
# 0.7621791147620189
# -0.7621791147620189 -0.7847513576185765
# {'model1': <models.features.pretrained_wrap object at 0x7eff0b529630>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}, 'corp': <models.features.fixed_makedata object at 0x7eff0d71b080>}
# 0.7549019607843138
# outer fold
# 2019-08-23 16:18:02.837694
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.5, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 16:18:03.061458
# [0.7602339181286549, 0.7928994082840236, 0.7662337662337663, 0.7894736842105262, 0.7741935483870969]
# 0.7766068650488136
# -0.7766068650488136 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 16:26:29.357064
# [0.7861271676300579, 0.75, 0.7272727272727273, 0.7612903225806451, 0.782608695652174]
# 0.7614597826271209
# -0.7614597826271209 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 16:33:34.372982
# [0.7810650887573963, 0.773006134969325, 0.7248322147651006, 0.7530864197530863, 0.7792207792207793]
# 0.7622421274931375
# -0.7622421274931375 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 16:45:15.218379
# [0.7951807228915663, 0.7469879518072289, 0.7368421052631579, 0.8, 0.7948717948717949]
# 0.7747765149667496
# -0.7747765149667496 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 16:55:15.044138
# [0.7931034482758621, 0.7547169811320754, 0.7152317880794701, 0.7549668874172185, 0.7792207792207793]
# 0.759447976825081
# -0.759447976825081 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 50, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 17:06:38.501804
# [0.7692307692307692, 0.7439024390243902, 0.7432432432432432, 0.7402597402597403, 0.7643312101910827]
# 0.7521934803898451
# -0.7521934803898451 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 17:24:27.221765
# [0.7906976744186047, 0.761904761904762, 0.7515923566878981, 0.7792207792207793, 0.7792207792207793]
# 0.7725272702905646
# -0.7725272702905646 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 16, 'learning_rate': 0.15, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 1}
# 2019-08-23 17:42:12.396564
# [0.7882352941176471, 0.761904761904762, 0.7152317880794701, 0.7547169811320754, 0.782051282051282]
# 0.7604280214570472
# -0.7604280214570472 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 10, 'subsample': 0.7}
# 2019-08-23 17:57:53.708817
# [0.7664670658682634, 0.7738095238095237, 0.7450980392156864, 0.7749999999999999, 0.7924528301886792]
# 0.7705654918164304
# -0.7705654918164304 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 18:08:26.074179
# [0.783625730994152, 0.7757575757575756, 0.7105263157894737, 0.7532467532467533, 0.7631578947368421]
# 0.7572628541049593
# -0.7572628541049593 -0.7766068650488136
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 18:19:09.228295
# [0.783625730994152, 0.7682926829268293, 0.7625, 0.7798742138364779, 0.794701986754967]
# 0.7777989229024851
# -0.7777989229024851 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 18:27:30.770377
# [0.7861271676300579, 0.7590361445783134, 0.7402597402597403, 0.7843137254901961, 0.7875]
# 0.7714473555916614
# -0.7714473555916614 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 18:43:18.740970
# [0.7692307692307692, 0.7577639751552795, 0.7297297297297297, 0.7741935483870969, 0.8104575163398693]
# 0.768275107768549
# -0.768275107768549 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 32, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.75, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.9}
# 2019-08-23 18:56:08.365167
# [0.7757575757575756, 0.8072289156626505, 0.6962025316455697, 0.7798742138364779, 0.7682119205298013]
# 0.765455031486415
# -0.765455031486415 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 1}
# 2019-08-23 19:04:29.097707
# [0.7692307692307692, 0.7882352941176471, 0.6845637583892616, 0.7662337662337663, 0.7749999999999999]
# 0.7566527175942889
# -0.7566527175942889 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.45, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 19:18:55.637752
# [0.7682926829268293, 0.7738095238095237, 0.7236842105263157, 0.7814569536423841, 0.7898089171974522]
# 0.767410457620501
# -0.767410457620501 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.75, 'bagging_fraction': 0.9, 'bagging_freq': 10, 'subsample': 1}
# 2019-08-23 19:39:02.269785
# [0.7692307692307692, 0.7636363636363638, 0.728476821192053, 0.7295597484276728, 0.7792207792207793]
# 0.7540248963415277
# -0.7540248963415277 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.15, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'subsample': 0.9}
# 2019-08-23 19:51:53.925503
# [0.7647058823529411, 0.75, 0.7374999999999999, 0.7974683544303799, 0.7662337662337663]
# 0.7631816006034174
# -0.7631816006034174 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 1, 'feature_fraction': 0.75, 'bagging_fraction': 0.75, 'bagging_freq': 5, 'subsample': 0.7}
# 2019-08-23 19:59:53.060716
# [0.7790697674418605, 0.7374999999999999, 0.7341772151898733, 0.735483870967742, 0.7741935483870969]
# 0.7520848803973145
# -0.7520848803973145 -0.7777989229024851
# {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 256, 'max_depth': 4, 'learning_rate': 0.15, 'gamma': 0.55, 'n_estimators': 2000, 'lambda_l2': 3, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 20, 'subsample': 0.9}
# 2019-08-23 20:08:33.416645
# [0.7485380116959064, 0.7393939393939394, 0.7532467532467533, 0.8050314465408805, 0.7974683544303799]
# 0.768735701061572
# -0.768735701061572 -0.7777989229024851
# {'model1': <models.features.pretrained_wrap object at 0x7efe13c1b080>, 'model2': <class 'lightgbm.sklearn.LGBMClassifier'>, 'method': ['wv', 'scale'], 'p2': {'class_weight': 'balanced', 'boosting': 'gbrt', 'num_leaves': 512, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0.65, 'n_estimators': 2000, 'lambda_l2': 10, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'subsample': 0.7}, 'corp': <models.features.fixed_makedata object at 0x7efe13c1b2e8>}
# 0.7282608695652175
# save to ../pickle/2019-08-23 20:18:17.259238.pickle
# save to ../csv/2019-08-23 20:18:18.566324.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.761   0.779          0.749       0.761         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
#
#                                                        model1  \
# 0  <models.features.pretrained_wrap object at 0x7efffc3b1908>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    model2  \
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=3, learning_rate=0.15,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-23 20:18:17.259238.pickle
# save to ../csv/2019-08-23 20:18:18.614230.csv
#   test_f1 test_precision test_recall test_accuracy train_f1 train_precision  \
# 0  0.787   0.823          0.759       0.791         1        1
# 0  0.774   0.77           0.779       0.767         1        1
# 0  0.802   0.814          0.791       0.8           1        1
# 0  0.761   0.779          0.749       0.761         1        1
#
#   train_recall train_accuracy  \
# 0  1            1
# 0  1            0.999
# 0  1            1
# 0  1            1
#
#                                                        model1  \
# 0  <models.features.salvador_wrap object at 0x7eff0be8a5f8>
# 0  <models.features.pretrained_wrap object at 0x7eff0bc1b5f8>
# 0  <models.features.pretrained_wrap object at 0x7eff7ddf48d0>
# 0  <models.features.pretrained_wrap object at 0x7efffc3b1908>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     model2  \
# 0  LGBMClassifier(bagging_fraction=0.5, bagging_freq=5, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.55,\n        importance_type='split', lambda_l2=3, learning_rate=0.1,\n        max_depth=16, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=32,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=1, learning_rate=0.1,\n        max_depth=4, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=64,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
# 0  LGBMClassifier(bagging_fraction=0.9, bagging_freq=20, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.5, gamma=0.45,\n        importance_type='split', lambda_l2=0.1, learning_rate=0.1,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=256,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=0.9, subsample_for_bin=200000,\n        subsample_freq=0)
# 0  LGBMClassifier(bagging_fraction=0.75, bagging_freq=10, boosting='gbrt',\n        boosting_type='gbdt', class_weight='balanced',\n        colsample_bytree=1.0, feature_fraction=0.75, gamma=0.45,\n        importance_type='split', lambda_l2=3, learning_rate=0.15,\n        max_depth=8, min_child_samples=20, min_child_weight=0.001,\n        min_split_gain=0.0, n_estimators=2000, n_jobs=-1, num_leaves=512,\n        objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,\n        silent=True, subsample=1, subsample_for_bin=200000,\n        subsample_freq=0)
#
#         method  tag                                  pickle_path
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 08:44:59.922065.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-22 22:35:04.945335.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-23 10:52:20.321026.pickle
# 0  [wv, scale]  AMT  ../pickle/2019-08-23 20:18:17.259238.pickle
# time: 2d 7h 27min 43s

# %%
model = 'scripts/fast_dawid_skene.py --dataset "AMT2" --dataset amt2 --mode aggregate --algorithm DS --print_result --output "data/amt2_dataset/predict.csv"'
# %run $model
# Out:
# Predictions:
#                  Question Annotation
# 0                Question      label
# 1     RecipeID: 18181<br>         A3
# 2     RecipeID: 25569<br>         A5
# 3     RecipeID: 01136<br>         A3
# 4     RecipeID: 24707<br>         A4
# 5     RecipeID: 23245<br>         A3
# 6     RecipeID: 36540<br>         A2
# 7     RecipeID: 35329<br>         A5
# 8     RecipeID: 24678<br>         A3
# 9     RecipeID: 42566<br>         A5
# 10    RecipeID: 31790<br>         A3
# 11    RecipeID: 29870<br>         A5
# 12    RecipeID: 36968<br>         A3
# 13    RecipeID: 06270<br>         A3
# 14    RecipeID: 24761<br>         A1
# 15    RecipeID: 46965<br>         A5
# 16    RecipeID: 26881<br>         A5
# 17    RecipeID: 44422<br>         A2
# 18    RecipeID: 27609<br>         A3
# 19    RecipeID: 25949<br>         A5
# 20    RecipeID: 09932<br>         A2
# 21    RecipeID: 20992<br>         A1
# 22    RecipeID: 37439<br>         A3
# 23    RecipeID: 26848<br>         A5
# ...

# %%
import pandas as pd
pd.read_csv('data/amt2_dataset/predict.csv')
# Out:
#                  Question Annotation
# 0                Question      label
# 1     RecipeID: 18181<br>         A3
# 2     RecipeID: 25569<br>         A5
# 3     RecipeID: 01136<br>         A3
# 4     RecipeID: 24707<br>         A4
# 5     RecipeID: 23245<br>         A3
# 6     RecipeID: 36540<br>         A2
# 7     RecipeID: 35329<br>         A5
# 8     RecipeID: 24678<br>         A3
# 9     RecipeID: 42566<br>         A5
# 10    RecipeID: 31790<br>         A3
# 11    RecipeID: 29870<br>         A5
# 12    RecipeID: 36968<br>         A3
# 13    RecipeID: 06270<br>         A3
# 14    RecipeID: 24761<br>         A1
# 15    RecipeID: 46965<br>         A5
# 16    RecipeID: 26881<br>         A5
# 17    RecipeID: 44422<br>         A2
# 18    RecipeID: 27609<br>         A3
# 19    RecipeID: 25949<br>         A5
# 20    RecipeID: 09932<br>         A2
# 21    RecipeID: 20992<br>         A1
# 22    RecipeID: 37439<br>         A3
# 23    RecipeID: 26848<br>         A5
# ...
